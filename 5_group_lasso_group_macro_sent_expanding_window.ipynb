# %% [markdown]
# ### 0. Setup

# %%
# ==============================================================================
# CELLULE 1 : SETUP, PARAMÈTRES GLOBAUX ET CHARGEMENT DES DONNÉES GDELT
# ==============================================================================
import csv
from datetime import datetime
import io
from pathlib import Path
import warnings
from group_lasso import GroupLasso
import numpy as np
import pandas as pd
import pandas_datareader.data as web
import requests
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

warnings.filterwarnings('ignore')

# --- PARAMÈTRES GLOBAUX ---
START_DATE = datetime(2013, 1, 1)
END_DATE = datetime(2026, 7, 1)
MIN_INDEX_DATE = '2015-03-01'

# --- CHARGEMENT GDELT (FRANCE / US / UK) ---
dir_geo = Path('./data/indicators_geo_monthly')
dir_geo_uk = Path('./data/indicators_geo_monthly_UK')

# 1. Chargement France / US
if dir_geo.exists():
  files_geo = list(dir_geo.glob('*.parquet'))
  df_geo_main = pd.concat(
      [pd.read_parquet(f) for f in files_geo], ignore_index=True
  )
else:
  raise FileNotFoundError('⚠ Dossier ./data/indicators_geo_monthly introuvable.')

# 2. Chargement UK
if dir_geo_uk.exists():
  files_uk = list(dir_geo_uk.glob('*.parquet'))
  if len(files_uk) > 0:
    df_geo_uk = pd.concat(
        [pd.read_parquet(f) for f in files_uk], ignore_index=True
    )
    df_geo_uk['region_key'] = 'UK'
  else:
    df_geo_uk = pd.DataFrame()
else:
  df_geo_uk = pd.DataFrame()

# 3. Fusion finale
df_geo = pd.concat([df_geo_main, df_geo_uk], ignore_index=True)

if 'region_key' in df_geo.columns:
  df_geo = (
      df_geo.groupby(['period', 'region_key']).max().reset_index().copy()
  )
  df_geo['period'] = pd.to_datetime(df_geo['period'])
  print(f'✓ Base RÉGIONALE GDELT chargée.')
  print(
      f"✓ Régions trouvées en mémoire : {df_geo['region_key'].unique().tolist()}"
  )
  print(f'✓ Lignes totales : {len(df_geo)}')
else:
  print("⚠ ERREUR CRITIQUE : La colonne 'region_key' est absente.")
# Out:
# ✓ Base RÉGIONALE GDELT chargée.
# ✓ Régions trouvées en mémoire : ['France', 'UK', 'US']
# ✓ Lignes totales : 411

# %% [markdown]
# ### Functions

# %%
# ==============================================================================
# CELLULE 2 : LIBRAIRIE DES FONCTIONS ÉCONOMÉTRIQUES ET DE PRÉPARATION
# ==============================================================================

def get_filtered_gdelt_cols(df):
    """ÉTAPE 0 : Ne conserve que les sous-variables des secteurs cibles."""
    allowed_prefixes = [
        'sent_bin_weight_agriculture_', 'sent_bin_weight_commodities_',
        'sent_bin_weight_energy_', 'sent_bin_weight_finance_',
        'sent_bin_weight_industry_' 
    ]
    return [col for col in df.columns if any(str(col).startswith(prefix) for prefix in allowed_prefixes)]

def strict_stationarize(df):
    """
    ÉTAPE 1 : Test ADF -> Différenciation si nécessaire.
    NB: La winsorisation globale a été retirée pour éviter le look-ahead bias. 
    Elle sera appliquée dynamiquement avec la fonction expanding.
    """
    df_stat = df.copy()
    diff_count = 0
    for col in df_stat.columns:
        valid_data = df_stat[col].dropna()
        if len(valid_data) > 10:
            if adfuller(valid_data, autolag='AIC')[1] >= 0.05:
                df_stat[col] = df_stat[col].diff()
                diff_count += 1
                # On ne fait plus de clipping global ici.
    return df_stat.dropna(), diff_count

def fetch_and_prep_macro_dynamic(region_config, start_date, end_date, region=None):
    """Télécharge la macro et génère 12 lags (pour fixer la taille de l'échantillon)."""
    macro_config = region_config['macro_vars']
    fred_tickers = {info['ticker']: var_name for var_name, info in macro_config.items() 
                    if not (region == 'France' and var_name == 'money') and 
                    not (region == 'UK' and info['ticker'] in ['IUMABEDR', 'LPMBD93', 'XUDLUSS'])}
    
    df = web.DataReader(list(fred_tickers.keys()), 'fred', start_date, end_date).rename(columns=fred_tickers).resample('MS').mean() if fred_tickers else pd.DataFrame()

    if region == 'France' and 'money' in macro_config:
        try:
            df_ecb = pd.read_csv('https://data-api.ecb.europa.eu/service/data/BSI/M.U2.Y.V.M30.X.1.U2.2300.Z01.E?format=csvdata')
            df_ecb['period'] = pd.to_datetime(df_ecb['TIME_PERIOD'])
            df_ecb = df_ecb.set_index('period').rename(columns={'OBS_VALUE': 'money'})[['money']].resample('MS').mean()
            df = df.join(df_ecb, how='left') if not df.empty else df_ecb
        except Exception as e: print(f'⚠ Erreur BCE: {e}')

    if region == 'UK':
        df_local_all = pd.DataFrame()
        for var_name, info in macro_config.items():
            if info['ticker'] in ['IUMABEDR', 'LPMBD93', 'XUDLUSS']:
                ticker = info['ticker']
                file_path = f'data/BoE/{ticker}.csv'
                if Path(file_path).exists():
                    df_temp = pd.read_csv(file_path, encoding='ISO-8859-1')
                    df_temp['period'] = pd.to_datetime(df_temp.iloc[:, 0], errors='coerce')
                    df_temp = df_temp.dropna(subset=['period']).set_index('period')
                    val_col = next((c for c in df_temp.columns if ticker in c), None)
                    if val_col:
                        if df_temp[val_col].dtype == object:
                            df_temp[val_col] = df_temp[val_col].astype(str).str.replace(',', '', regex=False).str.strip()
                        series = pd.to_numeric(df_temp[val_col], errors='coerce').rename(var_name).resample('MS').mean()
                        df_local_all = series.to_frame() if df_local_all.empty else df_local_all.join(series, how='outer')
        if not df_local_all.empty: df = df.join(df_local_all, how='outer') if not df.empty else df_local_all

    final_cols = []
    for var_name, info in macro_config.items():
        if var_name in df.columns:
            if info['transform'] == 'pct_change': df[var_name] = df[var_name].pct_change() * 100
            elif info['transform'] == 'diff': df[var_name] = df[var_name].diff()
            final_cols.append(var_name)

    for lag in range(1, 13):
        lag_name = f'inflation_lag{lag}'
        df[lag_name] = df['inflation'].shift(lag)
        final_cols.append(lag_name)

    return df[(df.index >= start_date) & (df.index <= end_date)][final_cols].dropna()

def expanding_stationarize_and_scale(df, min_periods=12):
    """
    Applique une winsorisation et une standardisation récursives (expanding)
    pour éviter tout biais d'anticipation (look-ahead bias).
    """
    df_transformed = df.copy()
    
    for col in df_transformed.columns:
        # 1. Winsorisation Expanding (Clipping dynamique)
        expanding_p05 = df_transformed[col].expanding(min_periods=min_periods).quantile(0.05)
        expanding_p95 = df_transformed[col].expanding(min_periods=min_periods).quantile(0.95)
        
        df_transformed[col] = df_transformed[col].clip(lower=expanding_p05, upper=expanding_p95)
        
        # 2. Standardisation Expanding (Z-Score dynamique)
        expanding_mean = df_transformed[col].expanding(min_periods=min_periods).mean()
        expanding_std = df_transformed[col].expanding(min_periods=min_periods).std()
        
        df_transformed[col] = (df_transformed[col] - expanding_mean) / expanding_std
        
    return df_transformed.dropna()

def run_cv_sparse_group_lasso(X, y, groups):
    """MODÈLE 2 : Sparse Group Lasso - X est attendu DÉJÀ mis à l'échelle via expanding."""
    tscv = TimeSeriesSplit(n_splits=5, gap=3) 
    lambdas = np.logspace(-4, -1, 50)
    alphas = [0.50, 0.75, 0.95] # Grille Data-Driven
    
    best_mse, best_lbd, best_alpha = np.inf, None, None

    for alpha in alphas:
        for lbd in lambdas:
            sgl = GroupLasso(groups=groups, l1_reg=lbd * alpha, group_reg=lbd * (1 - alpha), fit_intercept=False, n_iter=1000, supress_warning=True)
            mse_scores = []
            for train_idx, test_idx in tscv.split(X):
                # Utilise directement X puisque le look-ahead bias a été géré en amont par expanding()
                sgl.fit(X.iloc[train_idx].values, y.iloc[train_idx].values.reshape(-1, 1))
                mse_scores.append(np.mean((y.iloc[test_idx].values - sgl.predict(X.iloc[test_idx].values).flatten()) ** 2))
            
            if np.mean(mse_scores) < best_mse:
                best_mse, best_lbd, best_alpha = np.mean(mse_scores), lbd, alpha

    final_sgl = GroupLasso(groups=groups, l1_reg=best_lbd * best_alpha, group_reg=best_lbd * (1 - best_alpha), fit_intercept=False, n_iter=5000, supress_warning=True)
    final_sgl.fit(X.values, y.values.reshape(-1, 1))
    return final_sgl.coef_.flatten(), best_lbd, best_alpha

def run_post_lasso_ols(X, y, selected_features):
    """Inférence OLS Post-Selection et diagnostic de Ljung-Box."""
    X_selected_with_const = sm.add_constant(X[selected_features])
    results = sm.OLS(y.values, X_selected_with_const.values).fit()

    post_lasso_df = pd.DataFrame({
        'Variable': ['Intercept'] + selected_features,
        'Coefficient': results.params,
        'P-value': results.pvalues,
        'CI_Lower': results.conf_int()[:, 0],
        'CI_Upper': results.conf_int()[:, 1],
    })
    
    lb_pval = acorr_ljungbox(results.resid, lags=[12], return_df=True)['lb_pvalue'].values[0]
    return post_lasso_df, results.rsquared, results.rsquared_adj, lb_pval

# %% [markdown]
# ### 1. Inflation

# %%
CONFIG_REGIONS = {
    'France': {
        'macro_vars': {
            'inflation': {'ticker': 'CP0000FRM086NEST', 'transform': 'pct_change'},
            'rate': {'ticker': 'IRSTCI01FRM156N', 'transform': 'diff'},
            'unemp': {'ticker': 'LRHUTTTTFRM156S', 'transform': 'diff'},
            'indpro': {'ticker': 'FRAPRINTO01GYSAM', 'transform': 'pct_change'},
            'money': {'ticker': 'BCE_M3_API', 'transform': 'none'},
            'fx': {'ticker': 'DEXUSEU', 'transform': 'pct_change'},
            'mich': {'ticker': 'CSINFT02FRM460S', 'transform': 'diff'},
            'oil': {'ticker': 'DCOILBRENTEU', 'transform': 'pct_change'},
        },
        'deseasonalize_y': True,
    },
    'US': {
        'macro_vars': {
            'inflation': {'ticker': 'CPIAUCSL', 'transform': 'pct_change'},
            'rate': {'ticker': 'FEDFUNDS', 'transform': 'diff'},
            'unemp': {'ticker': 'UNRATE', 'transform': 'diff'},
            'indpro': {'ticker': 'INDPRO', 'transform': 'pct_change'},
            'money': {'ticker': 'M2SL', 'transform': 'pct_change'},
            'fx': {'ticker': 'DEXUSEU', 'transform': 'pct_change'},
            'mich': {'ticker': 'MICH', 'transform': 'diff'},
            'oil': {'ticker': 'WTISPLC', 'transform': 'pct_change'},
        },
        'deseasonalize_y': False,
    },
    'UK': {
        'macro_vars': {
            'inflation': {'ticker': 'GBRCPIALLMINMEI', 'transform': 'pct_change'},
            'rate': {'ticker': 'IUMABEDR', 'transform': 'diff'},
            'unemp': {'ticker': 'LRHUTTTTGBM156S', 'transform': 'diff'},
            'indpro': {'ticker': 'GBRPRINTO01GYSAM', 'transform': 'pct_change'},
            'money': {'ticker': 'LPMBD93', 'transform': 'pct_change'},
            'fx': {'ticker': 'XUDLUSS', 'transform': 'pct_change'},
            'oil': {'ticker': 'DCOILBRENTEU', 'transform': 'pct_change'},
        },
        'deseasonalize_y': True,
    },
}

# %%
final_results = {}

for region, config in CONFIG_REGIONS.items():
    print(f'\n' + '=' * 80)
    print(f' PIPELINE ACADÉMIQUE : {region.upper()} (RECHERCHE DYNAMIQUE DE LAGS)')
    print(f'================================================================================')

    df_macro = fetch_and_prep_macro_dynamic(config, START_DATE, END_DATE, region=region)
    df_macro = df_macro[df_macro.index >= MIN_INDEX_DATE]

    cols_gdelt = get_filtered_gdelt_cols(df_geo)
    df_gdelt_raw = df_geo[df_geo['region_key'] == region].set_index('period')[cols_gdelt]
    if 'sent_cont_weight_finance_international_orgs' in df_gdelt_raw.columns:
        df_gdelt_raw = df_gdelt_raw.drop(columns=['sent_cont_weight_finance_international_orgs'])

    df_gdelt_stat, diff_count = strict_stationarize(df_gdelt_raw)
    df_final = df_gdelt_stat.join(df_macro, how='inner')
    y_raw = df_final['inflation']

    # Désaisonnalisation éventuelle
    y_corr = (y_raw - seasonal_decompose(y_raw, model='additive', period=12).seasonal).dropna() if config['deseasonalize_y'] else y_raw.dropna()
    X_full = df_final.drop(columns=['inflation'])
    y_corr, X_contemp = y_corr.align(X_full, join='inner')

    # NOUVEAU : Centrage dynamique de la cible (y)
    y_centered = (y_corr - y_corr.expanding(min_periods=12).mean()).dropna()
    
    # NOUVEAU : Standardisation et Winsorisation Expanding (Sans look-ahead bias)
    X_scaled_full = expanding_stationarize_and_scale(X_contemp, min_periods=12)

    # NOUVEAU : Réalignement strict après la suppression des `min_periods` initiaux (les 11 premiers mois seront NaN)
    y_centered, X_scaled_full = y_centered.align(X_scaled_full, join='inner')

    macro_base_cols = [c for c in X_scaled_full.columns if c in df_macro.columns and not c.startswith('inflation_lag') and c != 'inflation']
    gdelt_cols = [c for c in X_scaled_full.columns if c in cols_gdelt]

    # --- RECHERCHE DYNAMIQUE DU NOMBRE DE LAGS ---
    max_lags_to_test = 12
    best_iteration_gl = None
    best_iteration_sgl = None

    for current_lag in range(1, max_lags_to_test + 1):
        active_lags = [f'inflation_lag{i}' for i in range(1, current_lag + 1)]
        current_cols = macro_base_cols + active_lags + gdelt_cols
        X_current = X_scaled_full[current_cols]
        
        groups, group_map, current_group_id = [], {}, 2
        for var in current_cols:
            if var in macro_base_cols: groups.append(0) 
            elif var in active_lags: groups.append(1) 
            else:
                sector = var.split('_')[2]
                if sector not in group_map:
                    group_map[sector], current_group_id = current_group_id, current_group_id + 1
                groups.append(group_map[sector])
        groups_array = np.array(groups)

        # # ---------------------------------------------------------
        # # MODÈLE 1 : GROUP LASSO (Yuan & Lin)
        # # ---------------------------------------------------------
        # coefs_gl, lbd_gl = run_cv_group_lasso(X_current, y_centered, groups_array)
        # selected_vars_gl = [current_cols[i] for i in range(len(current_cols)) if coefs_gl[i] != 0]
        # final_vars_gl = list(set(macro_base_cols + active_lags + selected_vars_gl))
        # final_vars_gl_sorted = [v for v in macro_base_cols if v in final_vars_gl] + [v for v in active_lags if v in final_vars_gl] + sorted([v for v in gdelt_cols if v in final_vars_gl])
        # df_gl, r2_gl, r2_adj_gl, lb_pval_gl = run_post_lasso_ols(X_current, y_centered, final_vars_gl_sorted)
        # best_iteration_gl = (current_lag, final_vars_gl_sorted, df_gl, r2_gl, r2_adj_gl, lb_pval_gl, lbd_gl)

        # ---------------------------------------------------------
        # MODÈLE 2 : SPARSE GROUP LASSO (Simon et al.)
        # ---------------------------------------------------------
        coefs_sgl, lbd_sgl, alpha_sgl = run_cv_sparse_group_lasso(X_current, y_centered, groups_array)
        selected_vars_sgl = [current_cols[i] for i in range(len(current_cols)) if coefs_sgl[i] != 0]
        final_vars_sgl = list(set(macro_base_cols + active_lags + selected_vars_sgl))
        final_vars_sgl_sorted = [v for v in macro_base_cols if v in final_vars_sgl] + [v for v in active_lags if v in final_vars_sgl] + sorted([v for v in gdelt_cols if v in final_vars_sgl])
        df_sgl, r2_sgl, r2_adj_sgl, lb_pval_sgl = run_post_lasso_ols(X_current, y_centered, final_vars_sgl_sorted)
        best_iteration_sgl = (current_lag, final_vars_sgl_sorted, df_sgl, r2_sgl, r2_adj_sgl, lb_pval_sgl, lbd_sgl, alpha_sgl)

        if lb_pval_sgl >= 0.05:
            print(f'  ✓ Bruit blanc validé au Lag {current_lag} (SGL Ljung-Box P-value : {lb_pval_sgl:.4f})')
            break
        else:
            print(f'  ↻ Autocorrélation résiduelle au Lag {current_lag} (P-value : {lb_pval_sgl:.4f}). Ajout du lag {current_lag+1}...')

    print(f'\n' + '=' * 80)
    print(f' RÉSULTATS COMPARATIFS FINAUX : {region.upper()} (STABILISÉ À {best_iteration_sgl[0]} LAG(S))')
    print(f'=' * 80)

    # # Affichage Group Lasso
    # lag_gl, vars_gl, df_gl, r2_gl, r2_adj_gl, pval_gl, lbd_gl = best_iteration_gl
    # gdelt_gl = [v for v in vars_gl if v in gdelt_cols]
    
    # print(f'\n▶ MODÈLE 1 : GROUP LASSO (Yuan & Lin, 2006) - Sélection de secteurs entiers')
    # print(f'  Tuning Data-Driven : Lambda = {lbd_gl:.4f} | Alpha forcé = 0.0')
    # print(f'  Variables totales (OLS) : {len(vars_gl)} (dont {len(gdelt_gl)} GDELT)')
    # print(f'  R-squared (Global/Adj) : {r2_gl:.4f} / {r2_adj_gl:.4f}')
    # print(f'  Ljung-Box P-value : {pval_gl:.4f}')
    # print("-" * 60)
    # print(df_gl.to_string(index=False))

    # Affichage Sparse Group Lasso
    lag_sgl, vars_sgl, df_sgl, r2_sgl, r2_adj_sgl, pval_sgl, lbd_sgl, alpha_sgl = best_iteration_sgl
    gdelt_sgl = [v for v in vars_sgl if v in gdelt_cols]
    
    print(f'\n\n▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs')
    print(f'  Tuning Data-Driven : Lambda = {lbd_sgl:.4f} | Alpha = {alpha_sgl:.2f}')
    print(f'  Variables totales (OLS) : {len(vars_sgl)} (dont {len(gdelt_sgl)} GDELT)')
    print(f'  R-squared (Global/Adj) : {r2_sgl:.4f} / {r2_adj_sgl:.4f}')
    print(f'  Ljung-Box P-value : {pval_sgl:.4f}')
    print("-" * 60)
    print(df_sgl.to_string(index=False))

    final_results[region] = {
        'SGL_Model': {
            'Vars': vars_sgl, 
            'OLS': df_sgl, 
            'R2_adj': r2_adj_sgl, 
            'Optimal_Alpha': alpha_sgl
        }
    }
# Out:
# ================================================================================
#  PIPELINE ACADÉMIQUE : FRANCE (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ↻ Autocorrélation résiduelle au Lag 1 (P-value : 0.0106). Ajout du lag 2...
#   ↻ Autocorrélation résiduelle au Lag 2 (P-value : 0.0115). Ajout du lag 3...
#   ↻ Autocorrélation résiduelle au Lag 3 (P-value : 0.0075). Ajout du lag 4...
#   ↻ Autocorrélation résiduelle au Lag 4 (P-value : 0.0274). Ajout du lag 5...
#   ✓ Bruit blanc validé au Lag 5 (SGL Ljung-Box P-value : 0.5737)
#
# ================================================================================
#  RÉSULTATS COMPARATIFS FINAUX : FRANCE (STABILISÉ À 5 LAG(S))
# ================================================================================
#
#
# ▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs
#   Tuning Data-Driven : Lambda = 0.0121 | Alpha = 0.50
#   Variables totales (OLS) : 29 (dont 17 GDELT)
#   R-squared (Global/Adj) : 0.5438 / 0.3764
#   Ljung-Box P-value : 0.5737
# ------------------------------------------------------------
#                                        Variable  Coefficient  P-value  CI_Lower  CI_Upper
#                                       Intercept    -0.054914 0.847303 -0.620683  0.510856
#                                            rate     0.042932 0.127319 -0.012522  0.098386
#                                           unemp    -0.003353 0.922165 -0.071437  0.064732
#                                          indpro    -0.042469 0.403447 -0.143104  0.058166
#                                           money     0.044678 0.781536 -0.274907  0.364262
#                                              fx     0.051582 0.283216 -0.043442  0.146607
#                                            mich     0.012886 0.685715 -0.050262  0.076034
#                                             oil     0.115467 0.008832  0.029873  0.201061
#                                  inflation_lag1    -0.024507 0.578211 -0.111878  0.062864
#                                  inflation_lag2     0.006492 0.882839 -0.080903  0.093887
#                                  inflation_lag3     0.023066 0.632590 -0.072593  0.118725
#                                  inflation_lag4     0.062232 0.179170 -0.029161  0.153626
#                                  inflation_lag5    -0.144180 0.001124 -0.229054 -0.059307
#       sent_bin_weight_agriculture_climate_risks    -0.204631 0.001891 -0.331324 -0.077939
#         sent_bin_weight_agriculture_food_prices    -0.003281 0.953758 -0.115561  0.108998
# sent_bin_weight_agriculture_infrastructure_tech     0.022278 0.659689 -0.078043  0.122599
#         sent_bin_weight_agriculture_rural_labor    -0.010127 0.865084 -0.128374  0.108121
#       sent_bin_weight_commodities_market_prices    -0.010567 0.867377 -0.136114  0.114980
#                   sent_bin_weight_energy_fossil    -0.041876 0.375420 -0.135384  0.051631
#               sent_bin_weight_energy_regulation     0.080812 0.077907 -0.009242  0.170865
#               sent_bin_weight_energy_renewables    -0.022725 0.613870 -0.112016  0.066567
#           sent_bin_weight_finance_central_banks    -0.088503 0.170679 -0.215914  0.038908
#                  sent_bin_weight_finance_credit    -0.125939 0.009081 -0.219650 -0.032228
#            sent_bin_weight_finance_private_debt     0.157188 0.008344  0.041559  0.272818
#           sent_bin_weight_finance_systemic_risk     0.189044 0.036316  0.012354  0.365734
#              sent_bin_weight_industry_factories     0.059833 0.333597 -0.062585  0.182250
#              sent_bin_weight_industry_logistics    -0.024990 0.556661 -0.109254  0.059273
#             sent_bin_weight_industry_regulation    -0.092524 0.106874 -0.205440  0.020392
#                  sent_bin_weight_industry_risks    -0.010842 0.779489 -0.087655  0.065972
#          sent_bin_weight_industry_supply_chains    -0.066390 0.106759 -0.147385  0.014605
#
# ================================================================================
#  PIPELINE ACADÉMIQUE : US (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ✓ Bruit blanc validé au Lag 1 (SGL Ljung-Box P-value : 0.6320)
#
# ================================================================================
#  RÉSULTATS COMPARATIFS FINAUX : US (STABILISÉ À 1 LAG(S))
# ================================================================================
#
#
# ▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs
#   Tuning Data-Driven : Lambda = 0.0139 | Alpha = 0.95
#   Variables totales (OLS) : 17 (dont 9 GDELT)
#   R-squared (Global/Adj) : 0.6316 / 0.5670
#   Ljung-Box P-value : 0.6320
# ------------------------------------------------------------
#                                  Variable  Coefficient      P-value  CI_Lower  CI_Upper
#                                 Intercept    -0.052542 1.121466e-01 -0.117589  0.012505
#                                      rate     0.002821 8.648178e-01 -0.029979  0.035621
#                                     unemp     0.007127 7.010273e-01 -0.029605  0.043858
#                                    indpro     0.021174 2.245382e-01 -0.013206  0.055554
#                                     money    -0.002105 9.059106e-01 -0.037362  0.033152
#                                        fx     0.004910 7.984591e-01 -0.033147  0.042966
#                                      mich     0.003566 7.945527e-01 -0.023539  0.030671
#                                       oil     0.143250 5.237629e-10  0.102074  0.184426
#                            inflation_lag1     0.080445 8.156974e-05  0.041636  0.119254
#    sent_bin_weight_commodities_extraction     0.027009 6.375783e-01 -0.086425  0.140444
# sent_bin_weight_commodities_market_prices    -0.025079 2.036194e-01 -0.063968  0.013810
#     sent_bin_weight_commodities_materials     0.055800 3.404796e-01 -0.059811  0.171412
#         sent_bin_weight_energy_regulation     0.024887 1.276666e-01 -0.007259  0.057033
#            sent_bin_weight_finance_credit     0.006850 7.454880e-01 -0.034916  0.048617
#        sent_bin_weight_finance_regulation     0.044035 9.437057e-02 -0.007700  0.095770
#    sent_bin_weight_finance_sovereign_debt    -0.065951 6.635085e-03 -0.113131 -0.018771
#        sent_bin_weight_industry_factories     0.007139 7.206628e-01 -0.032370  0.046647
#    sent_bin_weight_industry_supply_chains     0.026109 1.530190e-01 -0.009870  0.062088
#
# ================================================================================
#  PIPELINE ACADÉMIQUE : UK (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ↻ Autocorrélation résiduelle au Lag 1 (P-value : 0.0073). Ajout du lag 2...
#   ↻ Autocorrélation résiduelle au Lag 2 (P-value : 0.0099). Ajout du lag 3...
#   ↻ Autocorrélation résiduelle au Lag 3 (P-value : 0.0219). Ajout du lag 4...
#   ↻ Autocorrélation résiduelle au Lag 4 (P-value : 0.0248). Ajout du lag 5...
#   ↻ Autocorrélation résiduelle au Lag 5 (P-value : 0.0280). Ajout du lag 6...
#   ↻ Autocorrélation résiduelle au Lag 6 (P-value : 0.0216). Ajout du lag 7...
#   ↻ Autocorrélation résiduelle au Lag 7 (P-value : 0.0332). Ajout du lag 8...
#   ↻ Autocorrélation résiduelle au Lag 8 (P-value : 0.0424). Ajout du lag 9...
#   ✓ Bruit blanc validé au Lag 9 (SGL Ljung-Box P-value : 0.1196)
#
# ================================================================================
#  RÉSULTATS COMPARATIFS FINAUX : UK (STABILISÉ À 9 LAG(S))
# ================================================================================
#
#
# ▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs
#   Tuning Data-Driven : Lambda = 0.0105 | Alpha = 0.50
#   Variables totales (OLS) : 35 (dont 20 GDELT)
#   R-squared (Global/Adj) : 0.5208 / 0.2742
#   Ljung-Box P-value : 0.1196
# ------------------------------------------------------------
#                                        Variable  Coefficient  P-value  CI_Lower  CI_Upper
#                                       Intercept     0.016103 0.797160 -0.108425  0.140630
#                                            rate     0.038318 0.192881 -0.019822  0.096457
#                                           unemp     0.007835 0.751894 -0.041422  0.057092
#                                          indpro    -0.058913 0.055488 -0.119247  0.001421
#                                           money    -0.002526 0.933883 -0.063060  0.058008
#                                              fx    -0.039837 0.227444 -0.105105  0.025430
#                                             oil     0.015754 0.671608 -0.058078  0.089587
#                                  inflation_lag1    -0.001744 0.953624 -0.061369  0.057881
#                                  inflation_lag2    -0.027348 0.337467 -0.083841  0.029145
#                                  inflation_lag3     0.013377 0.693626 -0.054095  0.080848
#                                  inflation_lag4     0.059117 0.091774 -0.009858  0.128093
#                                  inflation_lag5     0.033297 0.276393 -0.027256  0.093849
#                                  inflation_lag6     0.044880 0.154621 -0.017338  0.107098
#                                  inflation_lag7     0.008368 0.788780 -0.053721  0.070458
#                                  inflation_lag8     0.036627 0.228869 -0.023567  0.096821
#                                  inflation_lag9    -0.033291 0.297589 -0.096579  0.029997
#       sent_bin_weight_agriculture_climate_risks    -0.024845 0.489220 -0.096147  0.046456
# sent_bin_weight_agriculture_infrastructure_tech    -0.030002 0.407183 -0.101783  0.041779
#         sent_bin_weight_agriculture_rural_labor    -0.005365 0.875438 -0.073405  0.062675
#               sent_bin_weight_agriculture_water     0.082970 0.022448  0.012095  0.153845
#          sent_bin_weight_commodities_extraction    -0.018028 0.841133 -0.196820  0.160763
#       sent_bin_weight_commodities_market_prices    -0.080897 0.025701 -0.151675 -0.010119
#           sent_bin_weight_commodities_materials     0.039040 0.696584 -0.159899  0.237978
#          sent_bin_weight_commodities_regulation    -0.000446 0.989685 -0.069011  0.068119
#                   sent_bin_weight_energy_fossil    -0.016923 0.609805 -0.082784  0.048939
#          sent_bin_weight_energy_infrastructures    -0.039986 0.243496 -0.107806  0.027834
#               sent_bin_weight_energy_regulation    -0.039645 0.262291 -0.109631  0.030341
#               sent_bin_weight_energy_renewables    -0.027579 0.364085 -0.087807  0.032649
#                   sent_bin_weight_finance_banks     0.035621 0.502702 -0.069866  0.141108
#                  sent_bin_weight_finance_credit    -0.042033 0.219390 -0.109697  0.025631
#       sent_bin_weight_finance_financial_markets     0.048189 0.451015 -0.078655  0.175033
#            sent_bin_weight_finance_private_debt     0.015897 0.708093 -0.068474  0.100268
#              sent_bin_weight_finance_regulation    -0.049284 0.164855 -0.119328  0.020760
#           sent_bin_weight_finance_systemic_risk     0.100509 0.125381 -0.028746  0.229763
#              sent_bin_weight_industry_factories     0.060477 0.075392 -0.006356  0.127310
#              sent_bin_weight_industry_logistics     0.020611 0.536460 -0.045584  0.086806

# %% [markdown]
# #### Robustness - only macro

# %%
final_results_macro_only = {}

for region, config in CONFIG_REGIONS.items():
    print(f'\n' + '=' * 80)
    print(f' BENCHMARK MACRO-ONLY : {region.upper()} (RECHERCHE DYNAMIQUE DE LAGS)')
    print(f'================================================================================')

    # 1. Préparation des données macro
    df_macro = fetch_and_prep_macro_dynamic(config, START_DATE, END_DATE, region=region)
    df_macro = df_macro[df_macro.index >= MIN_INDEX_DATE]

    # 2. Chargement GDELT (UNIQUEMENT POUR ALIGNER LES DATES ET GARANTIR LE MÊME 'N')
    cols_gdelt = get_filtered_gdelt_cols(df_geo)
    df_gdelt_raw = df_geo[df_geo['region_key'] == region].set_index('period')[cols_gdelt]
    if 'sent_cont_weight_finance_international_orgs' in df_gdelt_raw.columns:
        df_gdelt_raw = df_gdelt_raw.drop(columns=['sent_cont_weight_finance_international_orgs'])

    df_gdelt_stat, diff_count = strict_stationarize(df_gdelt_raw)
    
    # La jointure garantit que nous avons les mêmes lignes (Même échantillon N)
    df_final = df_gdelt_stat.join(df_macro, how='inner') 
    y_raw = df_final['inflation']

    # Désaisonnalisation éventuelle
    y_corr = (y_raw - seasonal_decompose(y_raw, model='additive', period=12).seasonal).dropna() if config['deseasonalize_y'] else y_raw.dropna()
    X_full = df_final.drop(columns=['inflation'])
    y_corr, X_contemp = y_corr.align(X_full, join='inner')

    # --- MODIFICATION ICI : Élimination du look-ahead bias ---
    y_centered = (y_corr - y_corr.expanding(min_periods=12).mean()).dropna()
    X_scaled_full = expanding_stationarize_and_scale(X_contemp, min_periods=12)
    y_centered, X_scaled_full = y_centered.align(X_scaled_full, join='inner')
    # ---------------------------------------------------------

    # 3. Isolation exclusive des variables macro (on exclut GDELT des prédicteurs)
    macro_base_cols = [c for c in X_scaled_full.columns if c in df_macro.columns and not c.startswith('inflation_lag') and c != 'inflation']

    # --- RECHERCHE DYNAMIQUE DU NOMBRE DE LAGS (OLS STANDARD) ---
    max_lags_to_test = 12
    best_iteration_arx = None

    for current_lag in range(1, max_lags_to_test + 1):
        active_lags = [f'inflation_lag{i}' for i in range(1, current_lag + 1)]
        current_cols = macro_base_cols + active_lags # UNIQUEMENT MACRO + LAGS
        X_current = X_scaled_full[current_cols]
        
        # Estimation OLS directe (Pas besoin de Lasso pour ~10 variables)
        X_current_with_const = sm.add_constant(X_current)
        results = sm.OLS(y_centered.values, X_current_with_const.values).fit()
        
        # Test de Ljung-Box sur les résidus
        lb_pval = acorr_ljungbox(results.resid, lags=[12], return_df=True)['lb_pvalue'].values[0]

        # Sauvegarde des résultats de l'itération
        post_arx_df = pd.DataFrame({
            'Variable': ['Intercept'] + current_cols,
            'Coefficient': results.params,
            'P-value': results.pvalues,
        })
        
        best_iteration_arx = (current_lag, current_cols, post_arx_df, results.rsquared, results.rsquared_adj, lb_pval)

        # Règle d'arrêt : Bruit blanc validé
        if lb_pval >= 0.05:
            print(f'  ✓ Bruit blanc validé au Lag {current_lag} (OLS Ljung-Box P-value : {lb_pval:.4f})')
            break
        else:
            print(f'  ↻ Autocorrélation résiduelle au Lag {current_lag} (P-value : {lb_pval:.4f}). Ajout du lag {current_lag+1}...')

    # --- AFFICHAGE DES RÉSULTATS DU BENCHMARK ---
    lag_arx, vars_arx, df_arx, r2_arx, r2_adj_arx, pval_arx = best_iteration_arx
    
    print(f'\n' + '=' * 80)
    print(f' RÉSULTATS FINAUX BENCHMARK MACRO : {region.upper()} (STABILISÉ À {lag_arx} LAG(S))')
    print(f'=' * 80)
    print(f'  Modèle : ARX (OLS Standard)')
    print(f'  Variables : {len(vars_arx)} (Macroéconomiques + Lags uniquement)')
    print(f'  R-squared (Global/Adj) : {r2_arx:.4f} / {r2_adj_arx:.4f}')
    print(f'  Ljung-Box P-value : {pval_arx:.4f}')
    print("-" * 60)
    print(df_arx.to_string(index=False))

    final_results_macro_only[region] = {
        'Vars': vars_arx, 
        'OLS': df_arx, 
        'R2_adj': r2_adj_arx
    }
# Out:
# ================================================================================
#  BENCHMARK MACRO-ONLY : FRANCE (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ✓ Bruit blanc validé au Lag 1 (OLS Ljung-Box P-value : 0.1501)
#
# ================================================================================
#  RÉSULTATS FINAUX BENCHMARK MACRO : FRANCE (STABILISÉ À 1 LAG(S))
# ================================================================================
#   Modèle : ARX (OLS Standard)
#   Variables : 8 (Macroéconomiques + Lags uniquement)
#   R-squared (Global/Adj) : 0.1724 / 0.1062
#   Ljung-Box P-value : 0.1501
# ------------------------------------------------------------
#       Variable  Coefficient  P-value
#      Intercept    -0.237533 0.418332
#           rate     0.074216 0.008160
#          unemp     0.010279 0.788207
#         indpro    -0.076791 0.137386
#          money     0.161756 0.325406
#             fx    -0.029377 0.520196
#           mich     0.032863 0.341116
#            oil     0.126652 0.005581
# inflation_lag1    -0.033666 0.447760
#
# ================================================================================
#  BENCHMARK MACRO-ONLY : US (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ✓ Bruit blanc validé au Lag 1 (OLS Ljung-Box P-value : 0.3088)
#
# ================================================================================
#  RÉSULTATS FINAUX BENCHMARK MACRO : US (STABILISÉ À 1 LAG(S))
# ================================================================================
#   Modèle : ARX (OLS Standard)
#   Variables : 8 (Macroéconomiques + Lags uniquement)
#   R-squared (Global/Adj) : 0.5439 / 0.5095
#   Ljung-Box P-value : 0.3088
# ------------------------------------------------------------
#       Variable  Coefficient      P-value
#      Intercept     0.037665 4.709167e-02
#           rate     0.032510 3.526501e-02
#          unemp     0.000964 9.568595e-01
#         indpro     0.002113 9.032401e-01
#          money     0.010355 5.376058e-01
#             fx    -0.010469 5.945490e-01
#           mich    -0.003654 7.971496e-01
#            oil     0.152687 5.509596e-11
# inflation_lag1     0.111938 2.097879e-08
#
# ================================================================================
#  BENCHMARK MACRO-ONLY : UK (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ↻ Autocorrélation résiduelle au Lag 1 (P-value : 0.0095). Ajout du lag 2...
#   ↻ Autocorrélation résiduelle au Lag 2 (P-value : 0.0083). Ajout du lag 3...
#   ↻ Autocorrélation résiduelle au Lag 3 (P-value : 0.0081). Ajout du lag 4...
#   ↻ Autocorrélation résiduelle au Lag 4 (P-value : 0.0048). Ajout du lag 5...
#   ↻ Autocorrélation résiduelle au Lag 5 (P-value : 0.0088). Ajout du lag 6...
#   ↻ Autocorrélation résiduelle au Lag 6 (P-value : 0.0225). Ajout du lag 7...
#   ↻ Autocorrélation résiduelle au Lag 7 (P-value : 0.0225). Ajout du lag 8...
#   ↻ Autocorrélation résiduelle au Lag 8 (P-value : 0.0280). Ajout du lag 9...
#   ↻ Autocorrélation résiduelle au Lag 9 (P-value : 0.0485). Ajout du lag 10...
#   ✓ Bruit blanc validé au Lag 10 (OLS Ljung-Box P-value : 0.0574)
#
# ================================================================================
#  RÉSULTATS FINAUX BENCHMARK MACRO : UK (STABILISÉ À 10 LAG(S))
# ================================================================================
#   Modèle : ARX (OLS Standard)
#   Variables : 16 (Macroéconomiques + Lags uniquement)
#   R-squared (Global/Adj) : 0.3629 / 0.2457
#   Ljung-Box P-value : 0.0574
# ------------------------------------------------------------
#        Variable  Coefficient  P-value
#       Intercept     0.007866 0.833841
#            rate     0.032968 0.161915
#           unemp    -0.000006 0.999801
#          indpro    -0.050619 0.078344
#           money     0.023055 0.394379
#              fx    -0.043480 0.151014
#             oil     0.027154 0.388946
#  inflation_lag1     0.023395 0.369473
#  inflation_lag2     0.015840 0.536217
#  inflation_lag3     0.031132 0.311129
#  inflation_lag4     0.046161 0.136758
#  inflation_lag5     0.046206 0.095960
#  inflation_lag6     0.054132 0.055618
#  inflation_lag7     0.005936 0.832565
#  inflation_lag8     0.025810 0.355641
#  inflation_lag9    -0.015833 0.572380
# inflation_lag10     0.011317 0.691055

# %%
# ==============================================================================
# CELLULE 5 : VISUALISATION ACADÉMIQUE DU DÉCROCHAGE MACRO (ÉCHELLE RÉELLE)
# ==============================================================================
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import statsmodels.api as sm
import os
import pandas as pd

# 1. INITIALISER SEABORN EN PREMIER 
sns.set_style("ticks")

# 2. FORCER LA POLICE TIMES NEW ROMAN
plt.rcParams.update({
    'font.family': 'serif',
    'font.serif': ['Times New Roman', 'Times', 'DejaVu Serif'], 
    'mathtext.fontset': 'stix', 
    'font.size': 12,
    'axes.labelsize': 12,
    'axes.titlesize': 14,
    'legend.fontsize': 10,
    'xtick.labelsize': 11,
    'ytick.labelsize': 11,
    'figure.dpi': 300 
})

# Choix de la région 
region = 'US'
config = CONFIG_REGIONS[region]

# 3. Préparation des données et alignement temporel
df_macro = fetch_and_prep_macro_dynamic(config, START_DATE, END_DATE, region=region)
df_macro = df_macro[df_macro.index >= MIN_INDEX_DATE]

cols_gdelt = get_filtered_gdelt_cols(df_geo)
df_gdelt_raw = df_geo[df_geo['region_key'] == region].set_index('period')[cols_gdelt]
if 'sent_cont_weight_finance_international_orgs' in df_gdelt_raw.columns:
    df_gdelt_raw = df_gdelt_raw.drop(columns=['sent_cont_weight_finance_international_orgs'])

df_gdelt_stat, diff_count = strict_stationarize(df_gdelt_raw)
df_final = df_gdelt_stat.join(df_macro, how='inner')
y_raw = df_final['inflation']

# Désaisonnalisation
y_corr = (y_raw - seasonal_decompose(y_raw, model='additive', period=12).seasonal).dropna() if config['deseasonalize_y'] else y_raw.dropna()
X_full = df_final.drop(columns=['inflation'])
y_corr, X_contemp = y_corr.align(X_full, join='inner')

# Récupération de la moyenne dynamique et alignement
y_expanding_mean = y_corr.expanding(min_periods=12).mean()
y_centered = (y_corr - y_expanding_mean).dropna()
X_scaled_full = expanding_stationarize_and_scale(X_contemp, min_periods=12)

# Réalignement strict
y_centered, X_scaled_full = y_centered.align(X_scaled_full, join='inner')
y_expanding_mean = y_expanding_mean.loc[y_centered.index]
y_corr_aligned = y_corr.loc[y_centered.index]

# 4. Calcul des Prédictions et RE-MISE À L'ÉCHELLE (+ y_expanding_mean)
# A. Benchmark : Macro-Only
vars_macro = final_results_macro_only[region]['Vars']
X_macro = sm.add_constant(X_scaled_full[vars_macro])
y_pred_macro_centered = sm.OLS(y_centered.values, X_macro.values).fit().fittedvalues
y_pred_macro = y_pred_macro_centered + y_expanding_mean.values

# B. Proposed Model : Hybrid SGL (GDELT + Macro)
vars_hybrid = final_results[region]['SGL_Model']['Vars']
X_hybrid = sm.add_constant(X_scaled_full[vars_hybrid])
y_pred_hybrid_centered = sm.OLS(y_centered.values, X_hybrid.values).fit().fittedvalues
y_pred_hybrid = y_pred_hybrid_centered + y_expanding_mean.values

# Extraction directe des R2 calculés par statsmodels (cohérence stricte avec les logs)
r2_adj_macro = final_results_macro_only[region]['R2_adj']
r2_adj_hybrid = final_results[region]['SGL_Model']['R2_adj']

# 5. Tracé du Graphique (Plotting)
fig, ax = plt.subplots(figsize=(12, 6))

# Ligne 1 : Vraie inflation (alignée)
ax.plot(y_corr_aligned.index, y_corr_aligned.values, 
        label='Actual Headline Inflation', 
        color='black', linewidth=1.5, zorder=3)

# Ligne 2 : Benchmark Macro (Pointillés rouges)
ax.plot(y_corr_aligned.index, y_pred_macro, 
        label=f'Benchmark: Macro Only (Adj. $R^2 = {r2_adj_macro:.2f}$)', 
        color='#b22222', linestyle='--', linewidth=1.4, alpha=0.8, zorder=2)

# Ligne 3 : Modèle SGL Hybride (Trait plein bleu)
ax.plot(y_corr_aligned.index, y_pred_hybrid, 
        label=f'SGL: Macro + GDELT (Adj. $R^2 = {r2_adj_hybrid:.2f}$)', 
        color='#004c99', linestyle='-', linewidth=1.6, zorder=4)

# 6. Habillage et Formattage
ax.axhline(0, color='black', linewidth=0.8, linestyle='-', alpha=0.5) 
ax.set_xlim(y_corr_aligned.index.min(), y_corr_aligned.index.max())
ax.set_ylabel('Headline Inflation (Monthly % Change)')
ax.set_title(f'Actual vs. Predicted Headline Inflation - {region}', pad=15, fontweight='bold')

# Formattage de l'axe X (Années propres)
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
fig.autofmt_xdate(rotation=0, ha='center')

# Légende
ax.legend(loc='upper left', frameon=True, edgecolor='black', fancybox=False, facecolor='white', framealpha=1)

# Grille
ax.grid(True, which='major', axis='y', linestyle=':', alpha=0.6)

# Nettoyage des bordures
sns.despine()

# Sauvegarde pour LaTeX
os.makedirs('./latex_tables', exist_ok=True)
plt.savefig(f'./latex_tables/Macro_Decoupling_{region}.png', format='png', bbox_inches='tight')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Robustness - no group macro

# %%
# ==============================================================================
# CELLULE 3 : CONFIGURATION DES MODÈLES (ARX - HEADLINE INFLATION)
# ==============================================================================
CONFIG_REGIONS = {
    'France': {
        'macro_vars': {
            'inflation': {'ticker': 'CP0000FRM086NEST', 'transform': 'pct_change'}
        },
        'deseasonalize_y': True,
    },
    'US': {
        'macro_vars': {
            'inflation': {'ticker': 'CPIAUCSL', 'transform': 'pct_change'}
        },
        'deseasonalize_y': False,
    },
    'UK': {
        'macro_vars': {
            'inflation': {'ticker': 'GBRCPIALLMINMEI', 'transform': 'pct_change'}
        },
        'deseasonalize_y': True,
    },
}

# %%
final_results = {}

for region, config in CONFIG_REGIONS.items():
    print(f'\n' + '=' * 80)
    print(f' PIPELINE ACADÉMIQUE : {region.upper()} (RECHERCHE DYNAMIQUE DE LAGS)')
    print(f'================================================================================')

    df_macro = fetch_and_prep_macro_dynamic(config, START_DATE, END_DATE, region=region)
    df_macro = df_macro[df_macro.index >= MIN_INDEX_DATE]

    cols_gdelt = get_filtered_gdelt_cols(df_geo)
    df_gdelt_raw = df_geo[df_geo['region_key'] == region].set_index('period')[cols_gdelt]
    if 'sent_cont_weight_finance_international_orgs' in df_gdelt_raw.columns:
        df_gdelt_raw = df_gdelt_raw.drop(columns=['sent_cont_weight_finance_international_orgs'])

    df_gdelt_stat, diff_count = strict_stationarize(df_gdelt_raw)
    df_final = df_gdelt_stat.join(df_macro, how='inner')
    y_raw = df_final['inflation']

    y_corr = (y_raw - seasonal_decompose(y_raw, model='additive', period=12).seasonal).dropna() if config['deseasonalize_y'] else y_raw.dropna()
    X_full = df_final.drop(columns=['inflation'])
    y_corr, X_contemp = y_corr.align(X_full, join='inner')

    # --- MODIFICATION ICI : Élimination du look-ahead bias ---
    y_centered = (y_corr - y_corr.expanding(min_periods=12).mean()).dropna()
    X_scaled_full = expanding_stationarize_and_scale(X_contemp, min_periods=12)
    y_centered, X_scaled_full = y_centered.align(X_scaled_full, join='inner')
    # ---------------------------------------------------------

    macro_base_cols = [c for c in X_scaled_full.columns if c in df_macro.columns and not c.startswith('inflation_lag') and c != 'inflation']
    gdelt_cols = [c for c in X_scaled_full.columns if c in cols_gdelt]

    max_lags_to_test = 12
    best_iteration_gl = None
    best_iteration_sgl = None

    for current_lag in range(1, max_lags_to_test + 1):
        active_lags = [f'inflation_lag{i}' for i in range(1, current_lag + 1)]
        current_cols = macro_base_cols + active_lags + gdelt_cols
        X_current = X_scaled_full[current_cols]
        
        groups, group_map, current_group_id = [], {}, 2
        for var in current_cols:
            if var in macro_base_cols: groups.append(0) 
            elif var in active_lags: groups.append(1) 
            else:
                sector = var.split('_')[2]
                if sector not in group_map:
                    group_map[sector], current_group_id = current_group_id, current_group_id + 1
                groups.append(group_map[sector])
        groups_array = np.array(groups)

        # ---------------------------------------------------------
        # MODÈLE 2 : SPARSE GROUP LASSO (Simon et al.)
        # ---------------------------------------------------------
        coefs_sgl, lbd_sgl, alpha_sgl = run_cv_sparse_group_lasso(X_current, y_centered, groups_array)
        selected_vars_sgl = [current_cols[i] for i in range(len(current_cols)) if coefs_sgl[i] != 0]
        final_vars_sgl = list(set(macro_base_cols + active_lags + selected_vars_sgl))
        final_vars_sgl_sorted = [v for v in macro_base_cols if v in final_vars_sgl] + [v for v in active_lags if v in final_vars_sgl] + sorted([v for v in gdelt_cols if v in final_vars_sgl])
        df_sgl, r2_sgl, r2_adj_sgl, lb_pval_sgl = run_post_lasso_ols(X_current, y_centered, final_vars_sgl_sorted)
        best_iteration_sgl = (current_lag, final_vars_sgl_sorted, df_sgl, r2_sgl, r2_adj_sgl, lb_pval_sgl, lbd_sgl, alpha_sgl)

        if lb_pval_sgl >= 0.05:
            print(f'  ✓ Bruit blanc validé au Lag {current_lag} (SGL Ljung-Box P-value : {lb_pval_sgl:.4f})')
            break
        else:
            print(f'  ↻ Autocorrélation résiduelle au Lag {current_lag} (P-value : {lb_pval_sgl:.4f}). Ajout du lag {current_lag+1}...')

    print(f'\n' + '=' * 80)
    print(f' RÉSULTATS COMPARATIFS FINAUX : {region.upper()} (STABILISÉ À {best_iteration_sgl[0]} LAG(S))')
    print(f'=' * 80)

    # Affichage Sparse Group Lasso
    lag_sgl, vars_sgl, df_sgl, r2_sgl, r2_adj_sgl, pval_sgl, lbd_sgl, alpha_sgl = best_iteration_sgl
    gdelt_sgl = [v for v in vars_sgl if v in gdelt_cols]
    
    print(f'\n\n▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs')
    print(f'  Tuning Data-Driven : Lambda = {lbd_sgl:.4f} | Alpha = {alpha_sgl:.2f}')
    print(f'  Variables totales (OLS) : {len(vars_sgl)} (dont {len(gdelt_sgl)} GDELT)')
    print(f'  R-squared (Global/Adj) : {r2_sgl:.4f} / {r2_adj_sgl:.4f}')
    print(f'  Ljung-Box P-value : {pval_sgl:.4f}')
    print("-" * 60)
    print(df_sgl.to_string(index=False))
    
    final_results[region] = {
        'SGL_Model': {
            'Vars': vars_sgl, 
            'OLS': df_sgl, 
            'R2_adj': r2_adj_sgl, 
            'Optimal_Alpha': alpha_sgl
        }
    }
# Out:
# ================================================================================
#  PIPELINE ACADÉMIQUE : FRANCE (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ↻ Autocorrélation résiduelle au Lag 1 (P-value : 0.0014). Ajout du lag 2...
#   ↻ Autocorrélation résiduelle au Lag 2 (P-value : 0.0034). Ajout du lag 3...
#   ↻ Autocorrélation résiduelle au Lag 3 (P-value : 0.0065). Ajout du lag 4...
#   ↻ Autocorrélation résiduelle au Lag 4 (P-value : 0.0146). Ajout du lag 5...
#   ✓ Bruit blanc validé au Lag 5 (SGL Ljung-Box P-value : 0.3645)
#
# ================================================================================
#  RÉSULTATS COMPARATIFS FINAUX : FRANCE (STABILISÉ À 5 LAG(S))
# ================================================================================
#
#
# ▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs
#   Tuning Data-Driven : Lambda = 0.0244 | Alpha = 0.50
#   Variables totales (OLS) : 29 (dont 24 GDELT)
#   R-squared (Global/Adj) : 0.4976 / 0.3155
#   Ljung-Box P-value : 0.3645
# ------------------------------------------------------------
#                                        Variable  Coefficient  P-value  CI_Lower  CI_Upper
#                                       Intercept     0.105038 0.232374 -0.068665  0.278740
#                                  inflation_lag1    -0.022471 0.622924 -0.113066  0.068123
#                                  inflation_lag2     0.002403 0.959022 -0.090390  0.095196
#                                  inflation_lag3    -0.023019 0.623932 -0.116092  0.070054
#                                  inflation_lag4     0.019743 0.682920 -0.076092  0.115578
#                                  inflation_lag5    -0.144638 0.002144 -0.235367 -0.053909
#       sent_bin_weight_agriculture_climate_risks    -0.248055 0.000419 -0.382132 -0.113978
#         sent_bin_weight_agriculture_food_prices    -0.031278 0.626844 -0.158813  0.096258
# sent_bin_weight_agriculture_infrastructure_tech     0.012489 0.814853 -0.093300  0.118279
#          sent_bin_weight_agriculture_regulation     0.017774 0.754914 -0.095149  0.130698
#         sent_bin_weight_agriculture_rural_labor     0.011068 0.857823 -0.111488  0.133625
#               sent_bin_weight_agriculture_water     0.012077 0.791904 -0.078713  0.102866
#       sent_bin_weight_commodities_market_prices     0.011934 0.860336 -0.122610  0.146477
#           sent_bin_weight_commodities_materials     0.052843 0.460622 -0.088998  0.194684
#                   sent_bin_weight_energy_fossil    -0.074094 0.133882 -0.171464  0.023276
#          sent_bin_weight_energy_infrastructures     0.112067 0.338135 -0.119370  0.343504
#                  sent_bin_weight_energy_nuclear    -0.075335 0.478617 -0.285937  0.135268
#               sent_bin_weight_energy_regulation     0.071809 0.121778 -0.019565  0.163183
#               sent_bin_weight_energy_renewables    -0.022444 0.636166 -0.116501  0.071612
#                    sent_bin_weight_energy_risks    -0.042801 0.613648 -0.210851  0.125248
#           sent_bin_weight_finance_central_banks    -0.118462 0.083168 -0.252826  0.015902
#                  sent_bin_weight_finance_credit    -0.105456 0.030178 -0.200545 -0.010367
#            sent_bin_weight_finance_private_debt     0.210015 0.000935  0.088428  0.331602
#              sent_bin_weight_finance_regulation    -0.154484 0.151854 -0.366972  0.058004
#           sent_bin_weight_finance_systemic_risk     0.263504 0.006951  0.074249  0.452759
#              sent_bin_weight_industry_factories     0.125603 0.047424  0.001463  0.249744
#              sent_bin_weight_industry_logistics    -0.057293 0.220212 -0.149568  0.034981
#             sent_bin_weight_industry_regulation    -0.090138 0.139138 -0.210214  0.029938
#                  sent_bin_weight_industry_risks    -0.008992 0.833488 -0.093831  0.075847
#          sent_bin_weight_industry_supply_chains    -0.056657 0.182732 -0.140546  0.027232
#
# ================================================================================
#  PIPELINE ACADÉMIQUE : US (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ✓ Bruit blanc validé au Lag 1 (SGL Ljung-Box P-value : 0.1112)
#
# ================================================================================
#  RÉSULTATS COMPARATIFS FINAUX : US (STABILISÉ À 1 LAG(S))
# ================================================================================
#
#
# ▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs
#   Tuning Data-Driven : Lambda = 0.0121 | Alpha = 0.50
#   Variables totales (OLS) : 24 (dont 23 GDELT)
#   R-squared (Global/Adj) : 0.5415 / 0.4193
#   Ljung-Box P-value : 0.1112
# ------------------------------------------------------------
#                                        Variable  Coefficient  P-value  CI_Lower  CI_Upper
#                                       Intercept    -0.012759 0.791312 -0.108272  0.082753
#                                  inflation_lag1     0.059368 0.013612  0.012506  0.106231
#        sent_bin_weight_agriculture_agribusiness     0.011401 0.717741 -0.051063  0.073865
#       sent_bin_weight_agriculture_climate_risks     0.022219 0.332047 -0.023043  0.067482
#         sent_bin_weight_agriculture_food_prices    -0.093198 0.003660 -0.155242 -0.031153
# sent_bin_weight_agriculture_infrastructure_tech    -0.024104 0.262959 -0.066613  0.018406
#          sent_bin_weight_agriculture_regulation     0.008511 0.744699 -0.043253  0.060275
#         sent_bin_weight_agriculture_rural_labor     0.005269 0.849550 -0.049752  0.060290
#               sent_bin_weight_agriculture_water    -0.009500 0.667266 -0.053259  0.034258
#          sent_bin_weight_commodities_extraction     0.003038 0.964214 -0.131123  0.137199
#       sent_bin_weight_commodities_market_prices    -0.001883 0.937505 -0.049463  0.045697
#           sent_bin_weight_commodities_materials     0.078466 0.244763 -0.054677  0.211608
#               sent_bin_weight_commodities_risks     0.005351 0.795669 -0.035581  0.046284
#                   sent_bin_weight_energy_fossil     0.029272 0.208223 -0.016606  0.075150
#          sent_bin_weight_energy_infrastructures    -0.007992 0.691439 -0.047867  0.031883
#               sent_bin_weight_energy_regulation     0.029906 0.131731 -0.009153  0.068964
#                  sent_bin_weight_finance_credit     0.006261 0.804065 -0.043731  0.056254
#       sent_bin_weight_finance_financial_markets     0.130439 0.001088  0.053676  0.207202
#              sent_bin_weight_finance_regulation     0.048550 0.100964 -0.009653  0.106753
#          sent_bin_weight_finance_sovereign_debt    -0.084914 0.015556 -0.153321 -0.016507
#              sent_bin_weight_industry_factories     0.018266 0.437928 -0.028309  0.064841
#              sent_bin_weight_industry_logistics     0.004657 0.828131 -0.037833  0.047147
#           sent_bin_weight_industry_productivity     0.024245 0.210752 -0.013968  0.062459
#             sent_bin_weight_industry_regulation    -0.001094 0.962669 -0.047390  0.045202
#          sent_bin_weight_industry_supply_chains     0.024212 0.268370 -0.018978  0.067401
#
# ================================================================================
#  PIPELINE ACADÉMIQUE : UK (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ↻ Autocorrélation résiduelle au Lag 1 (P-value : 0.0174). Ajout du lag 2...
#   ↻ Autocorrélation résiduelle au Lag 2 (P-value : 0.0168). Ajout du lag 3...
#   ↻ Autocorrélation résiduelle au Lag 3 (P-value : 0.0105). Ajout du lag 4...
#   ↻ Autocorrélation résiduelle au Lag 4 (P-value : 0.0094). Ajout du lag 5...
#   ↻ Autocorrélation résiduelle au Lag 5 (P-value : 0.0059). Ajout du lag 6...
#   ↻ Autocorrélation résiduelle au Lag 6 (P-value : 0.0207). Ajout du lag 7...
#   ↻ Autocorrélation résiduelle au Lag 7 (P-value : 0.0236). Ajout du lag 8...
#   ↻ Autocorrélation résiduelle au Lag 8 (P-value : 0.0260). Ajout du lag 9...
#   ↻ Autocorrélation résiduelle au Lag 9 (P-value : 0.0339). Ajout du lag 10...
#   ✓ Bruit blanc validé au Lag 10 (SGL Ljung-Box P-value : 0.0523)
#
# ================================================================================
#  RÉSULTATS COMPARATIFS FINAUX : UK (STABILISÉ À 10 LAG(S))
# ================================================================================
#
#
# ▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs
#   Tuning Data-Driven : Lambda = 0.0019 | Alpha = 0.95
#   Variables totales (OLS) : 32 (dont 22 GDELT)
#   R-squared (Global/Adj) : 0.5058 / 0.2977
#   Ljung-Box P-value : 0.0523
# ------------------------------------------------------------
#                                        Variable  Coefficient  P-value  CI_Lower  CI_Upper
#                                       Intercept     0.036550 0.553202 -0.085668  0.158767
#                                  inflation_lag1    -0.005107 0.854190 -0.060262  0.050049
#                                  inflation_lag2    -0.020792 0.405549 -0.070302  0.028718
#                                  inflation_lag3     0.053379 0.073337 -0.005168  0.111926
#                                  inflation_lag4     0.040778 0.150332 -0.015116  0.096672
#                                  inflation_lag5     0.066134 0.014473  0.013504  0.118763
#                                  inflation_lag6     0.050762 0.069674 -0.004185  0.105710
#                                  inflation_lag7     0.033315 0.244127 -0.023211  0.089840
#                                  inflation_lag8     0.021076 0.467148 -0.036363  0.078515
#                                  inflation_lag9    -0.047932 0.095517 -0.104489  0.008624
#                                 inflation_lag10     0.012062 0.687786 -0.047490  0.071613
#        sent_bin_weight_agriculture_agribusiness     0.020452 0.573007 -0.051505  0.092410
#       sent_bin_weight_agriculture_climate_risks    -0.060632 0.071849 -0.126782  0.005518
# sent_bin_weight_agriculture_infrastructure_tech    -0.036053 0.281783 -0.102294  0.030188
#               sent_bin_weight_agriculture_water     0.061197 0.064947 -0.003886  0.126279
#       sent_bin_weight_commodities_market_prices    -0.105845 0.001703 -0.170644 -0.041046
#           sent_bin_weight_commodities_materials     0.046222 0.361911 -0.054142  0.146585
#          sent_bin_weight_commodities_regulation     0.005518 0.862407 -0.057675  0.068711
#               sent_bin_weight_commodities_risks     0.008174 0.742565 -0.041211  0.057560
#                   sent_bin_weight_energy_fossil     0.032836 0.260304 -0.024828  0.090499
#          sent_bin_weight_energy_infrastructures    -0.046004 0.125523 -0.105153  0.013145
#               sent_bin_weight_energy_regulation    -0.008592 0.794848 -0.074171  0.056987
#               sent_bin_weight_energy_renewables    -0.044298 0.126415 -0.101389  0.012794
#                    sent_bin_weight_energy_risks     0.059032 0.074774 -0.006045  0.124110
#                  sent_bin_weight_finance_credit    -0.042823 0.187549 -0.106958  0.021312
#       sent_bin_weight_finance_financial_markets     0.035267 0.491029 -0.066232  0.136766
#            sent_bin_weight_finance_private_debt     0.041702 0.293365 -0.036794  0.120198
#              sent_bin_weight_finance_regulation    -0.063295 0.058020 -0.128795  0.002205
#           sent_bin_weight_finance_systemic_risk     0.175238 0.003914  0.057963  0.292512
#              sent_bin_weight_industry_factories     0.086291 0.034783  0.006333  0.166249
#           sent_bin_weight_industry_productivity     0.017927 0.510502 -0.036075  0.071929
#             sent_bin_weight_industry_regulation    -0.073163 0.128523 -0.167988  0.021662
#          sent_bin_weight_industry_supply_chains    -0.059812 0.052279 -0.120229  0.000605
