# %% [markdown]
# ### 0. Setup

# %%
# ==============================================================================
# CELLULE 1 : SETUP, PARAMÈTRES GLOBAUX ET CHARGEMENT DES DONNÉES GDELT
# ==============================================================================
import csv
from datetime import datetime
import io
from pathlib import Path
import warnings
from group_lasso import GroupLasso
import numpy as np
import pandas as pd
import pandas_datareader.data as web
import requests
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

warnings.filterwarnings('ignore')

# --- PARAMÈTRES GLOBAUX ---
START_DATE = datetime(2013, 1, 1)
END_DATE = datetime(2026, 7, 1)
MIN_INDEX_DATE = '2015-03-01'

# --- CHARGEMENT GDELT (FRANCE / US / UK) ---
dir_geo = Path('./data/indicators_france_consumers')
dir_geo_uk = Path('./data/indicators_geo_monthly_UK')

# 1. Chargement France / US
if dir_geo.exists():
  files_geo = list(dir_geo.glob('*.parquet'))
  df_geo_main = pd.concat(
      [pd.read_parquet(f) for f in files_geo], ignore_index=True
  )
else:
  raise FileNotFoundError('⚠ Dossier ./data/indicators_geo_monthly introuvable.')

# 2. Chargement UK
if dir_geo_uk.exists():
  files_uk = list(dir_geo_uk.glob('*.parquet'))
  if len(files_uk) > 0:
    df_geo_uk = pd.concat(
        [pd.read_parquet(f) for f in files_uk], ignore_index=True
    )
    df_geo_uk['region_key'] = 'UK'
  else:
    df_geo_uk = pd.DataFrame()
else:
  df_geo_uk = pd.DataFrame()

# 3. Fusion finale
df_geo = pd.concat([df_geo_main, df_geo_uk], ignore_index=True)

if 'region_key' in df_geo.columns:
  df_geo = (
      df_geo.groupby(['period', 'region_key']).max().reset_index().copy()
  )
  df_geo['period'] = pd.to_datetime(df_geo['period'])
  print(f'✓ Base RÉGIONALE GDELT chargée.')
  print(
      f"✓ Régions trouvées en mémoire : {df_geo['region_key'].unique().tolist()}"
  )
  print(f'✓ Lignes totales : {len(df_geo)}')
else:
  print("⚠ ERREUR CRITIQUE : La colonne 'region_key' est absente.")
# Out:
# ✓ Base RÉGIONALE GDELT chargée.
# ✓ Régions trouvées en mémoire : ['France']
# ✓ Lignes totales : 137

# %%
print(df_geo.columns[:60])
# Out:
# Index(['period', 'region_key', 'att_energy', 'att_energy_nuclear',
#        'att_energy_renewables', 'att_energy_risks', 'att_weight_energy',
#        'att_weight_energy_nuclear', 'att_weight_energy_renewables',
#        'att_weight_energy_risks', 'sent_cont_energy',
#        'sent_cont_energy_nuclear', 'sent_cont_energy_renewables',
#        'sent_cont_energy_risks', 'sent_bin_energy', 'sent_bin_energy_nuclear',
#        'sent_bin_energy_renewables', 'sent_bin_energy_risks',
#        'sent_cont_weight_energy', 'sent_cont_weight_energy_nuclear',
#        'sent_cont_weight_energy_renewables', 'sent_cont_weight_energy_risks',
#        'sent_bin_weight_energy', 'sent_bin_weight_energy_nuclear',
#        'sent_bin_weight_energy_renewables', 'sent_bin_weight_energy_risks',
#        'axs_cont_energy', 'axs_cont_energy_nuclear',
#        'axs_cont_energy_renewables', 'axs_cont_energy_risks',
#        'axs_cont_weight_energy', 'axs_cont_weight_energy_nuclear',
#        'axs_cont_weight_energy_renewables', 'axs_cont_weight_energy_risks',
#        'axs_bin_energy', 'axs_bin_energy_nuclear', 'axs_bin_energy_renewables',
#        'axs_bin_energy_risks', 'axs_bin_weight_energy',
#        'axs_bin_weight_energy_nuclear', 'axs_bin_weight_energy_renewables',
#        'axs_bin_weight_energy_risks', 'att_energy_fossil',
#        'att_energy_infrastructures', 'att_energy_regulation',
#        'att_weight_energy_fossil', 'att_weight_energy_infrastructures',
#        'att_weight_energy_regulation', 'sent_cont_energy_fossil',
#        'sent_cont_energy_infrastructures', 'sent_cont_energy_regulation',
#        'sent_bin_energy_fossil', 'sent_bin_energy_infrastructures',
#        'sent_bin_energy_regulation', 'sent_cont_weight_energy_fossil',
#        'sent_cont_weight_energy_infrastructures',
#        'sent_cont_weight_energy_regulation', 'sent_bin_weight_energy_fossil',
#        'sent_bin_weight_energy_infrastructures',
#        'sent_bin_weight_energy_regulation'],
#       dtype='str')

# %% [markdown]
# ### Functions

# %%
# ==============================================================================
# CELLULE 2 : LIBRAIRIE DES FONCTIONS ÉCONOMÉTRIQUES ET DE PRÉPARATION
# ==============================================================================

def get_filtered_gdelt_cols(df):
    """ÉTAPE 0 : Ne conserve que les sous-variables des 8 secteurs cibles."""
    allowed_prefixes = [
        'sent_bin_weight_agriculture_', 'sent_bin_weight_commodities_',
        'sent_bin_weight_energy_', 'sent_bin_weight_finance_',
        'sent_bin_weight_industry_', 'sent_bin_weight_real_estate_',
        'sent_bin_weight_tech_', 'sent_bin_weight_transport_' 
        # ,'sent_bin_weight_growth_', 'sent_bin_weight_conflict_', 'sent_bin_weight_politics_',
        # 'sent_bin_weight_health_', 'sent_bin_weight_consumer_goods_'
    ]
    return [col for col in df.columns if any(str(col).startswith(prefix) for prefix in allowed_prefixes)]

def strict_stationarize(df):
    """ÉTAPE 1 : Test ADF -> Différence -> Winsorisation si nécessaire."""
    df_stat = df.copy()
    diff_count = 0
    for col in df_stat.columns:
        valid_data = df_stat[col].dropna()
        if len(valid_data) > 10:
            if adfuller(valid_data, autolag='AIC')[1] >= 0.05:
                df_stat[col] = df_stat[col].diff()
                diff_count += 1
                valid_data_diff = df_stat[col].dropna()
                if len(valid_data_diff) > 10 and adfuller(valid_data_diff, autolag='AIC')[1] >= 0.05:
                    p95 = valid_data_diff.quantile(0.95)
                    p05 = valid_data_diff.quantile(0.05)
                    df_stat[col] = df_stat[col].clip(lower=p05, upper=p95)
    return df_stat.dropna(), diff_count

def fetch_and_prep_macro_dynamic(region_config, start_date, end_date, region=None):
    """Télécharge la macro et génère 12 lags (pour fixer la taille de l'échantillon)."""
    macro_config = region_config['macro_vars']
    fred_tickers = {info['ticker']: var_name for var_name, info in macro_config.items() 
                    if not (region == 'France' and var_name == 'money') and 
                    not (region == 'UK' and info['ticker'] in ['IUMABEDR', 'LPMBD93', 'XUDLUSS'])}
    
    df = web.DataReader(list(fred_tickers.keys()), 'fred', start_date, end_date).rename(columns=fred_tickers).resample('MS').mean() if fred_tickers else pd.DataFrame()

    if region == 'France' and 'money' in macro_config:
        try:
            df_ecb = pd.read_csv('https://data-api.ecb.europa.eu/service/data/BSI/M.U2.Y.V.M30.X.1.U2.2300.Z01.E?format=csvdata')
            df_ecb['period'] = pd.to_datetime(df_ecb['TIME_PERIOD'])
            df_ecb = df_ecb.set_index('period').rename(columns={'OBS_VALUE': 'money'})[['money']].resample('MS').mean()
            df = df.join(df_ecb, how='left') if not df.empty else df_ecb
        except Exception as e: print(f'⚠ Erreur BCE: {e}')

    if region == 'UK':
        df_local_all = pd.DataFrame()
        for var_name, info in macro_config.items():
            if info['ticker'] in ['IUMABEDR', 'LPMBD93', 'XUDLUSS']:
                ticker = info['ticker']
                file_path = f'data/BoE/{ticker}.csv'
                if Path(file_path).exists():
                    df_temp = pd.read_csv(file_path, encoding='ISO-8859-1')
                    df_temp['period'] = pd.to_datetime(df_temp.iloc[:, 0], errors='coerce')
                    df_temp = df_temp.dropna(subset=['period']).set_index('period')
                    val_col = next((c for c in df_temp.columns if ticker in c), None)
                    if val_col:
                        if df_temp[val_col].dtype == object:
                            df_temp[val_col] = df_temp[val_col].astype(str).str.replace(',', '', regex=False).str.strip()
                        series = pd.to_numeric(df_temp[val_col], errors='coerce').rename(var_name).resample('MS').mean()
                        df_local_all = series.to_frame() if df_local_all.empty else df_local_all.join(series, how='outer')
        if not df_local_all.empty: df = df.join(df_local_all, how='outer') if not df.empty else df_local_all

    final_cols = []
    for var_name, info in macro_config.items():
        if var_name in df.columns:
            if info['transform'] == 'pct_change': df[var_name] = df[var_name].pct_change() * 100
            elif info['transform'] == 'diff': df[var_name] = df[var_name].diff()
            final_cols.append(var_name)

    for lag in range(1, 13):
        lag_name = f'inflation_lag{lag}'
        df[lag_name] = df['inflation'].shift(lag)
        final_cols.append(lag_name)

    return df[(df.index >= start_date) & (df.index <= end_date)][final_cols].dropna()

def run_cv_group_lasso(X, y, groups):
    """MODÈLE 1 : Group Lasso (Yuan & Lin, 2006) - Alpha forcé à 0 (Pénalité de groupe pure)."""
    tscv = TimeSeriesSplit(n_splits=5, gap=3) 
    lambdas = np.logspace(-3, 1, 50)
    best_mse, best_lbd = np.inf, None

    for lbd in lambdas:
        gl = GroupLasso(groups=groups, l1_reg=0.0, group_reg=lbd, fit_intercept=False, n_iter=1000, supress_warning=True)
        mse_scores = []
        for train_idx, test_idx in tscv.split(X):
            gl.fit(X.iloc[train_idx].values, y.iloc[train_idx].values.reshape(-1, 1))
            mse_scores.append(np.mean((y.iloc[test_idx].values - gl.predict(X.iloc[test_idx].values).flatten()) ** 2))
        
        if np.mean(mse_scores) < best_mse:
            best_mse, best_lbd = np.mean(mse_scores), lbd

    final_gl = GroupLasso(groups=groups, l1_reg=0.0, group_reg=best_lbd, fit_intercept=False, n_iter=5000, supress_warning=True)
    final_gl.fit(X.values, y.values.reshape(-1, 1))
    return final_gl.coef_.flatten(), best_lbd

def run_cv_sparse_group_lasso(X, y, groups):
    """MODÈLE 2 : Sparse Group Lasso - Tuning de Lambda ET Alpha avec SEUIL STRICT."""
    tscv = TimeSeriesSplit(n_splits=5, gap=3) 
    lambdas = np.logspace(-3, 1, 50)
    alphas = [0.50, 0.75, 0.90, 0.95, 0.99]
    
    best_mse, best_lbd, best_alpha = np.inf, None, None
    MAX_VARS = 20  # 🛑 LA RÈGLE D'OR : Jamais plus de 15 variables (Macro + Lags + GDELT)

    for alpha in alphas:
        for lbd in lambdas:
            # Test rapide pour vérifier combien de variables ce (Lambda, Alpha) sélectionne
            test_sgl = GroupLasso(groups=groups, l1_reg=lbd * alpha, group_reg=lbd * (1 - alpha), fit_intercept=False, n_iter=1000, supress_warning=True)
            test_sgl.fit(X.values, y.values.reshape(-1, 1))
            n_selected = np.sum(test_sgl.coef_.flatten() != 0)
            
            # Si le modèle est trop bavard, on rejette immédiatement ces paramètres
            if n_selected > MAX_VARS or n_selected == 0:
                continue

            # Si le modèle est parcimonieux, on lance la validation croisée
            sgl = GroupLasso(groups=groups, l1_reg=lbd * alpha, group_reg=lbd * (1 - alpha), fit_intercept=False, n_iter=1000, supress_warning=True)
            mse_scores = []
            for train_idx, test_idx in tscv.split(X):
                sgl.fit(X.iloc[train_idx].values, y.iloc[train_idx].values.reshape(-1, 1))
                mse_scores.append(np.mean((y.iloc[test_idx].values - sgl.predict(X.iloc[test_idx].values).flatten()) ** 2))
            
            if np.mean(mse_scores) < best_mse:
                best_mse, best_lbd, best_alpha = np.mean(mse_scores), lbd, alpha

    # Sécurité : Si aucun modèle n'a respecté la règle (très rare), on force une pénalité énorme
    if best_lbd is None:
        best_lbd, best_alpha = 10.0, 0.99 

    final_sgl = GroupLasso(groups=groups, l1_reg=best_lbd * best_alpha, group_reg=best_lbd * (1 - best_alpha), fit_intercept=False, n_iter=5000, supress_warning=True)
    final_sgl.fit(X.values, y.values.reshape(-1, 1))
    return final_sgl.coef_.flatten(), best_lbd, best_alpha

def run_post_lasso_ols(X, y, selected_features):
    """Inférence OLS Post-Selection et diagnostic de Ljung-Box."""
    X_selected_with_const = sm.add_constant(X[selected_features])
    results = sm.OLS(y.values, X_selected_with_const.values).fit()

    post_lasso_df = pd.DataFrame({
        'Variable': ['Intercept'] + selected_features,
        'Coefficient': results.params,
        'P-value': results.pvalues,
        'CI_Lower': results.conf_int()[:, 0],
        'CI_Upper': results.conf_int()[:, 1],
    })
    
    lb_pval = acorr_ljungbox(results.resid, lags=[12], return_df=True)['lb_pvalue'].values[0]
    return post_lasso_df, results.rsquared, results.rsquared_adj, lb_pval

# %% [markdown]
# ### 1. Inflation

# %%
# ==============================================================================
# CELLULE 3 : CONFIGURATION DES MODÈLES RÉGIONAUX
# ==============================================================================
CONFIG_REGIONS = {
    'France': {
        'macro_vars': {
            'inflation': {'ticker': 'CP0000FRM086NEST', 'transform': 'pct_change'},
            'rate': {'ticker': 'IRSTCI01FRM156N', 'transform': 'diff'},
            'unemp': {'ticker': 'LRHUTTTTFRM156S', 'transform': 'diff'},
            'indpro': {'ticker': 'FRAPRINTO01GYSAM', 'transform': 'pct_change'},
            'money': {'ticker': 'BCE_M3_API', 'transform': 'none'},
            'fx': {'ticker': 'DEXUSEU', 'transform': 'pct_change'},
            'mich': {'ticker': 'CSINFT02FRM460S', 'transform': 'diff'},
            'oil': {'ticker': 'DCOILBRENTEU', 'transform': 'pct_change'},
        },
        'deseasonalize_y': True,
    }}

# %%
# ==============================================================================
# CELLULE 4bis : PIPELINE AVEC HOLD-OUT OUT-OF-SAMPLE RÉEL (SANS FUITE)
# ==============================================================================
# Remplace ta CELLULE 4. Logique :
#   - Le hold-out (les N derniers mois) n'est TOUCHÉ NULLE PART pendant le
#     tuning (lambda, alpha, nombre de lags). Il ne sert qu'à UNE évaluation
#     finale, une seule fois.
#   - Scaler et centrage de y sont calculés sur le TRAIN uniquement, puis
#     appliqués au holdout (pas de fit sur le holdout).
#   - Le tableau post-lasso OLS reste un objet DESCRIPTIF, estimé sur le train.
#     La validation du pouvoir prédictif se lit dans R2_oos / RMSE_oos.

N_HOLDOUT = 24  # nb de mois réservés en test final — à justifier dans le texte
                # (ex: ~20% de l'échantillon, ou une période macro spécifique)

def evaluate_oos(X_train, y_train, X_holdout, y_holdout, selected_features):
    """Réajuste l'OLS post-lasso sur le train, prédit sur le holdout jamais vu."""
    X_tr = sm.add_constant(X_train[selected_features])
    ols = sm.OLS(y_train.values, X_tr.values).fit()

    X_ho = sm.add_constant(X_holdout[selected_features], has_constant='add')
    y_pred = X_ho.values @ ols.params

    resid_oos = y_holdout.values - y_pred
    ss_res = np.sum(resid_oos ** 2)
    ss_tot = np.sum((y_holdout.values - y_train.values.mean()) ** 2)  # moyenne TRAIN, pas holdout
    r2_oos = 1 - ss_res / ss_tot
    rmse_oos = np.sqrt(np.mean(resid_oos ** 2))
    return r2_oos, rmse_oos


final_results = {}

for region, config in CONFIG_REGIONS.items():
    print(f'\n' + '=' * 80)
    print(f' PIPELINE ACADÉMIQUE : {region.upper()} (HOLD-OUT OUT-OF-SAMPLE = {N_HOLDOUT} MOIS)')
    print(f'=' * 80)

    # --- 1. Préparation macro / GDELT (inchangé) ---
    df_macro = fetch_and_prep_macro_dynamic(config, START_DATE, END_DATE, region=region)
    df_macro = df_macro[df_macro.index >= MIN_INDEX_DATE]

    cols_gdelt = get_filtered_gdelt_cols(df_geo)
    df_gdelt_raw = df_geo[df_geo['region_key'] == region].set_index('period')[cols_gdelt]
    if 'sent_cont_weight_finance_international_orgs' in df_gdelt_raw.columns:
        df_gdelt_raw = df_gdelt_raw.drop(columns=['sent_cont_weight_finance_international_orgs'])

    df_gdelt_stat, diff_count = strict_stationarize(df_gdelt_raw)
    df_final = df_gdelt_stat.join(df_macro, how='inner')
    y_raw = df_final['inflation']

    # NOTE / LIMITE ASSUMÉE : seasonal_decompose utilise toute la série
    # (y compris les mois du holdout). Fuite mineure documentée dans le texte.
    y_corr = (y_raw - seasonal_decompose(y_raw, model='additive', period=12).seasonal).dropna() \
        if config['deseasonalize_y'] else y_raw.dropna()
    X_full = df_final.drop(columns=['inflation'])
    y_corr, X_contemp = y_corr.align(X_full, join='inner')

    # --- 2. SPLIT TEMPOREL AVANT TOUTE CHOSE (rien après ce point ne doit
    #        recalculer une statistique sur l'ensemble complet) ---
    split_idx = len(y_corr) - N_HOLDOUT
    idx_train, idx_holdout = y_corr.index[:split_idx], y_corr.index[split_idx:]

    y_train_raw, y_holdout_raw = y_corr.loc[idx_train], y_corr.loc[idx_holdout]
    X_train_raw, X_holdout_raw = X_contemp.loc[idx_train], X_contemp.loc[idx_holdout]

    # --- 3. Centrage de y : moyenne TRAIN uniquement ---
    y_mean_train = y_train_raw.mean()
    y_train = y_train_raw - y_mean_train
    y_holdout = y_holdout_raw - y_mean_train  # même décalage, pas une nouvelle moyenne

    # --- 4. Scaling : fit sur TRAIN uniquement, transform sur les deux ---
    scaler = StandardScaler().fit(X_train_raw)
    X_train = pd.DataFrame(scaler.transform(X_train_raw), columns=X_train_raw.columns, index=idx_train)
    X_holdout = pd.DataFrame(scaler.transform(X_holdout_raw), columns=X_holdout_raw.columns, index=idx_holdout)

    macro_base_cols = [c for c in X_train.columns if c in df_macro.columns and not c.startswith('inflation_lag') and c != 'inflation']
    gdelt_cols = [c for c in X_train.columns if c in cols_gdelt]

    # --- 5. Recherche du nombre de lags : CV UNIQUEMENT SUR LE TRAIN ---
    max_lags_to_test = 6
    best_iteration_gl = None
    best_iteration_sgl = None

    for current_lag in range(1, max_lags_to_test + 1):
        active_lags = [f'inflation_lag{i}' for i in range(1, current_lag + 1)]
        current_cols = macro_base_cols + active_lags + gdelt_cols
        X_current_train = X_train[current_cols]  # jamais X_holdout ici

        groups, group_map, current_group_id = [], {}, 2
        for var in current_cols:
            if var in macro_base_cols: groups.append(0)
            elif var in active_lags: groups.append(1)
            else:
                sector = var.split('_')[2]
                if sector not in group_map:
                    group_map[sector], current_group_id = current_group_id, current_group_id + 1
                groups.append(group_map[sector])
        groups_array = np.array(groups)

        # MODÈLE 1 : GROUP LASSO — tuning + fit sur TRAIN
        coefs_gl, lbd_gl = run_cv_group_lasso(X_current_train, y_train, groups_array)
        selected_vars_gl = [current_cols[i] for i in range(len(current_cols)) if coefs_gl[i] != 0]
        final_vars_gl = list(set(macro_base_cols + active_lags + selected_vars_gl))
        final_vars_gl_sorted = [v for v in macro_base_cols if v in final_vars_gl] + \
            [v for v in active_lags if v in final_vars_gl] + \
            sorted([v for v in gdelt_cols if v in final_vars_gl])
        df_gl, r2_gl_train, r2_adj_gl_train, lb_pval_gl = run_post_lasso_ols(X_current_train, y_train, final_vars_gl_sorted)
        r2_oos_gl, rmse_oos_gl = evaluate_oos(X_current_train, y_train, X_holdout[current_cols], y_holdout, final_vars_gl_sorted)
        best_iteration_gl = (current_lag, final_vars_gl_sorted, df_gl, r2_gl_train, r2_adj_gl_train, lb_pval_gl, lbd_gl, r2_oos_gl, rmse_oos_gl)

        # MODÈLE 2 : SPARSE GROUP LASSO — tuning + fit sur TRAIN
        coefs_sgl, lbd_sgl, alpha_sgl = run_cv_sparse_group_lasso(X_current_train, y_train, groups_array)
        selected_vars_sgl = [current_cols[i] for i in range(len(current_cols)) if coefs_sgl[i] != 0]
        final_vars_sgl = list(set(macro_base_cols + active_lags + selected_vars_sgl))
        final_vars_sgl_sorted = [v for v in macro_base_cols if v in final_vars_sgl] + \
            [v for v in active_lags if v in final_vars_sgl] + \
            sorted([v for v in gdelt_cols if v in final_vars_sgl])
        df_sgl, r2_sgl_train, r2_adj_sgl_train, lb_pval_sgl = run_post_lasso_ols(X_current_train, y_train, final_vars_sgl_sorted)
        r2_oos_sgl, rmse_oos_sgl = evaluate_oos(X_current_train, y_train, X_holdout[current_cols], y_holdout, final_vars_sgl_sorted)
        best_iteration_sgl = (current_lag, final_vars_sgl_sorted, df_sgl, r2_sgl_train, r2_adj_sgl_train, lb_pval_sgl, lbd_sgl, alpha_sgl, r2_oos_sgl, rmse_oos_sgl)

        if lb_pval_sgl >= 0.05:
            print(f'  ✓ Bruit blanc validé au Lag {current_lag} (SGL Ljung-Box P-value train : {lb_pval_sgl:.4f})')
            break
        else:
            print(f'  ↻ Autocorrélation résiduelle au Lag {current_lag} (P-value train : {lb_pval_sgl:.4f}). Ajout du lag {current_lag+1}...')

    # --- 6. AFFICHAGE : deux blocs bien séparés, in-sample vs out-of-sample ---
    print(f'\n' + '=' * 80)
    print(f' RÉSULTATS : {region.upper()} (STABILISÉ À {best_iteration_sgl[0]} LAG(S), HOLDOUT = {N_HOLDOUT} MOIS)')
    print(f'=' * 80)

    lag_gl, vars_gl, df_gl, r2_gl, r2_adj_gl, pval_gl, lbd_gl, r2_oos_gl, rmse_oos_gl = best_iteration_gl
    gdelt_gl = [v for v in vars_gl if v in gdelt_cols]
    print(f'\n▶ MODÈLE 1 : GROUP LASSO')
    print(f'  [IN-SAMPLE / TRAIN]  R² = {r2_gl:.4f} | R²adj = {r2_adj_gl:.4f} | {len(vars_gl)} variables ({len(gdelt_gl)} GDELT)')
    print(f'  [OUT-OF-SAMPLE]      R²_oos = {r2_oos_gl:.4f} | RMSE_oos = {rmse_oos_gl:.4f}')
    print(df_gl.to_string(index=False))

    lag_sgl, vars_sgl, df_sgl, r2_sgl, r2_adj_sgl, pval_sgl, lbd_sgl, alpha_sgl, r2_oos_sgl, rmse_oos_sgl = best_iteration_sgl
    gdelt_sgl = [v for v in vars_sgl if v in gdelt_cols]
    print(f'\n▶ MODÈLE 2 : SPARSE GROUP LASSO')
    print(f'  [IN-SAMPLE / TRAIN]  R² = {r2_sgl:.4f} | R²adj = {r2_adj_sgl:.4f} | {len(vars_sgl)} variables ({len(gdelt_sgl)} GDELT)')
    print(f'  [OUT-OF-SAMPLE]      R²_oos = {r2_oos_sgl:.4f} | RMSE_oos = {rmse_oos_sgl:.4f}')
    print(df_sgl.to_string(index=False))

    final_results[region] = {
        'GL_Model': {'Vars': vars_gl, 'OLS': df_gl, 'R2_adj_train': r2_adj_gl, 'R2_oos': r2_oos_gl, 'RMSE_oos': rmse_oos_gl},
        'SGL_Model': {'Vars': vars_sgl, 'OLS': df_sgl, 'R2_adj_train': r2_adj_sgl, 'R2_oos': r2_oos_sgl, 'RMSE_oos': rmse_oos_sgl, 'Optimal_Alpha': alpha_sgl},
    }
# Out:
# ================================================================================
#  PIPELINE ACADÉMIQUE : FRANCE (HOLD-OUT OUT-OF-SAMPLE = 24 MOIS)
# ================================================================================
#   ✓ Bruit blanc validé au Lag 1 (SGL Ljung-Box P-value train : 0.1380)
#
# ================================================================================
#  RÉSULTATS : FRANCE (STABILISÉ À 1 LAG(S), HOLDOUT = 24 MOIS)
# ================================================================================
#
# ▶ MODÈLE 1 : GROUP LASSO
#   [IN-SAMPLE / TRAIN]  R² = 1.0000 | R²adj = nan | 58 variables (50 GDELT)
#   [OUT-OF-SAMPLE]      R²_oos = -6.6462 | RMSE_oos = 1.2405
#                                        Variable   Coefficient  P-value  CI_Lower  CI_Upper
#                                       Intercept  2.636780e-16      NaN       NaN       NaN
#                                            rate  4.908702e-02      NaN       NaN       NaN
#                                           unemp  6.600753e-02      NaN       NaN       NaN
#                                          indpro -8.334554e-02      NaN       NaN       NaN
#                                           money  4.546815e-01      NaN       NaN       NaN
#                                              fx -1.515124e-01      NaN       NaN       NaN
#                                            mich  4.544992e-02      NaN       NaN       NaN
#                                             oil -9.314853e-02      NaN       NaN       NaN
#                                  inflation_lag1 -5.994171e-02      NaN       NaN       NaN
#        sent_bin_weight_agriculture_agribusiness -1.098001e-02      NaN       NaN       NaN
#       sent_bin_weight_agriculture_climate_risks  7.329404e-02      NaN       NaN       NaN
#         sent_bin_weight_agriculture_food_prices -8.245502e-04      NaN       NaN       NaN
# sent_bin_weight_agriculture_infrastructure_tech  1.524527e-01      NaN       NaN       NaN
#          sent_bin_weight_agriculture_regulation -2.689523e-01      NaN       NaN       NaN
#         sent_bin_weight_agriculture_rural_labor  5.462583e-02      NaN       NaN       NaN
#               sent_bin_weight_agriculture_water  1.806649e-01      NaN       NaN       NaN
#          sent_bin_weight_commodities_extraction  6.569658e-02      NaN       NaN       NaN
#       sent_bin_weight_commodities_market_prices  1.882259e-01      NaN       NaN       NaN
#           sent_bin_weight_commodities_materials  6.669735e-04      NaN       NaN       NaN
#          sent_bin_weight_commodities_regulation  2.505452e-02      NaN       NaN       NaN
#               sent_bin_weight_commodities_risks  2.721071e-01      NaN       NaN       NaN
#                   sent_bin_weight_energy_fossil -6.569601e-02      NaN       NaN       NaN
#                                        Variable   Coefficient  P-value  CI_Lower  CI_Upper
#                                       Intercept -2.775558e-17 1.000000 -0.100784  0.100784
#                                            rate -2.807054e-02 0.769714 -0.224913  0.168772
#                                           unemp  9.279277e-02 0.148664 -0.035911  0.221496
#                                          indpro -7.551568e-02 0.434445 -0.272591  0.121560
#                                           money  6.648435e-02 0.532170 -0.151188  0.284157
#                                              fx -3.349443e-02 0.684425 -0.202510  0.135522
#                                            mich  1.214355e-02 0.876820 -0.148809  0.173096
#                                             oil  6.139322e-03 0.948797 -0.190316  0.202594
#                                  inflation_lag1 -5.317451e-02 0.503668 -0.215694  0.109345
# sent_bin_weight_agriculture_infrastructure_tech  1.853428e-02 0.852092 -0.185660  0.222729
#         sent_bin_weight_agriculture_rural_labor  3.610317e-02 0.629276 -0.117150  0.189357
#          sent_bin_weight_commodities_extraction  6.655511e-03 0.966614 -0.320106  0.333417
#           sent_bin_weight_commodities_materials -7.959265e-02 0.623728 -0.412033  0.252847
#               sent_bin_weight_commodities_risks  1.343811e-01 0.069876 -0.011927  0.280690
#          sent_bin_weight_energy_infrastructures -2.475411e-02 0.888419 -0.387233  0.337725
#                  sent_bin_weight_energy_nuclear  1.251471e-01 0.477042 -0.234314  0.484608
#               sent_bin_weight_energy_renewables -4.753961e-02 0.500669 -0.191810  0.096731
#                    sent_bin_weight_energy_risks  1.042338e-01 0.279827 -0.091167  0.299635
#           sent_bin_weight_finance_central_banks  5.449674e-02 0.644275 -0.187423  0.296416
#          sent_bin_weight_finance_sovereign_debt -7.026604e-02 0.463637 -0.266012  0.125480
#           sent_bin_weight_finance_systemic_risk  1.156179e-01 0.257807 -0.091093  0.322329
#              sent_bin_weight_industry_factories -5.758230e-02 0.540950 -0.250255  0.135090
#             sent_bin_weight_industry_regulation -1.205800e-02 0.911397 -0.234706  0.210590
#          sent_bin_weight_real_estate_regulation -2.638555e-02 0.798849 -0.238991  0.186220
#            sent_bin_weight_real_estate_urbanism -2.279573e-01 0.022107 -0.419789 -0.036126
#               sent_bin_weight_tech_gov_strategy  1.544747e-01 0.157594 -0.064730  0.373679
#             sent_bin_weight_transport_logistics -8.497327e-02 0.289256 -0.247507  0.077560
#                 sent_bin_weight_transport_modes  2.699883e-02 0.805116 -0.197707  0.251705
#            sent_bin_weight_transport_regulation -2.175120e-02 0.800276 -0.198297  0.154795

# %% [markdown]
# ## TEST NOUVEAUX ALPHAS

# %%
# ==============================================================================
# CELLULE 2 : LIBRAIRIE DES FONCTIONS ÉCONOMÉTRIQUES ET DE PRÉPARATION
# ==============================================================================

def get_filtered_gdelt_cols(df):
    """ÉTAPE 0 : Ne conserve que les sous-variables des 8 secteurs cibles."""
    allowed_prefixes = [
        'sent_bin_weight_agriculture_', 'sent_bin_weight_commodities_',
        'sent_bin_weight_energy_', 'sent_bin_weight_finance_',
        'sent_bin_weight_industry_', 'sent_bin_weight_real_estate_',
        'sent_bin_weight_tech_', 'sent_bin_weight_transport_' 
        # ,'sent_bin_weight_growth_', 'sent_bin_weight_conflict_', 'sent_bin_weight_politics_',
        # 'sent_bin_weight_health_', 'sent_bin_weight_consumer_goods_'
    ]
    return [col for col in df.columns if any(str(col).startswith(prefix) for prefix in allowed_prefixes)]

def strict_stationarize(df):
    """ÉTAPE 1 : Test ADF -> Différence -> Winsorisation si nécessaire."""
    df_stat = df.copy()
    diff_count = 0
    for col in df_stat.columns:
        valid_data = df_stat[col].dropna()
        if len(valid_data) > 10:
            if adfuller(valid_data, autolag='AIC')[1] >= 0.05:
                df_stat[col] = df_stat[col].diff()
                diff_count += 1
                valid_data_diff = df_stat[col].dropna()
                if len(valid_data_diff) > 10 and adfuller(valid_data_diff, autolag='AIC')[1] >= 0.05:
                    p95 = valid_data_diff.quantile(0.95)
                    p05 = valid_data_diff.quantile(0.05)
                    df_stat[col] = df_stat[col].clip(lower=p05, upper=p95)
    return df_stat.dropna(), diff_count

def fetch_and_prep_macro_dynamic(region_config, start_date, end_date, region=None):
    """Télécharge la macro et génère 12 lags (pour fixer la taille de l'échantillon)."""
    macro_config = region_config['macro_vars']
    fred_tickers = {info['ticker']: var_name for var_name, info in macro_config.items() 
                    if not (region == 'France' and var_name == 'money') and 
                    not (region == 'UK' and info['ticker'] in ['IUMABEDR', 'LPMBD93', 'XUDLUSS'])}
    
    df = web.DataReader(list(fred_tickers.keys()), 'fred', start_date, end_date).rename(columns=fred_tickers).resample('MS').mean() if fred_tickers else pd.DataFrame()

    if region == 'France' and 'money' in macro_config:
        try:
            df_ecb = pd.read_csv('https://data-api.ecb.europa.eu/service/data/BSI/M.U2.Y.V.M30.X.1.U2.2300.Z01.E?format=csvdata')
            df_ecb['period'] = pd.to_datetime(df_ecb['TIME_PERIOD'])
            df_ecb = df_ecb.set_index('period').rename(columns={'OBS_VALUE': 'money'})[['money']].resample('MS').mean()
            df = df.join(df_ecb, how='left') if not df.empty else df_ecb
        except Exception as e: print(f'⚠ Erreur BCE: {e}')

    if region == 'UK':
        df_local_all = pd.DataFrame()
        for var_name, info in macro_config.items():
            if info['ticker'] in ['IUMABEDR', 'LPMBD93', 'XUDLUSS']:
                ticker = info['ticker']
                file_path = f'data/BoE/{ticker}.csv'
                if Path(file_path).exists():
                    df_temp = pd.read_csv(file_path, encoding='ISO-8859-1')
                    df_temp['period'] = pd.to_datetime(df_temp.iloc[:, 0], errors='coerce')
                    df_temp = df_temp.dropna(subset=['period']).set_index('period')
                    val_col = next((c for c in df_temp.columns if ticker in c), None)
                    if val_col:
                        if df_temp[val_col].dtype == object:
                            df_temp[val_col] = df_temp[val_col].astype(str).str.replace(',', '', regex=False).str.strip()
                        series = pd.to_numeric(df_temp[val_col], errors='coerce').rename(var_name).resample('MS').mean()
                        df_local_all = series.to_frame() if df_local_all.empty else df_local_all.join(series, how='outer')
        if not df_local_all.empty: df = df.join(df_local_all, how='outer') if not df.empty else df_local_all

    final_cols = []
    for var_name, info in macro_config.items():
        if var_name in df.columns:
            if info['transform'] == 'pct_change': df[var_name] = df[var_name].pct_change() * 100
            elif info['transform'] == 'diff': df[var_name] = df[var_name].diff()
            final_cols.append(var_name)

    for lag in range(1, 13):
        lag_name = f'inflation_lag{lag}'
        df[lag_name] = df['inflation'].shift(lag)
        final_cols.append(lag_name)

    return df[(df.index >= start_date) & (df.index <= end_date)][final_cols].dropna()

def run_cv_group_lasso(X, y, groups):
    """MODÈLE 1 : Group Lasso (Yuan & Lin, 2006) - Alpha forcé à 0 (Pénalité de groupe pure)."""
    tscv = TimeSeriesSplit(n_splits=5, gap=3) 
    lambdas = np.logspace(-4, -1, 50)
    best_mse, best_lbd = np.inf, None

    for lbd in lambdas:
        gl = GroupLasso(groups=groups, l1_reg=0.0, group_reg=lbd, fit_intercept=False, n_iter=1000, supress_warning=True)
        mse_scores = []
        for train_idx, test_idx in tscv.split(X):
            gl.fit(X.iloc[train_idx].values, y.iloc[train_idx].values.reshape(-1, 1))
            mse_scores.append(np.mean((y.iloc[test_idx].values - gl.predict(X.iloc[test_idx].values).flatten()) ** 2))
        
        if np.mean(mse_scores) < best_mse:
            best_mse, best_lbd = np.mean(mse_scores), lbd

    final_gl = GroupLasso(groups=groups, l1_reg=0.0, group_reg=best_lbd, fit_intercept=False, n_iter=5000, supress_warning=True)
    final_gl.fit(X.values, y.values.reshape(-1, 1))
    return final_gl.coef_.flatten(), best_lbd

def run_cv_sparse_group_lasso(X, y, groups):
    """MODÈLE 2 : Sparse Group Lasso (Simon et al., 2013) - Tuning de Lambda ET Alpha."""
    tscv = TimeSeriesSplit(n_splits=5, gap=3) 
    lambdas = np.logspace(-4, -1, 50)
    alphas = [0.50, 0.75, 0.90, 0.95]
    
    best_mse, best_lbd, best_alpha = np.inf, None, None

    for alpha in alphas:
        for lbd in lambdas:
            sgl = GroupLasso(groups=groups, l1_reg=lbd * alpha, group_reg=lbd * (1 - alpha), fit_intercept=False, n_iter=1000, supress_warning=True)
            mse_scores = []
            for train_idx, test_idx in tscv.split(X):
                sgl.fit(X.iloc[train_idx].values, y.iloc[train_idx].values.reshape(-1, 1))
                mse_scores.append(np.mean((y.iloc[test_idx].values - sgl.predict(X.iloc[test_idx].values).flatten()) ** 2))
            
            if np.mean(mse_scores) < best_mse:
                best_mse, best_lbd, best_alpha = np.mean(mse_scores), lbd, alpha

    final_sgl = GroupLasso(groups=groups, l1_reg=best_lbd * best_alpha, group_reg=best_lbd * (1 - best_alpha), fit_intercept=False, n_iter=5000, supress_warning=True)
    final_sgl.fit(X.values, y.values.reshape(-1, 1))
    return final_sgl.coef_.flatten(), best_lbd, best_alpha

def run_post_lasso_ols(X, y, selected_features):
    """Inférence OLS Post-Selection et diagnostic de Ljung-Box."""
    X_selected_with_const = sm.add_constant(X[selected_features])
    results = sm.OLS(y.values, X_selected_with_const.values).fit()

    post_lasso_df = pd.DataFrame({
        'Variable': ['Intercept'] + selected_features,
        'Coefficient': results.params,
        'P-value': results.pvalues,
        'CI_Lower': results.conf_int()[:, 0],
        'CI_Upper': results.conf_int()[:, 1],
    })
    
    lb_pval = acorr_ljungbox(results.resid, lags=[12], return_df=True)['lb_pvalue'].values[0]
    return post_lasso_df, results.rsquared, results.rsquared_adj, lb_pval

# %% [markdown]
# ### 1. Inflation

# %%
# ==============================================================================
# CELLULE 3 : CONFIGURATION DES MODÈLES RÉGIONAUX
# ==============================================================================
CONFIG_REGIONS = {
    'France': {
        'macro_vars': {
            'inflation': {'ticker': 'CP0000FRM086NEST', 'transform': 'pct_change'},
            'rate': {'ticker': 'IRSTCI01FRM156N', 'transform': 'diff'},
            'unemp': {'ticker': 'LRHUTTTTFRM156S', 'transform': 'diff'},
            'indpro': {'ticker': 'FRAPRINTO01GYSAM', 'transform': 'pct_change'},
            'money': {'ticker': 'BCE_M3_API', 'transform': 'none'},
            'fx': {'ticker': 'DEXUSEU', 'transform': 'pct_change'},
            'mich': {'ticker': 'CSINFT02FRM460S', 'transform': 'diff'},
            'oil': {'ticker': 'DCOILBRENTEU', 'transform': 'pct_change'},
        },
        'deseasonalize_y': True,
    },
    'US': {
        'macro_vars': {
            'inflation': {'ticker': 'CPIAUCSL', 'transform': 'pct_change'},
            'rate': {'ticker': 'FEDFUNDS', 'transform': 'diff'},
            'unemp': {'ticker': 'UNRATE', 'transform': 'diff'},
            'indpro': {'ticker': 'INDPRO', 'transform': 'pct_change'},
            'money': {'ticker': 'M2SL', 'transform': 'pct_change'},
            'fx': {'ticker': 'DEXUSEU', 'transform': 'pct_change'},
            'mich': {'ticker': 'MICH', 'transform': 'diff'},
            'oil': {'ticker': 'WTISPLC', 'transform': 'pct_change'},
        },
        'deseasonalize_y': False,
    },
    'UK': {
        'macro_vars': {
            'inflation': {'ticker': 'GBRCPIALLMINMEI', 'transform': 'pct_change'},
            'rate': {'ticker': 'IUMABEDR', 'transform': 'diff'},
            'unemp': {'ticker': 'LRHUTTTTGBM156S', 'transform': 'diff'},
            'indpro': {'ticker': 'GBRPRINTO01GYSAM', 'transform': 'pct_change'},
            'money': {'ticker': 'LPMBD93', 'transform': 'pct_change'},
            'fx': {'ticker': 'XUDLUSS', 'transform': 'pct_change'},
            'oil': {'ticker': 'DCOILBRENTEU', 'transform': 'pct_change'},
        },
        'deseasonalize_y': True,
    },
}

# %%
# ==============================================================================
# CELLULE 4 : EXÉCUTION DU PIPELINE COMPLET AVEC COMPARAISON GL vs SGL
# ==============================================================================
final_results = {}

for region, config in CONFIG_REGIONS.items():
    print(f'\n' + '=' * 80)
    print(f' PIPELINE ACADÉMIQUE : {region.upper()} (RECHERCHE DYNAMIQUE DE LAGS)')
    print(f'================================================================================')

    # 1. Préparation des données (Tronquées pour garantir un 'n' constant)
    df_macro = fetch_and_prep_macro_dynamic(config, START_DATE, END_DATE, region=region)
    df_macro = df_macro[df_macro.index >= MIN_INDEX_DATE]

    # --- NOUVEAU : SAUVEGARDE VINTAGE ---
    # vintage_path = Path(f'./data/economic_data/macro_vintage_inflation_{region}_{datetime.now().strftime("%Y%m%d")}.csv')
    # df_macro.to_csv(vintage_path)
    # print(f'💾 Données Macro sauvegardées : {vintage_path}')
    # ------------------------------------

    cols_gdelt = get_filtered_gdelt_cols(df_geo)
    df_gdelt_raw = df_geo[df_geo['region_key'] == region].set_index('period')[cols_gdelt]
    if 'sent_cont_weight_finance_international_orgs' in df_gdelt_raw.columns:
        df_gdelt_raw = df_gdelt_raw.drop(columns=['sent_cont_weight_finance_international_orgs'])

    df_gdelt_stat, diff_count = strict_stationarize(df_gdelt_raw)
    df_final = df_gdelt_stat.join(df_macro, how='inner')
    y_raw = df_final['inflation']

    y_corr = (y_raw - seasonal_decompose(y_raw, model='additive', period=12).seasonal).dropna() if config['deseasonalize_y'] else y_raw.dropna()
    X_full = df_final.drop(columns=['inflation'])
    y_corr, X_contemp = y_corr.align(X_full, join='inner')

    y_centered = y_corr - y_corr.mean()
    X_scaled_full = pd.DataFrame(StandardScaler().fit_transform(X_contemp), columns=X_contemp.columns, index=X_contemp.index)

    macro_base_cols = [c for c in X_scaled_full.columns if c in df_macro.columns and not c.startswith('inflation_lag') and c != 'inflation']
    gdelt_cols = [c for c in X_scaled_full.columns if c in cols_gdelt]

    # --- RECHERCHE DYNAMIQUE DU NOMBRE DE LAGS ---
    max_lags_to_test = 12
    best_iteration_gl = None
    best_iteration_sgl = None

    for current_lag in range(1, max_lags_to_test + 1):
        active_lags = [f'inflation_lag{i}' for i in range(1, current_lag + 1)]
        current_cols = macro_base_cols + active_lags + gdelt_cols
        X_current = X_scaled_full[current_cols]
        
        # Définition des groupes
        groups, group_map, current_group_id = [], {}, 2
        for var in current_cols:
            if var in macro_base_cols: groups.append(0) 
            elif var in active_lags: groups.append(1) 
            else:
                sector = var.split('_')[2]
                if sector not in group_map:
                    group_map[sector], current_group_id = current_group_id, current_group_id + 1
                groups.append(group_map[sector])
        groups_array = np.array(groups)

        # ---------------------------------------------------------
        # MODÈLE 1 : GROUP LASSO (Yuan & Lin)
        # ---------------------------------------------------------
        coefs_gl, lbd_gl = run_cv_group_lasso(X_current, y_centered, groups_array)
        selected_vars_gl = [current_cols[i] for i in range(len(current_cols)) if coefs_gl[i] != 0]
        final_vars_gl = list(set(macro_base_cols + active_lags + selected_vars_gl))
        final_vars_gl_sorted = [v for v in macro_base_cols if v in final_vars_gl] + [v for v in active_lags if v in final_vars_gl] + sorted([v for v in gdelt_cols if v in final_vars_gl])
        df_gl, r2_gl, r2_adj_gl, lb_pval_gl = run_post_lasso_ols(X_current, y_centered, final_vars_gl_sorted)
        best_iteration_gl = (current_lag, final_vars_gl_sorted, df_gl, r2_gl, r2_adj_gl, lb_pval_gl, lbd_gl)

        # ---------------------------------------------------------
        # MODÈLE 2 : SPARSE GROUP LASSO (Simon et al.)
        # ---------------------------------------------------------
        coefs_sgl, lbd_sgl, alpha_sgl = run_cv_sparse_group_lasso(X_current, y_centered, groups_array)
        selected_vars_sgl = [current_cols[i] for i in range(len(current_cols)) if coefs_sgl[i] != 0]
        final_vars_sgl = list(set(macro_base_cols + active_lags + selected_vars_sgl))
        final_vars_sgl_sorted = [v for v in macro_base_cols if v in final_vars_sgl] + [v for v in active_lags if v in final_vars_sgl] + sorted([v for v in gdelt_cols if v in final_vars_sgl])
        df_sgl, r2_sgl, r2_adj_sgl, lb_pval_sgl = run_post_lasso_ols(X_current, y_centered, final_vars_sgl_sorted)
        best_iteration_sgl = (current_lag, final_vars_sgl_sorted, df_sgl, r2_sgl, r2_adj_sgl, lb_pval_sgl, lbd_sgl, alpha_sgl)

        # Règle d'arrêt : On s'arrête dès que le SGL capture toute la dynamique temporelle (Bruit blanc validé)
        if lb_pval_sgl >= 0.05:
            print(f'  ✓ Bruit blanc validé au Lag {current_lag} (SGL Ljung-Box P-value : {lb_pval_sgl:.4f})')
            break
        else:
            print(f'  ↻ Autocorrélation résiduelle au Lag {current_lag} (P-value : {lb_pval_sgl:.4f}). Ajout du lag {current_lag+1}...')

    # --- AFFICHAGE COMPARATIF DES RÉSULTATS OPTIMAUX ---
    print(f'\n' + '=' * 80)
    print(f' RÉSULTATS COMPARATIFS FINAUX : {region.upper()} (STABILISÉ À {best_iteration_sgl[0]} LAG(S))')
    print(f'=' * 80)

    # Affichage Group Lasso
    lag_gl, vars_gl, df_gl, r2_gl, r2_adj_gl, pval_gl, lbd_gl = best_iteration_gl
    gdelt_gl = [v for v in vars_gl if v in gdelt_cols]
    
    print(f'\n▶ MODÈLE 1 : GROUP LASSO (Yuan & Lin, 2006) - Sélection de secteurs entiers')
    print(f'  Tuning Data-Driven : Lambda = {lbd_gl:.4f} | Alpha forcé = 0.0')
    print(f'  Variables totales (OLS) : {len(vars_gl)} (dont {len(gdelt_gl)} GDELT)')
    print(f'  R-squared (Global/Adj) : {r2_gl:.4f} / {r2_adj_gl:.4f}')
    print(f'  Ljung-Box P-value : {pval_gl:.4f}')
    print("-" * 60)
    print(df_gl.to_string(index=False))

    # Affichage Sparse Group Lasso
    lag_sgl, vars_sgl, df_sgl, r2_sgl, r2_adj_sgl, pval_sgl, lbd_sgl, alpha_sgl = best_iteration_sgl
    gdelt_sgl = [v for v in vars_sgl if v in gdelt_cols]
    
    print(f'\n\n▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs')
    print(f'  Tuning Data-Driven : Lambda = {lbd_sgl:.4f} | Alpha = {alpha_sgl:.2f}')
    print(f'  Variables totales (OLS) : {len(vars_sgl)} (dont {len(gdelt_sgl)} GDELT)')
    print(f'  R-squared (Global/Adj) : {r2_sgl:.4f} / {r2_adj_sgl:.4f}')
    print(f'  Ljung-Box P-value : {pval_sgl:.4f}')
    print("-" * 60)
    print(df_sgl.to_string(index=False))

    final_results[region] = {
        'GL_Model': {'Vars': vars_gl, 'OLS': df_gl, 'R2_adj': r2_adj_gl},
        'SGL_Model': {'Vars': vars_sgl, 'OLS': df_sgl, 'R2_adj': r2_adj_sgl, 'Optimal_Alpha': alpha_sgl}
    }

    # ==========================================================================
    # EXPORT LATEX AUTOMATIQUE DES TABLEAUX DE RÉSULTATS
    # ==========================================================================
    
    # import os
    # # Création d'un dossier pour ranger vos tableaux propres
    # output_dir = "./latex_tables"
    # os.makedirs(output_dir, exist_ok=True)
    
    # # 1. Export du tableau Group Lasso (GL)
    # filename_gl = f"{output_dir}/OLS_GL_{region}.tex"
    # # On arrondit à 4 décimales et on supprime l'index (0, 1, 2...) de Pandas
    # latex_gl = df_gl.to_latex(index=False, float_format="%.4f", escape=True)
    # with open(filename_gl, 'w') as f:
    #     f.write(latex_gl)
        
    # # 2. Export du tableau Sparse Group Lasso (SGL)
    # filename_sgl = f"{output_dir}/OLS_SGL_{region}.tex"
    # latex_sgl = df_sgl.to_latex(index=False, float_format="%.4f", escape=True)
    # with open(filename_sgl, 'w') as f:
    #     f.write(latex_sgl)
        
    # # 3. BONUS : Export d'un tableau "Strict" (Uniquement les variables significatives p < 0.10)
    # # Très utile pour le corps de votre mémoire (les tableaux complets iront en annexe)
    # df_sgl_strict = df_sgl[df_sgl['P-value'] < 0.10]
    # filename_sgl_strict = f"{output_dir}/OLS_SGL_{region}_SIGNIFICANT.tex"
    # latex_sgl_strict = df_sgl_strict.to_latex(index=False, float_format="%.4f", escape=True)
    # with open(filename_sgl_strict, 'w') as f:
    #     f.write(latex_sgl_strict)
        
    # print(f"  📝 Tableaux LaTeX exportés avec succès dans le dossier '{output_dir}'.")
# Out:
# ================================================================================
#  PIPELINE ACADÉMIQUE : FRANCE (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ↻ Autocorrélation résiduelle au Lag 1 (P-value : 0.0085). Ajout du lag 2...
#   ↻ Autocorrélation résiduelle au Lag 2 (P-value : 0.0167). Ajout du lag 3...
#   ↻ Autocorrélation résiduelle au Lag 3 (P-value : 0.0167). Ajout du lag 4...
#   ↻ Autocorrélation résiduelle au Lag 4 (P-value : 0.0127). Ajout du lag 5...
#   ✓ Bruit blanc validé au Lag 5 (SGL Ljung-Box P-value : 0.2745)
#
# ================================================================================
#  RÉSULTATS COMPARATIFS FINAUX : FRANCE (STABILISÉ À 5 LAG(S))
# ================================================================================
#
# ▶ MODÈLE 1 : GROUP LASSO (Yuan & Lin, 2006) - Sélection de secteurs entiers
#   Tuning Data-Driven : Lambda = 0.0160 | Alpha forcé = 0.0
#   Variables totales (OLS) : 62 (dont 50 GDELT)
#   R-squared (Global/Adj) : 0.6145 / 0.1952
#   Ljung-Box P-value : 0.2834
# ------------------------------------------------------------
#                                        Variable   Coefficient  P-value  CI_Lower  CI_Upper
#                                       Intercept  1.214306e-16 1.000000 -0.071792  0.071792
#                                            rate  4.360786e-02 0.525698 -0.093153  0.180368
#                                           unemp  2.105922e-02 0.638569 -0.068242  0.110361
#                                          indpro  3.164960e-02 0.636293 -0.101654  0.164953
#                                           money  1.221909e-01 0.234906 -0.081625  0.326006
#                                              fx  7.319364e-02 0.216126 -0.043988  0.190375
#                                            mich  4.498294e-03 0.934784 -0.105098  0.114095
#                                             oil  1.189737e-01 0.061069 -0.005710  0.243657
#                                  inflation_lag1 -1.024167e-02 0.847416 -0.116342  0.095859
#                                  inflation_lag2  7.533776e-02 0.228187 -0.048507  0.199183
#                                  inflation_lag3  5.426553e-02 0.390969 -0.071440  0.179971
#                                  inflation_lag4  1.000444e-01 0.171924 -0.044765  0.244854
#                                  inflation_lag5 -1.542483e-01 0.007202 -0.265051 -0.043446
#        sent_bin_weight_agriculture_agribusiness -8.680227e-02 0.467250 -0.324303  0.150699
#       sent_bin_weight_agriculture_climate_risks -1.262298e-01 0.124218 -0.288228  0.035769
#         sent_bin_weight_agriculture_food_prices  6.687921e-02 0.599854 -0.186976  0.320734
# sent_bin_weight_agriculture_infrastructure_tech  6.998021e-02 0.413914 -0.100282  0.240242
#          sent_bin_weight_agriculture_regulation  6.141209e-02 0.346597 -0.068164  0.190988
#         sent_bin_weight_agriculture_rural_labor  5.161431e-02 0.638256 -0.167051  0.270280
#               sent_bin_weight_agriculture_water  7.309817e-03 0.902339 -0.111449  0.126069
# ------------------------------------------------------------
#                                        Variable   Coefficient  P-value  CI_Lower  CI_Upper
#                                       Intercept  1.366095e-17 1.000000 -0.039807  0.039807
#                                            rate  1.438372e-02 0.676218 -0.053833  0.082600
#                                           unemp  1.280877e-02 0.555106 -0.030161  0.055778
#                                          indpro -4.493304e-02 0.049872 -0.089840 -0.000026
#                                           money -2.785137e-02 0.368583 -0.089093  0.033390
#                                              fx -2.926835e-02 0.211199 -0.075451  0.016914
#                                             oil -3.334793e-02 0.189260 -0.083440  0.016744
#                                  inflation_lag1 -1.044972e-02 0.672040 -0.059339  0.038439
# sent_bin_weight_agriculture_infrastructure_tech -4.412038e-02 0.113273 -0.098934  0.010693
#         sent_bin_weight_agriculture_rural_labor  2.091432e-02 0.436656 -0.032275  0.074104
#          sent_bin_weight_commodities_extraction  3.969024e-02 0.626453 -0.121795  0.201176
#       sent_bin_weight_commodities_market_prices -1.921558e-02 0.544544 -0.081990  0.043559
#           sent_bin_weight_commodities_materials  5.698654e-02 0.458854 -0.095228  0.209201
#          sent_bin_weight_commodities_regulation  2.433941e-02 0.303394 -0.022384  0.071062
#          sent_bin_weight_energy_infrastructures -5.139000e-03 0.848954 -0.058604  0.048326
#               sent_bin_weight_energy_renewables -6.893233e-02 0.005251 -0.116787 -0.021078
#                    sent_bin_weight_energy_risks  3.825427e-02 0.095881 -0.006911  0.083420
#                  sent_bin_weight_finance_credit  5.036239e-02 0.108224 -0.011314  0.112039
#              sent_bin_weight_finance_regulation -3.029918e-02 0.199786 -0.076909  0.016310
#          sent_bin_weight_finance_sovereign_debt -1.043496e-01 0.013373 -0.186488 -0.022211
#           sent_bin_weight_finance_systemic_risk  4.923627e-02 0.074744 -0.005020  0.103492
#              sent_bin_weight_industry_factories  2.297756e-02 0.341505 -0.024769  0.070724
#              sent_bin_weight_industry_logistics  2.115843e-02 0.429190 -0.031782  0.074099
#           sent_bin_weight_real_estate_financing  7.452257e-02 0.014215  0.015320  0.133725
#          sent_bin_weight_real_estate_regulation -4.557648e-02 0.072587 -0.095418  0.004265
#             sent_bin_weight_tech_infrastructure -5.092504e-02 0.074066 -0.106909  0.005058
#                 sent_bin_weight_tech_innovation -4.753992e-02 0.042571 -0.093451 -0.001628
#                 sent_bin_weight_tech_regulation  3.903039e-02 0.101189 -0.007795  0.085856
#                 sent_bin_weight_transport_costs -1.037848e-01 0.000112 -0.154775 -0.052794
#        sent_bin_weight_transport_infrastructure -4.057113e-02 0.060882 -0.083035  0.001893
#   sent_bin_weight_transport_international_trade  2.656153e-02 0.419910 -0.038575  0.091699
#             sent_bin_weight_transport_logistics  5.078436e-02 0.144533 -0.017768  0.119337

# %% [markdown]
# ### 2. Core inflation

# %%
# ==============================================================================
# CELLULE 3 : CONFIGURATION DES MODÈLES RÉGIONAUX (CORE INFLATION)
# ==============================================================================
CONFIG_REGIONS = {
    'France': {
        'macro_vars': {
            # Mise à jour: Core CPI France (Non-Food, Non-Energy)
            'inflation': {'ticker': 'CPGRLE01FRM659N', 'transform': 'pct_change'},
            'rate': {'ticker': 'IRSTCI01FRM156N', 'transform': 'diff'},
            'unemp': {'ticker': 'LRHUTTTTFRM156S', 'transform': 'diff'},
            'indpro': {'ticker': 'FRAPRINTO01GYSAM', 'transform': 'pct_change'},
            'money': {'ticker': 'BCE_M3_API', 'transform': 'none'},
            'fx': {'ticker': 'DEXUSEU', 'transform': 'pct_change'},
            'mich': {'ticker': 'CSINFT02FRM460S', 'transform': 'diff'},
            'oil': {'ticker': 'DCOILBRENTEU', 'transform': 'pct_change'},
        },
        'deseasonalize_y': True,
    },
    'US': {
        'macro_vars': {
            # Mise à jour: Core CPI US (All Items Less Food & Energy)
            'inflation': {'ticker': 'CPILFESL', 'transform': 'pct_change'},
            'rate': {'ticker': 'FEDFUNDS', 'transform': 'diff'},
            'unemp': {'ticker': 'UNRATE', 'transform': 'diff'},
            'indpro': {'ticker': 'INDPRO', 'transform': 'pct_change'},
            'money': {'ticker': 'M2SL', 'transform': 'pct_change'},
            'fx': {'ticker': 'DEXUSEU', 'transform': 'pct_change'},
            'mich': {'ticker': 'MICH', 'transform': 'diff'},
            'oil': {'ticker': 'WTISPLC', 'transform': 'pct_change'},
        },
        'deseasonalize_y': False,
    },
    'UK': {
        'macro_vars': {
            'inflation': {'ticker': 'CPGRLE01GBM659N', 'transform': 'pct_change'},
            'rate': {'ticker': 'IUMABEDR', 'transform': 'diff'},
            'unemp': {'ticker': 'LRHUTTTTGBM156S', 'transform': 'diff'},
            'indpro': {'ticker': 'GBRPRINTO01GYSAM', 'transform': 'pct_change'},
            'money': {'ticker': 'LPMBD93', 'transform': 'pct_change'},
            'fx': {'ticker': 'XUDLUSS', 'transform': 'pct_change'},
            'oil': {'ticker': 'DCOILBRENTEU', 'transform': 'pct_change'},
        },
        'deseasonalize_y': True,
    },
}

# %%
# ==============================================================================
# CELLULE 4 : EXÉCUTION DU PIPELINE COMPLET AVEC COMPARAISON GL vs SGL
# ==============================================================================
final_results = {}

for region, config in CONFIG_REGIONS.items():
    print(f'\n' + '=' * 80)
    print(f' PIPELINE ACADÉMIQUE : {region.upper()} (RECHERCHE DYNAMIQUE DE LAGS)')
    print(f'================================================================================')

    # 1. Préparation des données (Tronquées pour garantir un 'n' constant)
    df_macro = fetch_and_prep_macro_dynamic(config, START_DATE, END_DATE, region=region)
    df_macro = df_macro[df_macro.index >= MIN_INDEX_DATE]

    # --- NOUVEAU : SAUVEGARDE VINTAGE ---
    # vintage_path = Path(f'./data/economic_data/macro_vintage_inflation_{region}_{datetime.now().strftime("%Y%m%d")}.csv')
    # df_macro.to_csv(vintage_path)
    # print(f'💾 Données Macro sauvegardées : {vintage_path}')
    # ------------------------------------

    cols_gdelt = get_filtered_gdelt_cols(df_geo)
    df_gdelt_raw = df_geo[df_geo['region_key'] == region].set_index('period')[cols_gdelt]
    if 'sent_cont_weight_finance_international_orgs' in df_gdelt_raw.columns:
        df_gdelt_raw = df_gdelt_raw.drop(columns=['sent_cont_weight_finance_international_orgs'])

    df_gdelt_stat, diff_count = strict_stationarize(df_gdelt_raw)
    df_final = df_gdelt_stat.join(df_macro, how='inner')
    y_raw = df_final['inflation']

    y_corr = (y_raw - seasonal_decompose(y_raw, model='additive', period=12).seasonal).dropna() if config['deseasonalize_y'] else y_raw.dropna()
    X_full = df_final.drop(columns=['inflation'])
    y_corr, X_contemp = y_corr.align(X_full, join='inner')

    y_centered = y_corr - y_corr.mean()
    X_scaled_full = pd.DataFrame(StandardScaler().fit_transform(X_contemp), columns=X_contemp.columns, index=X_contemp.index)

    macro_base_cols = [c for c in X_scaled_full.columns if c in df_macro.columns and not c.startswith('inflation_lag') and c != 'inflation']
    gdelt_cols = [c for c in X_scaled_full.columns if c in cols_gdelt]

    # --- RECHERCHE DYNAMIQUE DU NOMBRE DE LAGS ---
    max_lags_to_test = 12
    best_iteration_gl = None
    best_iteration_sgl = None

    for current_lag in range(1, max_lags_to_test + 1):
        active_lags = [f'inflation_lag{i}' for i in range(1, current_lag + 1)]
        current_cols = macro_base_cols + active_lags + gdelt_cols
        X_current = X_scaled_full[current_cols]
        
        # Définition des groupes
        groups, group_map, current_group_id = [], {}, 2
        for var in current_cols:
            if var in macro_base_cols: groups.append(0) 
            elif var in active_lags: groups.append(1) 
            else:
                sector = var.split('_')[2]
                if sector not in group_map:
                    group_map[sector], current_group_id = current_group_id, current_group_id + 1
                groups.append(group_map[sector])
        groups_array = np.array(groups)

        # ---------------------------------------------------------
        # MODÈLE 1 : GROUP LASSO (Yuan & Lin)
        # ---------------------------------------------------------
        coefs_gl, lbd_gl = run_cv_group_lasso(X_current, y_centered, groups_array)
        selected_vars_gl = [current_cols[i] for i in range(len(current_cols)) if coefs_gl[i] != 0]
        final_vars_gl = list(set(macro_base_cols + active_lags + selected_vars_gl))
        final_vars_gl_sorted = [v for v in macro_base_cols if v in final_vars_gl] + [v for v in active_lags if v in final_vars_gl] + sorted([v for v in gdelt_cols if v in final_vars_gl])
        df_gl, r2_gl, r2_adj_gl, lb_pval_gl = run_post_lasso_ols(X_current, y_centered, final_vars_gl_sorted)
        best_iteration_gl = (current_lag, final_vars_gl_sorted, df_gl, r2_gl, r2_adj_gl, lb_pval_gl, lbd_gl)

        # ---------------------------------------------------------
        # MODÈLE 2 : SPARSE GROUP LASSO (Simon et al.)
        # ---------------------------------------------------------
        coefs_sgl, lbd_sgl, alpha_sgl = run_cv_sparse_group_lasso(X_current, y_centered, groups_array)
        selected_vars_sgl = [current_cols[i] for i in range(len(current_cols)) if coefs_sgl[i] != 0]
        final_vars_sgl = list(set(macro_base_cols + active_lags + selected_vars_sgl))
        final_vars_sgl_sorted = [v for v in macro_base_cols if v in final_vars_sgl] + [v for v in active_lags if v in final_vars_sgl] + sorted([v for v in gdelt_cols if v in final_vars_sgl])
        df_sgl, r2_sgl, r2_adj_sgl, lb_pval_sgl = run_post_lasso_ols(X_current, y_centered, final_vars_sgl_sorted)
        best_iteration_sgl = (current_lag, final_vars_sgl_sorted, df_sgl, r2_sgl, r2_adj_sgl, lb_pval_sgl, lbd_sgl, alpha_sgl)

        # Règle d'arrêt : On s'arrête dès que le SGL capture toute la dynamique temporelle (Bruit blanc validé)
        if lb_pval_sgl >= 0.05:
            print(f'  ✓ Bruit blanc validé au Lag {current_lag} (SGL Ljung-Box P-value : {lb_pval_sgl:.4f})')
            break
        else:
            print(f'  ↻ Autocorrélation résiduelle au Lag {current_lag} (P-value : {lb_pval_sgl:.4f}). Ajout du lag {current_lag+1}...')

    # --- AFFICHAGE COMPARATIF DES RÉSULTATS OPTIMAUX ---
    print(f'\n' + '=' * 80)
    print(f' RÉSULTATS COMPARATIFS FINAUX : {region.upper()} (STABILISÉ À {best_iteration_sgl[0]} LAG(S))')
    print(f'=' * 80)

    # Affichage Group Lasso
    lag_gl, vars_gl, df_gl, r2_gl, r2_adj_gl, pval_gl, lbd_gl = best_iteration_gl
    gdelt_gl = [v for v in vars_gl if v in gdelt_cols]
    
    print(f'\n▶ MODÈLE 1 : GROUP LASSO (Yuan & Lin, 2006) - Sélection de secteurs entiers')
    print(f'  Tuning Data-Driven : Lambda = {lbd_gl:.4f} | Alpha forcé = 0.0')
    print(f'  Variables totales (OLS) : {len(vars_gl)} (dont {len(gdelt_gl)} GDELT)')
    print(f'  R-squared (Global/Adj) : {r2_gl:.4f} / {r2_adj_gl:.4f}')
    print(f'  Ljung-Box P-value : {pval_gl:.4f}')
    print("-" * 60)
    print(df_gl.to_string(index=False))

    # Affichage Sparse Group Lasso
    lag_sgl, vars_sgl, df_sgl, r2_sgl, r2_adj_sgl, pval_sgl, lbd_sgl, alpha_sgl = best_iteration_sgl
    gdelt_sgl = [v for v in vars_sgl if v in gdelt_cols]
    
    print(f'\n\n▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs')
    print(f'  Tuning Data-Driven : Lambda = {lbd_sgl:.4f} | Alpha = {alpha_sgl:.2f}')
    print(f'  Variables totales (OLS) : {len(vars_sgl)} (dont {len(gdelt_sgl)} GDELT)')
    print(f'  R-squared (Global/Adj) : {r2_sgl:.4f} / {r2_adj_sgl:.4f}')
    print(f'  Ljung-Box P-value : {pval_sgl:.4f}')
    print("-" * 60)
    print(df_sgl.to_string(index=False))

    final_results[region] = {
        'GL_Model': {'Vars': vars_gl, 'OLS': df_gl, 'R2_adj': r2_adj_gl},
        'SGL_Model': {'Vars': vars_sgl, 'OLS': df_sgl, 'R2_adj': r2_adj_sgl, 'Optimal_Alpha': alpha_sgl}
    }

    # ==========================================================================
    # EXPORT LATEX AUTOMATIQUE DES TABLEAUX DE RÉSULTATS
    # ==========================================================================
    
    # import os
    # # Création d'un dossier pour ranger vos tableaux propres
    # output_dir = "./latex_tables"
    # os.makedirs(output_dir, exist_ok=True)
    
    # # 1. Export du tableau Group Lasso (GL)
    # filename_gl = f"{output_dir}/OLS_GL_{region}.tex"
    # # On arrondit à 4 décimales et on supprime l'index (0, 1, 2...) de Pandas
    # latex_gl = df_gl.to_latex(index=False, float_format="%.4f", escape=True)
    # with open(filename_gl, 'w') as f:
    #     f.write(latex_gl)
        
    # # 2. Export du tableau Sparse Group Lasso (SGL)
    # filename_sgl = f"{output_dir}/OLS_SGL_{region}.tex"
    # latex_sgl = df_sgl.to_latex(index=False, float_format="%.4f", escape=True)
    # with open(filename_sgl, 'w') as f:
    #     f.write(latex_sgl)
        
    # # 3. BONUS : Export d'un tableau "Strict" (Uniquement les variables significatives p < 0.10)
    # # Très utile pour le corps de votre mémoire (les tableaux complets iront en annexe)
    # df_sgl_strict = df_sgl[df_sgl['P-value'] < 0.10]
    # filename_sgl_strict = f"{output_dir}/OLS_SGL_{region}_SIGNIFICANT.tex"
    # latex_sgl_strict = df_sgl_strict.to_latex(index=False, float_format="%.4f", escape=True)
    # with open(filename_sgl_strict, 'w') as f:
    #     f.write(latex_sgl_strict)
        
    # print(f"  📝 Tableaux LaTeX exportés avec succès dans le dossier '{output_dir}'.")
# Out:
# ================================================================================
#  PIPELINE ACADÉMIQUE : FRANCE (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ✓ Bruit blanc validé au Lag 1 (SGL Ljung-Box P-value : 0.4937)
#
# ================================================================================
#  RÉSULTATS COMPARATIFS FINAUX : FRANCE (STABILISÉ À 1 LAG(S))
# ================================================================================
#
# ▶ MODÈLE 1 : GROUP LASSO (Yuan & Lin, 2006) - Sélection de secteurs entiers
#   Tuning Data-Driven : Lambda = 0.1000 | Alpha forcé = 0.0
#   Variables totales (OLS) : 58 (dont 50 GDELT)
#   R-squared (Global/Adj) : 0.5196 / -0.0610
#   Ljung-Box P-value : 0.4878
# ------------------------------------------------------------
#                                        Variable   Coefficient  P-value    CI_Lower   CI_Upper
#                                       Intercept -4.935635e-14 1.000000  -13.136041  13.136041
#                                            rate -1.661109e+01 0.200562  -42.346245   9.124073
#                                           unemp  1.310564e+00 0.873277  -15.122427  17.743554
#                                          indpro  3.314350e+00 0.789405  -21.497579  28.126278
#                                           money -1.206963e+01 0.537817  -51.174949  27.035679
#                                              fx  2.149255e+00 0.844116  -19.709094  24.007603
#                                            mich -2.094280e+00 0.819618  -20.458968  16.270409
#                                             oil  4.883909e+00 0.683386  -19.047191  28.815009
#                                  inflation_lag1 -1.994475e+01 0.030003  -37.875509  -2.013990
#        sent_bin_weight_agriculture_agribusiness -1.876393e+01 0.386243  -61.909474  24.381606
#       sent_bin_weight_agriculture_climate_risks -5.125238e+00 0.722764  -34.002398  23.751921
#         sent_bin_weight_agriculture_food_prices -1.055552e+01 0.615613  -52.551248  31.440215
# sent_bin_weight_agriculture_infrastructure_tech  6.776961e+00 0.615119  -20.147801  33.701723
#          sent_bin_weight_agriculture_regulation  1.264475e+01 0.303978  -11.823275  37.112782
#         sent_bin_weight_agriculture_rural_labor  2.399136e+01 0.241539  -16.688302  64.671023
#               sent_bin_weight_energy_renewables -9.836117e-01 0.459412  -3.622063  1.654840
#                    sent_bin_weight_energy_risks  3.584241e+00 0.003709   1.205339  5.963142
#                   sent_bin_weight_finance_banks -4.755107e+00 0.174833 -11.676053  2.165839
#           sent_bin_weight_finance_central_banks  6.858624e+00 0.080128  -0.845830 14.563079
#                  sent_bin_weight_finance_credit -4.301201e-01 0.813752  -4.059951  3.199710
#       sent_bin_weight_finance_financial_markets -3.494099e+00 0.221326  -9.143516  2.155318
#            sent_bin_weight_finance_private_debt  1.972117e+00 0.378736  -2.470256  6.414489
#          sent_bin_weight_finance_sovereign_debt -3.662616e+00 0.386388 -12.047500  4.722268
#           sent_bin_weight_finance_systemic_risk  2.584720e+00 0.236906  -1.738179  6.907619
#              sent_bin_weight_industry_factories -9.416020e-01 0.532189  -3.934718  2.051514
#              sent_bin_weight_industry_logistics  3.271316e+00 0.032547   0.280168  6.262464
#           sent_bin_weight_industry_productivity -4.549789e-01 0.765102  -3.482065  2.572108
#             sent_bin_weight_industry_regulation  2.226905e+00 0.179207  -1.047666  5.501477
#                  sent_bin_weight_industry_risks -2.075916e+00 0.111832  -4.647590  0.495757
#          sent_bin_weight_industry_supply_chains  6.129106e-01 0.643012  -2.014615  3.240436
#        sent_bin_weight_real_estate_construction -1.484571e+00 0.265151  -4.121592  1.152449
#           sent_bin_weight_real_estate_financing  4.287684e+00 0.025157   0.550985  8.024384
#              sent_bin_weight_real_estate_market -2.247418e-01 0.902625  -3.877416  3.427932
#          sent_bin_weight_real_estate_regulation -1.374492e+00 0.322941  -4.129624  1.380639
#            sent_bin_weight_real_estate_urbanism -3.825379e-02 0.977196  -2.699481  2.622974
#               sent_bin_weight_tech_gov_strategy -6.162309e-01 0.694728  -3.736942  2.504481
#                 sent_bin_weight_tech_innovation -1.318881e+00 0.319923  -3.945985  1.308223
#                 sent_bin_weight_tech_regulation  1.578343e+00 0.264230  -1.219792  4.376478
#                      sent_bin_weight_tech_risks -9.203918e-01 0.572243  -4.157352  2.316568
#                 sent_bin_weight_transport_costs -3.755544e+00 0.004874  -6.329750 -1.181338
#        sent_bin_weight_transport_infrastructure -5.566091e-01 0.816007  -5.312564  4.199346
#   sent_bin_weight_transport_international_trade  2.381572e+00 0.284763  -2.026845  6.789988
#             sent_bin_weight_transport_logistics  1.771040e+00 0.319082  -1.750552  5.292633
#                 sent_bin_weight_transport_modes -8.109759e-01 0.739013  -5.649528  4.027576
#            sent_bin_weight_transport_regulation  4.643281e-01 0.779721  -2.836120  3.764777
#                 sent_bin_weight_transport_risks  2.222721e+00 0.096594  -0.409874  4.855315

# %% [markdown]
# ### 3. Robustness - no group macro - inflation

# %%
# ==============================================================================
# CELLULE 3 : CONFIGURATION DES MODÈLES (ARX - HEADLINE INFLATION)
# ==============================================================================
CONFIG_REGIONS = {
    'France': {
        'macro_vars': {
            'inflation': {'ticker': 'CP0000FRM086NEST', 'transform': 'pct_change'}
        },
        'deseasonalize_y': True,
    },
    'US': {
        'macro_vars': {
            'inflation': {'ticker': 'CPIAUCSL', 'transform': 'pct_change'}
        },
        'deseasonalize_y': False,
    },
    'UK': {
        'macro_vars': {
            'inflation': {'ticker': 'GBRCPIALLMINMEI', 'transform': 'pct_change'}
        },
        'deseasonalize_y': True,
    },
}

# %%
# ==============================================================================
# CELLULE 4 : EXÉCUTION DU PIPELINE COMPLET AVEC COMPARAISON GL vs SGL
# ==============================================================================
final_results = {}

for region, config in CONFIG_REGIONS.items():
    print(f'\n' + '=' * 80)
    print(f' PIPELINE ACADÉMIQUE : {region.upper()} (RECHERCHE DYNAMIQUE DE LAGS)')
    print(f'================================================================================')

    # 1. Préparation des données (Tronquées pour garantir un 'n' constant)
    df_macro = fetch_and_prep_macro_dynamic(config, START_DATE, END_DATE, region=region)
    df_macro = df_macro[df_macro.index >= MIN_INDEX_DATE]

    # --- NOUVEAU : SAUVEGARDE VINTAGE ---
    # vintage_path = Path(f'./data/economic_data/macro_vintage_coreinflation_{region}_{datetime.now().strftime("%Y%m%d")}.csv')
    # df_macro.to_csv(vintage_path)
    # print(f'💾 Données Macro sauvegardées : {vintage_path}')
    # # ------------------------------------

    cols_gdelt = get_filtered_gdelt_cols(df_geo)
    df_gdelt_raw = df_geo[df_geo['region_key'] == region].set_index('period')[cols_gdelt]
    if 'sent_cont_weight_finance_international_orgs' in df_gdelt_raw.columns:
        df_gdelt_raw = df_gdelt_raw.drop(columns=['sent_cont_weight_finance_international_orgs'])

    df_gdelt_stat, diff_count = strict_stationarize(df_gdelt_raw)
    df_final = df_gdelt_stat.join(df_macro, how='inner')
    y_raw = df_final['inflation']

    y_corr = (y_raw - seasonal_decompose(y_raw, model='additive', period=12).seasonal).dropna() if config['deseasonalize_y'] else y_raw.dropna()
    X_full = df_final.drop(columns=['inflation'])
    y_corr, X_contemp = y_corr.align(X_full, join='inner')

    y_centered = y_corr - y_corr.mean()
    X_scaled_full = pd.DataFrame(StandardScaler().fit_transform(X_contemp), columns=X_contemp.columns, index=X_contemp.index)

    macro_base_cols = [c for c in X_scaled_full.columns if c in df_macro.columns and not c.startswith('inflation_lag') and c != 'inflation']
    gdelt_cols = [c for c in X_scaled_full.columns if c in cols_gdelt]

    # --- RECHERCHE DYNAMIQUE DU NOMBRE DE LAGS ---
    max_lags_to_test = 12
    best_iteration_gl = None
    best_iteration_sgl = None

    for current_lag in range(1, max_lags_to_test + 1):
        active_lags = [f'inflation_lag{i}' for i in range(1, current_lag + 1)]
        current_cols = macro_base_cols + active_lags + gdelt_cols
        X_current = X_scaled_full[current_cols]
        
        # Définition des groupes
        groups, group_map, current_group_id = [], {}, 2
        for var in current_cols:
            if var in macro_base_cols: groups.append(0) 
            elif var in active_lags: groups.append(1) 
            else:
                sector = var.split('_')[2]
                if sector not in group_map:
                    group_map[sector], current_group_id = current_group_id, current_group_id + 1
                groups.append(group_map[sector])
        groups_array = np.array(groups)

        # ---------------------------------------------------------
        # MODÈLE 1 : GROUP LASSO (Yuan & Lin)
        # ---------------------------------------------------------
        coefs_gl, lbd_gl = run_cv_group_lasso(X_current, y_centered, groups_array)
        selected_vars_gl = [current_cols[i] for i in range(len(current_cols)) if coefs_gl[i] != 0]
        final_vars_gl = list(set(macro_base_cols + active_lags + selected_vars_gl))
        final_vars_gl_sorted = [v for v in macro_base_cols if v in final_vars_gl] + [v for v in active_lags if v in final_vars_gl] + sorted([v for v in gdelt_cols if v in final_vars_gl])
        df_gl, r2_gl, r2_adj_gl, lb_pval_gl = run_post_lasso_ols(X_current, y_centered, final_vars_gl_sorted)
        best_iteration_gl = (current_lag, final_vars_gl_sorted, df_gl, r2_gl, r2_adj_gl, lb_pval_gl, lbd_gl)

        # ---------------------------------------------------------
        # MODÈLE 2 : SPARSE GROUP LASSO (Simon et al.)
        # ---------------------------------------------------------
        coefs_sgl, lbd_sgl, alpha_sgl = run_cv_sparse_group_lasso(X_current, y_centered, groups_array)
        selected_vars_sgl = [current_cols[i] for i in range(len(current_cols)) if coefs_sgl[i] != 0]
        final_vars_sgl = list(set(macro_base_cols + active_lags + selected_vars_sgl))
        final_vars_sgl_sorted = [v for v in macro_base_cols if v in final_vars_sgl] + [v for v in active_lags if v in final_vars_sgl] + sorted([v for v in gdelt_cols if v in final_vars_sgl])
        df_sgl, r2_sgl, r2_adj_sgl, lb_pval_sgl = run_post_lasso_ols(X_current, y_centered, final_vars_sgl_sorted)
        best_iteration_sgl = (current_lag, final_vars_sgl_sorted, df_sgl, r2_sgl, r2_adj_sgl, lb_pval_sgl, lbd_sgl, alpha_sgl)

        # Règle d'arrêt : On s'arrête dès que le SGL capture toute la dynamique temporelle (Bruit blanc validé)
        if lb_pval_sgl >= 0.05:
            print(f'  ✓ Bruit blanc validé au Lag {current_lag} (SGL Ljung-Box P-value : {lb_pval_sgl:.4f})')
            break
        else:
            print(f'  ↻ Autocorrélation résiduelle au Lag {current_lag} (P-value : {lb_pval_sgl:.4f}). Ajout du lag {current_lag+1}...')

    # --- AFFICHAGE COMPARATIF DES RÉSULTATS OPTIMAUX ---
    print(f'\n' + '=' * 80)
    print(f' RÉSULTATS COMPARATIFS FINAUX : {region.upper()} (STABILISÉ À {best_iteration_sgl[0]} LAG(S))')
    print(f'=' * 80)

    # Affichage Group Lasso
    lag_gl, vars_gl, df_gl, r2_gl, r2_adj_gl, pval_gl, lbd_gl = best_iteration_gl
    gdelt_gl = [v for v in vars_gl if v in gdelt_cols]
    
    print(f'\n▶ MODÈLE 1 : GROUP LASSO (Yuan & Lin, 2006) - Sélection de secteurs entiers')
    print(f'  Tuning Data-Driven : Lambda = {lbd_gl:.4f} | Alpha forcé = 0.0')
    print(f'  Variables totales (OLS) : {len(vars_gl)} (dont {len(gdelt_gl)} GDELT)')
    print(f'  R-squared (Global/Adj) : {r2_gl:.4f} / {r2_adj_gl:.4f}')
    print(f'  Ljung-Box P-value : {pval_gl:.4f}')
    print("-" * 60)
    print(df_gl.to_string(index=False))

    # Affichage Sparse Group Lasso
    lag_sgl, vars_sgl, df_sgl, r2_sgl, r2_adj_sgl, pval_sgl, lbd_sgl, alpha_sgl = best_iteration_sgl
    gdelt_sgl = [v for v in vars_sgl if v in gdelt_cols]
    
    print(f'\n\n▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs')
    print(f'  Tuning Data-Driven : Lambda = {lbd_sgl:.4f} | Alpha = {alpha_sgl:.2f}')
    print(f'  Variables totales (OLS) : {len(vars_sgl)} (dont {len(gdelt_sgl)} GDELT)')
    print(f'  R-squared (Global/Adj) : {r2_sgl:.4f} / {r2_adj_sgl:.4f}')
    print(f'  Ljung-Box P-value : {pval_sgl:.4f}')
    print("-" * 60)
    print(df_sgl.to_string(index=False))

    final_results[region] = {
        'GL_Model': {'Vars': vars_gl, 'OLS': df_gl, 'R2_adj': r2_adj_gl},
        'SGL_Model': {'Vars': vars_sgl, 'OLS': df_sgl, 'R2_adj': r2_adj_sgl, 'Optimal_Alpha': alpha_sgl}
    }

    # ==========================================================================
    # EXPORT LATEX AUTOMATIQUE DES TABLEAUX DE RÉSULTATS
    # ==========================================================================
    
    import os
    # Création d'un dossier pour ranger vos tableaux propres
    output_dir = "./latex_tables"
    os.makedirs(output_dir, exist_ok=True)
    
    # 1. Export du tableau Group Lasso (GL)
    filename_gl = f"{output_dir}/OLS_GL_inflation{region}_no_macro.tex"
    # On arrondit à 4 décimales et on supprime l'index (0, 1, 2...) de Pandas
    latex_gl = df_gl.to_latex(index=False, float_format="%.4f", escape=True)
    with open(filename_gl, 'w') as f:
        f.write(latex_gl)
        
    # 2. Export du tableau Sparse Group Lasso (SGL)
    filename_sgl = f"{output_dir}/OLS_SGL_inflation{region}_no_macro.tex"
    latex_sgl = df_sgl.to_latex(index=False, float_format="%.4f", escape=True)
    with open(filename_sgl, 'w') as f:
        f.write(latex_sgl)
        
    # 3. BONUS : Export d'un tableau "Strict" (Uniquement les variables significatives p < 0.10)
    # Très utile pour le corps de votre mémoire (les tableaux complets iront en annexe)
    df_sgl_strict = df_sgl[df_sgl['P-value'] < 0.10]
    filename_sgl_strict = f"{output_dir}/OLS_SGL_inflation{region}_SIGNIFICANT_no_macro.tex"
    latex_sgl_strict = df_sgl_strict.to_latex(index=False, float_format="%.4f", escape=True)
    with open(filename_sgl_strict, 'w') as f:
        f.write(latex_sgl_strict)
        
    print(f"  📝 Tableaux LaTeX exportés avec succès dans le dossier '{output_dir}'.")
# Out:
# ================================================================================
#  PIPELINE ACADÉMIQUE : FRANCE (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
# 💾 Données Macro sauvegardées : data/economic_data/macro_vintage_coreinflation_France_20260828.csv
#   ✓ Bruit blanc validé au Lag 1 (SGL Ljung-Box P-value : 0.0526)
#
# ================================================================================
#  RÉSULTATS COMPARATIFS FINAUX : FRANCE (STABILISÉ À 1 LAG(S))
# ================================================================================
#
# ▶ MODÈLE 1 : GROUP LASSO (Yuan & Lin, 2006) - Sélection de secteurs entiers
#   Tuning Data-Driven : Lambda = 0.0091 | Alpha forcé = 0.0
#   Variables totales (OLS) : 65 (dont 64 GDELT)
#   R-squared (Global/Adj) : 0.7312 / 0.3817
#   Ljung-Box P-value : 0.0660
# ------------------------------------------------------------
#                                    Variable   Coefficient  P-value  CI_Lower  CI_Upper
#                                   Intercept -3.426079e-17 1.000000 -0.065008  0.065008
#                              inflation_lag1 -2.144338e-03 0.968717 -0.111420  0.107131
#         att_weight_agriculture_agribusiness  6.845677e-02 0.649550 -0.232325  0.369239
#        att_weight_agriculture_climate_risks  2.046569e-01 0.015301  0.040978  0.368336
#          att_weight_agriculture_food_prices  1.421765e-01 0.127857 -0.042264  0.326617
#  att_weight_agriculture_infrastructure_tech  6.420258e-02 0.233752 -0.042785  0.171190
#           att_weight_agriculture_regulation -1.073162e-01 0.035452 -0.207029 -0.007603
#          att_weight_agriculture_rural_labor -1.133590e-01 0.328579 -0.344135  0.117417
#                att_weight_agriculture_water  3.641670e-02 0.500077 -0.071260  0.144093
#              att_weight_tech_infrastructure  1.860897e-01 0.176155 -0.085927  0.458107
#                  att_weight_tech_innovation  1.368008e-02 0.765084 -0.077532  0.104893
#                  att_weight_tech_regulation -6.316026e-02 0.028532 -0.119452 -0.006868
#                       att_weight_tech_risks -5.543229e-03 0.841109 -0.060644  0.049557
#                    att_weight_tech_software -2.407293e-02 0.493854 -0.094057  0.045911
#                  att_weight_transport_costs  1.684181e-02 0.619092 -0.050607  0.084291
#         att_weight_transport_infrastructure  4.383847e-03 0.897414 -0.063381  0.072149
#    att_weight_transport_international_trade -4.679302e-02 0.478967 -0.178241  0.084655
#              att_weight_transport_logistics -4.917028e-02 0.128926 -0.113070  0.014730
#                  att_weight_transport_modes  3.613276e-02 0.305235 -0.033788  0.106054
#             att_weight_transport_regulation  1.865055e-02 0.782155 -0.115739  0.153040
#   📝 Tableaux LaTeX exportés avec succès dans le dossier './latex_tables'.

# %% [markdown]
# ### 3. Robustness - no group macro - core inflation

# %%
# ==============================================================================
# CELLULE 3 : CONFIGURATION DES MODÈLES (ARX - CORE INFLATION)
# ==============================================================================
CONFIG_REGIONS = {
    'France': {
        'macro_vars': {
            'inflation': {'ticker': 'CPGRLE01FRM659N', 'transform': 'pct_change'}
        },
        'deseasonalize_y': True,
    },
    'US': {
        'macro_vars': {
            'inflation': {'ticker': 'CPILFESL', 'transform': 'pct_change'}
        },
        'deseasonalize_y': False,
    },
    'UK': {
        'macro_vars': {
            'inflation': {'ticker': 'CPGRLE01GBM659N', 'transform': 'pct_change'}
        },
        'deseasonalize_y': True,
    },
}

# %%
# ==============================================================================
# CELLULE 4 : EXÉCUTION DU PIPELINE COMPLET AVEC COMPARAISON GL vs SGL
# ==============================================================================
final_results = {}

for region, config in CONFIG_REGIONS.items():
    print(f'\n' + '=' * 80)
    print(f' PIPELINE ACADÉMIQUE : {region.upper()} (RECHERCHE DYNAMIQUE DE LAGS)')
    print(f'================================================================================')

    # 1. Préparation des données (Tronquées pour garantir un 'n' constant)
    df_macro = fetch_and_prep_macro_dynamic(config, START_DATE, END_DATE, region=region)
    df_macro = df_macro[df_macro.index >= MIN_INDEX_DATE]

    # --- NOUVEAU : SAUVEGARDE VINTAGE ---
    # vintage_path = Path(f'./data/economic_data/macro_vintage_coreinflation_{region}_{datetime.now().strftime("%Y%m%d")}.csv')
    # df_macro.to_csv(vintage_path)
    # print(f'💾 Données Macro sauvegardées : {vintage_path}')
    # ------------------------------------

    cols_gdelt = get_filtered_gdelt_cols(df_geo)
    df_gdelt_raw = df_geo[df_geo['region_key'] == region].set_index('period')[cols_gdelt]
    if 'sent_cont_weight_finance_international_orgs' in df_gdelt_raw.columns:
        df_gdelt_raw = df_gdelt_raw.drop(columns=['sent_cont_weight_finance_international_orgs'])

    df_gdelt_stat, diff_count = strict_stationarize(df_gdelt_raw)
    df_final = df_gdelt_stat.join(df_macro, how='inner')
    y_raw = df_final['inflation']

    y_corr = (y_raw - seasonal_decompose(y_raw, model='additive', period=12).seasonal).dropna() if config['deseasonalize_y'] else y_raw.dropna()
    X_full = df_final.drop(columns=['inflation'])
    y_corr, X_contemp = y_corr.align(X_full, join='inner')

    y_centered = y_corr - y_corr.mean()
    X_scaled_full = pd.DataFrame(StandardScaler().fit_transform(X_contemp), columns=X_contemp.columns, index=X_contemp.index)

    macro_base_cols = [c for c in X_scaled_full.columns if c in df_macro.columns and not c.startswith('inflation_lag') and c != 'inflation']
    gdelt_cols = [c for c in X_scaled_full.columns if c in cols_gdelt]

    # --- RECHERCHE DYNAMIQUE DU NOMBRE DE LAGS ---
    max_lags_to_test = 12
    best_iteration_gl = None
    best_iteration_sgl = None

    for current_lag in range(1, max_lags_to_test + 1):
        active_lags = [f'inflation_lag{i}' for i in range(1, current_lag + 1)]
        current_cols = macro_base_cols + active_lags + gdelt_cols
        X_current = X_scaled_full[current_cols]
        
        # Définition des groupes
        groups, group_map, current_group_id = [], {}, 2
        for var in current_cols:
            if var in macro_base_cols: groups.append(0) 
            elif var in active_lags: groups.append(1) 
            else:
                sector = var.split('_')[2]
                if sector not in group_map:
                    group_map[sector], current_group_id = current_group_id, current_group_id + 1
                groups.append(group_map[sector])
        groups_array = np.array(groups)

        # ---------------------------------------------------------
        # MODÈLE 1 : GROUP LASSO (Yuan & Lin)
        # ---------------------------------------------------------
        coefs_gl, lbd_gl = run_cv_group_lasso(X_current, y_centered, groups_array)
        selected_vars_gl = [current_cols[i] for i in range(len(current_cols)) if coefs_gl[i] != 0]
        final_vars_gl = list(set(macro_base_cols + active_lags + selected_vars_gl))
        final_vars_gl_sorted = [v for v in macro_base_cols if v in final_vars_gl] + [v for v in active_lags if v in final_vars_gl] + sorted([v for v in gdelt_cols if v in final_vars_gl])
        df_gl, r2_gl, r2_adj_gl, lb_pval_gl = run_post_lasso_ols(X_current, y_centered, final_vars_gl_sorted)
        best_iteration_gl = (current_lag, final_vars_gl_sorted, df_gl, r2_gl, r2_adj_gl, lb_pval_gl, lbd_gl)

        # ---------------------------------------------------------
        # MODÈLE 2 : SPARSE GROUP LASSO (Simon et al.)
        # ---------------------------------------------------------
        coefs_sgl, lbd_sgl, alpha_sgl = run_cv_sparse_group_lasso(X_current, y_centered, groups_array)
        selected_vars_sgl = [current_cols[i] for i in range(len(current_cols)) if coefs_sgl[i] != 0]
        final_vars_sgl = list(set(macro_base_cols + active_lags + selected_vars_sgl))
        final_vars_sgl_sorted = [v for v in macro_base_cols if v in final_vars_sgl] + [v for v in active_lags if v in final_vars_sgl] + sorted([v for v in gdelt_cols if v in final_vars_sgl])
        df_sgl, r2_sgl, r2_adj_sgl, lb_pval_sgl = run_post_lasso_ols(X_current, y_centered, final_vars_sgl_sorted)
        best_iteration_sgl = (current_lag, final_vars_sgl_sorted, df_sgl, r2_sgl, r2_adj_sgl, lb_pval_sgl, lbd_sgl, alpha_sgl)

        # Règle d'arrêt : On s'arrête dès que le SGL capture toute la dynamique temporelle (Bruit blanc validé)
        if lb_pval_sgl >= 0.05:
            print(f'  ✓ Bruit blanc validé au Lag {current_lag} (SGL Ljung-Box P-value : {lb_pval_sgl:.4f})')
            break
        else:
            print(f'  ↻ Autocorrélation résiduelle au Lag {current_lag} (P-value : {lb_pval_sgl:.4f}). Ajout du lag {current_lag+1}...')

    # --- AFFICHAGE COMPARATIF DES RÉSULTATS OPTIMAUX ---
    print(f'\n' + '=' * 80)
    print(f' RÉSULTATS COMPARATIFS FINAUX : {region.upper()} (STABILISÉ À {best_iteration_sgl[0]} LAG(S))')
    print(f'=' * 80)

    # Affichage Group Lasso
    lag_gl, vars_gl, df_gl, r2_gl, r2_adj_gl, pval_gl, lbd_gl = best_iteration_gl
    gdelt_gl = [v for v in vars_gl if v in gdelt_cols]
    
    print(f'\n▶ MODÈLE 1 : GROUP LASSO (Yuan & Lin, 2006) - Sélection de secteurs entiers')
    print(f'  Tuning Data-Driven : Lambda = {lbd_gl:.4f} | Alpha forcé = 0.0')
    print(f'  Variables totales (OLS) : {len(vars_gl)} (dont {len(gdelt_gl)} GDELT)')
    print(f'  R-squared (Global/Adj) : {r2_gl:.4f} / {r2_adj_gl:.4f}')
    print(f'  Ljung-Box P-value : {pval_gl:.4f}')
    print("-" * 60)
    print(df_gl.to_string(index=False))

    # Affichage Sparse Group Lasso
    lag_sgl, vars_sgl, df_sgl, r2_sgl, r2_adj_sgl, pval_sgl, lbd_sgl, alpha_sgl = best_iteration_sgl
    gdelt_sgl = [v for v in vars_sgl if v in gdelt_cols]
    
    print(f'\n\n▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs')
    print(f'  Tuning Data-Driven : Lambda = {lbd_sgl:.4f} | Alpha = {alpha_sgl:.2f}')
    print(f'  Variables totales (OLS) : {len(vars_sgl)} (dont {len(gdelt_sgl)} GDELT)')
    print(f'  R-squared (Global/Adj) : {r2_sgl:.4f} / {r2_adj_sgl:.4f}')
    print(f'  Ljung-Box P-value : {pval_sgl:.4f}')
    print("-" * 60)
    print(df_sgl.to_string(index=False))

    final_results[region] = {
        'GL_Model': {'Vars': vars_gl, 'OLS': df_gl, 'R2_adj': r2_adj_gl},
        'SGL_Model': {'Vars': vars_sgl, 'OLS': df_sgl, 'R2_adj': r2_adj_sgl, 'Optimal_Alpha': alpha_sgl}
    }

    # ==========================================================================
    # EXPORT LATEX AUTOMATIQUE DES TABLEAUX DE RÉSULTATS
    # ==========================================================================
    
    import os
    # Création d'un dossier pour ranger vos tableaux propres
    output_dir = "./latex_tables"
    os.makedirs(output_dir, exist_ok=True)
    
    # 1. Export du tableau Group Lasso (GL)
    filename_gl = f"{output_dir}/OLS_GL_core_inflation{region}_no_macro.tex"
    # On arrondit à 4 décimales et on supprime l'index (0, 1, 2...) de Pandas
    latex_gl = df_gl.to_latex(index=False, float_format="%.4f", escape=True)
    with open(filename_gl, 'w') as f:
        f.write(latex_gl)
        
    # 2. Export du tableau Sparse Group Lasso (SGL)
    filename_sgl = f"{output_dir}/OLS_SGL_core_inflation{region}_no_macro.tex"
    latex_sgl = df_sgl.to_latex(index=False, float_format="%.4f", escape=True)
    with open(filename_sgl, 'w') as f:
        f.write(latex_sgl)
        
    # 3. BONUS : Export d'un tableau "Strict" (Uniquement les variables significatives p < 0.10)
    # Très utile pour le corps de votre mémoire (les tableaux complets iront en annexe)
    df_sgl_strict = df_sgl[df_sgl['P-value'] < 0.10]
    filename_sgl_strict = f"{output_dir}/OLS_SGL_core_inflation{region}_SIGNIFICANT_no_macro.tex"
    latex_sgl_strict = df_sgl_strict.to_latex(index=False, float_format="%.4f", escape=True)
    with open(filename_sgl_strict, 'w') as f:
        f.write(latex_sgl_strict)
        
    print(f"  📝 Tableaux LaTeX exportés avec succès dans le dossier '{output_dir}'.")
# Out:
# ================================================================================
#  PIPELINE ACADÉMIQUE : FRANCE (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ✓ Bruit blanc validé au Lag 1 (SGL Ljung-Box P-value : 0
#
#
# ▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs
#   Tuning Data-Driven : Lambda = 0.1000 | Alpha = 0.05
#   Variables totales (OLS) : 69 (dont 68 GDELT)
#   R-squared (Global/Adj) : 0.8220 / 0.4383
#   Ljung-Box P-value : 0.1510
# ------------------------------------------------------------
#                                    Variable   Coefficient  P-value    CI_Lower   CI_Upper
#                                   Intercept  7.396861e-14 1.000000  -10.172770  10.172770
#                              inflation_lag1  1.379404e+01 0.282458  -11.907556  39.495639
#         att_weight_agriculture_agribusiness -5.713785e+01 0.031585 -108.907033  -5.368673
#        att_weight_agriculture_climate_risks  1.352098e+01 0.358535  -16.043483  43.085443
#          att_weight_agriculture_food_prices  6.531313e+01 0.000587   30.442794 100.183470
#  att_weight_agriculture_infrastructure_tech -1.218686e+01 0.160929  -29.483106   5.109394
#           att_weight_agriculture_regulation -3.160033e+01 0.003163  -51.766259 -11.434405
#          att_weight_agriculture_rural_labor  4.054326e+01 0.049192    0.152364  80.934165
#                att_weight_agriculture_water -2.287171e+01 0.030016  -43.386410  -2.357000
#           att_weight_commodities_extraction  1.375746e+01 0.733601  -67.865424  95.380339
#        att_weight_commodities_market_prices -1.582758e+01 0.204156  -40.698842   9.043688
#            att_weight_commodities_materials -4.699118e+01 0.240057 -126.948654  32.966301
#           att_weight_commodities_regulation -1.085844e+01 0.227095  -28.817993   7.101110
#                att_weight_commodities_risks  9.435285e+00 0.255142   -7.151059  26.021629
#            att_weight_conflict_civil_unrest -3.035593e+01 0.025226  -56.691507  -4.020356
#                   att_weight_conflict_peace  1.105472e+01 0.393451  -14.975897  37.085340
#               att_weight_conflict_terrorism  2.235870e+01 0.120130   -6.162053  50.879455
#                     att_weight_conflict_war  2.661690e+01 0.133776   -8.624958  61.858765
#                 att_weight_conflict_weapons -1.795615e+00 0.874839  -24.830743  21.239513
#        att_weight_consumer_goods_automotive  7.943662e+00 0.327733   -8.336528  24.223852
#        att_weight_consumer_goods_e_commerce -1.604640e+01 0.230049  -42.759617  10.666816
# att_weight_consumer_goods_textile_cosmetics -6.788701e+00 0.459873  -25.273444  11.696042
#                    att_weight_energy_fossil -5.761874e+00 0.554104  -25.390966  13.867219
#           att_weight_energy_infrastructures  2.863573e+01 0.320240  -29.136199  86.407662
#                   att_weight_energy_nuclear -1.694368e+01 0.537291  -72.286023  38.398662
#                att_weight_energy_regulation  1.564790e+01 0.106545   -3.545181  34.840984
#                att_weight_energy_renewables  4.271680e+00 0.733137  -21.026306  29.569667
#                     att_weight_energy_risks -4.833554e-02 0.995503  -17.381586  17.284915
#                    att_weight_finance_banks  1.797083e+01 0.274016  -14.919237  50.860901
#            att_weight_finance_central_banks -2.437280e+01 0.065963  -50.450048   1.704439
#                   att_weight_finance_credit -5.278394e+01 0.013489  -93.896007 -11.671865
#        att_weight_finance_financial_markets  5.827694e+00 0.664544  -21.292752  32.948139
#             att_weight_finance_private_debt -7.229212e+01 0.017213 -130.894513 -13.689727
#               att_weight_finance_regulation  3.104200e+00 0.795242  -21.058758  27.267158
#           att_weight_finance_sovereign_debt  3.615968e+01 0.012396    8.368332  63.951034
#            att_weight_finance_systemic_risk  4.741343e+00 0.868543  -53.143970  62.626655
#      att_weight_growth_growth_and_recession -1.399003e+01 0.279903  -39.916152  11.936091
#           att_weight_health_care_facilities  5.631223e-01 0.981671  -48.977119  50.103364
#                  att_weight_health_diseases  1.822528e+01 0.498195  -35.959610  72.410178
# att_weight_health_epidemics_and_emergencies  4.605727e+01 0.205833  -26.592060 118.706595
#        att_weight_health_general_and_policy -1.083171e+02 0.007652 -185.824468 -30.809741
#       att_weight_health_pharma_and_med_tech  2.869493e+01 0.066171   -2.031625  59.421479
#               att_weight_industry_factories  8.371255e+00 0.513198  -17.416564  34.159074
#               att_weight_industry_logistics -3.145746e+01 0.003294  -51.630259 -11.284670
#            att_weight_industry_productivity -1.572278e+01 0.132162  -36.450785   5.005230
#              att_weight_industry_regulation  9.704380e+00 0.401512  -13.544695  32.953456
#                   att_weight_industry_risks  2.879819e-01 0.970977  -15.709071  16.285035
#           att_weight_industry_supply_chains  1.735308e+01 0.094280   -3.144805  37.850961
#              att_weight_politics_corruption  3.360054e+01 0.012487    7.746637  59.454439
#               att_weight_politics_elections  1.171855e+01 0.353830  -13.652031  37.089135
# att_weight_politics_institutions_governance -3.520180e+01 0.069599  -73.394021   2.990424
#       att_weight_politics_political_parties  2.675603e+01 0.059067   -1.086764  54.598833
#         att_weight_real_estate_construction  1.018424e+00 0.919482  -19.341876  21.378725
#            att_weight_real_estate_financing -8.782570e+00 0.481120  -33.879215  16.314074
#               att_weight_real_estate_market  1.016267e+01 0.412188  -14.750928  35.076273
#           att_weight_real_estate_regulation  2.928713e+01 0.014257    6.272635  52.301629
#             att_weight_real_estate_urbanism  1.888336e+01 0.143909   -6.791974  44.558699
#                att_weight_tech_gov_strategy -7.977696e+01 0.011580 -140.447874 -19.106050
#              att_weight_tech_infrastructure  3.749101e+01 0.149103  -14.167362  89.149387
#                  att_weight_tech_innovation -4.663513e+01 0.008335  -80.413206 -12.857060
#                  att_weight_tech_regulation -2.017465e+01 0.018599  -36.746330  -3.602973
#                       att_weight_tech_risks  2.662334e+01 0.009538    6.958715  46.287971
#                    att_weight_tech_software -5.860748e+00 0.601029  -28.463456  16.741961
#                  att_weight_transport_costs  1.219679e+01 0.131974   -3.874660  28.268241
#         att_weight_transport_infrastructure  3.181283e+01 0.027285    3.801067  59.824595
#    att_weight_transport_international_trade  2.786961e+01 0.011065    6.821440  48.917790
#              att_weight_transport_logistics -1.425145e+01 0.135190  -33.191997   4.689101
#                  att_weight_transport_modes  6.255962e+00 0.704928  -27.095683  39.607606
#             att_weight_transport_regulation -2.934017e+01 0.011557  -51.646840  -7.033500
#                  att_weight_transport_risks -3.593606e+01 0.004170  -59.658824 -12.213298
#   📝 Tableaux LaTeX exportés avec succès dans le dossier './latex_tables'.
#
# ================================================================================
#  PIPELINE ACADÉMIQUE : US (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ✓ Bruit blanc validé au Lag 1 (SGL Ljung-Box P-value : 0.7110)
#
# ================================================================================
#  RÉSULTATS COMPARATIFS FINAUX : US (STABILISÉ À 1 LAG(S))
# ================================================================================
#
# ▶ MODÈLE 1 : GROUP LASSO (Yuan & Lin, 2006) - Sélection de secteurs entiers
#   Tuning Data-Driven : Lambda = 0.0045 | Alpha forcé = 0.0
#   Variables totales (OLS) : 35 (dont 34 GDELT)
#   R-squared (Global/Adj) : 0.7142 / 0.6031
#   Ljung-Box P-value : 0.6054
# ------------------------------------------------------------
#                                    Variable   Coefficient  P-value  CI_Lower  CI_Upper
#                                   Interc