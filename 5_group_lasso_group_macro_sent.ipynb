# %% [markdown]
# ### 0. Setup

# %%
# ==============================================================================
# CELLULE 1 : SETUP, PARAMÈTRES GLOBAUX ET CHARGEMENT DES DONNÉES GDELT
# ==============================================================================
import csv
from datetime import datetime
import io
from pathlib import Path
import warnings
from group_lasso import GroupLasso
import numpy as np
import pandas as pd
import pandas_datareader.data as web
import requests
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

warnings.filterwarnings('ignore')

# --- PARAMÈTRES GLOBAUX ---
START_DATE = datetime(2013, 1, 1)
END_DATE = datetime(2026, 7, 1)
MIN_INDEX_DATE = '2015-03-01'

# --- CHARGEMENT GDELT (FRANCE / US / UK) ---
dir_geo = Path('./data/indicators_geo_monthly')
dir_geo_uk = Path('./data/indicators_geo_monthly_UK')

# 1. Chargement France / US
if dir_geo.exists():
  files_geo = list(dir_geo.glob('*.parquet'))
  df_geo_main = pd.concat(
      [pd.read_parquet(f) for f in files_geo], ignore_index=True
  )
else:
  raise FileNotFoundError('⚠ Dossier ./data/indicators_geo_monthly introuvable.')

# 2. Chargement UK
if dir_geo_uk.exists():
  files_uk = list(dir_geo_uk.glob('*.parquet'))
  if len(files_uk) > 0:
    df_geo_uk = pd.concat(
        [pd.read_parquet(f) for f in files_uk], ignore_index=True
    )
    df_geo_uk['region_key'] = 'UK'
  else:
    df_geo_uk = pd.DataFrame()
else:
  df_geo_uk = pd.DataFrame()

# 3. Fusion finale
df_geo = pd.concat([df_geo_main, df_geo_uk], ignore_index=True)

if 'region_key' in df_geo.columns:
  df_geo = (
      df_geo.groupby(['period', 'region_key']).max().reset_index().copy()
  )
  df_geo['period'] = pd.to_datetime(df_geo['period'])
  print(f'✓ Base RÉGIONALE GDELT chargée.')
  print(
      f"✓ Régions trouvées en mémoire : {df_geo['region_key'].unique().tolist()}"
  )
  print(f'✓ Lignes totales : {len(df_geo)}')
else:
  print("⚠ ERREUR CRITIQUE : La colonne 'region_key' est absente.")
# Out:
# ✓ Base RÉGIONALE GDELT chargée.
# ✓ Régions trouvées en mémoire : ['France', 'UK', 'US']
# ✓ Lignes totales : 411

# %% [markdown]
# ### Functions

# %%
# ==============================================================================
# CELLULE 2 : LIBRAIRIE DES FONCTIONS ÉCONOMÉTRIQUES ET DE PRÉPARATION
# ==============================================================================

def get_filtered_gdelt_cols(df):
    """ÉTAPE 0 : Ne conserve que les sous-variables des 8 secteurs cibles."""
    allowed_prefixes = [
        'sent_bin_weight_agriculture_', 'sent_bin_weight_commodities_',
        'sent_bin_weight_energy_', 'sent_bin_weight_finance_',
        'sent_bin_weight_industry_' # , 'sent_bin_weight_real_estate_',
        # 'sent_bin_weight_tech_', 'sent_bin_weight_transport_' 
        # ,'sent_bin_weight_growth_', 'sent_bin_weight_conflict_', 'sent_bin_weight_politics_',
        # 'sent_bin_weight_health_', 'sent_bin_weight_consumer_goods_'
    ]
    return [col for col in df.columns if any(str(col).startswith(prefix) for prefix in allowed_prefixes)]

def strict_stationarize(df):
    """ÉTAPE 1 : Test ADF -> Différence -> Winsorisation si nécessaire."""
    df_stat = df.copy()
    diff_count = 0
    for col in df_stat.columns:
        valid_data = df_stat[col].dropna()
        if len(valid_data) > 10:
            if adfuller(valid_data, autolag='AIC')[1] >= 0.05:
                df_stat[col] = df_stat[col].diff()
                diff_count += 1
                valid_data_diff = df_stat[col].dropna()
                if len(valid_data_diff) > 10 and adfuller(valid_data_diff, autolag='AIC')[1] >= 0.05:
                    p95 = valid_data_diff.quantile(0.95)
                    p05 = valid_data_diff.quantile(0.05)
                    df_stat[col] = df_stat[col].clip(lower=p05, upper=p95)
    return df_stat.dropna(), diff_count

def fetch_and_prep_macro_dynamic(region_config, start_date, end_date, region=None):
    """Télécharge la macro et génère 12 lags (pour fixer la taille de l'échantillon)."""
    macro_config = region_config['macro_vars']
    fred_tickers = {info['ticker']: var_name for var_name, info in macro_config.items() 
                    if not (region == 'France' and var_name == 'money') and 
                    not (region == 'UK' and info['ticker'] in ['IUMABEDR', 'LPMBD93', 'XUDLUSS'])}
    
    df = web.DataReader(list(fred_tickers.keys()), 'fred', start_date, end_date).rename(columns=fred_tickers).resample('MS').mean() if fred_tickers else pd.DataFrame()

    if region == 'France' and 'money' in macro_config:
        try:
            df_ecb = pd.read_csv('https://data-api.ecb.europa.eu/service/data/BSI/M.U2.Y.V.M30.X.1.U2.2300.Z01.E?format=csvdata')
            df_ecb['period'] = pd.to_datetime(df_ecb['TIME_PERIOD'])
            df_ecb = df_ecb.set_index('period').rename(columns={'OBS_VALUE': 'money'})[['money']].resample('MS').mean()
            df = df.join(df_ecb, how='left') if not df.empty else df_ecb
        except Exception as e: print(f'⚠ Erreur BCE: {e}')

    if region == 'UK':
        df_local_all = pd.DataFrame()
        for var_name, info in macro_config.items():
            if info['ticker'] in ['IUMABEDR', 'LPMBD93', 'XUDLUSS']:
                ticker = info['ticker']
                file_path = f'data/BoE/{ticker}.csv'
                if Path(file_path).exists():
                    df_temp = pd.read_csv(file_path, encoding='ISO-8859-1')
                    df_temp['period'] = pd.to_datetime(df_temp.iloc[:, 0], errors='coerce')
                    df_temp = df_temp.dropna(subset=['period']).set_index('period')
                    val_col = next((c for c in df_temp.columns if ticker in c), None)
                    if val_col:
                        if df_temp[val_col].dtype == object:
                            df_temp[val_col] = df_temp[val_col].astype(str).str.replace(',', '', regex=False).str.strip()
                        series = pd.to_numeric(df_temp[val_col], errors='coerce').rename(var_name).resample('MS').mean()
                        df_local_all = series.to_frame() if df_local_all.empty else df_local_all.join(series, how='outer')
        if not df_local_all.empty: df = df.join(df_local_all, how='outer') if not df.empty else df_local_all

    final_cols = []
    for var_name, info in macro_config.items():
        if var_name in df.columns:
            if info['transform'] == 'pct_change': df[var_name] = df[var_name].pct_change() * 100
            elif info['transform'] == 'diff': df[var_name] = df[var_name].diff()
            final_cols.append(var_name)

    for lag in range(1, 13):
        lag_name = f'inflation_lag{lag}'
        df[lag_name] = df['inflation'].shift(lag)
        final_cols.append(lag_name)

    return df[(df.index >= start_date) & (df.index <= end_date)][final_cols].dropna()

def run_cv_group_lasso(X, y, groups):
    """MODÈLE 1 : Group Lasso (Yuan & Lin, 2006) - Alpha forcé à 0 (Pénalité de groupe pure)."""
    tscv = TimeSeriesSplit(n_splits=5, gap=3) 
    lambdas = np.logspace(-4, -1, 50)
    best_mse, best_lbd = np.inf, None

    for lbd in lambdas:
        gl = GroupLasso(groups=groups, l1_reg=0.0, group_reg=lbd, fit_intercept=False, n_iter=1000, supress_warning=True)
        mse_scores = []
        for train_idx, test_idx in tscv.split(X):
            gl.fit(X.iloc[train_idx].values, y.iloc[train_idx].values.reshape(-1, 1))
            mse_scores.append(np.mean((y.iloc[test_idx].values - gl.predict(X.iloc[test_idx].values).flatten()) ** 2))
        
        if np.mean(mse_scores) < best_mse:
            best_mse, best_lbd = np.mean(mse_scores), lbd

    final_gl = GroupLasso(groups=groups, l1_reg=0.0, group_reg=best_lbd, fit_intercept=False, n_iter=5000, supress_warning=True)
    final_gl.fit(X.values, y.values.reshape(-1, 1))
    return final_gl.coef_.flatten(), best_lbd

def run_cv_sparse_group_lasso(X, y, groups):
    """MODÈLE 2 : Sparse Group Lasso (Simon et al., 2013) - Tuning de Lambda ET Alpha."""
    tscv = TimeSeriesSplit(n_splits=5, gap=3) 
    lambdas = np.logspace(-4, -1, 50)
    alphas = [0.50, 0.75, 0.95] # Grille Data-Driven
    
    best_mse, best_lbd, best_alpha = np.inf, None, None

    for alpha in alphas:
        for lbd in lambdas:
            sgl = GroupLasso(groups=groups, l1_reg=lbd * alpha, group_reg=lbd * (1 - alpha), fit_intercept=False, n_iter=1000, supress_warning=True)
            mse_scores = []
            for train_idx, test_idx in tscv.split(X):
                sgl.fit(X.iloc[train_idx].values, y.iloc[train_idx].values.reshape(-1, 1))
                mse_scores.append(np.mean((y.iloc[test_idx].values - sgl.predict(X.iloc[test_idx].values).flatten()) ** 2))
            
            if np.mean(mse_scores) < best_mse:
                best_mse, best_lbd, best_alpha = np.mean(mse_scores), lbd, alpha

    final_sgl = GroupLasso(groups=groups, l1_reg=best_lbd * best_alpha, group_reg=best_lbd * (1 - best_alpha), fit_intercept=False, n_iter=5000, supress_warning=True)
    final_sgl.fit(X.values, y.values.reshape(-1, 1))
    return final_sgl.coef_.flatten(), best_lbd, best_alpha

def run_post_lasso_ols(X, y, selected_features):
    """Inférence OLS Post-Selection et diagnostic de Ljung-Box."""
    X_selected_with_const = sm.add_constant(X[selected_features])
    results = sm.OLS(y.values, X_selected_with_const.values).fit()

    post_lasso_df = pd.DataFrame({
        'Variable': ['Intercept'] + selected_features,
        'Coefficient': results.params,
        'P-value': results.pvalues,
        'CI_Lower': results.conf_int()[:, 0],
        'CI_Upper': results.conf_int()[:, 1],
    })
    
    lb_pval = acorr_ljungbox(results.resid, lags=[12], return_df=True)['lb_pvalue'].values[0]
    return post_lasso_df, results.rsquared, results.rsquared_adj, lb_pval

# %% [markdown]
# ### 1. Inflation

# %%
CONFIG_REGIONS = {
    'France': {
        'macro_vars': {
            'inflation': {'ticker': 'CP0000FRM086NEST', 'transform': 'pct_change'},
            'rate': {'ticker': 'IRSTCI01FRM156N', 'transform': 'diff'},
            'unemp': {'ticker': 'LRHUTTTTFRM156S', 'transform': 'diff'},
            'indpro': {'ticker': 'FRAPRINTO01GYSAM', 'transform': 'pct_change'},
            'money': {'ticker': 'BCE_M3_API', 'transform': 'none'},
            'fx': {'ticker': 'DEXUSEU', 'transform': 'pct_change'},
            'mich': {'ticker': 'CSINFT02FRM460S', 'transform': 'diff'},
            'oil': {'ticker': 'DCOILBRENTEU', 'transform': 'pct_change'},
        },
        'deseasonalize_y': True,
    },
    'US': {
        'macro_vars': {
            'inflation': {'ticker': 'CPIAUCSL', 'transform': 'pct_change'},
            'rate': {'ticker': 'FEDFUNDS', 'transform': 'diff'},
            'unemp': {'ticker': 'UNRATE', 'transform': 'diff'},
            'indpro': {'ticker': 'INDPRO', 'transform': 'pct_change'},
            'money': {'ticker': 'M2SL', 'transform': 'pct_change'},
            'fx': {'ticker': 'DEXUSEU', 'transform': 'pct_change'},
            'mich': {'ticker': 'MICH', 'transform': 'diff'},
            'oil': {'ticker': 'WTISPLC', 'transform': 'pct_change'},
        },
        'deseasonalize_y': False,
    },
    'UK': {
        'macro_vars': {
            'inflation': {'ticker': 'GBRCPIALLMINMEI', 'transform': 'pct_change'},
            'rate': {'ticker': 'IUMABEDR', 'transform': 'diff'},
            'unemp': {'ticker': 'LRHUTTTTGBM156S', 'transform': 'diff'},
            'indpro': {'ticker': 'GBRPRINTO01GYSAM', 'transform': 'pct_change'},
            'money': {'ticker': 'LPMBD93', 'transform': 'pct_change'},
            'fx': {'ticker': 'XUDLUSS', 'transform': 'pct_change'},
            'oil': {'ticker': 'DCOILBRENTEU', 'transform': 'pct_change'},
        },
        'deseasonalize_y': True,
    },
}

# %%
final_results = {}

for region, config in CONFIG_REGIONS.items():
    print(f'\n' + '=' * 80)
    print(f' PIPELINE ACADÉMIQUE : {region.upper()} (RECHERCHE DYNAMIQUE DE LAGS)')
    print(f'================================================================================')

    df_macro = fetch_and_prep_macro_dynamic(config, START_DATE, END_DATE, region=region)
    df_macro = df_macro[df_macro.index >= MIN_INDEX_DATE]

    cols_gdelt = get_filtered_gdelt_cols(df_geo)
    df_gdelt_raw = df_geo[df_geo['region_key'] == region].set_index('period')[cols_gdelt]
    if 'sent_cont_weight_finance_international_orgs' in df_gdelt_raw.columns:
        df_gdelt_raw = df_gdelt_raw.drop(columns=['sent_cont_weight_finance_international_orgs'])

    df_gdelt_stat, diff_count = strict_stationarize(df_gdelt_raw)
    df_final = df_gdelt_stat.join(df_macro, how='inner')
    y_raw = df_final['inflation']

    y_corr = (y_raw - seasonal_decompose(y_raw, model='additive', period=12).seasonal).dropna() if config['deseasonalize_y'] else y_raw.dropna()
    X_full = df_final.drop(columns=['inflation'])
    y_corr, X_contemp = y_corr.align(X_full, join='inner')

    y_centered = y_corr - y_corr.mean()
    X_scaled_full = pd.DataFrame(StandardScaler().fit_transform(X_contemp), columns=X_contemp.columns, index=X_contemp.index)

    macro_base_cols = [c for c in X_scaled_full.columns if c in df_macro.columns and not c.startswith('inflation_lag') and c != 'inflation']
    gdelt_cols = [c for c in X_scaled_full.columns if c in cols_gdelt]

    # --- RECHERCHE DYNAMIQUE DU NOMBRE DE LAGS ---
    max_lags_to_test = 12
    best_iteration_gl = None
    best_iteration_sgl = None

    for current_lag in range(1, max_lags_to_test + 1):
        active_lags = [f'inflation_lag{i}' for i in range(1, current_lag + 1)]
        current_cols = macro_base_cols + active_lags + gdelt_cols
        X_current = X_scaled_full[current_cols]
        
        groups, group_map, current_group_id = [], {}, 2
        for var in current_cols:
            if var in macro_base_cols: groups.append(0) 
            elif var in active_lags: groups.append(1) 
            else:
                sector = var.split('_')[2]
                if sector not in group_map:
                    group_map[sector], current_group_id = current_group_id, current_group_id + 1
                groups.append(group_map[sector])
        groups_array = np.array(groups)

        # # ---------------------------------------------------------
        # # MODÈLE 1 : GROUP LASSO (Yuan & Lin)
        # # ---------------------------------------------------------
        # coefs_gl, lbd_gl = run_cv_group_lasso(X_current, y_centered, groups_array)
        # selected_vars_gl = [current_cols[i] for i in range(len(current_cols)) if coefs_gl[i] != 0]
        # final_vars_gl = list(set(macro_base_cols + active_lags + selected_vars_gl))
        # final_vars_gl_sorted = [v for v in macro_base_cols if v in final_vars_gl] + [v for v in active_lags if v in final_vars_gl] + sorted([v for v in gdelt_cols if v in final_vars_gl])
        # df_gl, r2_gl, r2_adj_gl, lb_pval_gl = run_post_lasso_ols(X_current, y_centered, final_vars_gl_sorted)
        # best_iteration_gl = (current_lag, final_vars_gl_sorted, df_gl, r2_gl, r2_adj_gl, lb_pval_gl, lbd_gl)

        # ---------------------------------------------------------
        # MODÈLE 2 : SPARSE GROUP LASSO (Simon et al.)
        # ---------------------------------------------------------
        coefs_sgl, lbd_sgl, alpha_sgl = run_cv_sparse_group_lasso(X_current, y_centered, groups_array)
        selected_vars_sgl = [current_cols[i] for i in range(len(current_cols)) if coefs_sgl[i] != 0]
        final_vars_sgl = list(set(macro_base_cols + active_lags + selected_vars_sgl))
        final_vars_sgl_sorted = [v for v in macro_base_cols if v in final_vars_sgl] + [v for v in active_lags if v in final_vars_sgl] + sorted([v for v in gdelt_cols if v in final_vars_sgl])
        df_sgl, r2_sgl, r2_adj_sgl, lb_pval_sgl = run_post_lasso_ols(X_current, y_centered, final_vars_sgl_sorted)
        best_iteration_sgl = (current_lag, final_vars_sgl_sorted, df_sgl, r2_sgl, r2_adj_sgl, lb_pval_sgl, lbd_sgl, alpha_sgl)

        if lb_pval_sgl >= 0.05:
            print(f'  ✓ Bruit blanc validé au Lag {current_lag} (SGL Ljung-Box P-value : {lb_pval_sgl:.4f})')
            break
        else:
            print(f'  ↻ Autocorrélation résiduelle au Lag {current_lag} (P-value : {lb_pval_sgl:.4f}). Ajout du lag {current_lag+1}...')

    print(f'\n' + '=' * 80)
    print(f' RÉSULTATS COMPARATIFS FINAUX : {region.upper()} (STABILISÉ À {best_iteration_sgl[0]} LAG(S))')
    print(f'=' * 80)

    # # Affichage Group Lasso
    # lag_gl, vars_gl, df_gl, r2_gl, r2_adj_gl, pval_gl, lbd_gl = best_iteration_gl
    # gdelt_gl = [v for v in vars_gl if v in gdelt_cols]
    
    # print(f'\n▶ MODÈLE 1 : GROUP LASSO (Yuan & Lin, 2006) - Sélection de secteurs entiers')
    # print(f'  Tuning Data-Driven : Lambda = {lbd_gl:.4f} | Alpha forcé = 0.0')
    # print(f'  Variables totales (OLS) : {len(vars_gl)} (dont {len(gdelt_gl)} GDELT)')
    # print(f'  R-squared (Global/Adj) : {r2_gl:.4f} / {r2_adj_gl:.4f}')
    # print(f'  Ljung-Box P-value : {pval_gl:.4f}')
    # print("-" * 60)
    # print(df_gl.to_string(index=False))

    # Affichage Sparse Group Lasso
    lag_sgl, vars_sgl, df_sgl, r2_sgl, r2_adj_sgl, pval_sgl, lbd_sgl, alpha_sgl = best_iteration_sgl
    gdelt_sgl = [v for v in vars_sgl if v in gdelt_cols]
    
    print(f'\n\n▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs')
    print(f'  Tuning Data-Driven : Lambda = {lbd_sgl:.4f} | Alpha = {alpha_sgl:.2f}')
    print(f'  Variables totales (OLS) : {len(vars_sgl)} (dont {len(gdelt_sgl)} GDELT)')
    print(f'  R-squared (Global/Adj) : {r2_sgl:.4f} / {r2_adj_sgl:.4f}')
    print(f'  Ljung-Box P-value : {pval_sgl:.4f}')
    print("-" * 60)
    print(df_sgl.to_string(index=False))

    final_results[region] = {
        'SGL_Model': {
            'Vars': vars_sgl, 
            'OLS': df_sgl, 
            'R2_adj': r2_adj_sgl, 
            'Optimal_Alpha': alpha_sgl
        }
    }
# Out:
# ================================================================================
#  PIPELINE ACADÉMIQUE : FRANCE (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ↻ Autocorrélation résiduelle au Lag 1 (P-value : 0.0045). Ajout du lag 2...
#   ↻ Autocorrélation résiduelle au Lag 2 (P-value : 0.0153). Ajout du lag 3...
#   ↻ Autocorrélation résiduelle au Lag 3 (P-value : 0.0155). Ajout du lag 4...
#   ↻ Autocorrélation résiduelle au Lag 4 (P-value : 0.0244). Ajout du lag 5...
#   ✓ Bruit blanc validé au Lag 5 (SGL Ljung-Box P-value : 0.2497)
#
# ================================================================================
#  RÉSULTATS COMPARATIFS FINAUX : FRANCE (STABILISÉ À 5 LAG(S))
# ================================================================================
#
#
# ▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs
#   Tuning Data-Driven : Lambda = 0.0160 | Alpha = 0.50
#   Variables totales (OLS) : 30 (dont 18 GDELT)
#   R-squared (Global/Adj) : 0.4740 / 0.2966
#   Ljung-Box P-value : 0.2497
# ------------------------------------------------------------
#                                        Variable   Coefficient  P-value  CI_Lower  CI_Upper
#                                       Intercept  3.295975e-17 1.000000 -0.066597  0.066597
#                                            rate  3.025065e-02 0.515699 -0.061854  0.122356
#                                           unemp  2.079507e-03 0.954445 -0.070047  0.074206
#                                          indpro  4.655722e-02 0.321788 -0.046291  0.139406
#                                           money  6.024037e-02 0.347046 -0.066377  0.186858
#                                              fx  6.443749e-02 0.139883 -0.021520  0.150395
#                                            mich  4.497433e-02 0.270305 -0.035586  0.125535
#                                             oil  1.126308e-01 0.009759  0.027896  0.197365
#                                  inflation_lag1 -9.395896e-03 0.810915 -0.087199  0.068407
#                                  inflation_lag2  4.952183e-02 0.253566 -0.036104  0.135148
#                                  inflation_lag3  2.413716e-02 0.577385 -0.061618  0.109892
#                                  inflation_lag4  8.828881e-02 0.049193  0.000319  0.176259
#                                  inflation_lag5 -1.174778e-01 0.005672 -0.199816 -0.035139
#       sent_bin_weight_agriculture_climate_risks -9.462245e-02 0.103833 -0.209029  0.019784
#         sent_bin_weight_agriculture_food_prices  2.298309e-04 0.997471 -0.143467  0.143926
# sent_bin_weight_agriculture_infrastructure_tech  4.261474e-02 0.506326 -0.084282  0.169512
#         sent_bin_weight_agriculture_rural_labor -2.763722e-02 0.567565 -0.123344  0.068070
#               sent_bin_weight_agriculture_water -1.562356e-04 0.997108 -0.085561  0.085249
#       sent_bin_weight_commodities_market_prices  1.725791e-03 0.976883 -0.116281  0.119733
#                   sent_bin_weight_energy_fossil -8.848684e-02 0.055601 -0.179137  0.002164
#               sent_bin_weight_energy_regulation  7.596113e-02 0.065508 -0.004978  0.156900
#               sent_bin_weight_energy_renewables -3.624477e-02 0.418700 -0.124887  0.052398
#                    sent_bin_weight_energy_risks -7.028639e-02 0.090614 -0.151922  0.011350
#           sent_bin_weight_finance_central_banks -1.164606e-01 0.071409 -0.243282  0.010361
#                  sent_bin_weight_finance_credit -6.910998e-02 0.086210 -0.148259  0.010039
#            sent_bin_weight_finance_private_debt  1.739026e-01 0.001034  0.072060  0.275745
#           sent_bin_weight_finance_systemic_risk  3.036836e-02 0.627104 -0.093409  0.154146
#              sent_bin_weight_industry_factories  6.753782e-02 0.290707 -0.058718  0.193794
#             sent_bin_weight_industry_regulation -4.406686e-02 0.302700 -0.128530  0.040396
#                  sent_bin_weight_industry_risks -3.047577e-02 0.441950 -0.108878  0.047927
#          sent_bin_weight_industry_supply_chains -6.483866e-02 0.136901 -0.150672  0.020994
#
# ================================================================================
#  PIPELINE ACADÉMIQUE : US (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ✓ Bruit blanc validé au Lag 1 (SGL Ljung-Box P-value : 0.3507)
#
# ================================================================================
#  RÉSULTATS COMPARATIFS FINAUX : US (STABILISÉ À 1 LAG(S))
# ================================================================================
#
#
# ▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs
#   Tuning Data-Driven : Lambda = 0.0060 | Alpha = 0.50
#   Variables totales (OLS) : 29 (dont 21 GDELT)
#   R-squared (Global/Adj) : 0.7120 / 0.6250
#   Ljung-Box P-value : 0.3507
# ------------------------------------------------------------
#                                        Variable   Coefficient  P-value  CI_Lower  CI_Upper
#                                       Intercept -1.105886e-16 1.000000 -0.029320  0.029320
#                                            rate -5.881421e-02 0.020449 -0.108343 -0.009285
#                                           unemp  4.100216e-02 0.206039 -0.022925  0.104929
#                                          indpro  5.894856e-02 0.060083 -0.002551  0.120448
#                                           money -9.260086e-02 0.005317 -0.157047 -0.028155
#                                              fx -1.745111e-04 0.991818 -0.033864  0.033515
#                                            mich  3.224932e-03 0.853288 -0.031298  0.037748
#                                             oil  1.056332e-01 0.000008  0.061123  0.150143
#                                  inflation_lag1  6.852946e-02 0.002299  0.025102  0.111957
#       sent_bin_weight_agriculture_climate_risks  2.198923e-02 0.263369 -0.016807  0.060786
#         sent_bin_weight_agriculture_food_prices -1.039067e-01 0.007795 -0.179793 -0.028021
# sent_bin_weight_agriculture_infrastructure_tech -9.026993e-03 0.585971 -0.041813  0.023759
#               sent_bin_weight_agriculture_water -1.600514e-02 0.336555 -0.048899  0.016889
#          sent_bin_weight_commodities_extraction  9.246589e-04 0.987211 -0.113286  0.115135
#       sent_bin_weight_commodities_market_prices -3.181012e-02 0.229971 -0.084075  0.020455
#           sent_bin_weight_commodities_materials  5.870182e-02 0.271167 -0.046581  0.163985
#               sent_bin_weight_commodities_risks -1.982141e-02 0.267906 -0.055129  0.015486
#                   sent_bin_weight_energy_fossil  2.957635e-02 0.088150 -0.004502  0.063654
#          sent_bin_weight_energy_infrastructures  9.093538e-03 0.657565 -0.031500  0.049687
#               sent_bin_weight_energy_regulation  1.176378e-02 0.490639 -0.021983  0.045510
#                   sent_bin_weight_finance_banks  2.266981e-02 0.487684 -0.041921  0.087260
#           sent_bin_weight_finance_central_banks -7.117722e-03 0.876286 -0.097630  0.083395
#                  sent_bin_weight_finance_credit -9.326833e-04 0.961190 -0.038880  0.037015
#       sent_bin_weight_finance_financial_markets  5.953867e-02 0.081401 -0.007568  0.126645
#              sent_bin_weight_finance_regulation  4.374905e-02 0.048113  0.000371  0.087128
#          sent_bin_weight_finance_sovereign_debt -6.046752e-02 0.085264 -0.129494  0.008559
#              sent_bin_weight_industry_factories  3.442372e-02 0.197354 -0.018214  0.087062
#              sent_bin_weight_industry_logistics  2.793018e-04 0.987369 -0.034650  0.035209
#           sent_bin_weight_industry_productivity  1.300187e-02 0.428136 -0.019431  0.045434
#          sent_bin_weight_industry_supply_chains  1.546672e-02 0.399936 -0.020845  0.051778
#
# ================================================================================
#  PIPELINE ACADÉMIQUE : UK (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ↻ Autocorrélation résiduelle au Lag 1 (P-value : 0.0060). Ajout du lag 2...
#   ↻ Autocorrélation résiduelle au Lag 2 (P-value : 0.0059). Ajout du lag 3...
#   ↻ Autocorrélation résiduelle au Lag 3 (P-value : 0.0039). Ajout du lag 4...
#   ↻ Autocorrélation résiduelle au Lag 4 (P-value : 0.0053). Ajout du lag 5...
#   ↻ Autocorrélation résiduelle au Lag 5 (P-value : 0.0062). Ajout du lag 6...
#   ✓ Bruit blanc validé au Lag 6 (SGL Ljung-Box P-value : 0.0589)
#
# ================================================================================
#  RÉSULTATS COMPARATIFS FINAUX : UK (STABILISÉ À 6 LAG(S))
# ================================================================================
#
#
# ▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs
#   Tuning Data-Driven : Lambda = 0.0105 | Alpha = 0.50
#   Variables totales (OLS) : 27 (dont 15 GDELT)
#   R-squared (Global/Adj) : 0.4773 / 0.3239
#   Ljung-Box P-value : 0.0589
# ------------------------------------------------------------
#                                        Variable   Coefficient  P-value  CI_Lower  CI_Upper
#                                       Intercept  5.139118e-17 1.000000 -0.045024  0.045024
#                                            rate  4.961440e-04 0.990393 -0.081122  0.082114
#                                           unemp -7.575130e-03 0.767637 -0.058344  0.043193
#                                          indpro -3.197185e-02 0.205230 -0.081743  0.017799
#                                           money -1.733754e-02 0.591091 -0.081205  0.046530
#                                              fx -3.385239e-02 0.203765 -0.086379  0.018674
#                                             oil  1.834064e-02 0.505153 -0.036106  0.072787
#                                  inflation_lag1  2.633970e-02 0.342109 -0.028442  0.081121
#                                  inflation_lag2  8.586988e-03 0.769015 -0.049317  0.066491
#                                  inflation_lag3  3.212991e-02 0.288937 -0.027698  0.091957
#                                  inflation_lag4  2.525782e-02 0.408063 -0.035100  0.085616
#                                  inflation_lag5  6.150941e-03 0.825746 -0.049179  0.061481
#                                  inflation_lag6  8.814443e-02 0.003421  0.029888  0.146400
# sent_bin_weight_agriculture_infrastructure_tech -2.354631e-02 0.469971 -0.088003  0.040910
#          sent_bin_weight_commodities_extraction  1.381015e-02 0.868509 -0.151404  0.179024
#       sent_bin_weight_commodities_market_prices -6.247426e-02 0.052190 -0.125553  0.000604
#           sent_bin_weight_commodities_materials  3.893915e-02 0.627626 -0.119960  0.197838
#          sent_bin_weight_commodities_regulation  1.785130e-02 0.514334 -0.036307  0.072010
#          sent_bin_weight_energy_infrastructures -2.160257e-02 0.443883 -0.077398  0.034193
#               sent_bin_weight_energy_renewables -3.202024e-02 0.211947 -0.082614  0.018574
#                  sent_bin_weight_finance_credit -1.572310e-02 0.647303 -0.083754  0.052308
#       sent_bin_weight_finance_financial_markets  1.247686e-02 0.764891 -0.070137  0.095091
#            sent_bin_weight_finance_private_debt  1.853828e-02 0.611086 -0.053617  0.090694
#              sent_bin_weight_finance_regulation -1.634019e-02 0.529507 -0.067759  0.035079
#           sent_bin_weight_finance_systemic_risk  2.039407e-02 0.457289 -0.033867  0.074656
#              sent_bin_weight_industry_factories  1.121900e-02 0.670082 -0.040914  0.063352
#              sent_bin_weight_industry_logistics -6.567068e-03 0.817832 -0.063031  0.049897
#                  sent_bin_weight_industry_risks -1.675698e-02 0.537148 -0.070483  0.036969

# %% [markdown]
# #### Robustness - only macro

# %%
final_results_macro_only = {}

for region, config in CONFIG_REGIONS.items():
    print(f'\n' + '=' * 80)
    print(f' BENCHMARK MACRO-ONLY : {region.upper()} (RECHERCHE DYNAMIQUE DE LAGS)')
    print(f'================================================================================')

    # 1. Préparation des données macro
    df_macro = fetch_and_prep_macro_dynamic(config, START_DATE, END_DATE, region=region)
    df_macro = df_macro[df_macro.index >= MIN_INDEX_DATE]

    # 2. Chargement GDELT (UNIQUEMENT POUR ALIGNER LES DATES ET GARANTIR LE MÊME 'N')
    cols_gdelt = get_filtered_gdelt_cols(df_geo)
    df_gdelt_raw = df_geo[df_geo['region_key'] == region].set_index('period')[cols_gdelt]
    if 'sent_cont_weight_finance_international_orgs' in df_gdelt_raw.columns:
        df_gdelt_raw = df_gdelt_raw.drop(columns=['sent_cont_weight_finance_international_orgs'])

    df_gdelt_stat, diff_count = strict_stationarize(df_gdelt_raw)
    
    # La jointure garantit que nous avons les mêmes lignes (Même échantillon N)
    df_final = df_gdelt_stat.join(df_macro, how='inner') 
    y_raw = df_final['inflation']

    # Désaisonnalisation éventuelle
    y_corr = (y_raw - seasonal_decompose(y_raw, model='additive', period=12).seasonal).dropna() if config['deseasonalize_y'] else y_raw.dropna()
    X_full = df_final.drop(columns=['inflation'])
    y_corr, X_contemp = y_corr.align(X_full, join='inner')

    y_centered = y_corr - y_corr.mean()
    X_scaled_full = pd.DataFrame(StandardScaler().fit_transform(X_contemp), columns=X_contemp.columns, index=X_contemp.index)

    # 3. Isolation exclusive des variables macro (on exclut GDELT des prédicteurs)
    macro_base_cols = [c for c in X_scaled_full.columns if c in df_macro.columns and not c.startswith('inflation_lag') and c != 'inflation']

    # --- RECHERCHE DYNAMIQUE DU NOMBRE DE LAGS (OLS STANDARD) ---
    max_lags_to_test = 12
    best_iteration_arx = None

    for current_lag in range(1, max_lags_to_test + 1):
        active_lags = [f'inflation_lag{i}' for i in range(1, current_lag + 1)]
        current_cols = macro_base_cols + active_lags # UNIQUEMENT MACRO + LAGS
        X_current = X_scaled_full[current_cols]
        
        # Estimation OLS directe (Pas besoin de Lasso pour ~10 variables)
        X_current_with_const = sm.add_constant(X_current)
        results = sm.OLS(y_centered.values, X_current_with_const.values).fit()
        
        # Test de Ljung-Box sur les résidus
        lb_pval = acorr_ljungbox(results.resid, lags=[12], return_df=True)['lb_pvalue'].values[0]

        # Sauvegarde des résultats de l'itération
        post_arx_df = pd.DataFrame({
            'Variable': ['Intercept'] + current_cols,
            'Coefficient': results.params,
            'P-value': results.pvalues,
        })
        
        best_iteration_arx = (current_lag, current_cols, post_arx_df, results.rsquared, results.rsquared_adj, lb_pval)

        # Règle d'arrêt : Bruit blanc validé
        if lb_pval >= 0.05:
            print(f'  ✓ Bruit blanc validé au Lag {current_lag} (OLS Ljung-Box P-value : {lb_pval:.4f})')
            break
        else:
            print(f'  ↻ Autocorrélation résiduelle au Lag {current_lag} (P-value : {lb_pval:.4f}). Ajout du lag {current_lag+1}...')

    # --- AFFICHAGE DES RÉSULTATS DU BENCHMARK ---
    lag_arx, vars_arx, df_arx, r2_arx, r2_adj_arx, pval_arx = best_iteration_arx
    
    print(f'\n' + '=' * 80)
    print(f' RÉSULTATS FINAUX BENCHMARK MACRO : {region.upper()} (STABILISÉ À {lag_arx} LAG(S))')
    print(f'=' * 80)
    print(f'  Modèle : ARX (OLS Standard)')
    print(f'  Variables : {len(vars_arx)} (Macroéconomiques + Lags uniquement)')
    print(f'  R-squared (Global/Adj) : {r2_arx:.4f} / {r2_adj_arx:.4f}')
    print(f'  Ljung-Box P-value : {pval_arx:.4f}')
    print("-" * 60)
    print(df_arx.to_string(index=False))

    final_results_macro_only[region] = {
        'Vars': vars_arx, 
        'OLS': df_arx, 
        'R2_adj': r2_adj_arx
    }
# Out:
# ================================================================================
#  BENCHMARK MACRO-ONLY : FRANCE (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ↻ Autocorrélation résiduelle au Lag 1 (P-value : 0.0010). Ajout du lag 2...
#   ↻ Autocorrélation résiduelle au Lag 2 (P-value : 0.0043). Ajout du lag 3...
#   ↻ Autocorrélation résiduelle au Lag 3 (P-value : 0.0033). Ajout du lag 4...
#   ↻ Autocorrélation résiduelle au Lag 4 (P-value : 0.0017). Ajout du lag 5...
#   ↻ Autocorrélation résiduelle au Lag 5 (P-value : 0.0288). Ajout du lag 6...
#   ✓ Bruit blanc validé au Lag 6 (OLS Ljung-Box P-value : 0.4404)
#
# ================================================================================
#  RÉSULTATS FINAUX BENCHMARK MACRO : FRANCE (STABILISÉ À 6 LAG(S))
# ================================================================================
#   Modèle : ARX (OLS Standard)
#   Variables : 13 (Macroéconomiques + Lags uniquement)
#   R-squared (Global/Adj) : 0.2613 / 0.1707
#   Ljung-Box P-value : 0.4404
# ------------------------------------------------------------
#       Variable   Coefficient  P-value
#      Intercept  1.301043e-17 1.000000
#           rate  1.440315e-01 0.002173
#          unemp -2.575065e-03 0.946817
#         indpro  2.356620e-02 0.555514
#          money  6.682257e-02 0.096813
#             fx -1.189568e-03 0.976034
#           mich  6.783812e-02 0.089141
#            oil  1.228171e-01 0.003291
# inflation_lag1 -3.564136e-02 0.360710
# inflation_lag2  5.301332e-02 0.167141
# inflation_lag3  2.453416e-02 0.532618
# inflation_lag4  6.171602e-02 0.125550
# inflation_lag5 -9.300892e-02 0.027376
# inflation_lag6 -8.428432e-02 0.040491
#
# ================================================================================
#  BENCHMARK MACRO-ONLY : US (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ↻ Autocorrélation résiduelle au Lag 1 (P-value : 0.0005). Ajout du lag 2...
#   ↻ Autocorrélation résiduelle au Lag 2 (P-value : 0.0010). Ajout du lag 3...
#   ✓ Bruit blanc validé au Lag 3 (OLS Ljung-Box P-value : 0.1100)
#
# ================================================================================
#  RÉSULTATS FINAUX BENCHMARK MACRO : US (STABILISÉ À 3 LAG(S))
# ================================================================================
#   Modèle : ARX (OLS Standard)
#   Variables : 10 (Macroéconomiques + Lags uniquement)
#   R-squared (Global/Adj) : 0.6103 / 0.5764
#   Ljung-Box P-value : 0.1100
# ------------------------------------------------------------
#       Variable   Coefficient      P-value
#      Intercept  6.288373e-18 1.000000e+00
#           rate -1.515355e-02 4.578316e-01
#          unemp  4.921499e-02 1.235087e-01
#         indpro  4.447547e-02 1.557149e-01
#          money -5.032139e-02 3.154024e-02
#             fx  3.355770e-03 8.418814e-01
#           mich -5.492789e-03 7.391134e-01
#            oil  1.384892e-01 3.559780e-10
# inflation_lag1  1.428499e-01 3.506379e-10
# inflation_lag2 -2.207547e-02 3.343659e-01
# inflation_lag3  7.051602e-02 3.044023e-04
#
# ================================================================================
#  BENCHMARK MACRO-ONLY : UK (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ↻ Autocorrélation résiduelle au Lag 1 (P-value : 0.0000). Ajout du lag 2...
#   ↻ Autocorrélation résiduelle au Lag 2 (P-value : 0.0000). Ajout du lag 3...
#   ↻ Autocorrélation résiduelle au Lag 3 (P-value : 0.0001). Ajout du lag 4...
#   ↻ Autocorrélation résiduelle au Lag 4 (P-value : 0.0002). Ajout du lag 5...
#   ↻ Autocorrélation résiduelle au Lag 5 (P-value : 0.0009). Ajout du lag 6...
#   ✓ Bruit blanc validé au Lag 6 (OLS Ljung-Box P-value : 0.0767)
#
# ================================================================================
#  RÉSULTATS FINAUX BENCHMARK MACRO : UK (STABILISÉ À 6 LAG(S))
# ================================================================================
#   Modèle : ARX (OLS Standard)
#   Variables : 12 (Macroéconomiques + Lags uniquement)
#   R-squared (Global/Adj) : 0.4088 / 0.3424
#   Ljung-Box P-value : 0.0767
# ------------------------------------------------------------
#       Variable   Coefficient  P-value
#      Intercept  9.540979e-18 1.000000
#           rate  6.510878e-03 0.843067
#          unemp -7.197443e-03 0.753366
#         indpro -3.106121e-02 0.190728
#          money -2.003062e-02 0.439779
#             fx -4.221896e-02 0.079227
#            oil  3.456383e-02 0.156756
# inflation_lag1  3.770263e-02 0.134013
# inflation_lag2  2.592436e-02 0.305957
# inflation_lag3  5.530068e-02 0.031729
# inflation_lag4  3.808330e-02 0.162172
# inflation_lag5  2.420151e-02 0.335224
# inflation_lag6  1.060676e-01 0.000049

# %% [markdown]
# #### Robustness - no group macro

# %%
# ==============================================================================
# CELLULE 3 : CONFIGURATION DES MODÈLES (ARX - HEADLINE INFLATION)
# ==============================================================================
CONFIG_REGIONS = {
    'France': {
        'macro_vars': {
            'inflation': {'ticker': 'CP0000FRM086NEST', 'transform': 'pct_change'}
        },
        'deseasonalize_y': True,
    },
    'US': {
        'macro_vars': {
            'inflation': {'ticker': 'CPIAUCSL', 'transform': 'pct_change'}
        },
        'deseasonalize_y': False,
    },
    'UK': {
        'macro_vars': {
            'inflation': {'ticker': 'GBRCPIALLMINMEI', 'transform': 'pct_change'}
        },
        'deseasonalize_y': True,
    },
}

# %%
final_results = {}

for region, config in CONFIG_REGIONS.items():
    print(f'\n' + '=' * 80)
    print(f' PIPELINE ACADÉMIQUE : {region.upper()} (RECHERCHE DYNAMIQUE DE LAGS)')
    print(f'================================================================================')

    df_macro = fetch_and_prep_macro_dynamic(config, START_DATE, END_DATE, region=region)
    df_macro = df_macro[df_macro.index >= MIN_INDEX_DATE]

    # --- NOUVEAU : SAUVEGARDE VINTAGE ---
    # vintage_path = Path(f'./data/economic_data/macro_vintage_inflation_{region}_{datetime.now().strftime("%Y%m%d")}.csv')
    # df_macro.to_csv(vintage_path)
    # print(f'💾 Données Macro sauvegardées : {vintage_path}')
    # ------------------------------------

    cols_gdelt = get_filtered_gdelt_cols(df_geo)
    df_gdelt_raw = df_geo[df_geo['region_key'] == region].set_index('period')[cols_gdelt]
    if 'sent_cont_weight_finance_international_orgs' in df_gdelt_raw.columns:
        df_gdelt_raw = df_gdelt_raw.drop(columns=['sent_cont_weight_finance_international_orgs'])

    df_gdelt_stat, diff_count = strict_stationarize(df_gdelt_raw)
    df_final = df_gdelt_stat.join(df_macro, how='inner')
    y_raw = df_final['inflation']

    y_corr = (y_raw - seasonal_decompose(y_raw, model='additive', period=12).seasonal).dropna() if config['deseasonalize_y'] else y_raw.dropna()
    X_full = df_final.drop(columns=['inflation'])
    y_corr, X_contemp = y_corr.align(X_full, join='inner')

    y_centered = y_corr - y_corr.mean()
    X_scaled_full = pd.DataFrame(StandardScaler().fit_transform(X_contemp), columns=X_contemp.columns, index=X_contemp.index)

    macro_base_cols = [c for c in X_scaled_full.columns if c in df_macro.columns and not c.startswith('inflation_lag') and c != 'inflation']
    gdelt_cols = [c for c in X_scaled_full.columns if c in cols_gdelt]

    max_lags_to_test = 12
    best_iteration_gl = None
    best_iteration_sgl = None

    for current_lag in range(1, max_lags_to_test + 1):
        active_lags = [f'inflation_lag{i}' for i in range(1, current_lag + 1)]
        current_cols = macro_base_cols + active_lags + gdelt_cols
        X_current = X_scaled_full[current_cols]
        
        groups, group_map, current_group_id = [], {}, 2
        for var in current_cols:
            if var in macro_base_cols: groups.append(0) 
            elif var in active_lags: groups.append(1) 
            else:
                sector = var.split('_')[2]
                if sector not in group_map:
                    group_map[sector], current_group_id = current_group_id, current_group_id + 1
                groups.append(group_map[sector])
        groups_array = np.array(groups)

        # # ---------------------------------------------------------
        # # MODÈLE 1 : GROUP LASSO (Yuan & Lin)
        # # ---------------------------------------------------------
        # coefs_gl, lbd_gl = run_cv_group_lasso(X_current, y_centered, groups_array)
        # selected_vars_gl = [current_cols[i] for i in range(len(current_cols)) if coefs_gl[i] != 0]
        # final_vars_gl = list(set(macro_base_cols + active_lags + selected_vars_gl))
        # final_vars_gl_sorted = [v for v in macro_base_cols if v in final_vars_gl] + [v for v in active_lags if v in final_vars_gl] + sorted([v for v in gdelt_cols if v in final_vars_gl])
        # df_gl, r2_gl, r2_adj_gl, lb_pval_gl = run_post_lasso_ols(X_current, y_centered, final_vars_gl_sorted)
        # best_iteration_gl = (current_lag, final_vars_gl_sorted, df_gl, r2_gl, r2_adj_gl, lb_pval_gl, lbd_gl)

        # ---------------------------------------------------------
        # MODÈLE 2 : SPARSE GROUP LASSO (Simon et al.)
        # ---------------------------------------------------------
        coefs_sgl, lbd_sgl, alpha_sgl = run_cv_sparse_group_lasso(X_current, y_centered, groups_array)
        selected_vars_sgl = [current_cols[i] for i in range(len(current_cols)) if coefs_sgl[i] != 0]
        final_vars_sgl = list(set(macro_base_cols + active_lags + selected_vars_sgl))
        final_vars_sgl_sorted = [v for v in macro_base_cols if v in final_vars_sgl] + [v for v in active_lags if v in final_vars_sgl] + sorted([v for v in gdelt_cols if v in final_vars_sgl])
        df_sgl, r2_sgl, r2_adj_sgl, lb_pval_sgl = run_post_lasso_ols(X_current, y_centered, final_vars_sgl_sorted)
        best_iteration_sgl = (current_lag, final_vars_sgl_sorted, df_sgl, r2_sgl, r2_adj_sgl, lb_pval_sgl, lbd_sgl, alpha_sgl)

        if lb_pval_sgl >= 0.05:
            print(f'  ✓ Bruit blanc validé au Lag {current_lag} (SGL Ljung-Box P-value : {lb_pval_sgl:.4f})')
            break
        else:
            print(f'  ↻ Autocorrélation résiduelle au Lag {current_lag} (P-value : {lb_pval_sgl:.4f}). Ajout du lag {current_lag+1}...')

    print(f'\n' + '=' * 80)
    print(f' RÉSULTATS COMPARATIFS FINAUX : {region.upper()} (STABILISÉ À {best_iteration_sgl[0]} LAG(S))')
    print(f'=' * 80)

    # # Affichage Group Lasso
    # lag_gl, vars_gl, df_gl, r2_gl, r2_adj_gl, pval_gl, lbd_gl = best_iteration_gl
    # gdelt_gl = [v for v in vars_gl if v in gdelt_cols]
    
    # print(f'\n▶ MODÈLE 1 : GROUP LASSO (Yuan & Lin, 2006) - Sélection de secteurs entiers')
    # print(f'  Tuning Data-Driven : Lambda = {lbd_gl:.4f} | Alpha forcé = 0.0')
    # print(f'  Variables totales (OLS) : {len(vars_gl)} (dont {len(gdelt_gl)} GDELT)')
    # print(f'  R-squared (Global/Adj) : {r2_gl:.4f} / {r2_adj_gl:.4f}')
    # print(f'  Ljung-Box P-value : {pval_gl:.4f}')
    # print("-" * 60)
    # print(df_gl.to_string(index=False))

    # Affichage Sparse Group Lasso
    lag_sgl, vars_sgl, df_sgl, r2_sgl, r2_adj_sgl, pval_sgl, lbd_sgl, alpha_sgl = best_iteration_sgl
    gdelt_sgl = [v for v in vars_sgl if v in gdelt_cols]
    
    print(f'\n\n▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs')
    print(f'  Tuning Data-Driven : Lambda = {lbd_sgl:.4f} | Alpha = {alpha_sgl:.2f}')
    print(f'  Variables totales (OLS) : {len(vars_sgl)} (dont {len(gdelt_sgl)} GDELT)')
    print(f'  R-squared (Global/Adj) : {r2_sgl:.4f} / {r2_adj_sgl:.4f}')
    print(f'  Ljung-Box P-value : {pval_sgl:.4f}')
    print("-" * 60)
    print(df_sgl.to_string(index=False))
# Out:
# ================================================================================
#  PIPELINE ACADÉMIQUE : FRANCE (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ↻ Autocorrélation résiduelle au Lag 1 (P-value : 0.0006). Ajout du lag 2...
#   ↻ Autocorrélation résiduelle au Lag 2 (P-value : 0.0012). Ajout du lag 3...
#   ↻ Autocorrélation résiduelle au Lag 3 (P-value : 0.0007). Ajout du lag 4...
#   ↻ Autocorrélation résiduelle au Lag 4 (P-value : 0.0010). Ajout du lag 5...
#   ✓ Bruit blanc validé au Lag 5 (SGL Ljung-Box P-value : 0.1409)
#
# ================================================================================
#  RÉSULTATS COMPARATIFS FINAUX : FRANCE (STABILISÉ À 5 LAG(S))
# ================================================================================
#
#
# ▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs
#   Tuning Data-Driven : Lambda = 0.0160 | Alpha = 0.50
#   Variables totales (OLS) : 27 (dont 22 GDELT)
#   R-squared (Global/Adj) : 0.4151 / 0.2453
#   Ljung-Box P-value : 0.1409
# ------------------------------------------------------------
#                                        Variable   Coefficient  P-value  CI_Lower  CI_Upper
#                                       Intercept  1.123536e-16 1.000000 -0.068335  0.068335
#                                  inflation_lag1 -1.279734e-02 0.758067 -0.095059  0.069464
#                                  inflation_lag2  1.566332e-02 0.722702 -0.071726  0.103053
#                                  inflation_lag3 -1.189035e-02 0.776447 -0.094804  0.071023
#                                  inflation_lag4  4.423934e-02 0.299463 -0.039956  0.128435
#                                  inflation_lag5 -1.180397e-01 0.004931 -0.199421 -0.036659
#       sent_bin_weight_agriculture_climate_risks -1.336774e-01 0.027869 -0.252495 -0.014860
#         sent_bin_weight_agriculture_food_prices -9.572475e-03 0.897866 -0.157263  0.138118
# sent_bin_weight_agriculture_infrastructure_tech -2.826457e-02 0.633197 -0.145488  0.088959
#         sent_bin_weight_agriculture_rural_labor  7.059931e-03 0.881938 -0.087081  0.101201
#               sent_bin_weight_agriculture_water -1.457916e-02 0.733472 -0.099348  0.070189
#       sent_bin_weight_commodities_market_prices  2.113681e-02 0.726911 -0.098687  0.140961
#                   sent_bin_weight_energy_fossil -1.006851e-01 0.036925 -0.195128 -0.006242
#          sent_bin_weight_energy_infrastructures  4.131994e-02 0.361418 -0.048142  0.130782
#               sent_bin_weight_energy_regulation  6.786302e-02 0.101131 -0.013525  0.149251
#               sent_bin_weight_energy_renewables -1.138540e-02 0.791506 -0.096665  0.073895
#                    sent_bin_weight_energy_risks -8.982419e-02 0.034978 -0.173179 -0.006469
#           sent_bin_weight_finance_central_banks -1.228270e-01 0.062776 -0.252335  0.006681
#                  sent_bin_weight_finance_credit -5.654865e-02 0.168061 -0.137377  0.024280
#            sent_bin_weight_finance_private_debt  1.640877e-01 0.001310  0.065776  0.262400
#              sent_bin_weight_finance_regulation -2.655749e-02 0.702046 -0.163989  0.110874
#           sent_bin_weight_finance_systemic_risk  9.123438e-02 0.186019 -0.044752  0.227221
#              sent_bin_weight_industry_factories  9.986214e-02 0.106979 -0.021973  0.221697
#              sent_bin_weight_industry_logistics -1.286722e-02 0.751656 -0.093372  0.067637
#           sent_bin_weight_industry_productivity -9.881547e-03 0.796441 -0.085734  0.065971
#             sent_bin_weight_industry_regulation -4.365779e-02 0.279436 -0.123346  0.036031
#                  sent_bin_weight_industry_risks -3.208421e-02 0.420571 -0.110838  0.046669
#          sent_bin_weight_industry_supply_chains -4.243365e-02 0.329719 -0.128434  0.043567
#
# ================================================================================
#  PIPELINE ACADÉMIQUE : US (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ✓ Bruit blanc validé au Lag 1 (SGL Ljung-Box P-value : 0.2492)
#
# ================================================================================
#  RÉSULTATS COMPARATIFS FINAUX : US (STABILISÉ À 1 LAG(S))
# ================================================================================
#
#
# ▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs
#   Tuning Data-Driven : Lambda = 0.0091 | Alpha = 0.50
#   Variables totales (OLS) : 25 (dont 24 GDELT)
#   R-squared (Global/Adj) : 0.5500 / 0.4374
#   Ljung-Box P-value : 0.2492
# ------------------------------------------------------------
#                                        Variable   Coefficient  P-value  CI_Lower  CI_Upper
#                                       Intercept -1.027824e-16 1.000000 -0.035893  0.035893
#                                  inflation_lag1  7.038273e-02 0.003909  0.023114  0.117651
#        sent_bin_weight_agriculture_agribusiness -8.515757e-03 0.773813 -0.067144  0.050113
#       sent_bin_weight_agriculture_climate_risks  4.188262e-02 0.136392 -0.013460  0.097225
# sent_bin_weight_agriculture_infrastructure_tech -2.895899e-02 0.170060 -0.070533  0.012615
#          sent_bin_weight_agriculture_regulation  3.897560e-03 0.871574 -0.043813  0.051608
#         sent_bin_weight_agriculture_rural_labor  1.380091e-02 0.626078 -0.042219  0.069821
#               sent_bin_weight_agriculture_water -1.481910e-02 0.470058 -0.055364  0.025726
#          sent_bin_weight_commodities_extraction -2.509591e-02 0.693944 -0.151258  0.101067
#       sent_bin_weight_commodities_market_prices -2.972143e-02 0.315167 -0.088133  0.028690
#           sent_bin_weight_commodities_materials  6.289758e-02 0.310369 -0.059488  0.185283
#               sent_bin_weight_commodities_risks  3.979269e-03 0.853115 -0.038551  0.046510
#                   sent_bin_weight_energy_fossil  2.054465e-02 0.316149 -0.019914  0.061003
#          sent_bin_weight_energy_infrastructures -2.329196e-02 0.360889 -0.073637  0.027053
#               sent_bin_weight_energy_regulation  3.111484e-02 0.132635 -0.009601  0.071830
#           sent_bin_weight_finance_central_banks -4.987899e-02 0.274972 -0.140030  0.040272
#                  sent_bin_weight_finance_credit -9.698417e-03 0.677218 -0.055787  0.036390
#       sent_bin_weight_finance_financial_markets  9.574801e-02 0.006727  0.027113  0.164383
#              sent_bin_weight_finance_regulation  2.947163e-02 0.248017 -0.020849  0.079793
#          sent_bin_weight_finance_sovereign_debt -4.489271e-02 0.292240 -0.129012  0.039227
#           sent_bin_weight_finance_systemic_risk -3.341365e-02 0.214256 -0.086452  0.019624
#              sent_bin_weight_industry_factories  3.476710e-02 0.282170 -0.029024  0.098559
#              sent_bin_weight_industry_logistics  7.646432e-03 0.705038 -0.032316  0.047609
#           sent_bin_weight_industry_productivity  2.644815e-02 0.176532 -0.012102  0.064999
#             sent_bin_weight_industry_regulation  1.131010e-02 0.603673 -0.031777  0.054397
#          sent_bin_weight_industry_supply_chains  1.289409e-02 0.553512 -0.030135  0.055923
#
# ================================================================================
#  PIPELINE ACADÉMIQUE : UK (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ↻ Autocorrélation résiduelle au Lag 1 (P-value : 0.0013). Ajout du lag 2...
#   ↻ Autocorrélation résiduelle au Lag 2 (P-value : 0.0011). Ajout du lag 3...
#   ↻ Autocorrélation résiduelle au Lag 3 (P-value : 0.0012). Ajout du lag 4...
#   ↻ Autocorrélation résiduelle au Lag 4 (P-value : 0.0016). Ajout du lag 5...
#   ↻ Autocorrélation résiduelle au Lag 5 (P-value : 0.0015). Ajout du lag 6...
#   ↻ Autocorrélation résiduelle au Lag 6 (P-value : 0.0104). Ajout du lag 7...
#   ↻ Autocorrélation résiduelle au Lag 7 (P-value : 0.0104). Ajout du lag 8...
#   ↻ Autocorrélation résiduelle au Lag 8 (P-value : 0.0106). Ajout du lag 9...
#   ↻ Autocorrélation résiduelle au Lag 9 (P-value : 0.0066). Ajout du lag 10...
#   ↻ Autocorrélation résiduelle au Lag 10 (P-value : 0.0093). Ajout du lag 11...
#   ✓ Bruit blanc validé au Lag 11 (SGL Ljung-Box P-value : 0.0508)
#
# ================================================================================
#  RÉSULTATS COMPARATIFS FINAUX : UK (STABILISÉ À 11 LAG(S))
# ================================================================================
#
#
# ▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs
#   Tuning Data-Driven : Lambda = 0.0105 | Alpha = 0.50
#   Variables totales (OLS) : 27 (dont 16 GDELT)
#   R-squared (Global/Adj) : 0.4978 / 0.3505
#   Ljung-Box P-value : 0.0508
# ------------------------------------------------------------
#                                        Variable   Coefficient  P-value  CI_Lower  CI_Upper
#                                       Intercept  6.375109e-17 1.000000 -0.044131  0.044131
#                                  inflation_lag1  1.591602e-02 0.614042 -0.046551  0.078383
#                                  inflation_lag2  1.000022e-02 0.749736 -0.052077  0.072078
#                                  inflation_lag3  6.068755e-02 0.055347 -0.001417  0.122792
#                                  inflation_lag4  1.121714e-02 0.721160 -0.051012  0.073446
#                                  inflation_lag5 -1.048611e-02 0.727748 -0.070129  0.049157
#                                  inflation_lag6  7.036373e-02 0.019585  0.011542  0.129185
#                                  inflation_lag7  4.986372e-03 0.871677 -0.056153  0.066126
#                                  inflation_lag8 -1.059668e-02 0.719509 -0.069022  0.047829
#                                  inflation_lag9 -6.888476e-02 0.025509 -0.129140 -0.008630
#                                 inflation_lag10  3.546100e-02 0.251126 -0.025522  0.096444
#                                 inflation_lag11  4.693755e-02 0.138818 -0.015495  0.109370
# sent_bin_weight_agriculture_infrastructure_tech -2.958242e-02 0.358163 -0.093203  0.034038
#         sent_bin_weight_agriculture_rural_labor  1.657243e-02 0.559937 -0.039685  0.072830
#          sent_bin_weight_commodities_extraction -2.309737e-02 0.769557 -0.179224  0.133030
#       sent_bin_weight_commodities_market_prices -5.779588e-02 0.067013 -0.119726  0.004134
#           sent_bin_weight_commodities_materials  7.633604e-02 0.325715 -0.077106  0.229778
#          sent_bin_weight_commodities_regulation  1.740558e-02 0.504775 -0.034219  0.069030
#          sent_bin_weight_energy_infrastructures -1.782420e-02 0.527752 -0.073674  0.038026
#               sent_bin_weight_energy_renewables -3.044002e-02 0.234016 -0.080907  0.020027
#                  sent_bin_weight_finance_credit -3.046561e-02 0.387262 -0.100117  0.039186
#       sent_bin_weight_finance_financial_markets  3.655696e-02 0.463983 -0.062176  0.135290
#            sent_bin_weight_finance_private_debt  6.580033e-02 0.123338 -0.018232  0.149833
#          sent_bin_weight_finance_sovereign_debt -7.274908e-02 0.269792 -0.202889  0.057391
#           sent_bin_weight_finance_systemic_risk  2.648683e-02 0.312928 -0.025358  0.078332
#              sent_bin_weight_industry_factories  2.498998e-02 0.326016 -0.025273  0.075253
#              sent_bin_weight_industry_logistics  4.898995e-04 0.985329 -0.052279  0.053259
#                  sent_bin_weight_industry_risks -2.351980e-02 0.362190 -0.074530  0.027490

# %% [markdown]
# #### Graph

# %%
# ==============================================================================
# CELLULE 5 : VISUALISATION ACADÉMIQUE DU DÉCROCHAGE MACRO (ÉCHELLE RÉELLE)
# ==============================================================================
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import statsmodels.api as sm
import os

# 1. INITIALISER SEABORN EN PREMIER 
sns.set_style("ticks")

# 2. FORCER LA POLICE TIMES NEW ROMAN
plt.rcParams.update({
    'font.family': 'serif',
    'font.serif': ['Times New Roman', 'Times', 'DejaVu Serif'], 
    'mathtext.fontset': 'stix', 
    'font.size': 12,
    'axes.labelsize': 12,
    'axes.titlesize': 14,
    'legend.fontsize': 10,
    'xtick.labelsize': 11,
    'ytick.labelsize': 11,
    'figure.dpi': 300 
})

# Choix de la région 
region = 'France'
config = CONFIG_REGIONS[region]

# 3. Préparation des données et alignement temporel
df_macro = fetch_and_prep_macro_dynamic(config, START_DATE, END_DATE, region=region)
df_macro = df_macro[df_macro.index >= MIN_INDEX_DATE]

cols_gdelt = get_filtered_gdelt_cols(df_geo)
df_gdelt_raw = df_geo[df_geo['region_key'] == region].set_index('period')[cols_gdelt]
if 'sent_cont_weight_finance_international_orgs' in df_gdelt_raw.columns:
    df_gdelt_raw = df_gdelt_raw.drop(columns=['sent_cont_weight_finance_international_orgs'])

df_gdelt_stat, diff_count = strict_stationarize(df_gdelt_raw)
df_final = df_gdelt_stat.join(df_macro, how='inner')
y_raw = df_final['inflation']

# Désaisonnalisation
y_corr = (y_raw - seasonal_decompose(y_raw, model='additive', period=12).seasonal).dropna() if config['deseasonalize_y'] else y_raw.dropna()
X_full = df_final.drop(columns=['inflation'])
y_corr, X_contemp = y_corr.align(X_full, join='inner')

# Récupération de la moyenne pour le retour à l'échelle réelle
y_mean = y_corr.mean()
y_centered = y_corr - y_mean
X_scaled_full = pd.DataFrame(StandardScaler().fit_transform(X_contemp), columns=X_contemp.columns, index=X_contemp.index)

# 4. Calcul des Prédictions et RE-MISE À L'ÉCHELLE (+ y_mean)
# A. Benchmark : Macro-Only
vars_macro = final_results_macro_only[region]['Vars']
X_macro = sm.add_constant(X_scaled_full[vars_macro])
y_pred_macro_centered = sm.OLS(y_centered.values, X_macro.values).fit().fittedvalues
y_pred_macro = y_pred_macro_centered + y_mean # Retour à la vraie inflation

# B. Proposed Model : Hybrid SGL (GDELT + Macro)
vars_hybrid = final_results[region]['SGL_Model']['Vars']
X_hybrid = sm.add_constant(X_scaled_full[vars_hybrid])
y_pred_hybrid_centered = sm.OLS(y_centered.values, X_hybrid.values).fit().fittedvalues
y_pred_hybrid = y_pred_hybrid_centered + y_mean # Retour à la vraie inflation

# 5. Tracé du Graphique (Plotting)
fig, ax = plt.subplots(figsize=(12, 6))

# Ligne 1 : Vraie inflation (y_corr et non y_centered)
ax.plot(y_corr.index, y_corr.values, 
        label='Actual Headline Inflation', 
        color='black', linewidth=1.5, zorder=3)

# Ligne 2 : Benchmark Macro (Pointillés rouges)
ax.plot(y_corr.index, y_pred_macro, 
        label=f'Benchmark: Macro Only (Adj. $R^2 = {final_results_macro_only[region]["R2_adj"]:.2f}$)', 
        color='#b22222', linestyle='--', linewidth=1.4, alpha=0.8, zorder=2)

# Ligne 3 : Modèle SGL Hybride (Trait plein bleu)
ax.plot(y_corr.index, y_pred_hybrid, 
        label=f'SGL: Macro + GDELT (Adj. $R^2 = {final_results[region]["SGL_Model"]["R2_adj"]:.2f}$)', 
        color='#004c99', linestyle='-', linewidth=1.6, zorder=4)

# 6. Habillage et Formattage
# La ligne 0 a maintenant un vrai sens économique : 0% d'inflation mensuelle
ax.axhline(0, color='black', linewidth=0.8, linestyle='-', alpha=0.5) 
# Force les courbes à toucher les bords gauche et droit du graphique
ax.set_xlim(y_corr.index.min(), y_corr.index.max())
ax.set_ylabel('Headline Inflation (Monthly % Change)')
ax.set_title(f'Actual vs. Predicted Headline Inflation - {region}', pad=15, fontweight='bold')

# Formattage de l'axe X (Années propres)
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
fig.autofmt_xdate(rotation=0, ha='center')

# Légende
ax.legend(loc='upper left', frameon=True, edgecolor='black', fancybox=False, facecolor='white', framealpha=1)

# Grille
ax.grid(True, which='major', axis='y', linestyle=':', alpha=0.6)

# Nettoyage des bordures
sns.despine()

# Sauvegarde pour LaTeX
os.makedirs('./latex_tables', exist_ok=True)
plt.savefig(f'./latex_tables/Macro_Decoupling_{region}.pdf', format='pdf', bbox_inches='tight')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2. Core inflation

# %%
# ==============================================================================
# CELLULE 3 : CONFIGURATION DES MODÈLES RÉGIONAUX (CORE INFLATION)
# ==============================================================================
CONFIG_REGIONS = {
    'France': {
        'macro_vars': {
            # Mise à jour: Core CPI France (Non-Food, Non-Energy)
            'inflation': {'ticker': 'CPGRLE01FRM659N', 'transform': 'pct_change'},
            'rate': {'ticker': 'IRSTCI01FRM156N', 'transform': 'diff'},
            'unemp': {'ticker': 'LRHUTTTTFRM156S', 'transform': 'diff'},
            'indpro': {'ticker': 'FRAPRINTO01GYSAM', 'transform': 'pct_change'},
            'money': {'ticker': 'BCE_M3_API', 'transform': 'none'},
            'fx': {'ticker': 'DEXUSEU', 'transform': 'pct_change'},
            'mich': {'ticker': 'CSINFT02FRM460S', 'transform': 'diff'},
            'oil': {'ticker': 'DCOILBRENTEU', 'transform': 'pct_change'},
        },
        'deseasonalize_y': True,
    },
    'US': {
        'macro_vars': {
            # Mise à jour: Core CPI US (All Items Less Food & Energy)
            'inflation': {'ticker': 'CPILFESL', 'transform': 'pct_change'},
            'rate': {'ticker': 'FEDFUNDS', 'transform': 'diff'},
            'unemp': {'ticker': 'UNRATE', 'transform': 'diff'},
            'indpro': {'ticker': 'INDPRO', 'transform': 'pct_change'},
            'money': {'ticker': 'M2SL', 'transform': 'pct_change'},
            'fx': {'ticker': 'DEXUSEU', 'transform': 'pct_change'},
            'mich': {'ticker': 'MICH', 'transform': 'diff'},
            'oil': {'ticker': 'WTISPLC', 'transform': 'pct_change'},
        },
        'deseasonalize_y': False,
    },
    'UK': {
        'macro_vars': {
            'inflation': {'ticker': 'CPGRLE01GBM659N', 'transform': 'pct_change'},
            'rate': {'ticker': 'IUMABEDR', 'transform': 'diff'},
            'unemp': {'ticker': 'LRHUTTTTGBM156S', 'transform': 'diff'},
            'indpro': {'ticker': 'GBRPRINTO01GYSAM', 'transform': 'pct_change'},
            'money': {'ticker': 'LPMBD93', 'transform': 'pct_change'},
            'fx': {'ticker': 'XUDLUSS', 'transform': 'pct_change'},
            'oil': {'ticker': 'DCOILBRENTEU', 'transform': 'pct_change'},
        },
        'deseasonalize_y': True,
    },
}

# %%
# ==============================================================================
# CELLULE 4 : EXÉCUTION DU PIPELINE COMPLET AVEC COMPARAISON GL vs SGL
# ==============================================================================
final_results = {}

for region, config in CONFIG_REGIONS.items():
    print(f'\n' + '=' * 80)
    print(f' PIPELINE ACADÉMIQUE : {region.upper()} (RECHERCHE DYNAMIQUE DE LAGS)')
    print(f'================================================================================')

    # 1. Préparation des données (Tronquées pour garantir un 'n' constant)
    df_macro = fetch_and_prep_macro_dynamic(config, START_DATE, END_DATE, region=region)
    df_macro = df_macro[df_macro.index >= MIN_INDEX_DATE]

    # --- NOUVEAU : SAUVEGARDE VINTAGE ---
    # vintage_path = Path(f'./data/economic_data/macro_vintage_inflation_{region}_{datetime.now().strftime("%Y%m%d")}.csv')
    # df_macro.to_csv(vintage_path)
    # print(f'💾 Données Macro sauvegardées : {vintage_path}')
    # ------------------------------------

    cols_gdelt = get_filtered_gdelt_cols(df_geo)
    df_gdelt_raw = df_geo[df_geo['region_key'] == region].set_index('period')[cols_gdelt]
    if 'sent_cont_weight_finance_international_orgs' in df_gdelt_raw.columns:
        df_gdelt_raw = df_gdelt_raw.drop(columns=['sent_cont_weight_finance_international_orgs'])

    df_gdelt_stat, diff_count = strict_stationarize(df_gdelt_raw)
    df_final = df_gdelt_stat.join(df_macro, how='inner')
    y_raw = df_final['inflation']

    y_corr = (y_raw - seasonal_decompose(y_raw, model='additive', period=12).seasonal).dropna() if config['deseasonalize_y'] else y_raw.dropna()
    X_full = df_final.drop(columns=['inflation'])
    y_corr, X_contemp = y_corr.align(X_full, join='inner')

    y_centered = y_corr - y_corr.mean()
    X_scaled_full = pd.DataFrame(StandardScaler().fit_transform(X_contemp), columns=X_contemp.columns, index=X_contemp.index)

    macro_base_cols = [c for c in X_scaled_full.columns if c in df_macro.columns and not c.startswith('inflation_lag') and c != 'inflation']
    gdelt_cols = [c for c in X_scaled_full.columns if c in cols_gdelt]

    # --- RECHERCHE DYNAMIQUE DU NOMBRE DE LAGS ---
    max_lags_to_test = 12
    best_iteration_gl = None
    best_iteration_sgl = None

    for current_lag in range(1, max_lags_to_test + 1):
        active_lags = [f'inflation_lag{i}' for i in range(1, current_lag + 1)]
        current_cols = macro_base_cols + active_lags + gdelt_cols
        X_current = X_scaled_full[current_cols]
        
        # Définition des groupes
        groups, group_map, current_group_id = [], {}, 2
        for var in current_cols:
            if var in macro_base_cols: groups.append(0) 
            elif var in active_lags: groups.append(1) 
            else:
                sector = var.split('_')[2]
                if sector not in group_map:
                    group_map[sector], current_group_id = current_group_id, current_group_id + 1
                groups.append(group_map[sector])
        groups_array = np.array(groups)

        # # ---------------------------------------------------------
        # # MODÈLE 1 : GROUP LASSO (Yuan & Lin)
        # # ---------------------------------------------------------
        # coefs_gl, lbd_gl = run_cv_group_lasso(X_current, y_centered, groups_array)
        # selected_vars_gl = [current_cols[i] for i in range(len(current_cols)) if coefs_gl[i] != 0]
        # final_vars_gl = list(set(macro_base_cols + active_lags + selected_vars_gl))
        # final_vars_gl_sorted = [v for v in macro_base_cols if v in final_vars_gl] + [v for v in active_lags if v in final_vars_gl] + sorted([v for v in gdelt_cols if v in final_vars_gl])
        # df_gl, r2_gl, r2_adj_gl, lb_pval_gl = run_post_lasso_ols(X_current, y_centered, final_vars_gl_sorted)
        # best_iteration_gl = (current_lag, final_vars_gl_sorted, df_gl, r2_gl, r2_adj_gl, lb_pval_gl, lbd_gl)

        # ---------------------------------------------------------
        # MODÈLE 2 : SPARSE GROUP LASSO (Simon et al.)
        # ---------------------------------------------------------
        coefs_sgl, lbd_sgl, alpha_sgl = run_cv_sparse_group_lasso(X_current, y_centered, groups_array)
        selected_vars_sgl = [current_cols[i] for i in range(len(current_cols)) if coefs_sgl[i] != 0]
        final_vars_sgl = list(set(macro_base_cols + active_lags + selected_vars_sgl))
        final_vars_sgl_sorted = [v for v in macro_base_cols if v in final_vars_sgl] + [v for v in active_lags if v in final_vars_sgl] + sorted([v for v in gdelt_cols if v in final_vars_sgl])
        df_sgl, r2_sgl, r2_adj_sgl, lb_pval_sgl = run_post_lasso_ols(X_current, y_centered, final_vars_sgl_sorted)
        best_iteration_sgl = (current_lag, final_vars_sgl_sorted, df_sgl, r2_sgl, r2_adj_sgl, lb_pval_sgl, lbd_sgl, alpha_sgl)

        # Règle d'arrêt : On s'arrête dès que le SGL capture toute la dynamique temporelle (Bruit blanc validé)
        if lb_pval_sgl >= 0.05:
            print(f'  ✓ Bruit blanc validé au Lag {current_lag} (SGL Ljung-Box P-value : {lb_pval_sgl:.4f})')
            break
        else:
            print(f'  ↻ Autocorrélation résiduelle au Lag {current_lag} (P-value : {lb_pval_sgl:.4f}). Ajout du lag {current_lag+1}...')

    # --- AFFICHAGE COMPARATIF DES RÉSULTATS OPTIMAUX ---
    print(f'\n' + '=' * 80)
    print(f' RÉSULTATS COMPARATIFS FINAUX : {region.upper()} (STABILISÉ À {best_iteration_sgl[0]} LAG(S))')
    print(f'=' * 80)

    # # Affichage Group Lasso
    # lag_gl, vars_gl, df_gl, r2_gl, r2_adj_gl, pval_gl, lbd_gl = best_iteration_gl
    # # gdelt_gl = [v for v in vars_gl if v in gdelt_cols]
    
    # print(f'\n▶ MODÈLE 1 : GROUP LASSO (Yuan & Lin, 2006) - Sélection de secteurs entiers')
    # print(f'  Tuning Data-Driven : Lambda = {lbd_gl:.4f} | Alpha forcé = 0.0')
    # print(f'  Variables totales (OLS) : {len(vars_gl)} (dont {len(gdelt_gl)} GDELT)')
    # print(f'  R-squared (Global/Adj) : {r2_gl:.4f} / {r2_adj_gl:.4f}')
    # print(f'  Ljung-Box P-value : {pval_gl:.4f}')
    # print("-" * 60)
    # print(df_gl.to_string(index=False))

    # Affichage Sparse Group Lasso
    lag_sgl, vars_sgl, df_sgl, r2_sgl, r2_adj_sgl, pval_sgl, lbd_sgl, alpha_sgl = best_iteration_sgl
    gdelt_sgl = [v for v in vars_sgl if v in gdelt_cols]
    
    print(f'\n\n▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs')
    print(f'  Tuning Data-Driven : Lambda = {lbd_sgl:.4f} | Alpha = {alpha_sgl:.2f}')
    print(f'  Variables totales (OLS) : {len(vars_sgl)} (dont {len(gdelt_sgl)} GDELT)')
    print(f'  R-squared (Global/Adj) : {r2_sgl:.4f} / {r2_adj_sgl:.4f}')
    print(f'  Ljung-Box P-value : {pval_sgl:.4f}')
    print("-" * 60)
    print(df_sgl.to_string(index=False))

    # final_results[region] = {
    #     'GL_Model': {'Vars': vars_gl, 'OLS': df_gl, 'R2_adj': r2_adj_gl},
    #     'SGL_Model': {'Vars': vars_sgl, 'OLS': df_sgl, 'R2_adj': r2_adj_sgl, 'Optimal_Alpha': alpha_sgl}
    # }

    # ==========================================================================
    # EXPORT LATEX AUTOMATIQUE DES TABLEAUX DE RÉSULTATS
    # ==========================================================================
    
    # import os
    # # Création d'un dossier pour ranger vos tableaux propres
    # output_dir = "./latex_tables"
    # os.makedirs(output_dir, exist_ok=True)
    
    # # 1. Export du tableau Group Lasso (GL)
    # filename_gl = f"{output_dir}/OLS_GL_{region}.tex"
    # # On arrondit à 4 décimales et on supprime l'index (0, 1, 2...) de Pandas
    # latex_gl = df_gl.to_latex(index=False, float_format="%.4f", escape=True)
    # with open(filename_gl, 'w') as f:
    #     f.write(latex_gl)
        
    # # 2. Export du tableau Sparse Group Lasso (SGL)
    # filename_sgl = f"{output_dir}/OLS_SGL_{region}.tex"
    # latex_sgl = df_sgl.to_latex(index=False, float_format="%.4f", escape=True)
    # with open(filename_sgl, 'w') as f:
    #     f.write(latex_sgl)
        
    # # 3. BONUS : Export d'un tableau "Strict" (Uniquement les variables significatives p < 0.10)
    # # Très utile pour le corps de votre mémoire (les tableaux complets iront en annexe)
    # df_sgl_strict = df_sgl[df_sgl['P-value'] < 0.10]
    # filename_sgl_strict = f"{output_dir}/OLS_SGL_{region}_SIGNIFICANT.tex"
    # latex_sgl_strict = df_sgl_strict.to_latex(index=False, float_format="%.4f", escape=True)
    # with open(filename_sgl_strict, 'w') as f:
    #     f.write(latex_sgl_strict)
        
    # print(f"  📝 Tableaux LaTeX exportés avec succès dans le dossier '{output_dir}'.")
# Out:
# ================================================================================
#  PIPELINE ACADÉMIQUE : FRANCE (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ✓ Bruit blanc validé au Lag 1 (SGL Ljung-Box P-value : 0.2236)
#
# ================================================================================
#  RÉSULTATS COMPARATIFS FINAUX : FRANCE (STABILISÉ À 1 LAG(S))
# ================================================================================
#
#
# ▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs
#   Tuning Data-Driven : Lambda = 0.1000 | Alpha = 0.50
#   Variables totales (OLS) : 37 (dont 29 GDELT)
#   R-squared (Global/Adj) : 0.3415 / -0.0116
#   Ljung-Box P-value : 0.2236
# ------------------------------------------------------------
#                                        Variable   Coefficient  P-value   CI_Lower  CI_Upper
#                                       Intercept  2.983724e-14 1.000000 -12.726954 12.726954
#                                            rate -2.391457e+01 0.023545 -44.515422 -3.313717
#                                           unemp -2.320765e+00 0.741550 -16.302602 11.661072
#                                          indpro -3.053670e+00 0.757926 -22.741134 16.633794
#                                           money -1.566902e+01 0.334093 -47.804690 16.466643
#                                              fx  2.648136e+00 0.759102 -14.510851 19.807123
#                                            mich -2.077103e+00 0.782648 -17.039150 12.884945
#                                             oil -4.753981e-01 0.956487 -17.794191 16.843395
#                                  inflation_lag1 -1.661951e+01 0.034998 -32.034829 -1.204199
#       sent_bin_weight_agriculture_climate_risks -1.021480e+01 0.413454 -34.981250 14.551659
#         sent_bin_weight_agriculture_food_prices -2.272662e+01 0.127878 -52.146987  6.693740
# sent_bin_weight_agriculture_infrastructure_tech  1.463118e+01 0.203696  -8.114418 37.376788
#          sent_bin_weight_agriculture_regulation  6.822653e+00 0.463942 -11.658531 25.303837
#         sent_bin_weight_agriculture_rural_labor  2.576590e+00 0.793107 -16.945773 22.098953
#               sent_bin_weight_agriculture_water -1.943588e+01 0.025793 -36.452621 -2.419130
#          sent_bin_weight_commodities_extraction -1.305256e+01 0.150106 -30.944509  4.839391
#       sent_bin_weight_commodities_market_prices -1.354300e+01 0.242264 -36.449642  9.363637
#           sent_bin_weight_commodities_materials  3.068196e+01 0.064752  -1.928648 63.292561
#          sent_bin_weight_commodities_regulation -5.984016e+00 0.472456 -22.507927 10.539896
#               sent_bin_weight_commodities_risks -8.957597e+00 0.242918 -24.129727  6.214533
#                   sent_bin_weight_energy_fossil  6.216843e+00 0.517046 -12.826837 25.260523
#          sent_bin_weight_energy_infrastructures  3.715199e+00 0.889302 -49.337873 56.768271
#                  sent_bin_weight_energy_nuclear -1.632811e+00 0.950229 -53.629190 50.363568
#               sent_bin_weight_energy_regulation -9.228332e-01 0.911630 -17.450219 15.604553
#               sent_bin_weight_energy_renewables -7.303549e+00 0.425165 -25.465275 10.858177
#           sent_bin_weight_finance_central_banks -1.442007e+01 0.409699 -49.101522 20.261389
#                  sent_bin_weight_finance_credit -5.809776e+00 0.460033 -21.409950  9.790397
#       sent_bin_weight_finance_financial_markets -5.767055e+00 0.737374 -39.938089 28.403978
#            sent_bin_weight_finance_private_debt -1.425327e+01 0.345267 -44.174243 15.667709
#              sent_bin_weight_finance_regulation  3.909124e+00 0.824679 -31.159981 38.978229
#          sent_bin_weight_finance_sovereign_debt  2.665839e+01 0.291805 -23.404908 76.721685
#           sent_bin_weight_finance_systemic_risk  5.149268e+00 0.708284 -22.192239 32.490774
#              sent_bin_weight_industry_factories  2.252182e+01 0.113310  -5.491476 50.535121
#              sent_bin_weight_industry_logistics -5.758094e+00 0.555047 -25.125631 13.609443
#           sent_bin_weight_industry_productivity -1.471177e+00 0.856022 -17.586404 14.644050
#             sent_bin_weight_industry_regulation  6.787949e+00 0.473163 -11.985941 25.561840
#                  sent_bin_weight_industry_risks -8.822494e+00 0.269298 -24.626865  6.981877
#          sent_bin_weight_industry_supply_chains  1.530695e+00 0.847573 -14.296314 17.357703
#
# ================================================================================
#  PIPELINE ACADÉMIQUE : US (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ✓ Bruit blanc validé au Lag 1 (SGL Ljung-Box P-value : 0.2101)
#
# ================================================================================
#  RÉSULTATS COMPARATIFS FINAUX : US (STABILISÉ À 1 LAG(S))
# ================================================================================
#
#
# ▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs
#   Tuning Data-Driven : Lambda = 0.0034 | Alpha = 0.50
#   Variables totales (OLS) : 30 (dont 22 GDELT)
#   R-squared (Global/Adj) : 0.6828 / 0.5826
#   Ljung-Box P-value : 0.2101
# ------------------------------------------------------------
#                                        Variable   Coefficient  P-value  CI_Lower  CI_Upper
#                                       Intercept -8.323962e-17 1.000000 -0.020265  0.020265
#                                            rate  1.422754e-02 0.410945 -0.019973  0.048428
#                                           unemp  8.154270e-03 0.712809 -0.035694  0.052003
#                                          indpro  3.395497e-02 0.117552 -0.008723  0.076633
#                                           money -2.707381e-02 0.244228 -0.072944  0.018796
#                                              fx -9.874371e-04 0.932308 -0.024005  0.022030
#                                            mich  4.682604e-03 0.695170 -0.018969  0.028334
#                                             oil -7.529679e-04 0.961292 -0.031472  0.029966
#                                  inflation_lag1  7.246319e-02 0.000033  0.039437  0.105489
#       sent_bin_weight_agriculture_climate_risks  3.866363e-02 0.020609  0.006063  0.071265
#         sent_bin_weight_agriculture_food_prices  9.457366e-03 0.721776 -0.043113  0.062028
# sent_bin_weight_agriculture_infrastructure_tech -3.860216e-02 0.001037 -0.061244 -0.015960
#          sent_bin_weight_agriculture_regulation  1.773218e-02 0.207592 -0.010012  0.045476
#         sent_bin_weight_agriculture_rural_labor -4.890348e-03 0.699391 -0.029957  0.020176
#               sent_bin_weight_agriculture_water -1.097625e-02 0.347298 -0.034047  0.012094
#          sent_bin_weight_commodities_extraction -5.329444e-02 0.183238 -0.132215  0.025626
#       sent_bin_weight_commodities_market_prices -2.001208e-02 0.272793 -0.056030  0.016005
#           sent_bin_weight_commodities_materials  6.290812e-02 0.090114 -0.010030  0.135846
#               sent_bin_weight_commodities_risks  3.677349e-03 0.765740 -0.020755  0.028109
#                   sent_bin_weight_energy_fossil  8.126917e-03 0.492567 -0.015293  0.031547
#          sent_bin_weight_energy_infrastructures -5.448768e-03 0.719051 -0.035430  0.024532
#               sent_bin_weight_energy_regulation -3.117946e-03 0.795152 -0.026893  0.020657
#           sent_bin_weight_finance_central_banks -3.396977e-02 0.223095 -0.088961  0.021021
#                  sent_bin_weight_finance_credit -2.161195e-03 0.874863 -0.029332  0.025009
#       sent_bin_weight_finance_financial_markets  3.616571e-02 0.122233 -0.009877  0.082209
#            sent_bin_weight_finance_private_debt  1.046243e-03 0.962974 -0.043578  0.045671
#              sent_bin_weight_finance_regulation  1.944524e-02 0.227169 -0.012313  0.051203
#          sent_bin_weight_finance_sovereign_debt -1.350355e-02 0.713043 -0.086179  0.059172
#           sent_bin_weight_finance_systemic_risk -2.988061e-02 0.076613 -0.063017  0.003256
#              sent_bin_weight_industry_factories  4.524950e-03 0.817888 -0.034380  0.043430
#              sent_bin_weight_industry_logistics -1.060381e-02 0.382522 -0.034599  0.013391
#
# ================================================================================
#  PIPELINE ACADÉMIQUE : UK (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ↻ Autocorrélation résiduelle au Lag 1 (P-value : 0.0180). Ajout du lag 2...
#   ✓ Bruit blanc validé au Lag 2 (SGL Ljung-Box P-value : 0.2204)
#
# ================================================================================
#  RÉSULTATS COMPARATIFS FINAUX : UK (STABILISÉ À 2 LAG(S))
# ================================================================================
#
#
# ▶ MODÈLE 2 : SPARSE GROUP LASSO (Simon et al., 2013) - Sélection intra-secteurs
#   Tuning Data-Driven : Lambda = 0.1000 | Alpha = 0.50
#   Variables totales (OLS) : 36 (dont 28 GDELT)
#   R-squared (Global/Adj) : 0.4187 / 0.1665
#   Ljung-Box P-value : 0.2204
# ------------------------------------------------------------
#                                        Variable   Coefficient  P-value  CI_Lower  CI_Upper
#                                       Intercept  2.831069e-15 1.000000 -2.009967  2.009967
#                                            rate  2.258549e-01 0.888742 -2.975373  3.427083
#                                           unemp -1.427796e+00 0.258971 -3.926295  1.070703
#                                          indpro -1.855103e-01 0.880943 -2.641466  2.270445
#                                           money  1.788370e+00 0.272290 -1.430210  5.006949
#                                              fx  3.179610e-01 0.802074 -2.196916  2.832838
#                                             oil -3.764800e-02 0.976661 -2.589459  2.514163
#                                  inflation_lag1 -5.491511e+00 0.000058 -8.067627 -2.915396
#                                  inflation_lag2 -2.550955e+00 0.035554 -4.925366 -0.176543
#        sent_bin_weight_agriculture_agribusiness -1.397564e+00 0.325526 -4.208110  1.412982
#       sent_bin_weight_agriculture_climate_risks -9.796390e-01 0.598826 -4.669082  2.709804
# sent_bin_weight_agriculture_infrastructure_tech  5.144643e-01 0.733253 -2.477928  3.506856
#          sent_bin_weight_agriculture_regulation -4.968484e-01 0.682698 -2.905797  1.912100
#         sent_bin_weight_agriculture_rural_labor  1.320382e+00 0.363623 -1.554468  4.195232
#          sent_bin_weight_commodities_extraction  5.355331e-01 0.887311 -6.957961  8.029027
#       sent_bin_weight_commodities_market_prices -4.885477e+00 0.006289 -8.351256 -1.419699
#           sent_bin_weight_commodities_materials  2.450096e+00 0.516799 -5.034718  9.934910
#          sent_bin_weight_commodities_regulation  1.283727e+00 0.345463 -1.407262  3.974717
#               sent_bin_weight_commodities_risks -1.279156e+00 0.296751 -3.702119  1.143807
#                   sent_bin_weight_energy_fossil  7.523317e-01 0.566173 -1.845504  3.350167
#          sent_bin_weight_energy_infrastructures -4.185967e+00 0.086431 -8.984313  0.612378
#                  sent_bin_weight_energy_nuclear  1.577596e+00 0.480754 -2.852521  6.007712
#               sent_bin_weight_energy_regulation -1.783784e+00 0.156326 -4.263938  0.696369
#               sent_bin_weight_energy_renewables  3.589619e-01 0.780837 -2.198811  2.916735
#                    sent_bin_weight_energy_risks  3.611367e+00 0.007944  0.970859  6.251875
#           sent_bin_weight_finance_central_banks  5.340455e+00 0.030086  0.527275 10.153634
#                  sent_bin_weight_finance_credit -2.428823e+00 0.114615 -5.458417  0.600772
#       sent_bin_weight_finance_financial_markets -3.703982e+00 0.139872 -8.646516  1.238552
#            sent_bin_weight_finance_private_debt  1.667261e+00 0.349944 -1.860510  5.195031
#              sent_bin_weight_finance_regulation -1.172696e+00 0.338015 -3.593093  1.247701
#           sent_bin_weight_finance_systemic_risk  3.192760e+00 0.083643 -0.433925  6.819445
#              sent_bin_weight_industry_factories -1.256419e+00 0.412949 -4.293369  1.780530
#              sent_bin_weight_industry_logistics  2.010021e+00 0.147373 -0.723500  4.743542
#           sent_bin_weight_industry_productivity -4.993133e-01 0.715565 -3.215422  2.216795
#             sent_bin_weight_industry_regulation  1.944501e+00 0.236469 -1.298751  5.187753
#                  sent_bin_weight_industry_risks -2.179190e+00 0.087694 -4.687373  0.328992
#          sent_bin_weight_industry_supply_chains  1.668422e-01 0.896878 -2.385709  2.719393

# %% [markdown]
# #### Robustness - only macro

# %%
# ==============================================================================
# CELLULE 4 (BENCHMARK) : EXÉCUTION DU PIPELINE "MACRO + LAGS UNIQUEMENT" (ARX)
# ==============================================================================
final_results_macro_only = {}

for region, config in CONFIG_REGIONS.items():
    print(f'\n' + '=' * 80)
    print(f' BENCHMARK MACRO-ONLY : {region.upper()} (RECHERCHE DYNAMIQUE DE LAGS)')
    print(f'================================================================================')

    # 1. Préparation des données macro
    df_macro = fetch_and_prep_macro_dynamic(config, START_DATE, END_DATE, region=region)
    df_macro = df_macro[df_macro.index >= MIN_INDEX_DATE]

    # 2. Chargement GDELT (UNIQUEMENT POUR ALIGNER LES DATES ET GARANTIR LE MÊME 'N')
    cols_gdelt = get_filtered_gdelt_cols(df_geo)
    df_gdelt_raw = df_geo[df_geo['region_key'] == region].set_index('period')[cols_gdelt]
    if 'sent_cont_weight_finance_international_orgs' in df_gdelt_raw.columns:
        df_gdelt_raw = df_gdelt_raw.drop(columns=['sent_cont_weight_finance_international_orgs'])

    df_gdelt_stat, diff_count = strict_stationarize(df_gdelt_raw)
    
    # La jointure garantit que nous avons les mêmes lignes (Même échantillon N)
    df_final = df_gdelt_stat.join(df_macro, how='inner') 
    y_raw = df_final['inflation']

    # Désaisonnalisation éventuelle
    y_corr = (y_raw - seasonal_decompose(y_raw, model='additive', period=12).seasonal).dropna() if config['deseasonalize_y'] else y_raw.dropna()
    X_full = df_final.drop(columns=['inflation'])
    y_corr, X_contemp = y_corr.align(X_full, join='inner')

    y_centered = y_corr - y_corr.mean()
    X_scaled_full = pd.DataFrame(StandardScaler().fit_transform(X_contemp), columns=X_contemp.columns, index=X_contemp.index)

    # 3. Isolation exclusive des variables macro (on exclut GDELT des prédicteurs)
    macro_base_cols = [c for c in X_scaled_full.columns if c in df_macro.columns and not c.startswith('inflation_lag') and c != 'inflation']

    # --- RECHERCHE DYNAMIQUE DU NOMBRE DE LAGS (OLS STANDARD) ---
    max_lags_to_test = 12
    best_iteration_arx = None

    for current_lag in range(1, max_lags_to_test + 1):
        active_lags = [f'inflation_lag{i}' for i in range(1, current_lag + 1)]
        current_cols = macro_base_cols + active_lags # UNIQUEMENT MACRO + LAGS
        X_current = X_scaled_full[current_cols]
        
        # Estimation OLS directe (Pas besoin de Lasso pour ~10 variables)
        X_current_with_const = sm.add_constant(X_current)
        results = sm.OLS(y_centered.values, X_current_with_const.values).fit()
        
        # Test de Ljung-Box sur les résidus
        lb_pval = acorr_ljungbox(results.resid, lags=[12], return_df=True)['lb_pvalue'].values[0]

        # Sauvegarde des résultats de l'itération
        post_arx_df = pd.DataFrame({
            'Variable': ['Intercept'] + current_cols,
            'Coefficient': results.params,
            'P-value': results.pvalues,
        })
        
        best_iteration_arx = (current_lag, current_cols, post_arx_df, results.rsquared, results.rsquared_adj, lb_pval)

        # Règle d'arrêt : Bruit blanc validé
        if lb_pval >= 0.05:
            print(f'  ✓ Bruit blanc validé au Lag {current_lag} (OLS Ljung-Box P-value : {lb_pval:.4f})')
            break
        else:
            print(f'  ↻ Autocorrélation résiduelle au Lag {current_lag} (P-value : {lb_pval:.4f}). Ajout du lag {current_lag+1}...')

    # --- AFFICHAGE DES RÉSULTATS DU BENCHMARK ---
    lag_arx, vars_arx, df_arx, r2_arx, r2_adj_arx, pval_arx = best_iteration_arx
    
    print(f'\n' + '=' * 80)
    print(f' RÉSULTATS FINAUX BENCHMARK MACRO : {region.upper()} (STABILISÉ À {lag_arx} LAG(S))')
    print(f'=' * 80)
    print(f'  Modèle : ARX (OLS Standard)')
    print(f'  Variables : {len(vars_arx)} (Macroéconomiques + Lags uniquement)')
    print(f'  R-squared (Global/Adj) : {r2_arx:.4f} / {r2_adj_arx:.4f}')
    print(f'  Ljung-Box P-value : {pval_arx:.4f}')
    print("-" * 60)
    print(df_arx.to_string(index=False))

    final_results_macro_only[region] = {
        'Vars': vars_arx, 
        'OLS': df_arx, 
        'R2_adj': r2_adj_arx
    }
# Out:
# ================================================================================
#  BENCHMARK MACRO-ONLY : FRANCE (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ✓ Bruit blanc validé au Lag 1 (OLS Ljung-Box P-value : 0.9577)
#
# ================================================================================
#  RÉSULTATS FINAUX BENCHMARK MACRO : FRANCE (STABILISÉ À 1 LAG(S))
# ================================================================================
#   Modèle : ARX (OLS Standard)
#   Variables : 8 (Macroéconomiques + Lags uniquement)
#   R-squared (Global/Adj) : 0.0487 / -0.0290
#   Ljung-Box P-value : 0.9577
# ------------------------------------------------------------
#       Variable   Coefficient  P-value
#      Intercept -1.554312e-15 1.000000
#           rate -5.943734e+00 0.386801
#          unemp -3.736583e+00 0.578128
#         indpro -3.795612e+00 0.583316
#          money  4.581004e+00 0.498421
#             fx -6.188178e-01 0.929013
#           mich -1.941923e+00 0.775118
#            oil -6.228963e-01 0.928529
# inflation_lag1 -1.207525e+01 0.064720
#
# ================================================================================
#  BENCHMARK MACRO-ONLY : US (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ✓ Bruit blanc validé au Lag 1 (OLS Ljung-Box P-value : 0.2018)
#
# ================================================================================
#  RÉSULTATS FINAUX BENCHMARK MACRO : US (STABILISÉ À 1 LAG(S))
# ================================================================================
#   Modèle : ARX (OLS Standard)
#   Variables : 8 (Macroéconomiques + Lags uniquement)
#   R-squared (Global/Adj) : 0.5526 / 0.5220
#   Ljung-Box P-value : 0.2018
# ------------------------------------------------------------
#       Variable   Coefficient      P-value
#      Intercept -2.469270e-17 1.000000e+00
#           rate  1.757031e-02 2.002638e-01
#          unemp  5.198354e-04 9.810178e-01
#         indpro  3.331869e-02 1.132276e-01
#          money -9.655609e-03 5.577810e-01
#             fx -1.430986e-03 8.990050e-01
#           mich -6.871041e-04 9.518082e-01
#            oil  2.341310e-02 9.605929e-02
# inflation_lag1  1.090077e-01 3.595933e-14
#
# ================================================================================
#  BENCHMARK MACRO-ONLY : UK (RECHERCHE DYNAMIQUE DE LAGS)
# ================================================================================
#   ↻ Autocorrélation résiduelle au Lag 1 (P-value : 0.0001). Ajout du lag 2...
#   ↻ Autocorrélation résiduelle au Lag 2 (P-value : 0.0001). Ajout du lag 3...
#   ✓ Bruit blanc validé au Lag 3 (OLS Ljung-Box P-value : 0.0530)
#
# ================================================================================
#  RÉSULTATS FINAUX BENCHMARK MACRO : UK (STABILISÉ À 3 LAG(S))
# ================================================================================
#   Modèle : ARX (OLS Standard)
#   Variables : 9 (Macroéconomiques + Lags uniquement)
#   R-squared (Global/Adj) : 0.2170 / 0.1530
#   Ljung-Box P-value : 0.0530
# ------------------------------------------------------------
#       Variable   Coefficient  P-value
#      Intercept -4.996004e-16 1.000000
#           rate  6.112991e-01 0.594531
#          unemp -9.677644e-01 0.357880
#         indpro -1.953179e-01 0.853521
#          money  7.057252e-01 0.540230
#             fx  1.790517e-01 0.866589
#            oil -6.745033e-01 0.539491
# inflation_lag1 -3.655881e+00 0.001092
# inflation_lag2  1.866230e-01 0.869862
# inflation_lag3  4.147754e+00 0.000247
