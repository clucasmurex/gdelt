# %% [markdown]
# ### Imports and data

# %%
import pandas as pd
from pathlib import Path
import pandas_datareader.data as web
import datetime
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
# !pip install scikit-learn
from sklearn.linear_model import LassoCV
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: scikit-learn in /home/clucas/venvs/gdelt/lib/python3.12/site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in /home/clucas/venvs/gdelt/lib/python3.12/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in /home/clucas/venvs/gdelt/lib/python3.12/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.4.0 in /home/clucas/venvs/gdelt/lib/python3.12/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in /home/clucas/venvs/gdelt/lib/python3.12/site-packages (from scikit-learn) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /home/clucas/venvs/gdelt/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2
# [notice] To update, run: pip install --upgrade pip

# %%
# ── 1. DICTIONNAIRE DES TICKERS FRED ──
MACRO_TICKERS = {
    "US": "CPIAUCSL",                 # US Consumer Price Index
    "European Union": "CP0000EZ19M086NEST", # Euro Area CPI
    "France": "CP0000FRM086NEST",
    "China": "CHNCPIALLMINMEI",      # China CPI (OCDE)
    "Japan": "CPALCY01JPM661N",
    "India" : "INDCPIALLMINMEI",
    "Africa" : "ZAFCPIALLMINMEI",       # South Africa CPI (Proxy Afrique)
    "Russia" : "RUSCPIALLMINMEI",
    "Middle East": "ISRCPIALLMINMEI", #Isarel CPI (Proxy Moyen-Orient)
    "North America": "CANCPALTT01IXOBSAM",  
    "South America": "BRACPIALLMINMEI", # Brésil CPI (Proxy Amérique du Sud)
    "South East Asia": "IDNCPIALLMINMEI", 
}

# %%
import pandas as pd
from pathlib import Path

# Définition de votre seuil académique de départ
start_date = pd.to_datetime('2015-03-02')

# ── 1. Chargement de la base GLOBALE (indicators) ──
dir_global = Path("./indicators")
if dir_global.exists():
    files_global = list(dir_global.glob("*.parquet"))
    df_global = pd.concat([pd.read_parquet(f) for f in files_global], ignore_index=True)
    df_global = df_global.groupby('period').max().reset_index()
    df_global['period'] = pd.to_datetime(df_global['period'])
    
    # 🔥 FILTRAGE TEMPOREL STRICT ICI
    df_global = df_global[df_global['period'] >= start_date]
    
    df_global = df_global.sort_values('period')
    print(f"✓ Base GLOBALE chargée : {len(df_global)} jours, de {df_global['period'].min().date()} à {df_global['period'].max().date()}")
else:
    df_global = None
    print("⚠ Dossier ./indicators introuvable.")

# ── 2. Chargement de la base RÉGIONALE (indicators_geo) ──
dir_geo = Path("./indicators_geo") # Modifiez si votre dossier s'appelle autrement
if dir_geo.exists():
    files_geo = list(dir_geo.glob("*.parquet"))
    df_geo = pd.concat([pd.read_parquet(f) for f in files_geo], ignore_index=True)
    df_geo = df_geo.groupby(['period', 'region_key']).max().reset_index()
    df_geo['period'] = pd.to_datetime(df_geo['period'])
    
    # 🔥 FILTRAGE TEMPOREL STRICT ICI
    df_geo = df_geo[df_geo['period'] >= start_date]
    
    df_geo = df_geo.sort_values(['period', 'region_key'])
    print(f"✓ Base RÉGIONALE chargée : {len(df_geo)} lignes, avec les régions {list(df_geo['region_key'].unique())}")
    print(f"  Départ de la série : {df_geo['period'].min().date()}")
else:
    df_geo = None
    print("⚠ Dossier ./indicators_geo introuvable.")
# Out:
# ✓ Base GLOBALE chargée : 4111 jours, de 2015-03-02 à 2026-06-19
# ✓ Base RÉGIONALE chargée : 53443 lignes, avec les régions ['Africa', 'China', 'European Union', 'France', 'India', 'Japan', 'Lebanon', 'Middle East', 'North America', 'Russia', 'South America', 'South East Asia', 'US']
#   Départ de la série : 2015-03-02

# %%
import pandas as pd
import numpy as np
import pandas_datareader.data as web
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lars

MACRO_TICKERS = {
    "US": "CPIAUCSL",                 
    "European Union": "CP0000EZ19M086NEST", 
    "France": "CP0000FRM086NEST",
    "China": "CHNCPIALLMINMEI",      
    "Japan": "CPALCY01JPM661N",
    "India" : "INDCPIALLMINMEI",
    "Africa" : "ZAFCPIALLMINMEI",       
    "Russia" : "RUSCPIALLMINMEI",
    "Middle East": "ISRCPIALLMINMEI", 
    "North America": "CANCPALTT01IXOBSAM",  
    "South America": "BRACPIALLMINMEI", 
    "South East Asia": "IDNCPIALLMINMEI", 
}

def run_post_lasso_inflation_att(df_geo, target_region, n_text_features=5, start_date='2015-03-01'):
    """
    Pipeline LASSO : Sélectionne les meilleurs narratifs (UNIQUEMENT att_weight) 
    SANS contrôler pour l'inertie de l'inflation (Pas de Lag AR1).
    """
    print(f"\n{'='*60}\n🚀 ANALYSE LASSO (FOCUS ATTENTION - SANS LAG) : {target_region}\n{'='*60}")
    
    # ====================================================
    # ÉTAPE 1 : TARGET 
    # ====================================================
    ticker = MACRO_TICKERS.get(target_region)
    if not ticker:
        raise ValueError(f"Aucun ticker FRED pour la région {target_region}")
        
    print(f"1. Téléchargement du CPI ({ticker})...")
    # On recule juste de 12 mois pour le calcul du YoY
    fred_start = pd.to_datetime(start_date) - pd.DateOffset(months=12)
    df_cpi = web.DataReader(ticker, 'fred', fred_start)
    
    df_cpi['Inflation_YoY'] = df_cpi[ticker].pct_change(12) * 100
    
    df_cpi = df_cpi.dropna()
    df_cpi.index.name = 'period'
    
    # ====================================================
    # ÉTAPE 2 : AGRÉGATION DES NARRATIFS GDELT (FILTRE STRICT)
    # ====================================================
    print("2. Agrégation mensuelle des narratifs (Filtre: att_weight uniquement)...")
    df_region = df_geo[df_geo['region_key'] == target_region].copy()
    
    # On ne garde QUE les colonnes att_weight des sous-secteurs
    feature_cols = [c for c in df_region.columns if c.startswith('att_weight_') and c.count('_') >= 3]
    
    df_monthly = df_region.set_index('period')[feature_cols].resample('MS').mean()
    
    # ====================================================
    # ÉTAPE 3 : FUSION ET STANDARDISATION
    # ====================================================
    print("3. Alignement des données et standardisation (Z-scores)...")
    df_merged = df_monthly.join(df_cpi[['Inflation_YoY']], how='inner').dropna()
    
    y = df_merged['Inflation_YoY']
    X = df_merged.drop(columns=['Inflation_YoY'])
    
    scaler = StandardScaler()
    X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns, index=X.index)
    
    # ====================================================
    # ÉTAPE 4 : SÉLECTION LARS COMPÉTITIVE
    # ====================================================
    print(f"4. Sélection algorithmique de {n_text_features} variables (LARS)...")
    lars = Lars(n_nonzero_coefs=n_text_features, fit_intercept=True)
    lars.fit(X_scaled, y)
    
    selected_features = X.columns[lars.coef_ != 0].tolist()
        
    print("\n🌟 Variables sélectionnées par le LASSO :")
    for feat in selected_features:
        print(f"   - {feat}")
        
    # ====================================================
    # ÉTAPE 5 : POST-LASSO OLS (Inférence)
    # ====================================================
    print("\n5. Estimation OLS Post-LASSO...")
    X_selected = X_scaled[selected_features]
    X_selected = sm.add_constant(X_selected) 
    
    ols_model = sm.OLS(y, X_selected).fit()
    
    print("\n" + "="*60)
    print(ols_model.summary())
    print("="*60)
    
    return df_merged, ols_model

# ------------------------------------------------------------------------------
# 🚀 EXÉCUTION
# ------------------------------------------------------------------------------

# %%
import pandas as pd
import numpy as np
import pandas_datareader.data as web
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lars

MACRO_TICKERS = {
    "US": "CPIAUCSL",                 
    "European Union": "CP0000EZ19M086NEST", 
    "France": "CP0000FRM086NEST",
    "China": "CHNCPIALLMINMEI",      
    "Japan": "CPALCY01JPM661N",
    "India" : "INDCPIALLMINMEI",
    "Africa" : "ZAFCPIALLMINMEI",       
    "Russia" : "RUSCPIALLMINMEI",
    "Middle East": "ISRCPIALLMINMEI", 
    "North America": "CANCPALTT01IXOBSAM",  
    "South America": "BRACPIALLMINMEI", 
    "South East Asia": "IDNCPIALLMINMEI", 
}

def run_post_lasso_arx_inflation(df_geo, target_region, n_text_features=5, start_date='2015-03-01'):
    """
    Pipeline LASSO ARX : Sélectionne les meilleurs narratifs (UNIQUEMENT att_weight) 
    TOUT EN contrôlant l'inertie de l'inflation.
    """
    print(f"\n{'='*60}\n🚀 ANALYSE LASSO ARX (FOCUS ATTENTION) : {target_region}\n{'='*60}")
    
    # ====================================================
    # ÉTAPE 1 : TARGET ET CRÉATION DU LAG AR(1)
    # ====================================================
    ticker = MACRO_TICKERS.get(target_region)
    if not ticker:
        raise ValueError(f"Aucun ticker FRED pour la région {target_region}")
        
    print(f"1. Téléchargement du CPI ({ticker}) et création du Lag AR(1)...")
    fred_start = pd.to_datetime(start_date) - pd.DateOffset(months=15)
    df_cpi = web.DataReader(ticker, 'fred', fred_start)
    
    df_cpi['Inflation_YoY'] = df_cpi[ticker].pct_change(12) * 100
    df_cpi['Inflation_lag1'] = df_cpi['Inflation_YoY'].shift(1)
    
    df_cpi = df_cpi.dropna()
    df_cpi.index.name = 'period'
    
    # ====================================================
    # ÉTAPE 2 : AGRÉGATION DES NARRATIFS GDELT (FILTRE STRICT)
    # ====================================================
    print("2. Agrégation mensuelle des narratifs (Filtre: att_weight uniquement)...")
    df_region = df_geo[df_geo['region_key'] == target_region].copy()
    
    # 🔥 MODIFICATION ICI : On ne garde QUE les colonnes att_weight des sous-secteurs
    feature_cols = [c for c in df_region.columns if c.startswith('att_weight_') and c.count('_') >= 3]
    
    df_monthly = df_region.set_index('period')[feature_cols].resample('MS').mean()
    
    # ====================================================
    # ÉTAPE 3 : FUSION ET STANDARDISATION
    # ====================================================
    print("3. Alignement des données et standardisation (Z-scores)...")
    df_merged = df_monthly.join(df_cpi[['Inflation_YoY', 'Inflation_lag1']], how='inner').dropna()
    
    y = df_merged['Inflation_YoY']
    X = df_merged.drop(columns=['Inflation_YoY'])
    
    scaler = StandardScaler()
    X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns, index=X.index)
    
    # ====================================================
    # ÉTAPE 4 : SÉLECTION LARS COMPÉTITIVE
    # ====================================================
    print(f"4. Sélection algorithmique de {n_text_features + 1} variables (LARS)...")
    lars = Lars(n_nonzero_coefs=n_text_features + 1, fit_intercept=True)
    lars.fit(X_scaled, y)
    
    selected_features = X.columns[lars.coef_ != 0].tolist()
    
    if 'Inflation_lag1' not in selected_features:
        selected_features.append('Inflation_lag1')
        
    print("\n🌟 Variables sélectionnées par le LASSO :")
    for feat in selected_features:
        print(f"   - {feat}")
        
    # ====================================================
    # ÉTAPE 5 : POST-LASSO OLS (Inférence)
    # ====================================================
    print("\n5. Estimation OLS Post-LASSO ARX...")
    X_selected = X_scaled[selected_features]
    X_selected = sm.add_constant(X_selected) 
    
    ols_model = sm.OLS(y, X_selected).fit()
    
    print("\n" + "="*60)
    print(ols_model.summary())
    print("="*60)
    
    return df_merged, ols_model

# %% [markdown]
# ### I. Targets and inflation
#
# LASSO to see which narratives influence inflation the most

# %%
df_data, model_results = run_post_lasso_inflation_att(df_geo, target_region="France", n_text_features=5)
# Out:
# ============================================================
# 🚀 ANALYSE LASSO (FOCUS ATTENTION - SANS LAG) : France
# ============================================================
# 1. Téléchargement du CPI (CP0000FRM086NEST)...
# 2. Agrégation mensuelle des narratifs (Filtre: att_weight uniquement)...
# 3. Alignement des données et standardisation (Z-scores)...
# 4. Sélection algorithmique de 5 variables (LARS)...
#
# 🌟 Variables sélectionnées par le LASSO :
#    - att_weight_energy_infrastructures
#    - att_weight_energy_renewables
#    - att_weight_finance_central_banks
#    - att_weight_real_estate_regulation
#    - att_weight_agriculture_infrastructure_tech
#
# 5. Estimation OLS Post-LASSO...
#
# ============================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Inflation_YoY   R-squared:                       0.782
# Model:                            OLS   Adj. R-squared:                  0.773
# Method:                 Least Squares   F-statistic:                     84.58
# Date:                Tue, 04 Aug 2026   Prob (F-statistic):           2.38e-37
# Time:                        14:18:13   Log-Likelihood:                -167.73
# No. Observations:                 124   AIC:                             347.5
# Df Residuals:                     118   BIC:                             364.4
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# const                                          1.9900      0.086     23.098      0.000       1.819       2.161
# att_weight_energy_infrastructures             -0.0152      0.131     -0.117      0.907      -0.274       0.243
# att_weight_energy_renewables                   0.2724      0.117      2.328      0.022       0.041       0.504
# att_weight_finance_central_banks               1.2375      0.111     11.111      0.000       1.017       1.458
# att_weight_real_estate_regulation             -0.4740      0.090     -5.256      0.000      -0.653      -0.295
# att_weight_agriculture_infrastructure_tech     0.4259      0.109      3.897      0.000       0.209       0.642
# ==============================================================================
# Omnibus:                        2.706   Durbin-Watson:                   0.881
# Prob(Omnibus):                  0.258   Jarque-Bera (JB):                2.696
# Skew:                           0.350   Prob(JB):                        0.260
# Kurtosis:                       2.824   Cond. No.                         2.90
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ============================================================

# %%
df_data, model_results = run_post_lasso_arx_inflation(df_geo, target_region="France", n_text_features=6)
# Out:
# ============================================================
# 🚀 ANALYSE LASSO ARX (FOCUS ATTENTION) : France
# ============================================================
# 1. Téléchargement du CPI (CP0000FRM086NEST) et création du Lag AR(1)...
# 2. Agrégation mensuelle des narratifs (Filtre: att_weight uniquement)...
# 3. Alignement des données et standardisation (Z-scores)...
# 4. Sélection algorithmique de 7 variables (LARS)...
#
# 🌟 Variables sélectionnées par le LASSO :
#    - att_weight_finance_private_debt
#    - att_weight_real_estate_regulation
#    - att_weight_agriculture_infrastructure_tech
#    - att_weight_agriculture_rural_labor
#    - att_weight_transport_infrastructure
#    - att_weight_commodities_market_prices
#    - Inflation_lag1
#
# 5. Estimation OLS Post-LASSO ARX...
#
# ============================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Inflation_YoY   R-squared:                       0.974
# Model:                            OLS   Adj. R-squared:                  0.973
# Method:                 Least Squares   F-statistic:                     628.9
# Date:                Tue, 04 Aug 2026   Prob (F-statistic):           4.39e-89
# Time:                        14:08:02   Log-Likelihood:                -35.068
# No. Observations:                 124   AIC:                             86.14
# Df Residuals:                     116   BIC:                             108.7
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# const                                          1.9900      0.030     66.759      0.000       1.931       2.049
# att_weight_finance_private_debt               -0.0265      0.032     -0.838      0.404      -0.089       0.036
# att_weight_real_estate_regulation             -0.0493      0.034     -1.449      0.150      -0.117       0.018
# att_weight_agriculture_infrastructure_tech     0.1258      0.058      2.177      0.032       0.011       0.240
# att_weight_agriculture_rural_labor            -0.0577      0.033     -1.761      0.081      -0.123       0.007
# att_weight_transport_infrastructure            0.0503      0.030      1.657      0.100      -0.010       0.110
# att_weight_commodities_market_prices           0.0508      0.058      0.877      0.382      -0.064       0.166
# Inflation_lag1                                 1.8448      0.039     47.917      0.000       1.769       1.921
# ==============================================================================
# Omnibus:                        0.802   Durbin-Watson:                   2.114
# Prob(Omnibus):                  0.670   Jarque-Bera (JB):                0.426
# Skew:                           0.097   Prob(JB):                        0.808
# Kurtosis:                       3.212   Cond. No.                         4.11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ============================================================

# %%
df_data, model_results = run_post_lasso_inflation_att(df_geo, target_region="US", n_text_features=5)
# Out:
# ============================================================
# 🚀 ANALYSE LASSO (FOCUS ATTENTION - SANS LAG) : US
# ============================================================
# 1. Téléchargement du CPI (CPIAUCSL)...
# 2. Agrégation mensuelle des narratifs (Filtre: att_weight uniquement)...
# 3. Alignement des données et standardisation (Z-scores)...
# 4. Sélection algorithmique de 5 variables (LARS)...
#
# 🌟 Variables sélectionnées par le LASSO :
#    - att_weight_energy_infrastructures
#    - att_weight_finance_central_banks
#    - att_weight_finance_sovereign_debt
#    - att_weight_real_estate_regulation
#    - att_weight_commodities_market_prices
#
# 5. Estimation OLS Post-LASSO...
#
# ============================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Inflation_YoY   R-squared:                       0.714
# Model:                            OLS   Adj. R-squared:                  0.703
# Method:                 Least Squares   F-statistic:                     64.42
# Date:                Tue, 04 Aug 2026   Prob (F-statistic):           2.09e-33
# Time:                        14:20:53   Log-Likelihood:                -208.37
# No. Observations:                 135   AIC:                             428.7
# Df Residuals:                     129   BIC:                             446.2
# Df Model:                           5
# Covariance Type:            nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# const                                    2.9265      0.100     29.347      0.000       2.729       3.124
# att_weight_energy_infrastructures        0.3743      0.131      2.848      0.005       0.114       0.634
# att_weight_finance_central_banks         0.6914      0.195      3.540      0.001       0.305       1.078
# att_weight_finance_sovereign_debt        0.2677      0.203      1.317      0.190      -0.134       0.670
# att_weight_real_estate_regulation       -0.8389      0.104     -8.087      0.000      -1.044      -0.634
# att_weight_commodities_market_prices     0.3865      0.123      3.136      0.002       0.143       0.630
# ==============================================================================
# Omnibus:                       12.567   Durbin-Watson:                   0.411
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               13.182
# Skew:                           0.715   Prob(JB):                      0.00137
# Kurtosis:                       3.545   Cond. No.                         4.48
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ============================================================

# %%
df_data, model_results = run_post_lasso_arx_inflation(df_geo, target_region="US", n_text_features=6)
# Out:
# ============================================================
# 🚀 ANALYSE LASSO ARX (FOCUS ATTENTION) : US
# ============================================================
# 1. Téléchargement du CPI (CPIAUCSL) et création du Lag AR(1)...
# 2. Agrégation mensuelle des narratifs (Filtre: att_weight uniquement)...
# 3. Alignement des données et standardisation (Z-scores)...
# 4. Sélection algorithmique de 7 variables (LARS)...
#
# 🌟 Variables sélectionnées par le LASSO :
#    - att_weight_energy_renewables
#    - att_weight_finance_financial_markets
#    - att_weight_finance_private_debt
#    - att_weight_finance_systemic_risk
#    - att_weight_agriculture_climate_risks
#    - att_weight_commodities_market_prices
#    - Inflation_lag1
#
# 5. Estimation OLS Post-LASSO ARX...
#
# ============================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Inflation_YoY   R-squared:                       0.979
# Model:                            OLS   Adj. R-squared:                  0.977
# Method:                 Least Squares   F-statistic:                     824.4
# Date:                Tue, 04 Aug 2026   Prob (F-statistic):          5.73e-102
# Time:                        14:08:19   Log-Likelihood:                -33.522
# No. Observations:                 134   AIC:                             83.04
# Df Residuals:                     126   BIC:                             106.2
# Df Model:                           7
# Covariance Type:            nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# const                                    2.9283      0.028    105.776      0.000       2.873       2.983
# att_weight_energy_renewables             0.1490      0.031      4.769      0.000       0.087       0.211
# att_weight_finance_financial_markets    -0.1004      0.031     -3.258      0.001      -0.161      -0.039
# att_weight_finance_private_debt         -0.0596      0.033     -1.781      0.077      -0.126       0.007
# att_weight_finance_systemic_risk        -0.0226      0.037     -0.616      0.539      -0.095       0.050
# att_weight_agriculture_climate_risks    -0.1074      0.039     -2.767      0.007      -0.184      -0.031
# att_weight_commodities_market_prices     0.1711      0.036      4.728      0.000       0.099       0.243
# Inflation_lag1                           1.9320      0.036     53.042      0.000       1.860       2.004
# ==============================================================================
# Omnibus:                        5.189   Durbin-Watson:                   1.483
# Prob(Omnibus):                  0.075   Jarque-Bera (JB):                7.583
# Skew:                           0.006   Prob(JB):                       0.0226
# Kurtosis:                       4.165   Cond. No.                         2.81
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ============================================================

# %% [markdown]
# ### II. Incremental LASSO
#
# Check if, controling the LASSO with macro variables, the results from .I stay the same

# %%
import pandas as pd
import numpy as np
import pandas_datareader.data as web
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LassoLarsIC

# ── DICTIONNAIRE MACRO (TARGET + CONTROLES) ──
MACRO_DATA = {
    "US": {
        "cpi": "CPIAUCSL", 
        "controls": {
            "Macro_Unemployment": "UNRATE",       
            "Macro_InterestRate": "FEDFUNDS"      
        }
    },
    "France": {
        "cpi": "CP0000FRM086NEST", 
        "controls": {
            "Macro_Unemployment": "LRHUTTTTFRM156S", 
            "Macro_InterestRate": "IR3TIB01EZM156N"  
        }
    }
}

def run_fully_data_driven_lasso(df_geo, target_region, start_date='2015-03-01'):
    """
    Pipeline Économétrique Complet :
    1. Sélection 100% Data-Driven via Critère d'Information Bayésien (BIC)
    2. Filtre strict sur l'attention médiatique pure (att_weight)
    3. Forçage Post-LASSO des variables macroéconomiques pour vérifier la valeur ajoutée du texte.
    """
    print(f"\n{'='*75}\n🚀 ANALYSE LASSO DATA-DRIVEN (BIC) + MACRO : {target_region}\n{'='*75}")
    
    if target_region not in MACRO_DATA:
        raise ValueError(f"Veuillez configurer les tickers macro pour la région {target_region} dans MACRO_DATA.")
        
    config = MACRO_DATA[target_region]
    
    # ====================================================
    # ÉTAPE 1 : TARGET ET CONTROLES MACRO (FRED)
    # ====================================================
    print("1. Téléchargement de la Macroéconomie (Inflation, Chômage, Taux)...")
    fred_start = pd.to_datetime(start_date) - pd.DateOffset(months=15)
    
    # Target
    df_macro = web.DataReader(config["cpi"], 'fred', fred_start)
    df_macro['Inflation_YoY'] = df_macro[config["cpi"]].pct_change(12) * 100
    
    # Création du Lag AR(1)
    df_macro['Inflation_lag1'] = df_macro['Inflation_YoY'].shift(1)
    
    # Autres Contrôles
    for col_name, ticker in config["controls"].items():
        df_tmp = web.DataReader(ticker, 'fred', fred_start)
        df_macro[col_name] = df_tmp[ticker]
        
    df_macro = df_macro.drop(columns=[config["cpi"]]).dropna()
    df_macro.index.name = 'period'
    
    # Liste des variables macro à forcer à la fin
    mandatory_controls = ['Inflation_lag1'] + list(config["controls"].keys())
    
    # ====================================================
    # ÉTAPE 2 : NARRATIFS (ATTENTION PURE)
    # ====================================================
    print("2. Agrégation des données textuelles GDELT (att_weight)...")
    df_region = df_geo[df_geo['region_key'] == target_region].copy()
    feature_cols = [c for c in df_region.columns if c.startswith('att_weight_') and c.count('_') >= 3]
    df_monthly = df_region.set_index('period')[feature_cols].resample('MS').mean()
    
    # ====================================================
    # ÉTAPE 3 : ALIGNEMENT & STANDARDISATION
    # ====================================================
    print("3. Alignement temporel et standardisation des features (Z-scores)...")
    df_merged = df_monthly.join(df_macro, how='inner').dropna()
    
    y = df_merged['Inflation_YoY']
    X = df_merged.drop(columns=['Inflation_YoY']) 
    
    scaler = StandardScaler()
    X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns, index=X.index)
    
    # ====================================================
    # ÉTAPE 4 : SÉLECTION DATA-DRIVEN (LASSO-LARS-IC avec BIC)
    # ====================================================
    print("4. Algorithme au travail : Sélection du nombre optimal de variables via BIC...")
    
    # Le critère BIC pénalise fortement la complexité, ce qui évite le sur-apprentissage
    lasso_ic = LassoLarsIC(criterion='bic', fit_intercept=True)
    lasso_ic.fit(X_scaled, y)
    
    # Variables où le coefficient n'a pas été écrasé à Zéro
    selected_by_lasso = X.columns[lasso_ic.coef_ != 0].tolist()
    
    # On isole les variables textuelles sélectionnées (pour y voir clair)
    selected_text_features = [f for f in selected_by_lasso if f not in mandatory_controls]
    
    print(f"\n🔍 Le critère BIC a déterminé que le nombre optimal de narratifs est de : {len(selected_text_features)}")
    for feat in selected_text_features:
        print(f"   - 📰 {feat}")
        
    # ====================================================
    # ÉTAPE 5 : POST-LASSO OLS (FORÇAGE DES CONTRÔLES)
    # ====================================================
    print("\n5. Estimation OLS Post-LASSO (avec forçage de la structure macro)...")
    
    # On unit les narratifs survivants + la structure macro de base
    final_features = list(set(selected_text_features + mandatory_controls))
    
    X_selected = X_scaled[final_features]
    X_selected = sm.add_constant(X_selected) 
    
    ols_model = sm.OLS(y, X_selected).fit()
    
    print("\n" + "="*75)
    print(ols_model.summary())
    print("="*75)
    
    return df_merged, ols_model

# ------------------------------------------------------------------------------
# 🚀 EXÉCUTION
# ------------------------------------------------------------------------------

# %%
df_data, model_results = run_fully_data_driven_lasso(df_geo, target_region="US")
# Out:
# ===========================================================================
# 🚀 ANALYSE LASSO DATA-DRIVEN (BIC) + MACRO : US
# ===========================================================================
# 1. Téléchargement de la Macroéconomie (Inflation, Chômage, Taux)...
# 2. Agrégation des données textuelles GDELT (att_weight)...
# 3. Alignement temporel et standardisation des features (Z-scores)...
# 4. Algorithme au travail : Sélection du nombre optimal de variables via BIC...
#
# 🔍 Le critère BIC a déterminé que le nombre optimal de narratifs est de : 8
#    - 📰 att_weight_energy_renewables
#    - 📰 att_weight_finance_financial_markets
#    - 📰 att_weight_finance_private_debt
#    - 📰 att_weight_finance_systemic_risk
#    - 📰 att_weight_real_estate_financing
#    - 📰 att_weight_industry_productivity
#    - 📰 att_weight_agriculture_climate_risks
#    - 📰 att_weight_commodities_market_prices
#
# 5. Estimation OLS Post-LASSO (avec forçage de la structure macro)...
#
# ===========================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Inflation_YoY   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.980
# Method:                 Least Squares   F-statistic:                     586.7
# Date:                Tue, 04 Aug 2026   Prob (F-statistic):          5.49e-100
# Time:                        14:31:10   Log-Likelihood:                -24.063
# No. Observations:                 134   AIC:                             72.13
# Df Residuals:                     122   BIC:                             106.9
# Df Model:                          11
# Covariance Type:            nonrobust
# ========================================================================================================
#                                            coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# const                                    2.9283      0.026    111.696      0.000       2.876       2.980
# Inflation_lag1                           1.9477      0.039     49.899      0.000       1.870       2.025
# Macro_InterestRate                      -0.0533      0.033     -1.637      0.104      -0.118       0.011
# att_weight_real_estate_financing        -0.1093      0.040     -2.707      0.008      -0.189      -0.029
# att_weight_finance_financial_markets    -0.0832      0.030     -2.758      0.007      -0.143      -0.023
# Macro_Unemployment                      -0.0438      0.032     -1.350      0.180      -0.108       0.020
# att_weight_finance_private_debt         -0.0387      0.032     -1.199      0.233      -0.102       0.025
# att_weight_finance_systemic_risk        -0.0118      0.035     -0.335      0.738      -0.081       0.058
# att_weight_agriculture_climate_risks    -0.0739      0.039     -1.873      0.063      -0.152       0.004
# att_weight_industry_productivity         0.0522      0.032      1.613      0.109      -0.012       0.116
# att_weight_commodities_market_prices     0.1661      0.035      4.798      0.000       0.098       0.235
# att_weight_energy_renewables             0.1442      0.035      4.096      0.000       0.075       0.214
# ==============================================================================
# Omnibus:                        7.409   Durbin-Watson:                   1.649
# Prob(Omnibus):                  0.025   Jarque-Bera (JB):               11.007
# Skew:                           0.240   Prob(JB):                      0.00407
# Kurtosis:                       4.319   Cond. No.                         3.82
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ===========================================================================

# %%
df_data, model_results = run_fully_data_driven_lasso(df_geo, target_region="France")
# Out:
# ===========================================================================
# 🚀 ANALYSE LASSO DATA-DRIVEN (BIC) + MACRO : France
# ===========================================================================
# 1. Téléchargement de la Macroéconomie (Inflation, Chômage, Taux)...
# 2. Agrégation des données textuelles GDELT (att_weight)...
# 3. Alignement temporel et standardisation des features (Z-scores)...
# 4. Algorithme au travail : Sélection du nombre optimal de variables via BIC...
#
# 🔍 Le critère BIC a déterminé que le nombre optimal de narratifs est de : 4
#    - 📰 att_weight_real_estate_regulation
#    - 📰 att_weight_agriculture_infrastructure_tech
#    - 📰 att_weight_agriculture_rural_labor
#    - 📰 att_weight_commodities_market_prices
#
# 5. Estimation OLS Post-LASSO (avec forçage de la structure macro)...
#
# ===========================================================================
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Inflation_YoY   R-squared:                       0.975
# Model:                            OLS   Adj. R-squared:                  0.973
# Method:                 Least Squares   F-statistic:                     624.0
# Date:                Tue, 04 Aug 2026   Prob (F-statistic):           1.39e-86
# Time:                        14:31:17   Log-Likelihood:                -34.101
# No. Observations:                 120   AIC:                             84.20
# Df Residuals:                     112   BIC:                             106.5
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# const                                          1.9870      0.030     65.409      0.000       1.927       2.047
# Inflation_lag1                                 1.9073      0.058     32.604      0.000       1.791       2.023
# att_weight_real_estate_regulation             -0.0093      0.052     -0.180      0.858      -0.111       0.093
# Macro_Unemployment                             0.0052      0.054      0.096      0.924      -0.102       0.112
# att_weight_agriculture_rural_labor            -0.0717      0.034     -2.103      0.038      -0.139      -0.004
# att_weight_commodities_market_prices           0.0292      0.055      0.531      0.597      -0.080       0.138
# att_weight_agriculture_infrastructure_tech     0.1400      0.056      2.520      0.013       0.030       0.250
# Macro_InterestRate                            -0.0660      0.057     -1.156      0.250      -0.179       0.047
# ==============================================================================
# Omnibus:                        1.609   Durbin-Watson:                   2.175
# Prob(Omnibus):                  0.447   Jarque-Bera (JB):                1.120
# Skew:                           0.131   Prob(JB):                        0.571
# Kurtosis:                       3.394   Cond. No.                         5.11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ===========================================================================

# %% [markdown]
# ### III. VAR prevision of inflation, with LASSO selection of topics prior to the VAR

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader.data as web
from statsmodels.tsa.api import VAR
import seaborn as sns

# ── CONFIGURATION MACRO ──
MACRO_DATA = {
    "US": {
        "cpi": "CPIAUCSL", 
        "interest_rate": "FEDFUNDS" # Taux directeur de la Fed
    },
    "France": {
        "cpi": "CP0000FRM086NEST", 
        "interest_rate": "IR3TIB01EZM156N" # Euribor 3 mois
    }
}

def plot_text_augmented_var_irf(df_geo, target_region, best_text_feature, lags=3, start_date='2015-03-01', filename="Fig_Bybee_IRF.pdf"):
    """
    Construit un Text-Augmented VAR dans l'esprit de Bybee et al. (2024) 
    et trace l'Impulse Response Function (IRF) d'un choc narratif sur l'inflation.
    """
    print(f"\n{'='*70}\n🚀 TEXT-AUGMENTED VAR (Méthode Bybee et al.) : {target_region}\n{'='*70}")
    
    config = MACRO_DATA[target_region]
    
    # ====================================================
    # 1. PRÉPARATION DES SÉRIES (TARGET + MACRO + TEXTE)
    # ====================================================
    print("1. Agrégation des données...")
    # FRED Data
    fred_start = pd.to_datetime(start_date) - pd.DateOffset(months=15)
    df_macro = web.DataReader([config["cpi"], config["interest_rate"]], 'fred', fred_start)
    df_macro['Inflation_YoY'] = df_macro[config["cpi"]].pct_change(12) * 100
    df_macro = df_macro.drop(columns=[config["cpi"]]).dropna()
    df_macro.index.name = 'period'
    
    # GDELT Data
    df_region = df_geo[df_geo['region_key'] == target_region].copy()
    if best_text_feature not in df_region.columns:
        raise ValueError(f"La feature '{best_text_feature}' est introuvable dans df_geo.")
        
    df_text = df_region.set_index('period')[[best_text_feature]].resample('MS').mean()
    
    # Fusion (Inner Join)
    df_var = df_text.join(df_macro, how='inner').dropna()
    
    # ====================================================
    # 2. ORDRE DE CHOLESKY (CRUCIAL EN VAR)
    # ====================================================
    # Bybee et al. ordonnent l'attention médiatique en PREMIER ou en DERNIER pour vérifier la robustesse.
    # Ici, nous plaçons l'Attention Narrative -> Taux d'intérêt -> Inflation
    # Cela suppose qu'un choc médiatique impacte la macroéconomie avec un décalage.
    var_cols = [best_text_feature, config["interest_rate"], 'Inflation_YoY']
    data_var = df_var[var_cols]
    
    # ====================================================
    # 3. ESTIMATION DU MODÈLE VAR
    # ====================================================
    print(f"2. Estimation du modèle VAR avec {lags} retards (lags)...")
    model = VAR(data_var)
    results = model.fit(lags)
    
    # ====================================================
    # 4. IMPULSE RESPONSE FUNCTION (IRF)
    # ====================================================
    print("3. Calcul de la fonction de réponse impulsionnelle (IRF)...")
    # Calcul de l'IRF sur 24 mois avec intervalles de confiance asymétriques (similaire à Bybee)
    irf = results.irf(24)
    
    # ====================================================
    # 5. TRACÉ ACADÉMIQUE DU GRAPHIQUE
    # ====================================================
    sns.set_theme(style="ticks", context="paper")
    plt.rcParams.update({"font.family": "serif", "font.size": 10, "figure.dpi": 300})
    
    fig, ax = plt.subplots(figsize=(8, 5))
    
    # Extraction des données de l'IRF pour le choc : Texte -> Inflation
    # Index 0 = Texte (choc), Index 2 = Inflation (réponse)
    irf_values = irf.irfs[:, 2, 0] 
    stderr = irf.stderr()[:, 2, 0]
    
    # Intervalles de confiance à 90% (1.645 standard errors)
    lower_bound = irf_values - 1.645 * stderr
    upper_bound = irf_values + 1.645 * stderr
    
    months = np.arange(len(irf_values))
    
    # Tracé (Reproduction de l'esthétique Bybee Figure 4)
    ax.plot(months, irf_values, color="#b2182b", marker="o", markersize=4, label="IRF (Réponse de l'Inflation)")
    ax.fill_between(months, lower_bound, upper_bound, color="#f4a582", alpha=0.4, label="Intervalle de confiance (90%)")
    ax.axhline(0, color='black', linewidth=0.8, linestyle='--')
    
    # Finitions
    ax.set_title(f"Réponse de l'Inflation à un choc sur '{best_text_feature}'", pad=15)
    ax.set_xlabel("Mois après le choc narratif")
    ax.set_ylabel("Impact sur l'Inflation YoY (points de %)")
    ax.legend(loc="best", frameon=False)
    sns.despine()
    
    plt.tight_layout()
    plt.savefig(filename)
    print(f"✔ Graphique IRF sauvegardé sous : {filename}")
    plt.show()

    return results

# ------------------------------------------------------------------------------
# 🚀 EXÉCUTION (Remplacez 'best_text_feature' par la variable gagnante du Lasso)
# ------------------------------------------------------------------------------

# %%
var_results = plot_text_augmented_var_irf(df_geo, "France", best_text_feature="att_weight_agriculture_infrastructure_tech")
# Out:
# ======================================================================
# 🚀 TEXT-AUGMENTED VAR (Méthode Bybee et al.) : France
# ======================================================================
# 1. Agrégation des données...
# 2. Estimation du modèle VAR avec 3 retards (lags)...
# 3. Calcul de la fonction de réponse impulsionnelle (IRF)...
# ✔ Graphique IRF sauvegardé sous : Fig_Bybee_IRF.pdf

# %% [markdown]
# ### Functions

# %%
def load_and_align_multi(df_geo, region_key, type_gdelt, sectors=None, start_date="2014-01-01"):
    """
    Télécharge, aligne et transforme dynamiquement les colonnes GDELT selon leur préfixe.
    Mode Deep Dive : Exclut le secteur parent pour ne garder que ses sous-catégories.
    """
    if region_key not in MACRO_TICKERS:
        raise ValueError(f"Pas de ticker FRED défini pour {region_key}.")
        
    ticker = MACRO_TICKERS[region_key]
    
    # ── 1. TÉLÉCHARGEMENT MACRO ──
    print(f"Téléchargement FRED pour {region_key} ({ticker})...")
    df_macro = web.DataReader(ticker, "fred", start_date)
    df_macro.index.name = 'period'
    macro_col = 'macro_yoy_%'
    df_macro[macro_col] = df_macro[ticker].pct_change(periods=12) * 100
    
    # ── 2. SÉLECTION DYNAMIQUE GDELT ──
    df_g = df_geo[(df_geo['region_key'] == region_key)].set_index('period').copy()
    
    if sectors:
        if len(sectors) == 1:
            # 👉 MODE DEEP DIVE : UNIQUEMENT les sous-catégories (exclusion du parent)
            base_col = f"{type_gdelt}_{sectors[0]}"
            
            # La modification est ici : on exige strictement que la colonne commence par "base_col_" 
            gdelt_cols = [c for c in df_g.columns if c.startswith(f"{base_col}_")]
            
            # Sécurité anti-crash si le secteur n'a aucune sous-catégorie
            if not gdelt_cols:
                print(f"⚠ Aucune sous-catégorie trouvée pour '{sectors[0]}'. Le secteur principal est conservé.")
                gdelt_cols = [base_col]
            else:
                print(f"🔍 Mode Deep Dive sur '{sectors[0]}' : {len(gdelt_cols)} sous-séries (Secteur global exclu).")
        else:
            # 👉 MODE COMPARAISON : Uniquement les agrégats des secteurs listés
            gdelt_cols = [f"{type_gdelt}_{s}" for s in sectors]
            print(f"📊 Mode Comparaison activé sur {len(sectors)} secteurs.")
    else:
        # 👉 MODE EXPLORATION : Toutes les colonnes correspondant au type
        gdelt_cols = [c for c in df_g.columns if c.startswith(f"{type_gdelt}_")]
        print(f"🌍 Mode Exploration Globale : {len(gdelt_cols)} séries détectées.")
        
    if not gdelt_cols:
        raise ValueError(f"Aucune colonne trouvée pour '{type_gdelt}'.")
        
    # Vérification anti-faute de frappe
    missing_cols = [c for c in gdelt_cols if c not in df_g.columns]
    if missing_cols:
        raise ValueError(f"Colonnes GDELT introuvables : {missing_cols}")
    
    # ── 3. TRANSFORMATIONS (Moyenne Mensuelle + Z-Score) ──
    df_g_monthly = df_g[gdelt_cols].resample('MS').mean()
    
    zscore_cols = []
    for col in gdelt_cols:
        rolling_mean = df_g_monthly[col].rolling(window=12).mean()
        rolling_std  = df_g_monthly[col].rolling(window=12).std()
        
        z_col = f"{col}_zscore"
        df_g_monthly[z_col] = (df_g_monthly[col] - rolling_mean) / rolling_std
        zscore_cols.append(z_col)
    
    # ── 4. FUSION ──
    df_merged = pd.merge(df_g_monthly, df_macro, left_index=True, right_index=True, how='inner')
    df_merged = df_merged.dropna()
    
    return df_merged, zscore_cols, macro_col

# %%
def plot_macro_vs_multi_gdelt(df_merged, region_key, zscore_cols, macro_col, macro_name="Indicateur Macro"):
    """
    Trace un graphique avec la Macroéconomie à droite et de multiples courbes GDELT à gauche.
    """
    fig = make_subplots(specs=[[{"secondary_y": True}]])
    palette = px.colors.qualitative.Alphabet + px.colors.qualitative.Dark24 # Grande palette

    # Courbe Macro YoY (Axe de droite, mise en évidence)
    fig.add_trace(
        go.Scatter(x=df_merged.index, y=df_merged[macro_col], 
                   name=f"🔴 {macro_name} YoY", 
                   line=dict(color='red', width=4, dash='dot')),
        secondary_y=True,
    )

    # Courbes GDELT Z-Score (Axe de gauche, boucle sur toutes les colonnes)
    for i, col in enumerate(zscore_cols):
        clean_name = col.replace('_zscore', '') # Rendre la légende plus jolie
        fig.add_trace(
            go.Scatter(x=df_merged.index, y=df_merged[col], 
                       name=clean_name, line=dict(color=palette[i % len(palette)], width=2)),
            secondary_y=False,
        )

    fig.update_layout(
        title_text=f"Région : {region_key} | Chocs GDELT (Gauche) vs {macro_name} (Droite)",
        template="plotly_white", hovermode="x unified",
        legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1)
    )
    
    # Ligne zéro de référence
    fig.add_hline(y=0, line_width=1, line_dash="dash", line_color="black", secondary_y=False)
    fig.update_yaxes(title_text="Z-Score (Anomalie Médiatique)", secondary_y=False)
    fig.update_yaxes(title_text="Variation sur 1 an (%)", secondary_y=True)

    fig.show()

# %%
def compute_multi_lagged_correlations(df_merged, zscore_cols, macro_col, max_lag=6):
    """
    Génère une matrice de corrélations décalées COMPACTE pour tous les indicateurs GDELT.
    """
    lags = range(-max_lag, max_lag + 1)
    results = {}
    
    for col in zscore_cols:
        col_corrs = []
        for lag in lags:
            # GDELT décalé par rapport à la Macro
            corr = df_merged[col].shift(lag).corr(df_merged[macro_col])
            col_corrs.append(corr)
        clean_name = col.replace('_zscore', '')
        results[clean_name] = col_corrs
        
    # 1. Labels ultra-courts pour gagner de la place en largeur
    index_labels = []
    for lag in lags:
        if lag == 0:
            index_labels.append("T (0)")
        elif lag > 0:
            index_labels.append(f"T+{lag}")
        else:
            index_labels.append(f"T{lag}")
            
    corr_df = pd.DataFrame(results, index=index_labels)
    
    # 2. TRANSPOSITION : Secteurs en lignes, Décalages (Lags) en colonnes
    corr_df = corr_df.T
    
    # 3. STYLISATION AVANCÉE (CSS intégré)
    return (
        corr_df.style
        # axis=None applique l'échelle de couleur sur TOUT le tableau, pas juste colonne par colonne
        .background_gradient(cmap='RdYlBu', vmin=-1, vmax=1, axis=None)
        .format("{:.2f}") # 2 décimales
        .set_properties(**{
            'font-size': '11px',      # Police plus petite
            'padding': '2px 5px',     # Marges réduites dans les cellules
            'text-align': 'center',   # Centrage
            'min-width': '45px'       # Largeur minimale contrainte
        })
    )

# %%
def compute_lasso_multi_lags_matrix(df_merged, zscore_cols, macro_col, max_lag=6):
    """
    Exécute un modèle Post-LASSO OLS sur tous les lags simultanément.
    Retourne un tableau récapitulatif coloré selon la significativité des coefficients.
    """
    print(f"🧠 Analyse Post-LASSO OLS globale (Lags de -{max_lag} à +{max_lag})...")
    
    # ── 1. CRÉATION DE LA MATRICE DE TOUS LES LAGS SIMULTANÉS ──
    X_dict = {}
    for col in zscore_cols:
        for lag in range(-max_lag, max_lag + 1):
            X_dict[f"{col}||{lag}"] = df_merged[col].shift(lag)
            
    df_features = pd.DataFrame(X_dict, index=df_merged.index)
    df_features[macro_col] = df_merged[macro_col]
    df_features = df_features.dropna()
    
    X = df_features[list(X_dict.keys())]
    y = df_features[macro_col]
    
    # ── 2. STANDARDISATION ET SÉLECTION VIA LASSO ──
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    lasso = LassoCV(cv=5, random_state=42, max_iter=20000)
    lasso.fit(X_scaled, y)
    
    selected_features = [X.columns[i] for i, coef in enumerate(lasso.coef_) if coef != 0]
    
    # ── 3. ESTIMATION DES P-VALUES VIA POST-LASSO OLS ──
    p_values = {}
    if selected_features:
        X_ols = sm.add_constant(X[selected_features])
        ols_model = sm.OLS(y, X_ols).fit()
        for feat in selected_features:
            p_values[feat] = ols_model.pvalues[feat]
            
    # ── 4. RECONSTRUCTION DU TABLEAU DE SYNTHÈSE ──
    sectors = sorted(list(set([c.split('||')[0].replace('_zscore', '') for c in X.columns])))
    lag_range = list(range(-max_lag, max_lag + 1))
    
    overview_df = pd.DataFrame("", index=sectors, columns=lag_range)
    
    for col_feat in X.columns:
        clean_sector = col_feat.split('||')[0].replace('_zscore', '')
        lag_val = int(col_feat.split('||')[1])
        
        lasso_coef = lasso.coef_[X.columns.get_loc(col_feat)]
        
        if lasso_coef == 0:
            overview_df.loc[clean_sector, lag_val] = "0.00"
        else:
            p_val = p_values.get(col_feat, 1.0)
            if p_val < 0.01:
                stars = "***"
            elif p_val < 0.05:
                stars = "**"
            elif p_val < 0.10:
                stars = "*"
            else:
                stars = " (ns)"
                
            overview_df.loc[clean_sector, lag_val] = f"{lasso_coef:+.2f}{stars}"
            
    columns_mapper = {l: (f"T+{l}" if l > 0 else (f"T{l}" if l < 0 else "T(0)")) for l in lag_range}
    overview_df = overview_df.rename(columns=columns_mapper)
    
    # ── 5. CODE COULEUR DE SIGNIFICATIVITÉ (CSS Dynamique) ──
    def apply_color_code(val):
        if "***" in val:
            # Vert émeraude soutenu - Signal ultra robuste (p < 1%)
            return 'background-color: #2e7d32; color: white; font-weight: bold;'
        elif "**" in val:
            # Vert herbe - Signal robuste (p < 5%)
            return 'background-color: #4caf50; color: white; font-weight: bold;'
        elif "*" in val:
            # Jaune pastel - Signal faible à surveiller (p < 10%)
            return 'background-color: #fff9c4; color: #5d4037;'
        elif "0.00" in val:
            # Gris très clair pour les variables éliminées (Invisible pour l'œil)
            return 'color: #cfd8dc; background-color: #fafafa;'
        else:
            # Variables gardées par le LASSO mais non significatives en OLS
            return 'color: #37474f; background-color: #eceff1;'
            
    return (
        overview_df.style
        .map(apply_color_code) # Applique le code couleur cellule par cellule
        .set_properties(**{
            'font-size': '12px',
            'padding': '6px 10px',
            'text-align': 'center',
            'border': '1px solid #e0e0e0' # Grille fine et propre
        })
    )

# %%
def compute_lasso_by_lag_matrix(df_merged, zscore_cols, macro_col, max_lag=6):
    """
    Exécute un modèle LASSO distinct POUR CHAQUE LAG (Horizon par Horizon).
    Les secteurs compétitionnent uniquement au sein d'un même horizon temporel,
    reproduisant les conditions réelles de prévision économique.
    """
    import pandas as pd
    import numpy as np
    from sklearn.linear_model import LassoCV
    from sklearn.preprocessing import StandardScaler
    import statsmodels.api as sm

    lag_range = list(range(-max_lag, max_lag + 1))
    # Extraction propre des noms de secteurs
    sectors = sorted(list(set([c.replace('_zscore', '') for c in zscore_cols])))
    
    # DataFrame final pour stocker la synthèse
    overview_df = pd.DataFrame("", index=sectors, columns=lag_range)

    # ── LA DISSOCIATION : On boucle SUR CHAQUE LAG INDÉPENDAMMENT ──
    for lag in lag_range:
        # 1. Création du mini-dataset dédié à ce lag spécifique
        X_dict = {}
        for col in zscore_cols:
            X_dict[col] = df_merged[col].shift(lag)
            
        df_lag = pd.DataFrame(X_dict, index=df_merged.index)
        df_lag[macro_col] = df_merged[macro_col]
        df_lag = df_lag.dropna()
        
        # Sécurité si le décalage vide trop la base
        if len(df_lag) < 15:
            continue
            
        X = df_lag[zscore_cols]
        y = df_lag[macro_col]
        
        # 2. Standardisation et LASSO local
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)
        
        # Le modèle ne gère plus que p variables (et non p x lags), il est beaucoup plus stable
        lasso = LassoCV(cv=5, random_state=42, max_iter=10000)
        lasso.fit(X_scaled, y)
        
        # 3. Post-LASSO OLS local pour la significativité
        selected_features = [X.columns[i] for i, coef in enumerate(lasso.coef_) if coef != 0]
        
        p_values = {f: 1.0 for f in zscore_cols}
        if selected_features:
            X_ols = sm.add_constant(X[selected_features])
            ols_model = sm.OLS(y, X_ols).fit()
            for feat in selected_features:
                p_values[feat] = ols_model.pvalues[feat]
        
        # 4. Remplissage de la colonne correspondante dans notre tableau
        for i, col in enumerate(zscore_cols):
            clean_sector = col.replace('_zscore', '')
            coef = lasso.coef_[i]
            
            if coef == 0:
                overview_df.loc[clean_sector, lag] = "0.00"
            else:
                p_val = p_values.get(col, 1.0)
                if p_val < 0.01: stars = "***"
                elif p_val < 0.05: stars = "**"
                elif p_val < 0.10: stars = "*"
                else: stars = " (ns)"
                
                overview_df.loc[clean_sector, lag] = f"{coef:+.2f}{stars}"

    # Formatage cosmétique des en-têtes de colonnes
    columns_mapper = {l: (f"T+{l}" if l > 0 else (f"T{l}" if l < 0 else "T(0)")) for l in lag_range}
    overview_df = overview_df.rename(columns=columns_mapper)
    
    # Même logique de code couleur automatique
    def apply_color_code(val):
        if "***" in val: return 'background-color: #2e7d32; color: white; font-weight: bold;'
        elif "**" in val: return 'background-color: #4caf50; color: white; font-weight: bold;'
        elif "*" in val: return 'background-color: #fff9c4; color: #5d4037;'
        elif "0.00" in val: return 'color: #cfd8dc; background-color: #fafafa;'
        else: return 'color: #37474f; background-color: #eceff1;'
            
    return overview_df.style.map(apply_color_code).set_properties(**{
        'font-size': '12px',
        'padding': '6px 10px',
        'text-align': 'center',
        'border': '1px solid #e0e0e0'
    })

# %%
def compute_lasso_by_lag_with_ar_matrix(df_merged, zscore_cols, macro_col, max_lag=6):
    """
    Exécute un modèle LASSO distinct pour chaque lag (Horizon par Horizon)
    en ajoutant l'inflation passée (terme autorégressif) comme variable de contrôle 
    pour les horizons prédictifs (lags > 0).
    """
    import pandas as pd
    import numpy as np
    from sklearn.linear_model import LassoCV
    from sklearn.preprocessing import StandardScaler
    import statsmodels.api as sm

    lag_range = list(range(-max_lag, max_lag + 1))
    sectors = sorted(list(set([c.replace('_zscore', '') for c in zscore_cols])))
    
    # On ajoute une ligne spéciale dans notre tableau pour voir le poids de l'inflation passée
    row_labels = sectors + ["_PAST_MACRO_INERTIA_"]
    overview_df = pd.DataFrame("", index=row_labels, columns=lag_range)

    for lag in lag_range:
        # 1. Construction du dataset pour ce lag spécifique
        X_dict = {}
        for col in zscore_cols:
            X_dict[col] = df_merged[col].shift(lag)
            
        # CRUCIAL : Si on essaie de prédire le FUTUR (lag > 0), 
        # on injecte l'inflation du passé (décalée du même lag) comme variable explicative
        if lag > 0:
            X_dict["_PAST_MACRO_INERTIA_"] = df_merged[macro_col].shift(lag)
            
        df_lag = pd.DataFrame(X_dict, index=df_merged.index)
        df_lag[macro_col] = df_merged[macro_col]
        df_lag = df_lag.dropna()
        
        if len(df_lag) < 15:
            continue
            
        current_features = list(X_dict.keys())
        X = df_lag[current_features]
        y = df_lag[macro_col]
        
        # 2. LASSO
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)
        
        lasso = LassoCV(cv=5, random_state=42, max_iter=10000)
        lasso.fit(X_scaled, y)
        
        # 3. Post-LASSO OLS pour la significativité
        selected_features = [X.columns[i] for i, coef in enumerate(lasso.coef_) if coef != 0]
        
        p_values = {f: 1.0 for f in current_features}
        if selected_features:
            X_ols = sm.add_constant(X[selected_features])
            ols_model = sm.OLS(y, X_ols).fit()
            for feat in selected_features:
                p_values[feat] = ols_model.pvalues[feat]
        
        # 4. Remplissage du tableau
        for feat in current_features:
            coef = lasso.coef_[X.columns.get_loc(feat)]
            p_val = p_values.get(feat, 1.0)
            
            if p_val < 0.01: stars = "***"
            elif p_val < 0.05: stars = "**"
            elif p_val < 0.10: stars = "*"
            else: stars = " (ns)"
            
            # Détermination de la ligne de destination
            dest_row = "_PAST_MACRO_INERTIA_" if feat == "_PAST_MACRO_INERTIA_" else feat.replace('_zscore', '')
            
            if coef == 0:
                overview_df.loc[dest_row, lag] = "0.00"
            else:
                overview_df.loc[dest_row, lag] = f"{coef:+.2f}{stars}"

    # Nettoyage des cellules vides pour les lignes/colonnes non concernées
    overview_df.loc["_PAST_MACRO_INERTIA_", [l for l in lag_range if l <= 0]] = "N/A"
    
    # Formatage cosmétique
    columns_mapper = {l: (f"T+{l}" if l > 0 else (f"T{l}" if l < 0 else "T(0)")) for l in lag_range}
    overview_df = overview_df.rename(columns=columns_mapper)
    
    def apply_color_code(val):
        if val == "N/A": return 'color: #b0bec5; background-color: #cfd8dc; font-style: italic;'
        elif "***" in val: return 'background-color: #2e7d32; color: white; font-weight: bold;'
        elif "**" in val: return 'background-color: #4caf50; color: white; font-weight: bold;'
        elif "*" in val: return 'background-color: #fff9c4; color: #5d4037;'
        elif "0.00" in val: return 'color: #cfd8dc; background-color: #fafafa;'
        else: return 'color: #37474f; background-color: #eceff1;'
            
    return overview_df.style.map(apply_color_code).set_properties(**{
        'font-size': '12px', 'padding': '6px 10px', 'text-align': 'center', 'border': '1px solid #e0e0e0'
    })

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LassoCV, LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

def plot_out_of_sample_forecast(df_merged, zscore_cols, macro_col, lag_months=2, test_ratio=0.25):
    """
    Simule une prévision réelle en coupant les données (Train = Passé, Test = Futur).
    Compare un modèle 'Inertie Seule' vs 'Inertie + GDELT'.
    """
    print(f"🔮 Test Out-of-Sample à T+{lag_months} mois")
    
    # 1. Préparation des données décalées
    df_model = pd.DataFrame(index=df_merged.index)
    df_model['Target_Macro'] = df_merged[macro_col]
    df_model['Past_Macro'] = df_merged[macro_col].shift(lag_months)
    
    for col in zscore_cols:
        df_model[col] = df_merged[col].shift(lag_months)
        
    df_model = df_model.dropna()
    
    # 2. Split temporel strict (Pas de mélange aléatoire !)
    split_idx = int(len(df_model) * (1 - test_ratio))
    train_data = df_model.iloc[:split_idx]
    test_data = df_model.iloc[split_idx:]
    split_date = test_data.index[0].strftime('%Y-%m')
    print(f"Entraînement jusqu'à {split_date} | Test sur les données suivantes.")

    # Variables
    X_train_naive = train_data[['Past_Macro']]
    X_test_naive = test_data[['Past_Macro']]
    
    X_train_full = train_data[['Past_Macro'] + zscore_cols]
    X_test_full = test_data[['Past_Macro'] + zscore_cols]
    
    y_train = train_data['Target_Macro']
    y_test = test_data['Target_Macro']
    
    # 3. Entraînement Modèle Naïf (Régression simple sur le passé)
    model_naive = LinearRegression()
    model_naive.fit(X_train_naive, y_train)
    preds_naive = model_naive.predict(X_test_naive)
    
    # 4. Entraînement Modèle Complet (LASSO avec StandardScaler)
    scaler = StandardScaler()
    X_train_full_scaled = scaler.fit_transform(X_train_full)
    X_test_full_scaled = scaler.transform(X_test_full)
    
    model_full = LassoCV(cv=5, random_state=42)
    model_full.fit(X_train_full_scaled, y_train)
    preds_full = model_full.predict(X_test_full_scaled)
    
    # 5. Calcul des erreurs (RMSE : Plus c'est bas, mieux c'est)
    rmse_naive = np.sqrt(mean_squared_error(y_test, preds_naive))
    rmse_full = np.sqrt(mean_squared_error(y_test, preds_full))
    
    print(f"📉 Erreur Modèle Naïf   : {rmse_naive:.3f}")
    print(f"📉 Erreur Modèle Complet: {rmse_full:.3f}")
    if rmse_full < rmse_naive:
        print("✅ VICTOIRE : GDELT améliore concrètement la prévision !")
    else:
        print("❌ ECHEC : GDELT n'apporte pas d'information supérieure à l'inertie.")

    # 6. Graphique
    plt.figure(figsize=(12, 6))
    plt.plot(train_data.index, y_train, color='black', alpha=0.3, label='Réalité (In-Sample)')
    plt.plot(test_data.index, y_test, color='black', linewidth=2, label='Réalité (Out-of-Sample)')
    plt.plot(test_data.index, preds_naive, color='red', linestyle='--', label='Prévision Naïve (Sans GDELT)')
    plt.plot(test_data.index, preds_full, color='blue', linewidth=2, label='Prévision Modèle (Avec GDELT)')
    
    plt.axvline(train_data.index[-1], color='gray', linestyle=':', linewidth=2)
    plt.title(f"Test de Prévision sur données invisibles (Horizon {lag_months} mois)")
    plt.legend()
    plt.grid(alpha=0.3)
    plt.show()

# %%
def plot_rolling_coefficients(df_merged, zscore_cols, macro_col, target_sector, lag_months=1, window_size=48):
    """
    Calcule et trace l'évolution du coefficient d'un secteur spécifique au fil du temps 
    (Fenêtre glissante). Idéal pour détecter les changements de régime économique.
    """
    print(f"⏳ Analyse glissante sur fenêtres de {window_size} mois (Lag: {lag_months})")
    
    # ── SÉCURITÉ : Rajoute '_zscore' si l'utilisateur l'a oublié ──
    if not target_sector.endswith('_zscore'):
        target_sector += '_zscore'
        
    if target_sector not in zscore_cols:
        raise ValueError(f"Le secteur '{target_sector}' est introuvable. Colonnes disponibles : {zscore_cols}")
        
    df_model = pd.DataFrame(index=df_merged.index)
    df_model['Target_Macro'] = df_merged[macro_col]
    df_model['Past_Macro'] = df_merged[macro_col].shift(lag_months)
    
    for col in zscore_cols:
        df_model[col] = df_merged[col].shift(lag_months)
        
    df_model = df_model.dropna()
    
    dates = []
    coefs = []
    
    # Boucle Glissante (Rolling Window)
    for i in range(len(df_model) - window_size):
        window_data = df_model.iloc[i : i + window_size]
        X = window_data[['Past_Macro'] + zscore_cols]
        y = window_data['Target_Macro']
        
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)
        
        from sklearn.linear_model import Ridge
        model = Ridge(alpha=1.0)
        model.fit(X_scaled, y)
        
        target_idx = zscore_cols.index(target_sector) + 1
        coefs.append(model.coef_[target_idx])
        dates.append(window_data.index[-1]) 
        
    # Graphique
    plt.figure(figsize=(10, 5))
    plt.plot(dates, coefs, color='darkorange', linewidth=2.5)
    plt.axhline(0, color='black', linestyle='--', linewidth=1)
    
    plt.fill_between(dates, 0, coefs, where=(np.array(coefs) > 0), color='green', alpha=0.2)
    plt.fill_between(dates, 0, coefs, where=(np.array(coefs) < 0), color='red', alpha=0.2)
    
    clean_name = target_sector.replace('_zscore', '')
    plt.title(f"Évolution de l'influence de '{clean_name}' sur l'inflation au fil du temps")
    plt.ylabel("Poids (Coefficient)")
    plt.grid(alpha=0.3)
    plt.show()

# %%
from statsmodels.tsa.api import VAR
import matplotlib.pyplot as plt

def plot_var_irf(df_merged, gdelt_col, macro_col, max_lag_var=3, steps_ahead=12):
    """
    Modélise un choc sur la variable GDELT et trace la réponse de l'inflation (IRF).
    """
    # ── SÉCURITÉ : Rajoute '_zscore' ──
    if not gdelt_col.endswith('_zscore'):
        gdelt_col += '_zscore'
        
    print(f"💥 Simulation de Choc (Modèle VAR) sur : {gdelt_col.replace('_zscore', '')}")
    
    # 1. Isoler les deux variables pour le modèle VAR
    df_var = df_merged[[gdelt_col, macro_col]].dropna()
    
    # 2. Entraînement du modèle VAR
    model = VAR(df_var)
    results = model.fit(maxlags=max_lag_var, ic='aic')
    
    # 3. Calcul de la Réponse Impulsionnelle (IRF)
    irf = results.irf(steps_ahead)
    
    # ── CORRECTION : Extraction officielle des bornes de confiance dans statsmodels ──
    lower_bound_matrix, upper_bound_matrix = irf.err_band_sz1(orth=True, signif=0.05)
    
    # 4. Graphique
    plt.figure(figsize=(8, 5))
    
    # L'index 1 est la macro, l'index 0 est gdelt. Donc choc sur 0 -> effet sur 1.
    effect_on_macro = irf.orth_irfs[:, 1, 0] 
    lower_bound = lower_bound_matrix[:, 1, 0]
    upper_bound = upper_bound_matrix[:, 1, 0]
    
    plt.plot(range(steps_ahead + 1), effect_on_macro, color='blue', linewidth=2, label="Impact sur l'Inflation")
    
    # Intervalle de confiance à 95%
    plt.fill_between(range(steps_ahead + 1), lower_bound, upper_bound, color='blue', alpha=0.15, label="Intervalle de Confiance (95%)")
    plt.axhline(0, color='black', linestyle='--')
    
    clean_name = gdelt_col.replace('_zscore', '')
    plt.title(f"Réponse de l'inflation suite à un choc médiatique sur '{clean_name}'")
    plt.xlabel("Mois après le choc")
    plt.ylabel("Impact (%)")
    plt.legend()
    plt.grid(alpha=0.3)
    plt.show()

# %% [markdown]
# ### Viz

# %%
region = "European Union"
type_gdelt_indicator = "att_weight"
sectors = ["finance", "energy", "agriculture", "tech", "industry", "commodities", "real_estate", "transport"]  # Liste des secteurs à comparer

df_align, z_cols, m_col = load_and_align_multi(
    df_geo=df_geo, 
    region_key=region, 
    type_gdelt=type_gdelt_indicator, 
    sectors=sectors 
)

# Le graphique affichera l'énergie globale + le pétrole, le nucléaire, etc.
plot_macro_vs_multi_gdelt(df_align, region, z_cols, m_col, macro_name="Inflation")

# La matrice détaillera les corrélations de chaque sous-catégorie
display(compute_multi_lagged_correlations(df_align, z_cols, m_col, max_lag=6))
# Out:
# Téléchargement FRED pour European Union (CP0000EZ19M086NEST)...
# 📊 Mode Comparaison activé sur 8 secteurs.
# <style type="text/css">
# #T_3ff77_row0_col0, #T_3ff77_row5_col3 {
#   background-color: #f3fbd4;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row0_col1, #T_3ff77_row2_col0, #T_3ff77_row5_col6, #T_3ff77_row6_col11 {
#   background-color: #e7f6eb;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row0_col2, #T_3ff77_row1_col7, #T_3ff77_row4_col7, #T_3ff77_row5_col8, #T_3ff77_row7_col1 {
#   background-color: #dcf1f7;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row0_col3, #T_3ff77_row1_col9, #T_3ff77_row4_col3 {
#   background-color: #cbe9f2;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row0_col4, #T_3ff77_row1_col12, #T_3ff77_row3_col6 {
#   background-color: #bde2ee;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row0_col5 {
#   background-color: #aedbea;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row0_col6 {
#   background-color: #a3d3e6;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row0_col7, #T_3ff77_row2_col9 {
#   background-color: #94c7df;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row0_col8, #T_3ff77_row2_col10 {
#   background-color: #8cc0db;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row0_col9 {
#   background-color: #81b7d7;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row0_col10 {
#   background-color: #76afd2;
#   color: #f1f1f1;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row0_col11, #T_3ff77_row0_col12 {
#   background-color: #70a9cf;
#   color: #f1f1f1;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row1_col0 {
#   background-color: #feefa6;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row1_col1 {
#   background-color: #fff5af;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row1_col2 {
#   background-color: #fffbb9;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row1_col3 {
#   background-color: #fffebe;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row1_col4 {
#   background-color: #f8fccb;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row1_col5 {
#   background-color: #f0f9db;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row1_col6, #T_3ff77_row7_col4, #T_3ff77_row7_col10 {
#   background-color: #e6f5ed;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row1_col8 {
#   background-color: #cfebf3;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row1_col10 {
#   background-color: #c9e8f2;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row1_col11 {
#   background-color: #c1e4ef;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row2_col1, #T_3ff77_row5_col7, #T_3ff77_row7_col0 {
#   background-color: #e1f3f6;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row2_col2, #T_3ff77_row7_col2 {
#   background-color: #def2f7;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row2_col3, #T_3ff77_row6_col7 {
#   background-color: #daf0f6;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row2_col4, #T_3ff77_row3_col3, #T_3ff77_row4_col4, #T_3ff77_row5_col10, #T_3ff77_row6_col4 {
#   background-color: #cdeaf3;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row2_col5, #T_3ff77_row3_col5, #T_3ff77_row3_col12, #T_3ff77_row6_col2 {
#   background-color: #bfe3ef;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row2_col6 {
#   background-color: #b2ddeb;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row2_col7 {
#   background-color: #aad8e9;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row2_col8 {
#   background-color: #9fd0e4;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row2_col11, #T_3ff77_row2_col12 {
#   background-color: #85bbd9;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row3_col0, #T_3ff77_row6_col9, #T_3ff77_row7_col3, #T_3ff77_row7_col6, #T_3ff77_row7_col7 {
#   background-color: #e2f4f4;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row3_col1 {
#   background-color: #d8eff6;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row3_col2, #T_3ff77_row4_col5 {
#   background-color: #d1ecf4;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row3_col4, #T_3ff77_row4_col2, #T_3ff77_row5_col11, #T_3ff77_row6_col3 {
#   background-color: #c7e7f1;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row3_col7 {
#   background-color: #b6dfec;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row3_col8, #T_3ff77_row6_col0 {
#   background-color: #b4deec;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row3_col9, #T_3ff77_row6_col1 {
#   background-color: #b9e0ed;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row3_col10, #T_3ff77_row3_col11 {
#   background-color: #bbe1ed;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row4_col0, #T_3ff77_row4_col1, #T_3ff77_row5_col12 {
#   background-color: #c5e6f0;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row4_col6, #T_3ff77_row5_col9, #T_3ff77_row6_col6 {
#   background-color: #d6eef5;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row4_col8, #T_3ff77_row6_col10, #T_3ff77_row7_col9 {
#   background-color: #e5f5ef;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row4_col9, #T_3ff77_row7_col12 {
#   background-color: #ecf8e2;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row4_col10 {
#   background-color: #f5fbd2;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row4_col11 {
#   background-color: #fbfdc7;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row4_col12, #T_3ff77_row5_col0 {
#   background-color: #fffcba;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_3ff77_row5_col1 {
#   background-color: #feffc0;
#   color: #000000;
#   font-size: 11px;
#   paddi

# %%
region = "US"
type_gdelt_indicator = "att_weight"
sectors = ["finance", "energy", "agriculture", "tech", "industry", "commodities", "real_estate", "transport"]  # Liste des secteurs à comparer

df_align, z_cols, m_col = load_and_align_multi(
    df_geo=df_geo, 
    region_key=region, 
    type_gdelt=type_gdelt_indicator, 
    sectors=sectors 
)

# Le graphique affichera l'énergie globale + le pétrole, le nucléaire, etc.
plot_macro_vs_multi_gdelt(df_align, region, z_cols, m_col, macro_name="Inflation")

# La matrice détaillera les corrélations de chaque sous-catégorie
display(compute_multi_lagged_correlations(df_align, z_cols, m_col, max_lag=6))
# Out:
# Téléchargement FRED pour US (CPIAUCSL)...
# 📊 Mode Comparaison activé sur 8 secteurs.
# <style type="text/css">
# #T_caece_row0_col0, #T_caece_row5_col8 {
#   background-color: #b9e0ed;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row0_col1, #T_caece_row2_col12, #T_caece_row6_col4 {
#   background-color: #acdae9;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row0_col2, #T_caece_row2_col7 {
#   background-color: #a1d1e5;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row0_col3, #T_caece_row6_col6 {
#   background-color: #99cae1;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row0_col4, #T_caece_row6_col7 {
#   background-color: #90c3dd;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row0_col5, #T_caece_row0_col6, #T_caece_row0_col7 {
#   background-color: #8cc0db;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row0_col8, #T_caece_row6_col9 {
#   background-color: #85bbd9;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row0_col9, #T_caece_row0_col11 {
#   background-color: #81b7d7;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row0_col10, #T_caece_row6_col11 {
#   background-color: #7db4d5;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row0_col12 {
#   background-color: #8ec2dc;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row1_col0, #T_caece_row4_col11 {
#   background-color: #f6fbd0;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row1_col1, #T_caece_row3_col12 {
#   background-color: #f7fcce;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row1_col2, #T_caece_row3_col11, #T_caece_row5_col0 {
#   background-color: #f5fbd2;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row1_col3 {
#   background-color: #f2fad6;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row1_col4, #T_caece_row1_col5, #T_caece_row1_col6, #T_caece_row1_col12, #T_caece_row3_col10, #T_caece_row4_col10 {
#   background-color: #f1fad9;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row1_col7, #T_caece_row3_col9 {
#   background-color: #edf8df;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row1_col8, #T_caece_row7_col2 {
#   background-color: #e9f6e8;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row1_col9, #T_caece_row3_col5 {
#   background-color: #e7f6eb;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row1_col10, #T_caece_row3_col1, #T_caece_row3_col8, #T_caece_row4_col8, #T_caece_row5_col3 {
#   background-color: #e6f5ed;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row1_col11, #T_caece_row5_col2 {
#   background-color: #ebf7e4;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row2_col0, #T_caece_row4_col5, #T_caece_row7_col5, #T_caece_row7_col12 {
#   background-color: #d8eff6;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row2_col1 {
#   background-color: #cfebf3;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row2_col2, #T_caece_row5_col6, #T_caece_row7_col8 {
#   background-color: #c9e8f2;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row2_col3, #T_caece_row6_col0 {
#   background-color: #c1e4ef;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row2_col4 {
#   background-color: #b6dfec;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row2_col5 {
#   background-color: #aedbea;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row2_col6 {
#   background-color: #a6d5e7;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row2_col8, #T_caece_row6_col5 {
#   background-color: #9fd0e4;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row2_col9, #T_caece_row2_col10 {
#   background-color: #9dcee3;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row2_col11 {
#   background-color: #a3d3e6;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row3_col0, #T_caece_row3_col6, #T_caece_row4_col7 {
#   background-color: #e2f4f4;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row3_col2, #T_caece_row3_col4, #T_caece_row4_col9, #T_caece_row7_col1 {
#   background-color: #ecf8e2;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row3_col3 {
#   background-color: #eff9dd;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row3_col7, #T_caece_row5_col4, #T_caece_row7_col4 {
#   background-color: #e1f3f6;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row4_col0, #T_caece_row4_col1, #T_caece_row5_col7 {
#   background-color: #c3e5f0;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row4_col2 {
#   background-color: #c7e7f1;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row4_col3, #T_caece_row4_col4 {
#   background-color: #cdeaf3;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row4_col6 {
#   background-color: #e0f3f8;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row4_col12 {
#   background-color: #fafdc9;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row5_col1, #T_caece_row7_col0 {
#   background-color: #f0f9db;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row5_col5, #T_caece_row7_col11 {
#   background-color: #d6eef5;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row5_col9, #T_caece_row5_col12 {
#   background-color: #b2ddeb;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row5_col10, #T_caece_row5_col11 {
#   background-color: #b0dcea;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row6_col1 {
#   background-color: #bfe3ef;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row6_col2 {
#   background-color: #bbe1ed;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row6_col3 {
#   background-color: #b4deec;
#   color: #000000;
#   font-size: 11px;
#   padding: 2px 5px;
#   text-align: center;
#   min-width: 45px;
# }
# #T_caece_row6_col8 {
#   background-color: #8abeda;
#   col

# %% [markdown]
# ### Models

# %%
region = "US"
type_gdelt_indicator = "att_weight"
sectors = ["real_estate"]  # Liste des secteurs à comparer

df_align, z_cols, m_col = load_and_align_multi(
    df_geo=df_geo, 
    region_key=region, 
    type_gdelt=type_gdelt_indicator, 
    sectors=sectors 
)
# Out:
# Téléchargement FRED pour US (CPIAUCSL)...
# 🔍 Mode Deep Dive sur 'real_estate' : 5 sous-séries (Secteur global exclu).
# 🧠 Analyse Post-LASSO OLS globale (Lags de -6 à +6)...
# <style type="text/css">
# #T_aa070_row0_col0, #T_aa070_row0_col1, #T_aa070_row0_col2, #T_aa070_row0_col3, #T_aa070_row0_col4, #T_aa070_row0_col5, #T_aa070_row0_col6, #T_aa070_row0_col7, #T_aa070_row0_col8, #T_aa070_row0_col9, #T_aa070_row0_col12, #T_aa070_row2_col7, #T_aa070_row2_col8, #T_aa070_row2_col9, #T_aa070_row2_col10, #T_aa070_row2_col11, #T_aa070_row3_col1, #T_aa070_row3_col2, #T_aa070_row3_col3, #T_aa070_row3_col6, #T_aa070_row3_col7, #T_aa070_row3_col8, #T_aa070_row3_col9, #T_aa070_row4_col2, #T_aa070_row4_col3 {
#   color: #cfd8dc;
#   background-color: #fafafa;
#   font-size: 12px;
#   padding: 6px 10px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# #T_aa070_row0_col10, #T_aa070_row1_col0 {
#   background-color: #fff9c4;
#   color: #5d4037;
#   font-size: 12px;
#   padding: 6px 10px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# #T_aa070_row0_col11, #T_aa070_row1_col1, #T_aa070_row1_col2, #T_aa070_row1_col7, #T_aa070_row1_col10, #T_aa070_row1_col11, #T_aa070_row1_col12, #T_aa070_row2_col0, #T_aa070_row2_col1, #T_aa070_row2_col2, #T_aa070_row2_col3, #T_aa070_row2_col4, #T_aa070_row2_col5, #T_aa070_row2_col6, #T_aa070_row2_col12, #T_aa070_row3_col0, #T_aa070_row3_col4, #T_aa070_row3_col5, #T_aa070_row3_col10, #T_aa070_row3_col11, #T_aa070_row3_col12, #T_aa070_row4_col1, #T_aa070_row4_col5, #T_aa070_row4_col6, #T_aa070_row4_col7, #T_aa070_row4_col8, #T_aa070_row4_col9, #T_aa070_row4_col10, #T_aa070_row4_col11, #T_aa070_row4_col12 {
#   color: #37474f;
#   background-color: #eceff1;
#   font-size: 12px;
#   padding: 6px 10px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# #T_aa070_row1_col3, #T_aa070_row1_col4, #T_aa070_row1_col5, #T_aa070_row1_col6, #T_aa070_row1_col9, #T_aa070_row4_col0, #T_aa070_row4_col4 {
#   background-color: #4caf50;
#   color: white;
#   font-weight: bold;
#   font-size: 12px;
#   padding: 6px 10px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# #T_aa070_row1_col8 {
#   background-color: #2e7d32;
#   color: white;
#   font-weight: bold;
#   font-size: 12px;
#   padding: 6px 10px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# </style>
# <table id="T_aa070">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa070_level0_col0" class="col_heading level0 col0" >T-6</th>
#       <th id="T_aa070_level0_col1" class="col_heading level0 col1" >T-5</th>
#       <th id="T_aa070_level0_col2" class="col_heading level0 col2" >T-4</th>
#       <th id="T_aa070_level0_col3" class="col_heading level0 col3" >T-3</th>
#       <th id="T_aa070_level0_col4" class="col_heading level0 col4" >T-2</th>
#       <th id="T_aa070_level0_col5" class="col_heading level0 col5" >T-1</th>
#       <th id="T_aa070_level0_col6" class="col_heading level0 col6" >T(0)</th>
#       <th id="T_aa070_level0_col7" class="col_heading level0 col7" >T+1</th>
#       <th id="T_aa070_level0_col8" class="col_heading level0 col8" >T+2</th>
#       <th id="T_aa070_level0_col9" class="col_heading level0 col9" >T+3</th>
#       <th id="T_aa070_level0_col10" class="col_heading level0 col10" >T+4</th>
#       <th id="T_aa070_level0_col11" class="col_heading level0 col11" >T+5</th>
#       <th id="T_aa070_level0_col12" class="col_heading level0 col12" >T+6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa070_level0_row0" class="row_heading level0 row0" >att_weight_real_estate_construction</th>
#       <td id="T_aa070_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_aa070_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_aa070_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_aa070_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_aa070_row0_col4" class="data row0 col4" >0.00</td>
#       <td id="T_aa070_row0_col5" class="data row0 col5" >0.00</td>
#       <td id="T_aa070_row0_col6" class="data row0 col6" >0.00</td>
#       <td id="T_aa070_row0_col7" class="data row0 col7" >0.00</td>
#       <td id="T_aa070_row0_col8" class="data row0 col8" >0.00</td>
#       <td id="T_aa070_row0_col9" class="data row0 col9" >0.00</td>
#       <td id="T_aa070_row0_col10" class="data row0 col10" >-0.10*</td>
#       <td id="T_aa070_row0_col11" class="data row0 col11" >-0.01 (ns)</td>
#       <td id="T_aa070_row0_col12" class="data row0 col12" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_aa070_level0_row1" class="row_heading level0 row1" >att_weight_real_estate_financing</th>
#       <td id="T_aa070_row1_col0" class="data row1 col0" >+0.25*</td>
#       <td id="T_aa070_row1_col1" class="data row1 col1" >+0.13 (ns)</td>
#       <td id="T_aa070_row1_col2" class="data row1 col2" >+0.19 (ns)</td>
#       <td id="T_aa070_row1_col3" class="data row1 col3" >+0.30**</td>
#       <td id="T_aa070_row1_col4" class="data row1 col4" >+0.31**</td>
#       <td id="T_aa070_row1_col5" class="data row1 col5" >+0.28**</td>
#       <td id="T_aa070_row1_col6" class="data row1 col6" >+0.21**</td>
#       <td id="T_aa070_row1_col7" class="data row1 col7" >+0.17 (ns)</td>
#       <td id="T_aa070_row1_col8" class="data row1 col8" >+0.25***</td>
#       <td id="T_aa070_row1_col9" class="data row1 col9" >+0.27**</td>
#       <td id="T_aa070_row1_col10" class="data row1 col10" >+0.22 (ns)</td>
#       <td id="T_aa070_row1_col11" class="data row1 col11" >+0.25 (ns)</td>
#       <td id="T_aa070_row1_col12" class="data row1 col12" >+0.09 (ns)</td>
#     </tr>
#     <tr>
#       <th id="T_aa070_level0_row2" class="row_heading level0 row2" >att_weight_real_estate_market</th>
#       <td id="T_aa070_row2_col0" class="data row2 col0" >-0.03 (ns)</td>
#       <td id="T_aa070_row2_col1" class="data row2 col1" >-0.09 (ns)</td>
#       <td id="T_aa070_row2_col2" class="data row2 col2" >-0.12 (ns)</td>
#       <td id="T_aa070_row2_col3" class="data row2 col3" >-0.15 (ns)</td>
#       <td id="T_aa070_row2_col4" class="data row2 col4" >-0.13 (ns)</td>
#       <td id="T_aa070_row2_col5" class="data row2 col5" >-0.17 (ns)</td>
#       <td id="T_aa070_row2_col6" class="data row2 col6" >-0.08 (ns)</td>
#       <td id="T_aa070_row2_col7" class="data row2 col7" >0.00</td>
#       <td id="T_aa070_row2_col8" class="data row2 col8" >0.00</td>
#       <td id="T_aa070_row2_col9" class="data row2 col9" >0.00</td>
#       <td id="T_aa070_row2_col10" class="data row2 col10" >0.00</td>
#       <td id="T_aa070_row2_col11" class="data row2 col11" >0.00</td>
#       <td id="T_aa070_row2_col12" class="data row2 col12" >+0.12 (ns)</td>
#     </tr>
#     <tr>
#       <th id="T_aa070_level0_row3" class="row_heading level0 row3" >att_weight_real_estate_regulation</th>
#       <td id="T_aa070_row3_col0" class="data row3 col0" >-0.09 (ns)</td>
#       <td id="T_aa070_row3_col1" class="data row3 col1" >0.00</td>
#       <td id="T_aa070_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_aa070_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_aa070_row3_col4" class="data row3 col4" >-0.03 (ns)</td>
#       <td id="T_aa070_row3_col5" class="data row3 col5" >-0.06 (ns)</td>
#       <td id="T_aa070_row3_col6" class="data row3 col6" >-0.00 (ns)</td>
#       <td id="T_aa070_row3_col7" class="data row3 col7" >0.00</td>
#       <td id="T_aa070_row3_col8" class="data row3 col8" >0.00</td>
#       <td id="T_aa070_row3_col9" class="data row3 col9" >0.00</td>
#       <td id="T_aa070_row3_col10" class="data row3 col10" >+0.08 (ns)</td>
#       <td id="T_aa070_row3_col11" class="data row3 col11" >+0.06 (ns)</td>
#       <td id="T_aa070_row3_col12" class="data row3 col12" >+0.11 (ns)</td>
#     </tr>
#     <tr>
#       <th id="T_aa070_level0_row4" class="row_heading level0 row4" >att_weight_real_estate_urbanism</th>
#       <td id="T_aa070_row4_col0" class="data row4 col0" >+0.11**</td>
#       <td id="T_aa070_row4_col1" class="data row4 col1" >+0.06 (ns)</td>
#       <td id="T_aa070_row4_col2" class="data row4 col2" >0.00</td>
#       <td id="T_aa070_row4_col3" class="data row4 col3" >+0.00 (ns)</td>
#       <td id="T_aa070_row4_col4" class="data row4 col4" >+0.13**</td>
#       <td id="T_aa070_row4_col5" class="data row4 col5" >+0.16 (ns)</td>
#       <td id="T_aa070_row4_col6" class="data row4 col6" >+0.05 (ns)</td>
#       <td

# %%
compute_lasso_by_lag_with_ar_matrix(df_align, z_cols, m_col)
# Out:
# <style type="text/css">
# #T_e0617_row0_col0, #T_e0617_row0_col1, #T_e0617_row0_col2, #T_e0617_row0_col3, #T_e0617_row0_col4, #T_e0617_row0_col5, #T_e0617_row0_col6, #T_e0617_row1_col10, #T_e0617_row3_col5, #T_e0617_row3_col6 {
#   color: #37474f;
#   background-color: #eceff1;
#   font-size: 12px;
#   padding: 6px 10px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# #T_e0617_row0_col7, #T_e0617_row0_col8, #T_e0617_row0_col9, #T_e0617_row0_col10, #T_e0617_row0_col11, #T_e0617_row0_col12, #T_e0617_row1_col7, #T_e0617_row1_col8, #T_e0617_row1_col9, #T_e0617_row1_col11, #T_e0617_row1_col12, #T_e0617_row2_col0, #T_e0617_row2_col1, #T_e0617_row2_col2, #T_e0617_row2_col3, #T_e0617_row2_col4, #T_e0617_row2_col5, #T_e0617_row2_col6, #T_e0617_row3_col0, #T_e0617_row3_col1, #T_e0617_row3_col2, #T_e0617_row3_col3, #T_e0617_row3_col4, #T_e0617_row4_col7, #T_e0617_row4_col8, #T_e0617_row4_col9, #T_e0617_row4_col10, #T_e0617_row4_col11, #T_e0617_row4_col12 {
#   color: #cfd8dc;
#   background-color: #fafafa;
#   font-size: 12px;
#   padding: 6px 10px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# #T_e0617_row1_col0, #T_e0617_row1_col1, #T_e0617_row2_col7, #T_e0617_row2_col8, #T_e0617_row2_col9, #T_e0617_row2_col10, #T_e0617_row3_col7, #T_e0617_row3_col8, #T_e0617_row3_col10, #T_e0617_row4_col1, #T_e0617_row4_col2 {
#   background-color: #4caf50;
#   color: white;
#   font-weight: bold;
#   font-size: 12px;
#   padding: 6px 10px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# #T_e0617_row1_col2, #T_e0617_row1_col3, #T_e0617_row1_col4, #T_e0617_row1_col5, #T_e0617_row1_col6, #T_e0617_row2_col11, #T_e0617_row2_col12, #T_e0617_row3_col9, #T_e0617_row3_col11, #T_e0617_row3_col12, #T_e0617_row4_col0, #T_e0617_row4_col3, #T_e0617_row4_col4, #T_e0617_row4_col5, #T_e0617_row4_col6, #T_e0617_row5_col7, #T_e0617_row5_col8, #T_e0617_row5_col9, #T_e0617_row5_col10, #T_e0617_row5_col11, #T_e0617_row5_col12 {
#   background-color: #2e7d32;
#   color: white;
#   font-weight: bold;
#   font-size: 12px;
#   padding: 6px 10px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# #T_e0617_row5_col0, #T_e0617_row5_col1, #T_e0617_row5_col2, #T_e0617_row5_col3, #T_e0617_row5_col4, #T_e0617_row5_col5, #T_e0617_row5_col6 {
#   color: #b0bec5;
#   background-color: #cfd8dc;
#   font-style: italic;
#   font-size: 12px;
#   padding: 6px 10px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# </style>
# <table id="T_e0617">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0617_level0_col0" class="col_heading level0 col0" >T-6</th>
#       <th id="T_e0617_level0_col1" class="col_heading level0 col1" >T-5</th>
#       <th id="T_e0617_level0_col2" class="col_heading level0 col2" >T-4</th>
#       <th id="T_e0617_level0_col3" class="col_heading level0 col3" >T-3</th>
#       <th id="T_e0617_level0_col4" class="col_heading level0 col4" >T-2</th>
#       <th id="T_e0617_level0_col5" class="col_heading level0 col5" >T-1</th>
#       <th id="T_e0617_level0_col6" class="col_heading level0 col6" >T(0)</th>
#       <th id="T_e0617_level0_col7" class="col_heading level0 col7" >T+1</th>
#       <th id="T_e0617_level0_col8" class="col_heading level0 col8" >T+2</th>
#       <th id="T_e0617_level0_col9" class="col_heading level0 col9" >T+3</th>
#       <th id="T_e0617_level0_col10" class="col_heading level0 col10" >T+4</th>
#       <th id="T_e0617_level0_col11" class="col_heading level0 col11" >T+5</th>
#       <th id="T_e0617_level0_col12" class="col_heading level0 col12" >T+6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0617_level0_row0" class="row_heading level0 row0" >att_weight_real_estate_construction</th>
#       <td id="T_e0617_row0_col0" class="data row0 col0" >+0.08 (ns)</td>
#       <td id="T_e0617_row0_col1" class="data row0 col1" >+0.08 (ns)</td>
#       <td id="T_e0617_row0_col2" class="data row0 col2" >+0.10 (ns)</td>
#       <td id="T_e0617_row0_col3" class="data row0 col3" >+0.08 (ns)</td>
#       <td id="T_e0617_row0_col4" class="data row0 col4" >+0.12 (ns)</td>
#       <td id="T_e0617_row0_col5" class="data row0 col5" >+0.15 (ns)</td>
#       <td id="T_e0617_row0_col6" class="data row0 col6" >+0.22 (ns)</td>
#       <td id="T_e0617_row0_col7" class="data row0 col7" >0.00</td>
#       <td id="T_e0617_row0_col8" class="data row0 col8" >0.00</td>
#       <td id="T_e0617_row0_col9" class="data row0 col9" >0.00</td>
#       <td id="T_e0617_row0_col10" class="data row0 col10" >0.00</td>
#       <td id="T_e0617_row0_col11" class="data row0 col11" >0.00</td>
#       <td id="T_e0617_row0_col12" class="data row0 col12" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e0617_level0_row1" class="row_heading level0 row1" >att_weight_real_estate_financing</th>
#       <td id="T_e0617_row1_col0" class="data row1 col0" >+0.29**</td>
#       <td id="T_e0617_row1_col1" class="data row1 col1" >+0.34**</td>
#       <td id="T_e0617_row1_col2" class="data row1 col2" >+0.48***</td>
#       <td id="T_e0617_row1_col3" class="data row1 col3" >+0.58***</td>
#       <td id="T_e0617_row1_col4" class="data row1 col4" >+0.64***</td>
#       <td id="T_e0617_row1_col5" class="data row1 col5" >+0.65***</td>
#       <td id="T_e0617_row1_col6" class="data row1 col6" >+0.61***</td>
#       <td id="T_e0617_row1_col7" class="data row1 col7" >0.00</td>
#       <td id="T_e0617_row1_col8" class="data row1 col8" >0.00</td>
#       <td id="T_e0617_row1_col9" class="data row1 col9" >0.00</td>
#       <td id="T_e0617_row1_col10" class="data row1 col10" >+0.02 (ns)</td>
#       <td id="T_e0617_row1_col11" class="data row1 col11" >0.00</td>
#       <td id="T_e0617_row1_col12" class="data row1 col12" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e0617_level0_row2" class="row_heading level0 row2" >att_weight_real_estate_market</th>
#       <td id="T_e0617_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_e0617_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_e0617_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_e0617_row2_col3" class="data row2 col3" >0.00</td>
#       <td id="T_e0617_row2_col4" class="data row2 col4" >0.00</td>
#       <td id="T_e0617_row2_col5" class="data row2 col5" >0.00</td>
#       <td id="T_e0617_row2_col6" class="data row2 col6" >+0.00 (ns)</td>
#       <td id="T_e0617_row2_col7" class="data row2 col7" >+0.03**</td>
#       <td id="T_e0617_row2_col8" class="data row2 col8" >+0.06**</td>
#       <td id="T_e0617_row2_col9" class="data row2 col9" >+0.06**</td>
#       <td id="T_e0617_row2_col10" class="data row2 col10" >+0.13**</td>
#       <td id="T_e0617_row2_col11" class="data row2 col11" >+0.12***</td>
#       <td id="T_e0617_row2_col12" class="data row2 col12" >+0.12***</td>
#     </tr>
#     <tr>
#       <th id="T_e0617_level0_row3" class="row_heading level0 row3" >att_weight_real_estate_regulation</th>
#       <td id="T_e0617_row3_col0" class="data row3 col0" >0.00</td>
#       <td id="T_e0617_row3_col1" class="data row3 col1" >0.00</td>
#       <td id="T_e0617_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_e0617_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_e0617_row3_col4" class="data row3 col4" >0.00</td>
#       <td id="T_e0617_row3_col5" class="data row3 col5" >+0.01 (ns)</td>
#       <td id="T_e0617_row3_col6" class="data row3 col6" >+0.07 (ns)</td>
#       <td id="T_e0617_row3_col7" class="data row3 col7" >+0.03**</td>
#       <td id="T_e0617_row3_col8" class="data row3 col8" >+0.07**</td>
#       <td id="T_e0617_row3_col9" class="data row3 col9" >+0.10***</td>
#       <td id="T_e0617_row3_col10" class="data row3 col10" >+0.10**</td>
#       <td id="T_e0617_row3_col11" class="data row3 col11" >+0.13***</td>
#       <td id="T_e0617_row3_col12" class="data row3 col12" >+0.13***</td>
#     </tr>
#     <tr>
#       <th id="T_e0617_level0_row4" class="row_heading level0 row4" >att_weight_real_estate_urbanism</th>
#       <td id="T_e0617_row4_col0" class="data row4 col0" >+0.47***</td>
#       <td id="T_e0617_row4_col1" class="data row4 col1" >+0.45**</td>
#       <td id="T_e0617_row4_col2" class="data row4 col2" >+0.46**</td>
#       <td id="T_e0617_row4_col3" c

# %%
plot_out_of_sample_forecast(df_align, z_cols, m_col, lag_months=2, test_ratio=0.25)
# Out:
# 🔮 Test Out-of-Sample à T+2 mois
# Entraînement jusqu'à 2023-10 | Test sur les données suivantes.
# 📉 Erreur Modèle Naïf   : 0.449
# 📉 Erreur Modèle Complet: 0.500
# ❌ ECHEC : GDELT n'apporte pas d'information supérieure à l'inertie.

# %%
# 1. Évolution de l'influence du secteur "Transport" au fil du temps
plot_rolling_coefficients(
    df_merged=df_align, 
    zscore_cols=z_cols, 
    macro_col=m_col, 
    target_sector="att_weight_real_estate_regulation", # Remplacez par le secteur de votre choix
    lag_months=1,      # On étudie sa capacité à prédire l'inflation à +1 mois
    window_size=48     # Taille de la fenêtre : 48 mois (4 ans d'apprentissage glissant)
)
# Out:
# ⏳ Analyse glissante sur fenêtres de 48 mois (Lag: 1)

# %%
# 2. Impact d'un choc médiatique sur l'inflation (Courbe de réponse)
plot_var_irf(
    df_merged=df_align, 
    gdelt_col="att_weight_real_estate_regulation", # Le secteur qui va subir le choc de +1 écart-type
    macro_col=m_col, 
    max_lag_var=12,     # Le modèle utilise 12 mois d'historique pour modéliser la relation
    steps_ahead=12     # On trace la propagation de l'onde de choc sur les 12 prochains mois
)
# Out:
# 💥 Simulation de Choc (Modèle VAR) sur : att_weight_real_estate_regulation
# /home/clucas/venvs/gdelt/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/clucas/venvs/gdelt/lib/python3.12/site-packages/statsmodels/tsa/vector_ar/irf.py:528: ComplexWarning: Casting complex values to real discards the imaginary part
#   W[i,j,:,:], eigva[i,j,:,0], k[i,j] = util.eigval_decomp(cov_hold[i,j,:,:])

# %% [markdown]
# ### Test

# %%
def generate_regional_report(df_geo, region, type_gdelt, sectors, oos_test_ratio=0.25):
    """
    Pipeline automatisé : Exécute de bout en bout l'analyse macro vs GDELT pour une région donnée.
    Sélectionne dynamiquement le meilleur indicateur avancé (T+1 à T+6) et l'horizon optimal.
    """
    print(f"===================================================================")
    print(f"🌍 RAPPORT SYSTÉMATIQUE : {region.upper()} | INDICATEUR : {type_gdelt.upper()}")
    print(f"===================================================================\n")
    
    # 1. Alignement des données
    try:
        df_align, z_cols, m_col = load_and_align_multi(
            df_geo=df_geo, region_key=region, type_gdelt=type_gdelt, sectors=sectors
        )
    except Exception as e:
        print(f"❌ Erreur lors de l'alignement pour {region}: {e}")
        return

    # 2. Détection du meilleur Prédicteur Avancé (Strictement sur T+1 à T+6)
    # Élimine le biais de simultanéité (T=0) et de retard (T<0)
    best_sector = None
    best_score = 0
    best_lag = 1
    
    for col in z_cols:
        for lag in range(1, 7): # Boucle uniquement sur le futur
            corr = df_align[col].shift(lag).corr(df_align[m_col])
            
            if pd.notna(corr) and abs(corr) > best_score:
                best_score = abs(corr)
                best_sector = col
                best_lag = lag

    if not best_sector:
        print("⚠ Impossible de trouver un prédicteur valide avec les données actuelles.")
        return

    clean_sector_name = best_sector.replace('_zscore', '')
    print(f"🎯 PRÉDICTEUR OPTIMAL DÉTECTÉ : {clean_sector_name.upper()}")
    print(f"   => Pic de signal prédictif à : T+{best_lag} mois (Corrélation: {best_score:.2f})")

    # 3. Affichage de la Matrice Econométrique (Le Diagnostic)
    print("\n📌 1. DIAGNOSTIC ÉCONOMÉTRIQUE (Post-LASSO OLS avec Inertie)")
    lasso_matrix = compute_lasso_by_lag_with_ar_matrix(df_align, z_cols, m_col, max_lag=6)
    display(lasso_matrix)
    
    # 4. Le Test Out-of-Sample (La Preuve)
    # ⚡ Le test de prévision utilise désormais le meilleur lag trouvé automatiquement !
    print(f"\n📌 2. TEST DE PRÉVISION EN CONDITIONS RÉELLES (Horizon cible : +{best_lag} mois)")
    plot_out_of_sample_forecast(df_align, z_cols, m_col, lag_months=best_lag, test_ratio=oos_test_ratio)
    
    # 5. La Courbe de Choc (L'Impact)
    print(f"\n📌 3. DYNAMIQUE DE CHOC (Modèle VAR sur le meilleur prédicteur)")
    plot_var_irf(df_align, gdelt_col=best_sector, macro_col=m_col, max_lag_var=3, steps_ahead=12)
    
    print(f"================ FIN DU RAPPORT POUR {region.upper()} ================\n")

# ── COMMENT L'APPELER (Ultra-compact) ──
# generate_regional_report(df_geo, "France", "att_weight", ["energy", "finance"])
def compare_regions_predictive_power(df_geo, type_gdelt, target_sector, lag_months=2, test_ratio=0.25):
    """
    Évalue dans quelles régions du monde la narration GDELT anticipe le mieux l'économie.
    Calcule la réduction de l'erreur de prévision (RMSE) grâce aux médias.
    """
    print(f"🌐 LANCEMENT DU BENCHMARK GLOBAL | Thème : {target_sector} | Horizon : T+{lag_months}")
    results = {}
    
    # On boucle sur toutes les régions définies dans votre dictionnaire MACRO_TICKERS
    for region in MACRO_TICKERS.keys():
        try:
            # Mode silencieux (on coupe temporairement les prints des sous-fonctions)
            import sys, os
            old_stdout = sys.stdout
            sys.stdout = open(os.devnull, 'w')
            
            # Alignement
            df_align, z_cols, m_col = load_and_align_multi(
                df_geo=df_geo, region_key=region, type_gdelt=type_gdelt, sectors=[target_sector]
            )
            
            # Préparation des données pour l'évaluation OOS
            df_model = pd.DataFrame(index=df_align.index)
            df_model['Target'] = df_align[m_col]
            df_model['Past_Macro'] = df_align[m_col].shift(lag_months)
            for col in z_cols:
                df_model[col] = df_align[col].shift(lag_months)
            df_model = df_model.dropna()
            
            if len(df_model) < 20: # Ignorer si pas assez de données
                sys.stdout = old_stdout
                continue
                
            split_idx = int(len(df_model) * (1 - test_ratio))
            train, test = df_model.iloc[:split_idx], df_model.iloc[split_idx:]
            
            # Modèle Naïf (Inertie Macro uniquement)
            X_train_n, X_test_n = train[['Past_Macro']], test[['Past_Macro']]
            model_n = LinearRegression().fit(X_train_n, train['Target'])
            rmse_naive = np.sqrt(mean_squared_error(test['Target'], model_n.predict(X_test_n)))
            
            # Modèle Complet (Inertie Macro + GDELT)
            X_train_f, X_test_f = train[['Past_Macro'] + z_cols], test[['Past_Macro'] + z_cols]
            model_f = LassoCV(cv=3, random_state=42).fit(StandardScaler().fit_transform(X_train_f), train['Target'])
            rmse_gdelt = np.sqrt(mean_squared_error(test['Target'], model_f.predict(StandardScaler().fit_transform(X_test_f))))
            
            # Calcul de la valeur ajoutée (Amélioration du RMSE en %)
            improvement_pct = ((rmse_naive - rmse_gdelt) / rmse_naive) * 100
            results[region] = improvement_pct
            
            # Rétablir la console
            sys.stdout = old_stdout
            
        except Exception:
            sys.stdout = old_stdout
            continue # Si une région plante (manque de données), on passe à la suivante
            
    if not results:
        print("⚠ Aucune région n'a pu être évaluée.")
        return

    # Création et affichage du classement
    df_results = pd.DataFrame.from_dict(results, orient='index', columns=['Gain_Predictif_%'])
    df_results = df_results.sort_values(by='Gain_Predictif_%', ascending=True)
    
    # Graphique Plotly
    fig = px.bar(
        df_results, x='Gain_Predictif_%', y=df_results.index, orientation='h',
        title=f"Pouvoir Prédictif de '{target_sector}' sur l'Inflation par Région (Horizon +{lag_months} mois)",
        labels={'index': 'Région', 'Gain_Predictif_%': "Réduction de l'erreur de prévision (%)"},
        color='Gain_Predictif_%', color_continuous_scale=px.colors.diverging.RdYlGn
    )
    
    fig.add_vline(x=0, line_width=2, line_dash="dash", line_color="black")
    fig.update_layout(template="plotly_white", showlegend=False)
    fig.show()

# %%
# ── COMMENT L'APPELER ──
# compare_regions_predictive_power(df_geo, type_gdelt="att_weight", target_sector="energy", lag_months=2)
# 1. Je veux un audit complet sur l'immobilier aux US
# Un audit complet en 1 ligne (le lag optimal sera découvert tout seul)
generate_regional_report(df_geo, "US", "att_weight", ["real_estate"])
# Out:
# ===================================================================
# 🌍 RAPPORT SYSTÉMATIQUE : US | INDICATEUR : ATT_WEIGHT
# ===================================================================
#
# Téléchargement FRED pour US (CPIAUCSL)...
# 🔍 Mode Deep Dive sur 'real_estate' : 5 sous-séries (Secteur global exclu).
# 🎯 PRÉDICTEUR OPTIMAL DÉTECTÉ : ATT_WEIGHT_REAL_ESTATE_URBANISM
#    => Pic de signal prédictif à : T+1 mois (Corrélation: 0.47)
#
# 📌 1. DIAGNOSTIC ÉCONOMÉTRIQUE (Post-LASSO OLS avec Inertie)
# <style type="text/css">
# #T_1bf74_row0_col0, #T_1bf74_row0_col1, #T_1bf74_row0_col2, #T_1bf74_row0_col3, #T_1bf74_row0_col4, #T_1bf74_row0_col5, #T_1bf74_row0_col6, #T_1bf74_row1_col10, #T_1bf74_row3_col5, #T_1bf74_row3_col6 {
#   color: #37474f;
#   background-color: #eceff1;
#   font-size: 12px;
#   padding: 6px 10px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# #T_1bf74_row0_col7, #T_1bf74_row0_col8, #T_1bf74_row0_col9, #T_1bf74_row0_col10, #T_1bf74_row0_col11, #T_1bf74_row0_col12, #T_1bf74_row1_col7, #T_1bf74_row1_col8, #T_1bf74_row1_col9, #T_1bf74_row1_col11, #T_1bf74_row1_col12, #T_1bf74_row2_col0, #T_1bf74_row2_col1, #T_1bf74_row2_col2, #T_1bf74_row2_col3, #T_1bf74_row2_col4, #T_1bf74_row2_col5, #T_1bf74_row2_col6, #T_1bf74_row3_col0, #T_1bf74_row3_col1, #T_1bf74_row3_col2, #T_1bf74_row3_col3, #T_1bf74_row3_col4, #T_1bf74_row4_col7, #T_1bf74_row4_col8, #T_1bf74_row4_col9, #T_1bf74_row4_col10, #T_1bf74_row4_col11, #T_1bf74_row4_col12 {
#   color: #cfd8dc;
#   background-color: #fafafa;
#   font-size: 12px;
#   padding: 6px 10px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# #T_1bf74_row1_col0, #T_1bf74_row1_col1, #T_1bf74_row2_col7, #T_1bf74_row2_col8, #T_1bf74_row2_col9, #T_1bf74_row2_col10, #T_1bf74_row3_col7, #T_1bf74_row3_col8, #T_1bf74_row3_col10, #T_1bf74_row4_col1, #T_1bf74_row4_col2 {
#   background-color: #4caf50;
#   color: white;
#   font-weight: bold;
#   font-size: 12px;
#   padding: 6px 10px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# #T_1bf74_row1_col2, #T_1bf74_row1_col3, #T_1bf74_row1_col4, #T_1bf74_row1_col5, #T_1bf74_row1_col6, #T_1bf74_row2_col11, #T_1bf74_row2_col12, #T_1bf74_row3_col9, #T_1bf74_row3_col11, #T_1bf74_row3_col12, #T_1bf74_row4_col0, #T_1bf74_row4_col3, #T_1bf74_row4_col4, #T_1bf74_row4_col5, #T_1bf74_row4_col6, #T_1bf74_row5_col7, #T_1bf74_row5_col8, #T_1bf74_row5_col9, #T_1bf74_row5_col10, #T_1bf74_row5_col11, #T_1bf74_row5_col12 {
#   background-color: #2e7d32;
#   color: white;
#   font-weight: bold;
#   font-size: 12px;
#   padding: 6px 10px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# #T_1bf74_row5_col0, #T_1bf74_row5_col1, #T_1bf74_row5_col2, #T_1bf74_row5_col3, #T_1bf74_row5_col4, #T_1bf74_row5_col5, #T_1bf74_row5_col6 {
#   color: #b0bec5;
#   background-color: #cfd8dc;
#   font-style: italic;
#   font-size: 12px;
#   padding: 6px 10px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# </style>
# <table id="T_1bf74">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1bf74_level0_col0" class="col_heading level0 col0" >T-6</th>
#       <th id="T_1bf74_level0_col1" class="col_heading level0 col1" >T-5</th>
#       <th id="T_1bf74_level0_col2" class="col_heading level0 col2" >T-4</th>
#       <th id="T_1bf74_level0_col3" class="col_heading level0 col3" >T-3</th>
#       <th id="T_1bf74_level0_col4" class="col_heading level0 col4" >T-2</th>
#       <th id="T_1bf74_level0_col5" class="col_heading level0 col5" >T-1</th>
#       <th id="T_1bf74_level0_col6" class="col_heading level0 col6" >T(0)</th>
#       <th id="T_1bf74_level0_col7" class="col_heading level0 col7" >T+1</th>
#       <th id="T_1bf74_level0_col8" class="col_heading level0 col8" >T+2</th>
#       <th id="T_1bf74_level0_col9" class="col_heading level0 col9" >T+3</th>
#       <th id="T_1bf74_level0_col10" class="col_heading level0 col10" >T+4</th>
#       <th id="T_1bf74_level0_col11" class="col_heading level0 col11" >T+5</th>
#       <th id="T_1bf74_level0_col12" class="col_heading level0 col12" >T+6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bf74_level0_row0" class="row_heading level0 row0" >att_weight_real_estate_construction</th>
#       <td id="T_1bf74_row0_col0" class="data row0 col0" >+0.08 (ns)</td>
#       <td id="T_1bf74_row0_col1" class="data row0 col1" >+0.08 (ns)</td>
#       <td id="T_1bf74_row0_col2" class="data row0 col2" >+0.10 (ns)</td>
#       <td id="T_1bf74_row0_col3" class="data row0 col3" >+0.08 (ns)</td>
#       <td id="T_1bf74_row0_col4" class="data row0 col4" >+0.12 (ns)</td>
#       <td id="T_1bf74_row0_col5" class="data row0 col5" >+0.15 (ns)</td>
#       <td id="T_1bf74_row0_col6" class="data row0 col6" >+0.22 (ns)</td>
#       <td id="T_1bf74_row0_col7" class="data row0 col7" >0.00</td>
#       <td id="T_1bf74_row0_col8" class="data row0 col8" >0.00</td>
#       <td id="T_1bf74_row0_col9" class="data row0 col9" >0.00</td>
#       <td id="T_1bf74_row0_col10" class="data row0 col10" >0.00</td>
#       <td id="T_1bf74_row0_col11" class="data row0 col11" >0.00</td>
#       <td id="T_1bf74_row0_col12" class="data row0 col12" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_1bf74_level0_row1" class="row_heading level0 row1" >att_weight_real_estate_financing</th>
#       <td id="T_1bf74_row1_col0" class="data row1 col0" >+0.29**</td>
#       <td id="T_1bf74_row1_col1" class="data row1 col1" >+0.34**</td>
#       <td id="T_1bf74_row1_col2" class="data row1 col2" >+0.48***</td>
#       <td id="T_1bf74_row1_col3" class="data row1 col3" >+0.58***</td>
#       <td id="T_1bf74_row1_col4" class="data row1 col4" >+0.64***</td>
#       <td id="T_1bf74_row1_col5" class="data row1 col5" >+0.65***</td>
#       <td id="T_1bf74_row1_col6" class="data row1 col6" >+0.61***</td>
#       <td id="T_1bf74_row1_col7" class="data row1 col7" >0.00</td>
#       <td id="T_1bf74_row1_col8" class="data row1 col8" >0.00</td>
#       <td id="T_1bf74_row1_col9" class="data row1 col9" >0.00</td>
#       <td id="T_1bf74_row1_col10" class="data row1 col10" >+0.02 (ns)</td>
#       <td id="T_1bf74_row1_col11" class="data row1 col11" >0.00</td>
#       <td id="T_1bf74_row1_col12" class="data row1 col12" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_1bf74_level0_row2" class="row_heading level0 row2" >att_weight_real_estate_market</th>
#       <td id="T_1bf74_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_1bf74_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_1bf74_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_1bf74_row2_col3" class="data row2 col3" >0.00</td>
#       <td id="T_1bf74_row2_col4" class="data row2 col4" >0.00</td>
#       <td id="T_1bf74_row2_col5" class="data row2 col5" >0.00</td>
#       <td id="T_1bf74_row2_col6" class="data row2 col6" >+0.00 (ns)</td>
#       <td id="T_1bf74_row2_col7" class="data row2 col7" >+0.03**</td>
#       <td id="T_1bf74_row2_col8" class="data row2 col8" >+0.06**</td>
#       <td id="T_1bf74_row2_col9" class="data row2 col9" >+0.06**</td>
#       <td id="T_1bf74_row2_col10" class="data row2 col10" >+0.13**</td>
#       <td id="T_1bf74_row2_col11" class="data row2 col11" >+0.12***</td>
#       <td id="T_1bf74_row2_col12" class="data row2 col12" >+0.12***</td>
#     </tr>
#     <tr>
#       <th id="T_1bf74_level0_row3" class="row_heading level0 row3" >att_weight_real_estate_regulation</th>
#       <td id="T_1bf74_row3_col0" class="data row3 col0" >0.00</td>
#       <td id="T_1bf74_row3_col1" class="data row3 col1" >0.00</td>
#       <td id="T_1bf74_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_1bf74_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_1bf74_row3_col4" class="data row3 col4" >0.00</td>
#       <td id="T_1bf74_row3_col5" class="data row3 col5" >+0.01 (ns)</td>
#       <td id="T_1bf74_row3_col6" class="data row3 col6" >+0.07 (ns)</td>
#       <td id="T_1bf74_row3_col7" class="data row3 col7" >+0.03**</td>
#       <td id="T_1bf74_row3_col8" class="data row3 col8" >+0.07**</td>
#       <td id="T_1bf74_row3_col9" class="data row3 col9" >+0.10***</td>
#       <td id="T_1bf74_row3_col10" class="data row3 col10" >+0.10**</td>
#       <td id="T_1bf74_row3_col11" class="data row3 col11" >+0.13***</td>
#       <td id="T_1bf74_row3_col12" class="data row3 col12" >+0.13***</td>
#     </tr>
#     <tr>
#       <th id="T_1bf74_level0_row4" class="row_heading level0 row4" >att_weight_real_estate_urbanism</th>
#       <td id="T_1bf74_row4_col0" class="data row4 col0" >+0.47***</td>
#       <td id="T_1bf74_row4_col1" class="data row4 col1" >+0.45**</td>
#       <td id="T_1bf74_row4_col2" class="data row4 col2" >+0.46**</td>
#       <td id="T_1bf74_row4_col3" c
# 📌 2. TEST DE PRÉVISION EN CONDITIONS RÉELLES (Horizon cible : +1 mois)
# 🔮 Test Out-of-Sample à T+1 mois
# Entraînement jusqu'à 2023-10 | Test sur les données suivantes.
# 📉 Erreur Modèle Naïf   : 0.276
# 📉 Erreur Modèle Complet: 0.291
# ❌ ECHEC : GDELT n'apporte pas d'information supérieure à l'inertie.
# 📌 3. DYNAMIQUE DE CHOC (Modèle VAR sur le meilleur prédicteur)
# 💥 Simulation de Choc (Modèle VAR) sur : att_weight_real_estate_urbanism
# /home/clucas/venvs/gdelt/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/clucas/venvs/gdelt/lib/python3.12/site-packages/statsmodels/tsa/vector_ar/irf.py:528: ComplexWarning: Casting complex values to real discards the imaginary part
#   W[i,j,:,:], eigva[i,j,:,0], k[i,j] = util.eigval_decomp(cov_hold[i,j,:,:])
# ================ FIN DU RAPPORT POUR US ================

# %%
# 2. Je veux savoir quelle zone mondiale est la plus sensible aux récits sur l'énergie
compare_regions_predictive_power(df_geo, "att_weight", "transport", lag_months=3)
# Out:
# 🌐 LANCEMENT DU BENCHMARK GLOBAL | Thème : transport | Horizon : T+3

# %% [markdown]
# ### Test 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LassoCV
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
from statsmodels.tsa.api import VAR
import warnings
warnings.filterwarnings("ignore")

def apply_strict_color_code(val):
    """
    Applique le code couleur : 
    - Foncé (Bleu/Rouge) et texte blanc si *** ou ** (Significatif, p < 0.05)
    - Pâle (Bleu/Rouge) et texte noir si * (Faiblement significatif, p < 0.10)
    - Gris si non significatif (ns) ou 0.00
    """
    val_str = str(val)
    if pd.isna(val) or val == "0.00" or val == "N/A":
        return 'color: #cfd8dc; background-color: #fafafa;'
    
    is_strong = "***" in val_str or "**" in val_str
    is_weak = "*" in val_str and not is_strong
    is_positive = "+" in val_str
    is_negative = "-" in val_str
    
    if is_strong and is_positive:
        return 'background-color: #1565c0; color: white; font-weight: bold;' # Bleu Foncé
    elif is_strong and is_negative:
        return 'background-color: #c62828; color: white; font-weight: bold;' # Rougé Foncé
    elif is_weak and is_positive:
        return 'background-color: #bbdefb; color: black;' # Bleu Pâle
    elif is_weak and is_negative:
        return 'background-color: #ffcdd2; color: black;' # Rouge Pâle
    else:
        return 'color: #78909c; background-color: #eceff1;' # Gris pour (ns)

def run_lasso_horizon(df_model, features, target):
    """Mini-moteur LASSO + OLS pour un horizon donné"""
    X = df_model[features]
    y = df_model[target]
    
    # 1. Sélection LASSO
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    lasso = LassoCV(cv=5, random_state=42, max_iter=10000).fit(X_scaled, y)
    
    # 2. P-values via OLS sur les survivants
    selected = [features[i] for i, coef in enumerate(lasso.coef_) if coef != 0]
    p_values = {f: 1.0 for f in features}
    
    if selected:
        X_ols = sm.add_constant(X[selected])
        ols_model = sm.OLS(y, X_ols).fit()
        for f in selected:
            p_values[f] = ols_model.pvalues[f]
            
    return lasso.coef_, p_values, selected

def format_coef(coef, p_val):
    if coef == 0: return "0.00"
    stars = "***" if p_val < 0.01 else "**" if p_val < 0.05 else "*" if p_val < 0.10 else " (ns)"
    return f"{coef:+.2f}{stars}"

# %%
def master_econometric_pipeline(df_align, zscore_cols, macro_col, region_name):
    print("="*80)
    print(f"🚀 PIPELINE ÉCONOMÉTRIQUE GLOBAL : {region_name.upper()}")
    print("="*80)
    
    lag_range = list(range(6, -7, -1)) # De T+6 (Futur) à T-6 (Passé)
    col_names = [(f"T+{l}" if l > 0 else (f"T{l}" if l < 0 else "T(0)")) for l in lag_range]
    
    # =========================================================================
    # ÉTAPE 1 : LE FILTRE GLOBAL (BATTLE ROYALE)
    # =========================================================================
    print("\n" + "▼"*80)
    print("📌 ÉTAPE 1 : FILTRE GLOBAL (COMPÉTITION DE TOUS LES SECTEURS)")
    print("Objectif : Mettre toutes les variables GDELT en concurrence face à l'Inertie Macro.")
    print("Interprétation :")
    print("  - Les cases '0.00' sont les variables éliminées car redondantes (bruit).")
    print("  - Concentrez-vous sur le bloc de gauche (T+6 à T+1) : ce sont les indicateurs AVANCÉS.")
    print("▼"*80)

    row_labels = [c.replace('_zscore', '') for c in zscore_cols] + ["_MACRO_INERTIA_"]
    df_step1 = pd.DataFrame("0.00", index=row_labels, columns=lag_range)
    
    for lag in lag_range:
        X_dict = {col: df_align[col].shift(lag) for col in zscore_cols}
        if lag > 0: # Contrôle autorégressif (AR) stricte pour les prévisions
            X_dict["_MACRO_INERTIA_"] = df_align[macro_col].shift(lag)
            
        df_lag = pd.DataFrame(X_dict, index=df_align.index)
        df_lag[macro_col] = df_align[macro_col]
        df_lag = df_lag.dropna()
        
        if len(df_lag) < 20: continue
            
        features = list(X_dict.keys())
        coefs, p_vals, _ = run_lasso_horizon(df_lag, features, macro_col)
        
        for i, feat in enumerate(features):
            row_name = "_MACRO_INERTIA_" if feat == "_MACRO_INERTIA_" else feat.replace('_zscore', '')
            df_step1.loc[row_name, lag] = format_coef(coefs[i], p_vals[feat])
            
    df_step1.loc["_MACRO_INERTIA_", [l for l in lag_range if l <= 0]] = "N/A"
    df_step1.columns = col_names
    
    display(df_step1.style.map(apply_strict_color_code).set_properties(**{
        'font-size': '12px', 'padding': '6px', 'text-align': 'center', 'border': '1px solid #e0e0e0'
    }))

    # --> DÉTECTION DES SECTEURS PERTINENTS (Ceux qui ont survécu à l'étape 1 dans le futur)
    relevant_sectors = []
    for col in zscore_cols:
        clean_name = col.replace('_zscore', '')
        # On vérifie s'il y a un "***" ou "**" dans les colonnes prédictives (T+1 à T+6)
        has_signal = any(("***" in str(df_step1.loc[clean_name, col_name]) or "**" in str(df_step1.loc[clean_name, col_name])) 
                         for col_name in col_names[:6])
        if has_signal: relevant_sectors.append(col)

    if not relevant_sectors:
        print("\n❌ Aucun secteur ne possède un pouvoir prédictif statistiquement robuste face à l'inertie de l'inflation. Fin de l'analyse.")
        return

    # =========================================================================
    # ÉTAPE 2 : LE FOCUS LOCAL (ISOLATION DU SIGNAL)
    # =========================================================================
    print("\n\n" + "▼"*80)
    print(f"📌 ÉTAPE 2 : FOCUS SUR LES {len(relevant_sectors)} SECTEURS PERTINENTS")
    print("Objectif : Analyser le signal pur de chaque secteur vainqueur (1 LASSO par secteur + AR).")
    print("Interprétation : Les coefficients ici reflètent le vrai pouvoir prédictif isolé.")
    print("▼"*80)

    clean_relevant = [c.replace('_zscore', '') for c in relevant_sectors]
    df_step2 = pd.DataFrame("0.00", index=clean_relevant, columns=lag_range)
    top_candidates = [] # Pour stocker les meilleurs couples (Secteur, Lag) pour l'IRF

    for sector in relevant_sectors:
        clean_name = sector.replace('_zscore', '')
        for lag in lag_range:
            X_dict = {sector: df_align[sector].shift(lag)}
            if lag > 0: X_dict["_MACRO_INERTIA_"] = df_align[macro_col].shift(lag)
                
            df_lag = pd.DataFrame(X_dict, index=df_align.index)
            df_lag[macro_col] = df_align[macro_col]
            df_lag = df_lag.dropna()
            
            if len(df_lag) < 20: continue
                
            features = list(X_dict.keys())
            coefs, p_vals, _ = run_lasso_horizon(df_lag, features, macro_col)
            
            sector_coef = coefs[features.index(sector)]
            sector_pval = p_vals[sector]
            df_step2.loc[clean_name, lag] = format_coef(sector_coef, sector_pval)
            
            # Enregistrement pour l'étape 3 : on cherche le plus gros impact prédictif (lag > 0, p < 0.05)
            if lag > 0 and sector_pval < 0.05 and sector_coef != 0:
                top_candidates.append({'sector': sector, 'lag': lag, 'abs_coef': abs(sector_coef)})

    df_step2.columns = col_names
    display(df_step2.style.map(apply_strict_color_code).set_properties(**{
        'font-size': '12px', 'padding': '6px', 'text-align': 'center', 'border': '1px solid #e0e0e0'
    }))

    if not top_candidates:
        print("\n❌ Bien que pertinents globalement, les secteurs ont perdu leur significativité en isolation. Pas d'IRF possible.")
        return

    # =========================================================================
    # ÉTAPE 3 : DYNAMIQUE DE CHOC (VAR / IRF)
    # =========================================================================
    print("\n\n" + "▼"*80)
    print("📌 ÉTAPE 3 : MODÉLISATION DES CHOCS NARRATIFS (IRF)")
    print("Objectif : Simuler l'impact réel d'une explosion médiatique (+1 écart-type) sur l'économie.")
    print("Variables sélectionnées : Celles ayant les coefficients les plus massifs à l'Etape 2.")
    print("▼"*80)

    # Trier les candidats pour prendre les 2 meilleurs (pour éviter de surcharger l'écran d'IRFs)
    top_candidates = sorted(top_candidates, key=lambda x: x['abs_coef'], reverse=True)
    best_unique_sectors = list(dict.fromkeys([c['sector'] for c in top_candidates]))[:2]

    for best_sector in best_unique_sectors:
        clean_name = best_sector.replace('_zscore', '')
        print(f"\n💥 Génération du choc sur : {clean_name.upper()}")
        
        df_var = df_align[[best_sector, macro_col]].dropna()
        model = VAR(df_var)
        results = model.fit(maxlags=3, ic='aic')
        irf = results.irf(12) # Propagation sur 12 mois
        
        lower_bound_matrix, upper_bound_matrix = irf.err_band_sz1(orth=True, signif=0.05)
        effect_on_macro = irf.orth_irfs[:, 1, 0] 
        lower_bound = lower_bound_matrix[:, 1, 0]
        upper_bound = upper_bound_matrix[:, 1, 0]
        
        plt.figure(figsize=(10, 4))
        plt.plot(range(13), effect_on_macro, color='#1565c0', linewidth=2.5, label=f"Impact sur {macro_col}")
        plt.fill_between(range(13), lower_bound, upper_bound, color='#1565c0', alpha=0.15, label="Intervalle de Confiance (95%)")
        plt.axhline(0, color='black', linestyle='--', linewidth=1)
        
        plt.title(f"Réponse de la macroéconomie à un choc GDELT sur '{clean_name}'", fontsize=12)
        plt.xlabel("Mois suivant le choc")
        plt.ylabel("Impact Standardisé")
        plt.legend()
        plt.grid(alpha=0.3)
        plt.show()

    print("\n" + "="*80)
    print(f"✅ FIN DU PIPELINE POUR {region_name.upper()}")
    print("="*80 + "\n")

# %%
# =========================================================================
# ⚙️ 1. PARAMÉTRAGE DE L'ANALYSE
# =========================================================================
region = "France"                         # Pays/Zone à étudier (ex: "France", "European Union")
type_gdelt_indicator = "att_weight"   # L'indicateur GDELT de base (ex: "sent_cont", "att_weight")
sectors = ["finance", "energy", "agriculture", "tech", "industry", "commodities", "real_estate", "transport"]  # Liste des secteurs à comparer

# =========================================================================
# 🔄 2. ALIGNEMENT ET SYNCHRONISATION (Data Prep)
# =========================================================================
# Cette fonction télécharge la macroéconomie (FRED), calcule les Z-Scores GDELT,
# et fusionne le tout sur un calendrier mensuel strict.
df_align, z_cols, m_col = load_and_align_multi(
    df_geo=df_geo, 
    region_key=region, 
    type_gdelt=type_gdelt_indicator, 
    sectors=sectors 
)

# =========================================================================
# 🚀 3. LANCEMENT DU MOTEUR ÉCONOMÉTRIQUE
# =========================================================================
# On envoie les données propres dans le pipeline de modélisation
master_econometric_pipeline(
    df_align=df_align, 
    zscore_cols=z_cols, 
    macro_col=m_col, 
    region_name=region
)
# Out:
# Téléchargement FRED pour France (CP0000FRM086NEST)...
# 📊 Mode Comparaison activé sur 8 secteurs.
# ================================================================================
# 🚀 PIPELINE ÉCONOMÉTRIQUE GLOBAL : FRANCE
# ================================================================================
#
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
# 📌 ÉTAPE 1 : FILTRE GLOBAL (COMPÉTITION DE TOUS LES SECTEURS)
# Objectif : Mettre toutes les variables GDELT en concurrence face à l'Inertie Macro.
# Interprétation :
#   - Les cases '0.00' sont les variables éliminées car redondantes (bruit).
#   - Concentrez-vous sur le bloc de gauche (T+6 à T+1) : ce sont les indicateurs AVANCÉS.
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
# <style type="text/css">
# #T_e11f0_row0_col0, #T_e11f0_row0_col1, #T_e11f0_row0_col2, #T_e11f0_row0_col3, #T_e11f0_row0_col4, #T_e11f0_row0_col5, #T_e11f0_row0_col6, #T_e11f0_row0_col7, #T_e11f0_row2_col0, #T_e11f0_row2_col1, #T_e11f0_row2_col2, #T_e11f0_row2_col3, #T_e11f0_row2_col4, #T_e11f0_row3_col0, #T_e11f0_row3_col1, #T_e11f0_row3_col2, #T_e11f0_row3_col3, #T_e11f0_row3_col4, #T_e11f0_row3_col5, #T_e11f0_row6_col6, #T_e11f0_row6_col7, #T_e11f0_row6_col11, #T_e11f0_row6_col12, #T_e11f0_row7_col3, #T_e11f0_row7_col5, #T_e11f0_row8_col0, #T_e11f0_row8_col1, #T_e11f0_row8_col2, #T_e11f0_row8_col3, #T_e11f0_row8_col4, #T_e11f0_row8_col5 {
#   background-color: #1565c0;
#   color: white;
#   font-weight: bold;
#   font-size: 12px;
#   padding: 6px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# #T_e11f0_row0_col8, #T_e11f0_row0_col9, #T_e11f0_row0_col10, #T_e11f0_row0_col11, #T_e11f0_row0_col12, #T_e11f0_row1_col6, #T_e11f0_row1_col7, #T_e11f0_row1_col8, #T_e11f0_row1_col9, #T_e11f0_row1_col10, #T_e11f0_row1_col11, #T_e11f0_row1_col12, #T_e11f0_row2_col7, #T_e11f0_row2_col8, #T_e11f0_row2_col9, #T_e11f0_row2_col10, #T_e11f0_row2_col11, #T_e11f0_row2_col12, #T_e11f0_row3_col6, #T_e11f0_row3_col7, #T_e11f0_row3_col8, #T_e11f0_row3_col9, #T_e11f0_row3_col10, #T_e11f0_row3_col11, #T_e11f0_row3_col12, #T_e11f0_row4_col8, #T_e11f0_row4_col9, #T_e11f0_row4_col10, #T_e11f0_row4_col11, #T_e11f0_row4_col12, #T_e11f0_row5_col5, #T_e11f0_row5_col8, #T_e11f0_row5_col9, #T_e11f0_row5_col10, #T_e11f0_row5_col11, #T_e11f0_row5_col12, #T_e11f0_row6_col5, #T_e11f0_row6_col8, #T_e11f0_row6_col9, #T_e11f0_row6_col10, #T_e11f0_row7_col7, #T_e11f0_row7_col8, #T_e11f0_row7_col9, #T_e11f0_row7_col10, #T_e11f0_row7_col11, #T_e11f0_row7_col12, #T_e11f0_row8_col6, #T_e11f0_row8_col7, #T_e11f0_row8_col8, #T_e11f0_row8_col9, #T_e11f0_row8_col10, #T_e11f0_row8_col11, #T_e11f0_row8_col12 {
#   color: #cfd8dc;
#   background-color: #fafafa;
#   font-size: 12px;
#   padding: 6px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# #T_e11f0_row1_col0, #T_e11f0_row1_col2, #T_e11f0_row1_col3, #T_e11f0_row1_col4, #T_e11f0_row1_col5, #T_e11f0_row2_col6, #T_e11f0_row4_col3, #T_e11f0_row4_col4, #T_e11f0_row4_col5, #T_e11f0_row4_col6, #T_e11f0_row4_col7, #T_e11f0_row5_col0, #T_e11f0_row5_col1, #T_e11f0_row5_col2, #T_e11f0_row5_col3, #T_e11f0_row5_col4, #T_e11f0_row5_col6, #T_e11f0_row5_col7, #T_e11f0_row6_col0, #T_e11f0_row6_col1, #T_e11f0_row6_col2, #T_e11f0_row7_col0, #T_e11f0_row7_col6 {
#   color: #78909c;
#   background-color: #eceff1;
#   font-size: 12px;
#   padding: 6px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# #T_e11f0_row1_col1, #T_e11f0_row2_col5, #T_e11f0_row7_col1, #T_e11f0_row7_col2, #T_e11f0_row7_col4 {
#   background-color: #bbdefb;
#   color: black;
#   font-size: 12px;
#   padding: 6px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# #T_e11f0_row4_col0, #T_e11f0_row4_col1, #T_e11f0_row4_col2 {
#   background-color: #c62828;
#   color: white;
#   font-weight: bold;
#   font-size: 12px;
#   padding: 6px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# #T_e11f0_row6_col3, #T_e11f0_row6_col4 {
#   background-color: #ffcdd2;
#   color: black;
#   font-size: 12px;
#   padding: 6px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# </style>
# <table id="T_e11f0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e11f0_level0_col0" class="col_heading level0 col0" >T+6</th>
#       <th id="T_e11f0_level0_col1" class="col_heading level0 col1" >T+5</th>
#       <th id="T_e11f0_level0_col2" class="col_heading level0 col2" >T+4</th>
#       <th id="T_e11f0_level0_col3" class="col_heading level0 col3" >T+3</th>
#       <th id="T_e11f0_level0_col4" class="col_heading level0 col4" >T+2</th>
#       <th id="T_e11f0_level0_col5" class="col_heading level0 col5" >T+1</th>
#       <th id="T_e11f0_level0_col6" class="col_heading level0 col6" >T(0)</th>
#       <th id="T_e11f0_level0_col7" class="col_heading level0 col7" >T-1</th>
#       <th id="T_e11f0_level0_col8" class="col_heading level0 col8" >T-2</th>
#       <th id="T_e11f0_level0_col9" class="col_heading level0 col9" >T-3</th>
#       <th id="T_e11f0_level0_col10" class="col_heading level0 col10" >T-4</th>
#       <th id="T_e11f0_level0_col11" class="col_heading level0 col11" >T-5</th>
#       <th id="T_e11f0_level0_col12" class="col_heading level0 col12" >T-6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e11f0_level0_row0" class="row_heading level0 row0" >att_weight_finance</th>
#       <td id="T_e11f0_row0_col0" class="data row0 col0" >+0.41***</td>
#       <td id="T_e11f0_row0_col1" class="data row0 col1" >+0.32***</td>
#       <td id="T_e11f0_row0_col2" class="data row0 col2" >+0.24***</td>
#       <td id="T_e11f0_row0_col3" class="data row0 col3" >+0.20***</td>
#       <td id="T_e11f0_row0_col4" class="data row0 col4" >+0.11**</td>
#       <td id="T_e11f0_row0_col5" class="data row0 col5" >+0.07**</td>
#       <td id="T_e11f0_row0_col6" class="data row0 col6" >+0.41***</td>
#       <td id="T_e11f0_row0_col7" class="data row0 col7" >+0.32***</td>
#       <td id="T_e11f0_row0_col8" class="data row0 col8" >0.00</td>
#       <td id="T_e11f0_row0_col9" class="data row0 col9" >0.00</td>
#       <td id="T_e11f0_row0_col10" class="data row0 col10" >0.00</td>
#       <td id="T_e11f0_row0_col11" class="data row0 col11" >0.00</td>
#       <td id="T_e11f0_row0_col12" class="data row0 col12" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e11f0_level0_row1" class="row_heading level0 row1" >att_weight_energy</th>
#       <td id="T_e11f0_row1_col0" class="data row1 col0" >+0.15 (ns)</td>
#       <td id="T_e11f0_row1_col1" class="data row1 col1" >+0.14*</td>
#       <td id="T_e11f0_row1_col2" class="data row1 col2" >+0.09 (ns)</td>
#       <td id="T_e11f0_row1_col3" class="data row1 col3" >+0.06 (ns)</td>
#       <td id="T_e11f0_row1_col4" class="data row1 col4" >+0.08 (ns)</td>
#       <td id="T_e11f0_row1_col5" class="data row1 col5" >+0.00 (ns)</td>
#       <td id="T_e11f0_row1_col6" class="data row1 col6" >0.00</td>
#       <td id="T_e11f0_row1_col7" class="data row1 col7" >0.00</td>
#       <td id="T_e11f0_row1_col8" class="data row1 col8" >0.00</td>
#       <td id="T_e11f0_row1_col9" class="data row1 col9" >0.00</td>
#       <td id="T_e11f0_row1_col10" class="data row1 col10" >0.00</td>
#       <td id="T_e11f0_row1_col11" class="data row1 col11" >0.00</td>
#       <td id="T_e11f0_row1_col12" class="data row1 col12" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e11f0_level0_row2" class="row_heading level0 row2" >att_weight_agriculture</th>
#       <td id="T_e11f0_row2_col0" class="data row2 col0" >+0.46***</td>
#       <td id="T_e11f0_row2_col1" class="data row2 col1" >+0.44***</td>
#       <td id="T_e11f0_row2_col2" class="data row2 col2" >+0.36***</td>
#       <td id="T_e11f0_row2_col3" class="data row2 col3" >+0.25***</td>
#       <td id="T_e11f0_row2_col4" class="data row2 col4" >+0.13**</td>
#       <td id="T_e11f0_row2_col5" class="data row2 col5" >+0.05*</td>
#       <td id="T_e11f0_row2_col6" class="data row2 col6" >+0.00 (ns)</td>
#       <td id="T_e11f0_row2_col7" class="data row2 col7" >0.00</td>
#       <td id="T_e11f0_row2_col8" class="data row2 col8" >0.00</td>
#       <td id="T_e11f0_row2_col9" class="data row2 col9" >0.00</td>
#       <td id="T_e11f0_row2_col10" class="data row2 col10" >0.00</td>
#       <td id="T_e11f0_row2_col11" class="data row2 col11" >0.00</td>
#       <td id="T_e11f0_row2_col12" class="data row2 col12" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e11f0_level0_row3" class="row_heading level0 row3" >att_weight_tech</th>
#       <td id="T_e11f0_row3_col0" class="data row3 col0" >+0.29***</td>
#       <td id="T_e11f0_row3_col1" class="data row3 col1" >+0.29***</td>
#       <td id="T_e11f0_row3_col2" class="data row3 col2" >+0.35***</td>
#       <td id="T_e11f0_row3_col3" class="data row3 col3" >+0.33***</td>
#       <td id="T_e11f0_row3_col4" class="data row3 col4" >+0.23***</td>
#       <td id="T_e11f0_row3_col5" class="data row3 col5" >+0.08***</td>
#       <td id="T_e11f0_row3_col6" class="data ro
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
# 📌 ÉTAPE 2 : FOCUS SUR LES 5 SECTEURS PERTINENTS
# Objectif : Analyser le signal pur de chaque secteur vainqueur (1 LASSO par secteur + AR).
# Interprétation : Les coefficients ici reflètent le vrai pouvoir prédictif isolé.
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
# <style type="text/css">
# #T_7f321_row0_col0, #T_7f321_row0_col1, #T_7f321_row0_col2, #T_7f321_row0_col3, #T_7f321_row0_col4, #T_7f321_row0_col5, #T_7f321_row0_col6, #T_7f321_row0_col7, #T_7f321_row0_col8, #T_7f321_row0_col9, #T_7f321_row1_col0, #T_7f321_row1_col1, #T_7f321_row1_col2, #T_7f321_row1_col3, #T_7f321_row1_col4, #T_7f321_row1_col5, #T_7f321_row1_col6, #T_7f321_row1_col7, #T_7f321_row2_col1, #T_7f321_row2_col2, #T_7f321_row2_col3, #T_7f321_row2_col4, #T_7f321_row2_col5, #T_7f321_row3_col12 {
#   background-color: #1565c0;
#   color: white;
#   font-weight: bold;
#   font-size: 12px;
#   padding: 6px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# #T_7f321_row0_col10, #T_7f321_row0_col11, #T_7f321_row1_col8, #T_7f321_row1_col9, #T_7f321_row3_col0, #T_7f321_row3_col1, #T_7f321_row4_col0, #T_7f321_row4_col1, #T_7f321_row4_col2, #T_7f321_row4_col3, #T_7f321_row4_col4 {
#   color: #78909c;
#   background-color: #eceff1;
#   font-size: 12px;
#   padding: 6px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# #T_7f321_row0_col12, #T_7f321_row1_col10, #T_7f321_row1_col11, #T_7f321_row1_col12, #T_7f321_row2_col6, #T_7f321_row2_col7, #T_7f321_row2_col8, #T_7f321_row2_col9, #T_7f321_row2_col10, #T_7f321_row2_col11, #T_7f321_row2_col12, #T_7f321_row3_col3, #T_7f321_row3_col4, #T_7f321_row3_col5, #T_7f321_row3_col6, #T_7f321_row3_col7, #T_7f321_row3_col8, #T_7f321_row3_col9, #T_7f321_row3_col10, #T_7f321_row3_col11, #T_7f321_row4_col6, #T_7f321_row4_col7, #T_7f321_row4_col8, #T_7f321_row4_col9, #T_7f321_row4_col10, #T_7f321_row4_col11, #T_7f321_row4_col12 {
#   color: #cfd8dc;
#   background-color: #fafafa;
#   font-size: 12px;
#   padding: 6px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# #T_7f321_row2_col0, #T_7f321_row4_col5 {
#   background-color: #bbdefb;
#   color: black;
#   font-size: 12px;
#   padding: 6px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# #T_7f321_row3_col2 {
#   background-color: #ffcdd2;
#   color: black;
#   font-size: 12px;
#   padding: 6px;
#   text-align: center;
#   border: 1px solid #e0e0e0;
# }
# </style>
# <table id="T_7f321">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f321_level0_col0" class="col_heading level0 col0" >T+6</th>
#       <th id="T_7f321_level0_col1" class="col_heading level0 col1" >T+5</th>
#       <th id="T_7f321_level0_col2" class="col_heading level0 col2" >T+4</th>
#       <th id="T_7f321_level0_col3" class="col_heading level0 col3" >T+3</th>
#       <th id="T_7f321_level0_col4" class="col_heading level0 col4" >T+2</th>
#       <th id="T_7f321_level0_col5" class="col_heading level0 col5" >T+1</th>
#       <th id="T_7f321_level0_col6" class="col_heading level0 col6" >T(0)</th>
#       <th id="T_7f321_level0_col7" class="col_heading level0 col7" >T-1</th>
#       <th id="T_7f321_level0_col8" class="col_heading level0 col8" >T-2</th>
#       <th id="T_7f321_level0_col9" class="col_heading level0 col9" >T-3</th>
#       <th id="T_7f321_level0_col10" class="col_heading level0 col10" >T-4</th>
#       <th id="T_7f321_level0_col11" class="col_heading level0 col11" >T-5</th>
#       <th id="T_7f321_level0_col12" class="col_heading level0 col12" >T-6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f321_level0_row0" class="row_heading level0 row0" >att_weight_finance</th>
#       <td id="T_7f321_row0_col0" class="data row0 col0" >+0.54***</td>
#       <td id="T_7f321_row0_col1" class="data row0 col1" >+0.44***</td>
#       <td id="T_7f321_row0_col2" class="data row0 col2" >+0.32***</td>
#       <td id="T_7f321_row0_col3" class="data row0 col3" >+0.22***</td>
#       <td id="T_7f321_row0_col4" class="data row0 col4" >+0.11**</td>
#       <td id="T_7f321_row0_col5" class="data row0 col5" >+0.07**</td>
#       <td id="T_7f321_row0_col6" class="data row0 col6" >+0.65***</td>
#       <td id="T_7f321_row0_col7" class="data row0 col7" >+0.60***</td>
#       <td id="T_7f321_row0_col8" class="data row0 col8" >+0.48***</td>
#       <td id="T_7f321_row0_col9" class="data row0 col9" >+0.37**</td>
#       <td id="T_7f321_row0_col10" class="data row0 col10" >+0.24 (ns)</td>
#       <td id="T_7f321_row0_col11" class="data row0 col11" >+0.11 (ns)</td>
#       <td id="T_7f321_row0_col12" class="data row0 col12" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_7f321_level0_row1" class="row_heading level0 row1" >att_weight_agriculture</th>
#       <td id="T_7f321_row1_col0" class="data row1 col0" >+0.51***</td>
#       <td id="T_7f321_row1_col1" class="data row1 col1" >+0.48***</td>
#       <td id="T_7f321_row1_col2" class="data row1 col2" >+0.35***</td>
#       <td id="T_7f321_row1_col3" class="data row1 col3" >+0.26***</td>
#       <td id="T_7f321_row1_col4" class="data row1 col4" >+0.14***</td>
#       <td id="T_7f321_row1_col5" class="data row1 col5" >+0.07**</td>
#       <td id="T_7f321_row1_col6" class="data row1 col6" >+0.45**</td>
#       <td id="T_7f321_row1_col7" class="data row1 col7" >+0.36**</td>
#       <td id="T_7f321_row1_col8" class="data row1 col8" >+0.25 (ns)</td>
#       <td id="T_7f321_row1_col9" class="data row1 col9" >+0.16 (ns)</td>
#       <td id="T_7f321_row1_col10" class="data row1 col10" >0.00</td>
#       <td id="T_7f321_row1_col11" class="data row1 col11" >0.00</td>
#       <td id="T_7f321_row1_col12" class="data row1 col12" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_7f321_level0_row2" class="row_heading level0 row2" >att_weight_tech</th>
#       <td id="T_7f321_row2_col0" class="data row2 col0" >+0.17*</td>
#       <td id="T_7f321_row2_col1" class="data row2 col1" >+0.19**</td>
#       <td id="T_7f321_row2_col2" class="data row2 col2" >+0.22***</td>
#       <td id="T_7f321_row2_col3" class="data row2 col3" >+0.18***</td>
#       <td id="T_7f321_row2_col4" class="data row2 col4" >+0.12***</td>
#       <td id="T_7f321_row2_col5" class="data row2 col5" >+0.05**</td>
#       <td id="T_7f321_row2_col6" class="data row2 col6" >0.00</td>
#       <td id="T_7f321_row2_col7" class="data row2 col7" >0.00</td>
#       <td id="T_7f321_row2_col8" class="data row2 col8" >0.00</td>
#       <td id="T_7f321_row2_col9" class="data row2 col9" >0.00</td>
#       <td id="T_7f321_row2_col10" class="data row2 col10" >0.00</td>
#       <td id="T_7f321_row2_col11" class="data row2 col11" >0.00</td>
#       <td id="T_7f321_row2_col12" class="data row2 col12" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_7f321_level0_row3" class="row_heading level0 row3" >att_weight_industry</th>
#       <td id="T_7f321_row3_col0" class="data row3 col0" >-0.17 (ns)</td>
#       <td id="T_7f321_row3_col1" class="data row3 col1" >-0.14 (ns)</td>
#       <td id="T_7f321_row3_col2" class="data row3 col2" >-0.14*</td>
#       <td id="T_7f321_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_7f321_row3_col4" class="data row3 col4" >0.00</td>
#       <td id="T_7f321_row3_col5" class="data row3 col5" >0.00</td>
#       <td id="T_7f321_row3_col6" class="data row3 col6" >0.00</td>
#       <td id="T_7f321_row3_col7" class="data row3 col7" >0.00</td>
#       <td id="T_7f321_row3_col8" class="data row3 col8" >0.00</td>
#       <td id="T_7f321_row3_col9" class="data row3 col9" >0.00</td>
#       <td id="T_7f321_row3_col10" class="data row3 col10" >0.00</td>
#       <td id="T_7f321_row3_col11" class="data row3 col11" >0.00</td>
#       <td id="T_7f321_row3_col12" class="data row3 col12" >+0.03**</td>
#     </tr>
#     <tr>
#       <th id="T_7f321_level0_row4" class="row_heading level0 row4" >att_weight_transport</th>
#       <td id="T_7f321_row4_col0" class="data row4 col0" >+0.05 (ns)</td>
#       <td id="T_7f321_row4_col1" class="data row4 col1" >+0.06 (ns)</td>
#       <td id="T_7f321_row4_col2" class="data row4 col2" >+0.07 (ns)</td>
#       <td id="T_7f321_row4_col3" class="data row4 col3" >+0.07 (ns)</td>
#       <td id="T_7f321_row4_col4" class="data row4 col4" >+0.03 (ns)</td>
#       <td id="T_7f321_row4_col5" class="data row4 col5" >+0.04*</td>
#       <td id="T_7f321_row4_col6" class="data row4 col6" >0.00</td>
#       <td id="T_7f321_row4_col7" class="data row4 col7" >0.00</td>
#       <td id="T_7f321_row4_col8" class="data row4 col8" >0.00</td>
#       <td id="T
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
# 📌 ÉTAPE 3 : MODÉLISATION DES CHOCS NARRATIFS (IRF)
# Objectif : Simuler l'impact réel d'une explosion médiatique (+1 écart-type) sur l'économie.
# Variables sélectionnées : Celles ayant les coefficients les plus massifs à l'Etape 2.
# ▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼▼
#
# 💥 Génération du choc sur : ATT_WEIGHT_FINANCE
# 💥 Génération du choc sur : ATT_WEIGHT_AGRICULTURE
# ================================================================================
# ✅ FIN DU PIPELINE POUR FRANCE
# ================================================================================
